# %%
import pandas as pd
import os

# %%
# Folder containing the CSV files
input_folder = r"C:\Users\nwn86\ResearchProject_singlensp\Input\Energy"

# %%
input_folder
# Out:
# 'C:\\Users\\nwn86\\ResearchProject_singlensp\\Input\\Energy'

# %%
# Get all CSV files in the folder
csv_files = [f for f in os.listdir(input_folder) if f.endswith(".csv")]

# %%
csv_files
# Out:
# ['200001_Generation_MD.csv',
#  '200002_Generation_MD.csv',
#  '200003_Generation_MD.csv',
#  '200004_Generation_MD.csv',
#  '200005_Generation_MD.csv',
#  '200006_Generation_MD.csv',
#  '200007_Generation_MD.csv',
#  '200008_Generation_MD.csv',
#  '200009_Generation_MD.csv',
#  '200010_Generation_MD.csv',
#  '200011_Generation_MD.csv',
#  '200012_Generation_MD.csv',
#  '200101_Generation_MD.csv',
#  '200102_Generation_MD.csv',
#  '200103_Generation_MD.csv',
#  '200104_Generation_MD.csv',
#  '200105_Generation_MD.csv',
#  '200106_Generation_MD.csv',
#  '200107_Generation_MD.csv',
#  '200108_Generation_MD.csv',
#  '200109_Generation_MD.csv',
#  '200110_Generation_MD.csv',
#  '200111_Generation_MD.csv',
#  '200112_Generation_MD.csv',
#  '200201_Generation_MD.csv',
#  '200202_Generation_MD.csv',
#  '200203_Generation_MD.csv',
#  '200204_Generation_MD.csv',
#  '200205_Generation_MD.csv',
#  '200206_Generation_MD.csv',
#  '200207_Generation_MD.csv',
#  '200208_Generation_MD.csv',
#  '200209_Generation_MD.csv',
#  '200210_Generation_MD.csv',
#  '200211_Generation_MD.csv',
#  '200212_Generation_MD.csv',
#  '200301_Generation_MD.csv',
#  '200302_Generation_MD.csv',
#  '200303_Generation_MD.csv',
#  '200304_Generation_MD.csv',
#  '200305_Generation_MD.csv',
#  '200306_Generation_MD.csv',
#  '200307_Generation_MD.csv',
#  '200308_Generation_MD.csv',
#  '200309_Generation_MD.csv',
#  '200310_Generation_MD.csv',
#  '200311_Generation_MD.csv',
#  '200312_Generation_MD.csv',
#  '200401_Generation_MD.csv',
#  '200402_Generation_MD.csv',
#  '200403_Generation_MD.csv',
#  '200404_Generation_MD.csv',
#  '200405_Generation_MD.csv',
#  '200406_Generation_MD.csv',
#  '200407_Generation_MD.csv',
#  '200408_Generation_MD.csv',
#  '200409_Generation_MD.csv',
#  '200410_Generation_MD.csv',
#  '200411_Generation_MD.csv',
#  '200412_Generation_MD.csv',
#  '200501_Generation_MD.csv',
#  '200502_Generation_MD.csv',
#  '200503_Generation_MD.csv',
#  '200504_Generation_MD.csv',
#  '200505_Generation_MD.csv',
#  '200506_Generation_MD.csv',
#  '200507_Generation_MD.csv',
#  '200508_Generation_MD.csv',
#  '200509_Generation_MD.csv',
#  '200510_Generation_MD.csv',
#  '200511_Generation_MD.csv',
#  '200512_Generation_MD.csv',
#  '200601_Generation_MD.csv',
#  '200602_Generation_MD.csv',
#  '200603_Generation_MD.csv',
#  '200604_Generation_MD.csv',
#  '200605_Generation_MD.csv',
#  '200606_Generation_MD.csv',
#  '200607_Generation_MD.csv',
#  '200608_Generation_MD.csv',
#  '200609_Generation_MD.csv',
#  '200610_Generation_MD.csv',
#  '200611_Generation_MD.csv',
#  '200612_Generation_MD.csv',
#  '200701_Generation_MD.csv',
#  '200702_Generation_MD.csv',
#  '200703_Generation_MD.csv',
#  '200704_Generation_MD.csv',
#  '200705_Generation_MD.csv',
#  '200706_Generation_MD.csv',
#  '200707_Generation_MD.csv',
#  '200708_Generation_MD.csv',
#  '200709_Generation_MD.csv',
#  '200710_Generation_MD.csv',
#  '200711_Generation_MD.csv',
#  '200712_Generation_MD.csv',
#  '200801_Generation_MD.csv',
#  '200802_Generation_MD.csv',
#  '200803_Generation_MD.csv',
#  '200804_Generation_MD.csv',
#  '200805_Generation_MD.csv',
#  '200806_Generation_MD.csv',
#  '200807_Generation_MD.csv',
#  '200808_Generation_MD.csv',
#  '200809_Generation_MD.csv',
#  '200810_Generation_MD.csv',
#  '200811_Generation_MD.csv',
#  '200812_Generation_MD.csv',
#  '200901_Generation_MD.csv',
#  '200902_Generation_MD.csv',
#  '200903_Generation_MD.csv',
#  '200904_Generation_MD.csv',
#  '200905_Generation_MD.csv',
#  '200906_Generation_MD.csv',
#  '200907_Generation_MD.csv',
#  '200908_Generation_MD.csv',
#  '200909_Generation_MD.csv',
#  '200910_Generation_MD.csv',
#  '200911_Generation_MD.csv',
#  '200912_Generation_MD.csv',
#  '201001_Generation_MD.csv',
#  '201002_Generation_MD.csv',
#  '201003_Generation_MD.csv',
#  '201004_Generation_MD.csv',
#  '201005_Generation_MD.csv',
#  '201006_Generation_MD.csv',
#  '201007_Generation_MD.csv',
#  '201008_Generation_MD.csv',
#  '201009_Generation_MD.csv',
#  '201010_Generation_MD.csv',
#  '201011_Generation_MD.csv',
#  '201012_Generation_MD.csv',
#  '201101_Generation_MD.csv',
#  '201102_Generation_MD.csv',
#  '201103_Generation_MD.csv',
#  '201104_Generation_MD.csv',
#  '201105_Generation_MD.csv',
#  '201106_Generation_MD.csv',
#  '201107_Generation_MD.csv',
#  '201108_Generation_MD.csv',
#  '201109_Generation_MD.csv',
#  '201110_Generation_MD.csv',
#  '201111_Generation_MD.csv',
#  '201112_Generation_MD.csv',
#  '201201_Generation_MD.csv',
#  '201202_Generation_MD.csv',
#  '201203_Generation_MD.csv',
#  '201204_Generation_MD.csv',
#  '201205_Generation_MD.csv',
#  '201206_Generation_MD.csv',
#  '201207_Generation_MD.csv',
#  '201208_Generation_MD.csv',
#  '201209_Generation_MD.csv',
#  '201210_Generation_MD.csv',
#  '201211_Generation_MD.csv',
#  '201212_Generation_MD.csv',
#  '201301_Generation_MD.csv',
#  '201302_Generation_MD.csv',
#  '201303_Generation_MD.csv',
#  '201304_Generation_MD.csv',
#  '201305_Generation_MD.csv',
#  '201306_Generation_MD.csv',
#  '201307_Generation_MD.csv',
#  '201308_Generation_MD.csv',
#  '201309_Generation_MD.csv',
#  '201310_Generation_MD.csv',
#  '201311_Generation_MD.csv',
#  '201312_Generation_MD.csv',
#  '201401_Generation_MD.csv',
#  '201402_Generation_MD.csv',
#  '201403_Generation_MD.csv',
#  '201404_Generation_MD.csv',
#  '201405_Generation_MD.csv',
#  '201406_Generation_MD.csv',
#  '201407_Generation_MD.csv',
#  '201408_Generation_MD.csv',
#  '201409_Generation_MD.csv',
#  '201410_Generation_MD.csv',
#  '201411_Generation_MD.csv',
#  '201412_Generation_MD.csv',
#  '201501_Generation_MD.csv',
#  '201502_Generation_MD.csv',
#  '201503_Generation_MD.csv',
#  '201504_Generation_MD.csv',
#  '201505_Generation_MD.csv',
#  '201506_Generation_MD.csv',
#  '201507_Generation_MD.csv',
#  '201508_Generation_MD.csv',
#  '201509_Generation_MD.csv',
#  '201510_Generation_MD.csv',
#  '201511_Generation_MD.csv',
#  '201512_Generation_MD.csv',
#  '201601_Generation_MD.csv',
#  '201602_Generation_MD.csv',
#  '201603_Generation_MD.csv',
#  '201604_Generation_MD.csv',
#  '201605_Generation_MD.csv',
#  '201606_Generation_MD.csv',
#  '201607_Generation_MD.csv',
#  '201608_Generation_MD.csv',
#  '201609_Generation_MD.csv',
#  '201610_Generation_MD.csv',
#  '201611_Generation_MD.csv',
#  '201612_Generation_MD.csv',
#  '201701_Generation_MD.csv',
#  '201702_Generation_MD.csv',
#  '201703_Generation_MD.csv',
#  '201704_Generation_MD.csv',
#  '201705_Generation_MD.csv',
#  '201706_Generation_MD.csv',
#  '201707_Generation_MD.csv',
#  '201708_Generation_MD.csv',
#  '201709_Generation_MD.csv',
#  '201710_Generation_MD.csv',
#  '201711_Generation_MD.csv',
#  '201712_Generation_MD.csv',
#  '201801_Generation_MD.csv',
#  '201802_Generation_MD.csv',
#  '201803_Generation_MD.csv',
#  '201804_Generation_MD.csv',
#  '201805_Generation_MD.csv',
#  '201806_Generation_MD.csv',
#  '201807_Generation_MD.csv',
#  '201808_Generation_MD.csv',
#  '201809_Generation_MD.csv',
#  '201810_Generation_MD.csv',
#  '201811_Generation_MD.csv',
#  '201812_Generation_MD.csv',
#  '201901_Generation_MD.csv',
#  '201902_Generation_MD.csv',
#  '201903_Generation_MD.csv',
#  '201904_Generation_MD.csv',
#  '201905_Generation_MD.csv',
#  '201906_Generation_MD.csv',
#  '201907_Generation_MD.csv',
#  '201908_Generation_MD.csv',
#  '201909_Generation_MD.csv',
#  '201910_Generation_MD.csv',
#  '201911_Generation_MD.csv',
#  '201912_Generation_MD.csv',
#  '202001_Generation_MD.csv',
#  '202002_Generation_MD.csv',
#  '202003_Generation_MD.csv',
#  '202004_Generation_MD.csv',
#  '202005_Generation_MD.csv',
#  '202006_Generation_MD.csv',
#  '202007_Generation_MD.csv',
#  '202008_Generation_MD.csv',
#  '202009_Generation_MD.csv',
#  '202010_Generation_MD.csv',
#  '202011_Generation_MD.csv',
#  '202012_Generation_MD.csv',
#  '202101_Generation_MD.csv',
#  '202102_Generation_MD.csv',
#  '202103_Generation_MD.csv',
#  '202104_Generation_MD.csv',
#  '202105_Generation_MD.csv',
#  '202106_Generation_MD.csv',
#  '202107_Generation_MD.csv',
#  '202108_Generation_MD.csv',
#  '202109_Generation_MD.csv',
#  '202110_Generation_MD.csv',
#  '202111_Generation_MD.csv',
#  '202112_Generation_MD.csv',
#  '202201_Generation_MD.csv',
#  '202202_Generation_MD.csv',
#  '202203_Generation_MD.csv',
#  '202204_Generation_MD.csv',
#  '202205_Generation_MD.csv',
#  '202206_Generation_MD.csv',
#  '202207_Generation_MD.csv',
#  '202208_Generation_MD.csv',
#  '202209_Generation_MD.csv',
#  '202210_Generation_MD.csv',
#  '202211_Generation_MD.csv',
#  '202212_Generation_MD.csv',
#  '202301_Generation_MD.csv',
#  '202302_Generation_MD.csv',
#  '202303_Generation_MD.csv',
#  '202304_Generation_MD.csv',
#  '202305_Generation_MD.csv',
#  '202306_Generation_MD.csv',
#  '202307_Generation_MD.csv',
#  '202308_Generation_MD.csv',
#  '202309_Generation_MD.csv',
#  '202310_Generation_MD.csv',
#  '202311_Generation_MD.csv',
#  '202312_Generation_MD.csv',
#  '202401_Generation_MD.csv',
#  '202402_Generation_MD.csv',
#  '202403_Generation_MD.csv',
#  '202404_Generation_MD.csv',
#  '202405_Generation_MD.csv',
#  '202406_Generation_MD.csv',
#  '202407_Generation_MD.csv',
#  '202408_Generation_MD.csv',
#  '202409_Generation_MD.csv',
#  '202410_Generation_MD.csv',
#  '202411_Generation_MD.csv',
#  '202412_Generation_MD.csv',
#  '202501_Generation_MD.csv']

# %%
# Process each CSV file
for file_name in csv_files:
    file_path = os.path.join(input_folder, file_name)

    # Load the dataset
    df = pd.read_csv(file_path)

    df.columns = df.columns.str.replace('Trading_Date', 'Trading_date')

    # Filter rows where Fuel_Code is 'Hydro' or 'Wind'
    filtered_df = df[df['Fuel_Code'].isin(['Hydro', 'Wind'])]

    # Identify TP columns (TP1 to TP48)
    tp_columns = [col for col in df.columns if col.startswith('TP')]

    # Select required columns (Fuel_Code and Trading_date)
    final_df = filtered_df[['Fuel_Code','POC_Code', 'Trading_date']].copy()

    # Calculate the sum of TP1 to TP50 for each row and create a new column 'Total_TP'
    final_df['Total_TP'] = filtered_df[tp_columns].sum(axis=1)

    # Group by Fuel_Code and Trading_date, then sum the Total_TP for each group
    final_df = final_df.groupby(['Fuel_Code','POC_Code', 'Trading_date'], as_index=False)['Total_TP'].sum()

    # Save to a new CSV file with a modified name
    output_folder = r"C:\Users\nwn86\ResearchProject_singlensp\Staging\Energy"  # Updated output folder path
    output_file = f"filtered_{file_name}"
    output_path = os.path.join(output_folder, output_file)
    final_df.to_csv(output_path, index=False)

    print(f"Processed and saved: {output_file}")
# Out:
# Processed and saved: filtered_200001_Generation_MD.csv
# Processed and saved: filtered_200002_Generation_MD.csv
# Processed and saved: filtered_200003_Generation_MD.csv
# Processed and saved: filtered_200004_Generation_MD.csv
# Processed and saved: filtered_200005_Generation_MD.csv
# Processed and saved: filtered_200006_Generation_MD.csv
# Processed and saved: filtered_200007_Generation_MD.csv
# Processed and saved: filtered_200008_Generation_MD.csv
# Processed and saved: filtered_200009_Generation_MD.csv
# Processed and saved: filtered_200010_Generation_MD.csv
# Processed and saved: filtered_200011_Generation_MD.csv
# Processed and saved: filtered_200012_Generation_MD.csv
# Processed and saved: filtered_200101_Generation_MD.csv
# Processed and saved: filtered_200102_Generation_MD.csv
# Processed and saved: filtered_200103_Generation_MD.csv
# Processed and saved: filtered_200104_Generation_MD.csv
# Processed and saved: filtered_200105_Generation_MD.csv
# Processed and saved: filtered_200106_Generation_MD.csv
# Processed and saved: filtered_200107_Generation_MD.csv
# Processed and saved: filtered_200108_Generation_MD.csv
# Processed and saved: filtered_200109_Generation_MD.csv
# Processed and saved: filtered_200110_Generation_MD.csv
# Processed and saved: filtered_200111_Generation_MD.csv
# Processed and saved: filtered_200112_Generation_MD.csv
# Processed and saved: filtered_200201_Generation_MD.csv
# Processed and saved: filtered_200202_Generation_MD.csv
# Processed and saved: filtered_200203_Generation_MD.csv
# Processed and saved: filtered_200204_Generation_MD.csv
# Processed and saved: filtered_200205_Generation_MD.csv
# Processed and saved: filtered_200206_Generation_MD.csv
# Processed and saved: filtered_200207_Generation_MD.csv
# Processed and saved: filtered_200208_Generation_MD.csv
# Processed and saved: filtered_200209_Generation_MD.csv
# Processed and saved: filtered_200210_Generation_MD.csv
# Processed and saved: filtered_200211_Generation_MD.csv
# Processed and saved: filtered_200212_Generation_MD.csv
# Processed and saved: filtered_200301_Generation_MD.csv
# Processed and saved: filtered_200302_Generation_MD.csv
# Processed and saved: filtered_200303_Generation_MD.csv
# Processed and saved: filtered_200304_Generation_MD.csv
# Processed and saved: filtered_200305_Generation_MD.csv
# Processed and saved: filtered_200306_Generation_MD.csv
# Processed and saved: filtered_200307_Generation_MD.csv
# Processed and saved: filtered_200308_Generation_MD.csv
# Processed and saved: filtered_200309_Generation_MD.csv
# Processed and saved: filtered_200310_Generation_MD.csv
# Processed and saved: filtered_200311_Generation_MD.csv
# Processed and saved: filtered_200312_Generation_MD.csv
# Processed and saved: filtered_200401_Generation_MD.csv
# Processed and saved: filtered_200402_Generation_MD.csv
# Processed and saved: filtered_200403_Generation_MD.csv
# Processed and saved: filtered_200404_Generation_MD.csv
# Processed and saved: filtered_200405_Generation_MD.csv
# Processed and saved: filtered_200406_Generation_MD.csv
# Processed and saved: filtered_200407_Generation_MD.csv
# Processed and saved: filtered_200408_Generation_MD.csv
# Processed and saved: filtered_200409_Generation_MD.csv
# Processed and saved: filtered_200410_Generation_MD.csv
# Processed and saved: filtered_200411_Generation_MD.csv
# Processed and saved: filtered_200412_Generation_MD.csv
# Processed and saved: filtered_200501_Generation_MD.csv
# Processed and saved: filtered_200502_Generation_MD.csv
# Processed and saved: filtered_200503_Generation_MD.csv
# Processed and saved: filtered_200504_Generation_MD.csv
# Processed and saved: filtered_200505_Generation_MD.csv
# Processed and saved: filtered_200506_Generation_MD.csv
# Processed and saved: filtered_200507_Generation_MD.csv
# Processed and saved: filtered_200508_Generation_MD.csv
# Processed and saved: filtered_200509_Generation_MD.csv
# Processed and saved: filtered_200510_Generation_MD.csv
# Processed and saved: filtered_200511_Generation_MD.csv
# Processed and saved: filtered_200512_Generation_MD.csv
# Processed and saved: filtered_200601_Generation_MD.csv
# Processed and saved: filtered_200602_Generation_MD.csv
# Processed and saved: filtered_200603_Generation_MD.csv
# Processed and saved: filtered_200604_Generation_MD.csv
# Processed and saved: filtered_200605_Generation_MD.csv
# Processed and saved: filtered_200606_Generation_MD.csv
# Processed and saved: filtered_200607_Generation_MD.csv
# Processed and saved: filtered_200608_Generation_MD.csv
# Processed and saved: filtered_200609_Generation_MD.csv
# Processed and saved: filtered_200610_Generation_MD.csv
# Processed and saved: filtered_200611_Generation_MD.csv
# Processed and saved: filtered_200612_Generation_MD.csv
# Processed and saved: filtered_200701_Generation_MD.csv
# Processed and saved: filtered_200702_Generation_MD.csv
# Processed and saved: filtered_200703_Generation_MD.csv
# Processed and saved: filtered_200704_Generation_MD.csv
# Processed and saved: filtered_200705_Generation_MD.csv
# Processed and saved: filtered_200706_Generation_MD.csv
# Processed and saved: filtered_200707_Generation_MD.csv
# Processed and saved: filtered_200708_Generation_MD.csv
# Processed and saved: filtered_200709_Generation_MD.csv
# Processed and saved: filtered_200710_Generation_MD.csv
# Processed and saved: filtered_200711_Generation_MD.csv
# Processed and saved: filtered_200712_Generation_MD.csv
# Processed and saved: filtered_200801_Generation_MD.csv
# Processed and saved: filtered_200802_Generation_MD.csv
# Processed and saved: filtered_200803_Generation_MD.csv
# Processed and saved: filtered_200804_Generation_MD.csv
# Processed and saved: filtered_200805_Generation_MD.csv
# Processed and saved: filtered_200806_Generation_MD.csv
# Processed and saved: filtered_200807_Generation_MD.csv
# Processed and saved: filtered_200808_Generation_MD.csv
# Processed and saved: filtered_200809_Generation_MD.csv
# Processed and saved: filtered_200810_Generation_MD.csv
# Processed and saved: filtered_200811_Generation_MD.csv
# Processed and saved: filtered_200812_Generation_MD.csv
# Processed and saved: filtered_200901_Generation_MD.csv
# Processed and saved: filtered_200902_Generation_MD.csv
# Processed and saved: filtered_200903_Generation_MD.csv
# Processed and saved: filtered_200904_Generation_MD.csv
# Processed and saved: filtered_200905_Generation_MD.csv
# Processed and saved: filtered_200906_Generation_MD.csv
# Processed and saved: filtered_200907_Generation_MD.csv
# Processed and saved: filtered_200908_Generation_MD.csv
# Processed and saved: filtered_200909_Generation_MD.csv
# Processed and saved: filtered_200910_Generation_MD.csv
# Processed and saved: filtered_200911_Generation_MD.csv
# Processed and saved: filtered_200912_Generation_MD.csv
# Processed and saved: filtered_201001_Generation_MD.csv
# Processed and saved: filtered_201002_Generation_MD.csv
# Processed and saved: filtered_201003_Generation_MD.csv
# Processed and saved: filtered_201004_Generation_MD.csv
# Processed and saved: filtered_201005_Generation_MD.csv
# Processed and saved: filtered_201006_Generation_MD.csv
# Processed and saved: filtered_201007_Generation_MD.csv
# Processed and saved: filtered_201008_Generation_MD.csv
# Processed and saved: filtered_201009_Generation_MD.csv
# Processed and saved: filtered_201010_Generation_MD.csv
# Processed and saved: filtered_201011_Generation_MD.csv
# Processed and saved: filtered_201012_Generation_MD.csv
# Processed and saved: filtered_201101_Generation_MD.csv
# Processed and saved: filtered_201102_Generation_MD.csv
# Processed and saved: filtered_201103_Generation_MD.csv
# Processed and saved: filtered_201104_Generation_MD.csv
# Processed and saved: filtered_201105_Generation_MD.csv
# Processed and saved: filtered_201106_Generation_MD.csv
# Processed and saved: filtered_201107_Generation_MD.csv
# Processed and saved: filtered_201108_Generation_MD.csv
# Processed and saved: filtered_201109_Generation_MD.csv
# Processed and saved: filtered_201110_Generation_MD.csv
# Processed and saved: filtered_201111_Generation_MD.csv
# Processed and saved: filtered_201112_Generation_MD.csv
# Processed and saved: filtered_201201_Generation_MD.csv
# Processed and saved: filtered_201202_Generation_MD.csv
# Processed and saved: filtered_201203_Generation_MD.csv
# Processed and saved: filtered_201204_Generation_MD.csv
# Processed and saved: filtered_201205_Generation_MD.csv
# Processed and saved: filtered_201206_Generation_MD.csv
# Processed and saved: filtered_201207_Generation_MD.csv
# Processed and saved: filtered_201208_Generation_MD.csv
# Processed and saved: filtered_201209_Generation_MD.csv
# Processed and saved: filtered_201210_Generation_MD.csv
# Processed and saved: filtered_201211_Generation_MD.csv
# Processed and saved: filtered_201212_Generation_MD.csv
# Processed and saved: filtered_201301_Generation_MD.csv
# Processed and saved: filtered_201302_Generation_MD.csv
# Processed and saved: filtered_201303_Generation_MD.csv
# Processed and saved: filtered_201304_Generation_MD.csv
# Processed and saved: filtered_201305_Generation_MD.csv
# Processed and saved: filtered_201306_Generation_MD.csv
# Processed and saved: filtered_201307_Generation_MD.csv
# Processed and saved: filtered_201308_Generation_MD.csv
# Processed and saved: filtered_201309_Generation_MD.csv
# Processed and saved: filtered_201310_Generation_MD.csv
# Processed and saved: filtered_201311_Generation_MD.csv
# Processed and saved: filtered_201312_Generation_MD.csv
# Processed and saved: filtered_201401_Generation_MD.csv
# Processed and saved: filtered_201402_Generation_MD.csv
# Processed and saved: filtered_201403_Generation_MD.csv
# Processed and saved: filtered_201404_Generation_MD.csv
# Processed and saved: filtered_201405_Generation_MD.csv
# Processed and saved: filtered_201406_Generation_MD.csv
# Processed and saved: filtered_201407_Generation_MD.csv
# Processed and saved: filtered_201408_Generation_MD.csv
# Processed and saved: filtered_201409_Generation_MD.csv
# Processed and saved: filtered_201410_Generation_MD.csv
# Processed and saved: filtered_201411_Generation_MD.csv
# Processed and saved: filtered_201412_Generation_MD.csv
# Processed and saved: filtered_201501_Generation_MD.csv
# Processed and saved: filtered_201502_Generation_MD.csv
# Processed and saved: filtered_201503_Generation_MD.csv
# Processed and saved: filtered_201504_Generation_MD.csv
# Processed and saved: filtered_201505_Generation_MD.csv
# Processed and saved: filtered_201506_Generation_MD.csv
# Processed and saved: filtered_201507_Generation_MD.csv
# Processed and saved: filtered_201508_Generation_MD.csv
# Processed and saved: filtered_201509_Generation_MD.csv
# Processed and saved: filtered_201510_Generation_MD.csv
# Processed and saved: filtered_201511_Generation_MD.csv
# Processed and saved: filtered_201512_Generation_MD.csv
# Processed and saved: filtered_201601_Generation_MD.csv
# Processed and saved: filtered_201602_Generation_MD.csv
# Processed and saved: filtered_201603_Generation_MD.csv
# Processed and saved: filtered_201604_Generation_MD.csv
# Processed and saved: filtered_201605_Generation_MD.csv
# Processed and saved: filtered_201606_Generation_MD.csv
# Processed and saved: filtered_201607_Generation_MD.csv
# Processed and saved: filtered_201608_Generation_MD.csv
# Processed and saved: filtered_201609_Generation_MD.csv
# Processed and saved: filtered_201610_Generation_MD.csv
# Processed and saved: filtered_201611_Generation_MD.csv
# Processed and saved: filtered_201612_Generation_MD.csv
# Processed and saved: filtered_201701_Generation_MD.csv
# Processed and saved: filtered_201702_Generation_MD.csv
# Processed and saved: filtered_201703_Generation_MD.csv
# Processed and saved: filtered_201704_Generation_MD.csv
# Processed and saved: filtered_201705_Generation_MD.csv
# Processed and saved: filtered_201706_Generation_MD.csv
# Processed and saved: filtered_201707_Generation_MD.csv
# Processed and saved: filtered_201708_Generation_MD.csv
# Processed and saved: filtered_201709_Generation_MD.csv
# Processed and saved: filtered_201710_Generation_MD.csv
# Processed and saved: filtered_201711_Generation_MD.csv
# Processed and saved: filtered_201712_Generation_MD.csv
# Processed and saved: filtered_201801_Generation_MD.csv
# Processed and saved: filtered_201802_Generation_MD.csv
# Processed and saved: filtered_201803_Generation_MD.csv
# Processed and saved: filtered_201804_Generation_MD.csv
# Processed and saved: filtered_201805_Generation_MD.csv
# Processed and saved: filtered_201806_Generation_MD.csv
# Processed and saved: filtered_201807_Generation_MD.csv
# Processed and saved: filtered_201808_Generation_MD.csv
# Processed and saved: filtered_201809_Generation_MD.csv
# Processed and saved: filtered_201810_Generation_MD.csv
# Processed and saved: filtered_201811_Generation_MD.csv
# Processed and saved: filtered_201812_Generation_MD.csv
# Processed and saved: filtered_201901_Generation_MD.csv
# Processed and saved: filtered_201902_Generation_MD.csv
# Processed and saved: filtered_201903_Generation_MD.csv
# Processed and saved: filtered_201904_Generation_MD.csv
# Processed and saved: filtered_201905_Generation_MD.csv
# Processed and saved: filtered_201906_Generation_MD.csv
# Processed and saved: filtered_201907_Generation_MD.csv
# Processed and saved: filtered_201908_Generation_MD.csv
# Processed and saved: filtered_201909_Generation_MD.csv
# Processed and saved: filtered_201910_Generation_MD.csv
# Processed and saved: filtered_201911_Generation_MD.csv
# Processed and saved: filtered_201912_Generation_MD.csv
# Processed and saved: filtered_202001_Generation_MD.csv
# Processed and saved: filtered_202002_Generation_MD.csv
# Processed and saved: filtered_202003_Generation_MD.csv
# Processed and saved: filtered_202004_Generation_MD.csv
# Processed and saved: filtered_202005_Generation_MD.csv
# Processed and saved: filtered_202006_Generation_MD.csv
# Processed and saved: filtered_202007_Generation_MD.csv
# Processed and saved: filtered_202008_Generation_MD.csv
# Processed and saved: filtered_202009_Generation_MD.csv
# Processed and saved: filtered_202010_Generation_MD.csv
# Processed and saved: filtered_202011_Generation_MD.csv
# Processed and saved: filtered_202012_Generation_MD.csv
# Processed and saved: filtered_202101_Generation_MD.csv
# Processed and saved: filtered_202102_Generation_MD.csv
# Processed and saved: filtered_202103_Generation_MD.csv
# Processed and saved: filtered_202104_Generation_MD.csv
# Processed and saved: filtered_202105_Generation_MD.csv
# Processed and saved: filtered_202106_Generation_MD.csv
# Processed and saved: filtered_202107_Generation_MD.csv
# Processed and saved: filtered_202108_Generation_MD.csv
# Processed and saved: filtered_202109_Generation_MD.csv
# Processed and saved: filtered_202110_Generation_MD.csv
# Processed and saved: filtered_202111_Generation_MD.csv
# Processed and saved: filtered_202112_Generation_MD.csv
# Processed and saved: filtered_202201_Generation_MD.csv
# Processed and saved: filtered_202202_Generation_MD.csv
# Processed and saved: filtered_202203_Generation_MD.csv
# Processed and saved: filtered_202204_Generation_MD.csv
# Processed and saved: filtered_202205_Generation_MD.csv
# Processed and saved: filtered_202206_Generation_MD.csv
# Processed and saved: filtered_202207_Generation_MD.csv
# Processed and saved: filtered_202208_Generation_MD.csv
# Processed and saved: filtered_202209_Generation_MD.csv
# Processed and saved: filtered_202210_Generation_MD.csv
# Processed and saved: filtered_202211_Generation_MD.csv
# Processed and saved: filtered_202212_Generation_MD.csv
# Processed and saved: filtered_202301_Generation_MD.csv
# Processed and saved: filtered_202302_Generation_MD.csv
# Processed and saved: filtered_202303_Generation_MD.csv
# Processed and saved: filtered_202304_Generation_MD.csv
# Processed and saved: filtered_202305_Generation_MD.csv
# Processed and saved: filtered_202306_Generation_MD.csv
# Processed and saved: filtered_202307_Generation_MD.csv
# Processed and saved: filtered_202308_Generation_MD.csv
# Processed and saved: filtered_202309_Generation_MD.csv
# Processed and saved: filtered_202310_Generation_MD.csv
# Processed and saved: filtered_202311_Generation_MD.csv
# Processed and saved: filtered_202312_Generation_MD.csv
# Processed and saved: filtered_202401_Generation_MD.csv
# Processed and saved: filtered_202402_Generation_MD.csv
# Processed and saved: filtered_202403_Generation_MD.csv
# Processed and saved: filtered_202404_Generation_MD.csv
# Processed and saved: filtered_202405_Generation_MD.csv
# Processed and saved: filtered_202406_Generation_MD.csv
# Processed and saved: filtered_202407_Generation_MD.csv
# Processed and saved: filtered_202408_Generation_MD.csv
# Processed and saved: filtered_202409_Generation_MD.csv
# Processed and saved: filtered_202410_Generation_MD.csv
# Processed and saved: filtered_202411_Generation_MD.csv
# Processed and saved: filtered_202412_Generation_MD.csv
# Processed and saved: filtered_202501_Generation_MD.csv

# %%
df.head()
# Out:
#   Site_Code POC_Code Nwk_Code   Gen_Code Fuel_Code Tech_Code Trading_Date  \
# 0       ARA  ARA2201     MRPL  aratiatia     Hydro     Hydro   2025-01-01
# 1       ARA  ARA2201     MRPL  aratiatia     Hydro     Hydro   2025-01-02
# 2       ARA  ARA2201     MRPL  aratiatia     Hydro     Hydro   2025-01-03
# 3       ARA  ARA2201     MRPL  aratiatia     Hydro     Hydro   2025-01-04
# 4       ARA  ARA2201     MRPL  aratiatia     Hydro     Hydro   2025-01-05
#
#      TP1    TP2    TP3  ...   TP41   TP42   TP43   TP44   TP45   TP46   TP47  \
# 0   7880   7840   7870  ...   7850   7860   7880   7840   7850   7860   7900
# 1   7860   7880   7860  ...  24660  24600  24670  24550  24670  21650   9260
# 2   7930   7860   8610  ...  22540  24600  24600  24750  24570  24590  20190
# 3   7890   7850   7900  ...  21370  21690  21640  21650  21740  21690  21580
# 4  13860  13780  12950  ...  11810  11810  11830  11800  11610  10800  10850
#
#     TP48  TP49  TP50
# 0   7860   NaN   NaN
# 1   7990   NaN   NaN
# 2   9070   NaN   NaN
# 3  12640   NaN   NaN
# 4  10820   NaN   NaN
#
# [5 rows x 57 columns]

# %%
trading_date_counts = df['Trading_Date'].value_counts()
print(trading_date_counts)
# Out:
# Trading_Date
# 2025-01-31    89
# 2025-01-30    89
# 2025-01-29    89
# 2025-01-14    88
# 2025-01-28    88
# 2025-01-26    88
# 2025-01-25    88
# 2025-01-24    88
# 2025-01-23    88
# 2025-01-22    88
# 2025-01-21    88
# 2025-01-18    88
# 2025-01-17    88
# 2025-01-16    88
# 2025-01-09    88
# 2025-01-08    88
# 2025-01-13    88
# 2025-01-04    88
# 2025-01-03    87
# 2025-01-05    87
# 2025-01-27    87
# 2025-01-06    87
# 2025-01-07    87
# 2025-01-15    87
# 2025-01-02    87
# 2025-01-10    87
# 2025-01-11    87
# 2025-01-20    87
# 2025-01-19    87
# 2025-01-12    87
# 2025-01-01    86
# Name: count, dtype: int64

# %%
output_file
# Out:
# 'filtered_filtered_202501_Generation_MD.csv'
