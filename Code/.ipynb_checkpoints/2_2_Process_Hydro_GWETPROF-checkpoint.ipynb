# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import requests
import os
import time

# %%
#Input_folder_EVLAND = r"C:\Users\nwn86\ResearchProject\Code\NASA_Climate_Downloads\Hydro\EVLAND"

# %%
file_path = r"C:\Users\nwn86\ResearchProject_singlensp\Input"

# %%
file_name = "nsp_info_final_v1.csv"

# %%
output_file = os.path.join(file_path, file_name)

# %%
nsp_info = pd.read_csv(output_file)

# %%
nsp_info
# Out:
#    POC_Code  NZTM_easting  NZTM_northing  \
# 0   ARA2201     1873657.0      5721160.0
# 1   ARG1101     1616836.0      5386748.0
# 2   ARI1101     1831834.0      5782895.0
# 3   ARI1102     1831834.0      5782895.0
# 4   ASB0661     1503869.0      5133912.0
# 5   ATI2201     1863994.0      5746271.0
# 6   AVI2201     1390245.0      5051586.0
# 7   BEN2202     1377144.0      5061473.0
# 8   BPE0331     1824481.0      5537751.0
# 9   BWK1101     1375377.0      4908483.0
# 10  COL0661     1480658.0      5197735.0
# 11  CYD0331     1309790.0      4990370.0
# 12  CYD2201     1309790.0      4990370.0
# 13  EDG0331     1936285.0      5788677.0
# 14  GOR0331     1284097.0      4885035.0
# 15  HWA1101     1712537.0      5619536.0
# 16  HWB0331     1404029.0      4918978.0
# 17  HWB0331     1404029.0      4918978.0
# 18  KOE1101     1673614.0      6082721.0
# 19  KPO1101     1823029.0      5799542.0
# 20  LTN0331     1823277.0      5523360.0
# 21  LTN2201     1823277.0      5523360.0
# 22  MAN2201     1153098.0      4943235.0
# 23  MAT1101     1934456.0      5774722.0
# 24  MHO0331     1807281.0      5505363.0
# 25  MTI2201     1839802.0      5751482.0
# 26  NMA0331     1242677.0      4861547.0
# 27  NSY0331     1371044.0      5009253.0
# 28  OHA2201     1362883.0      5094304.0
# 29  OHB2201     1369516.0      5090545.0
# 30  OHC2201     1375175.0      5086098.0
# 31  OHK2201     1869462.0      5744408.0
# 32  ROT1101     1882790.0      5772814.0
# 33  ROX1101     1312313.0      4957442.0
# 34  ROX2201     1312313.0      4957442.0
# 35  RPO2201     1845189.0      5662388.0
# 36  STK0661     1620344.0      5426252.0
# 37  TGA0331     1875930.0      5819779.0
# 38  TKA0111     1396471.0      5123459.0
# 39  TKB2201     1376922.0      5110445.0
# 40  TKU2201     1839960.0      5681601.0
# 41  TUI1101     1960528.0      5696630.0
# 42  TWC2201     1835550.0      5529228.0
# 43  TWH0331     1789809.0      5821033.0
# 44  WDV1101     1842684.0      5533314.0
# 45  WIL0331     1747405.0      5431065.0
# 46  WKM2201     1844481.0      5743971.0
# 47  WPA2201     1834680.0      5758417.0
# 48  WPG0331     1404006.0      4918940.0
# 49  WTK0111     1396285.0      5048037.0
# 50  WVY1101     1740109.0      5598256.0
# 51  WWD1102     1739027.0      5427096.0
# 52  WWD1103     1739027.0      5427096.0
# 53  HRP2201           NaN            NaN
#
#                                    Network Island Fuel_Code   Latitude  \
# 0                  Taupo (Unison Networks)     NI     Hydro -38.615891
# 1          Marlborough (Marlborough Lines)     SI     Hydro -41.670851
# 2                  Thames Valley (Powerco)     NI     Hydro -38.072026
# 3                  Thames Valley (Powerco)     NI     Hydro -38.072026
# 4        Ashburton (Electricity Ashburton)     SI     Hydro -43.941637
# 5         King Country (The Lines Company)     NI     Hydro -38.392831
# 6                Waitaki (Network Waitaki)     SI     Hydro -44.658443
# 7                Waitaki (Network Waitaki)     SI     Hydro -44.565596
# 8                       Manawatu (Powerco)     NI      Wind -40.280614
# 9                  Dunedin (Aurora Energy)     SI     Hydro -45.940470
# 10  Central Canterbury (Orion New Zealand)     SI     Hydro -43.363766
# 11           Central Otago (Aurora Energy)     SI     Hydro -45.180391
# 12           Central Otago (Aurora Energy)     SI     Hydro -45.180391
# 13  Eastern Bay of Plenty (Horizon Energy)     NI     Solar -37.987259
# 14           Southland (The Power Company)     SI      Wind -46.115091
# 15                      Taranaki (Powerco)     NI     Hydro -39.566497
# 16                 Dunedin (Aurora Energy)     SI     Hydro -45.854874
# 17                     Otago (OtagoNet JV)     SI     Hydro -45.854874
# 18             Bay of Islands (Top Energy)     NI     Solar -35.396162
# 19                 Thames Valley (Powerco)     NI     Hydro -37.924349
# 20                      Manawatu (Powerco)     NI      Wind -40.410452
# 21                      Manawatu (Powerco)     NI      Wind -40.410452
# 22           Southland (The Power Company)     SI     Hydro -45.520868
# 23  Eastern Bay of Plenty (Horizon Energy)     NI     Hydro -38.113429
# 24         Kapiti and Horowhenua (Electra)     NI     Hydro -40.576575
# 25        King Country (The Lines Company)     NI     Hydro -38.352736
# 26           Southland (The Power Company)     SI      Wind -46.305391
# 27                     Otago (OtagoNet JV)     SI     Hydro -45.033180
# 28        South Canterbury (Alpine Energy)     SI     Hydro -44.265872
# 29               Waitaki (Network Waitaki)     SI     Hydro -44.301801
# 30               Waitaki (Network Waitaki)     SI     Hydro -44.343561
# 31               Rotorua (Unison Networks)     NI     Hydro -38.407966
# 32               Rotorua (Unison Networks)     NI     Hydro -38.148250
# 33           Central Otago (Aurora Energy)     SI     Hydro -45.477213
# 34           Central Otago (Aurora Energy)     SI     Hydro -45.477213
# 35        King Country (The Lines Company)     NI     Hydro -39.153194
# 36                 Tasman (Network Tasman)     SI     Hydro -41.314941
# 37                      Tauranga (Powerco)     NI     Hydro -37.727716
# 38        South Canterbury (Alpine Energy)     SI     Hydro -44.013807
# 39        South Canterbury (Alpine Energy)     SI     Hydro -44.125161
# 40        King Country (The Lines Company)     NI     Hydro -38.981721
# 41             Eastland (Eastland Network)     NI     Hydro -38.805354
# 42                      Manawatu (Powerco)     NI      Wind -40.354267
# 43                  Waikato (WEL Networks)     NI      Wind -37.738327
# 44        Southern Hawke's Bay (Scanpower)     NI      Wind -40.315457
# 45     Wellington (Wellington Electricity)     NI      Wind -41.258396
# 46        King Country (The Lines Company)     NI     Hydro -38.419082
# 47                  Waipa (Waipa Networks)     NI     Hydro -38.291661
# 48                 Dunedin (Aurora Energy)     SI     Hydro -45.855209
# 49               Waitaki (Network Waitaki)     SI     Hydro -44.692099
# 50                      Wanganui (Powerco)     NI      Wind -39.754097
# 51     Wellington (Wellington Electricity)     NI      Wind -41.295618
# 52     Wellington (Wellington Electricity)     NI      Wind -41.295618
# 53           Hawke's Bay (Unison Networks)     NI      Wind -39.604330
#
#      Longitude
# 0   176.143036
# 1   173.202251
# 2   175.642919
# 3   175.642919
# 4   171.802149
# 5   176.022730
# 6   170.354335
# 7   170.193571
# 8   175.640510
# 9   170.102172
# 10  171.527122
# 11  169.306224
# 12  169.306224
# 13  176.828883
# 14  168.911652
# 15  174.310117
# 16  170.475700
# 17  170.475700
# 18  173.810632
# 19  175.537461
# 20  175.631394
# 21  175.631394
# 22  167.277500
# 23  176.814617
# 24  175.448930
# 25  175.744267
# 26  168.359527
# 27  170.093353
# 28  170.029212
# 29  170.110551
# 30  170.179492
# 31  176.085969
# 32  176.227041
# 33  169.319136
# 34  169.319136
# 35  175.837443
# 36  173.243059
# 37  176.130869
# 38  170.460853
# 39  170.211748
# 40  175.770224
# 41  177.151399
# 42  175.773710
# 43  175.154139
# 44  175.856067
# 45  174.759556
# 46  175.800363
# 47  175.683408
# 48  170.475388
# 49  170.429029
# 50  174.635503
# 51  174.660496
# 52  174.660496
# 53  176.753550

# %%
df_unique_nsp_info = nsp_info[['POC_Code', 'Fuel_Code', 'Island']].drop_duplicates()

# %%
df_unique_nsp_info
# Out:
#    POC_Code Fuel_Code Island
# 0   ARA2201     Hydro     NI
# 1   ARG1101     Hydro     SI
# 2   ARI1101     Hydro     NI
# 3   ARI1102     Hydro     NI
# 4   ASB0661     Hydro     SI
# 5   ATI2201     Hydro     NI
# 6   AVI2201     Hydro     SI
# 7   BEN2202     Hydro     SI
# 8   BPE0331      Wind     NI
# 9   BWK1101     Hydro     SI
# 10  COL0661     Hydro     SI
# 11  CYD0331     Hydro     SI
# 12  CYD2201     Hydro     SI
# 13  EDG0331     Solar     NI
# 14  GOR0331      Wind     SI
# 15  HWA1101     Hydro     NI
# 16  HWB0331     Hydro     SI
# 18  KOE1101     Solar     NI
# 19  KPO1101     Hydro     NI
# 20  LTN0331      Wind     NI
# 21  LTN2201      Wind     NI
# 22  MAN2201     Hydro     SI
# 23  MAT1101     Hydro     NI
# 24  MHO0331     Hydro     NI
# 25  MTI2201     Hydro     NI
# 26  NMA0331      Wind     SI
# 27  NSY0331     Hydro     SI
# 28  OHA2201     Hydro     SI
# 29  OHB2201     Hydro     SI
# 30  OHC2201     Hydro     SI
# 31  OHK2201     Hydro     NI
# 32  ROT1101     Hydro     NI
# 33  ROX1101     Hydro     SI
# 34  ROX2201     Hydro     SI
# 35  RPO2201     Hydro     NI
# 36  STK0661     Hydro     SI
# 37  TGA0331     Hydro     NI
# 38  TKA0111     Hydro     SI
# 39  TKB2201     Hydro     SI
# 40  TKU2201     Hydro     NI
# 41  TUI1101     Hydro     NI
# 42  TWC2201      Wind     NI
# 43  TWH0331      Wind     NI
# 44  WDV1101      Wind     NI
# 45  WIL0331      Wind     NI
# 46  WKM2201     Hydro     NI
# 47  WPA2201     Hydro     NI
# 48  WPG0331     Hydro     SI
# 49  WTK0111     Hydro     SI
# 50  WVY1101      Wind     NI
# 51  WWD1102      Wind     NI
# 52  WWD1103      Wind     NI
# 53  HRP2201      Wind     NI

# %%
poc_counts = df_unique_nsp_info.groupby(['Island', 'Fuel_Code'])['POC_Code'].nunique().reset_index()
poc_counts.rename(columns={'POC_Code': 'Unique_POC_Count'}, inplace=True)

print(poc_counts)
# Out:
#   Island Fuel_Code  Unique_POC_Count
# 0     NI     Hydro                17
# 1     NI     Solar                 2
# 2     NI      Wind                11
# 3     SI     Hydro                21
# 4     SI      Wind                 2

# %%
nsp_info_Hydro = df_unique_nsp_info[df_unique_nsp_info['Fuel_Code'].isin(['Hydro'])]

# %%
Hydro_counts = df_unique_nsp_info['Fuel_Code'].value_counts()

# %%
Hydro_counts
# Out:
# Fuel_Code
# Hydro    38
# Wind     13
# Solar     2
# Name: count, dtype: int64

# %%
nsp_info_Hydro.reset_index()
# Out:
#     index POC_Code Fuel_Code Island
# 0       0  ARA2201     Hydro     NI
# 1       1  ARG1101     Hydro     SI
# 2       2  ARI1101     Hydro     NI
# 3       3  ARI1102     Hydro     NI
# 4       4  ASB0661     Hydro     SI
# 5       5  ATI2201     Hydro     NI
# 6       6  AVI2201     Hydro     SI
# 7       7  BEN2202     Hydro     SI
# 8       9  BWK1101     Hydro     SI
# 9      10  COL0661     Hydro     SI
# 10     11  CYD0331     Hydro     SI
# 11     12  CYD2201     Hydro     SI
# 12     15  HWA1101     Hydro     NI
# 13     16  HWB0331     Hydro     SI
# 14     19  KPO1101     Hydro     NI
# 15     22  MAN2201     Hydro     SI
# 16     23  MAT1101     Hydro     NI
# 17     24  MHO0331     Hydro     NI
# 18     25  MTI2201     Hydro     NI
# 19     27  NSY0331     Hydro     SI
# 20     28  OHA2201     Hydro     SI
# 21     29  OHB2201     Hydro     SI
# 22     30  OHC2201     Hydro     SI
# 23     31  OHK2201     Hydro     NI
# 24     32  ROT1101     Hydro     NI
# 25     33  ROX1101     Hydro     SI
# 26     34  ROX2201     Hydro     SI
# 27     35  RPO2201     Hydro     NI
# 28     36  STK0661     Hydro     SI
# 29     37  TGA0331     Hydro     NI
# 30     38  TKA0111     Hydro     SI
# 31     39  TKB2201     Hydro     SI
# 32     40  TKU2201     Hydro     NI
# 33     41  TUI1101     Hydro     NI
# 34     46  WKM2201     Hydro     NI
# 35     47  WPA2201     Hydro     NI
# 36     48  WPG0331     Hydro     SI
# 37     49  WTK0111     Hydro     SI

# %%
Input_folder_EVLAND = r"C:\Users\nwn86\ResearchProject_singlensp\Input\NASA_Climate_Downloads\Hydro\GWETPROF"

# %%
# parameters = "EVLAND"

# %%
# Filename_EVLAND = f"{output_folder}/NASA_{poc}_{parameters}_{start_date}_{end_date}.csv"

# %%
# Filename_EVLAND = "NASA_BPE0331_EVLAND_20150101_20250228.csv"

# %%
#Read_file_EVLAND = os.path.join(Input_folder_EVLAND, Filename_EVLAND)

# %%
# Read_file_EVLAND

# %%
# nsp_info = pd.read_csv(Read_file_EVLAND)

# %%
# with open(Read_file_EVLAND, 'r') as f:
#     for i, line in enumerate(f):
#         if line.startswith('YEAR') or 'DATE' in line:
#             header_line = i
#             # break

# %%
# EVLAND_Data = pd.read_csv(Read_file_EVLAND, skiprows=header_line)

# %%
# EVLAND_Data

# %%
# Get list of POC codes to load
selected_pocs = nsp_info_Hydro['POC_Code'].unique()

# %%
selected_pocs

# %%
# Initialize empty list to store DataFrames
dfs = []

# %%
# Loop through each selected POC
for poc in selected_pocs:
    file_EVLAND = os.path.join(
        Input_folder_EVLAND, f"NASA_{poc}_EVLAND_20150101_20250228.csv"
    )
    
    # Check if file exists before loading
    if os.path.exists(file_EVLAND):
        # Skip metadata rows and load actual data
        print(f"Loading file: {file_EVLAND}")
        with open(file_EVLAND, 'r') as f:
            for i, line in enumerate(f):
                if line.startswith('YEAR') or 'DATE' in line:
                    header_line = i
                    break
        #df = pd.read_csv(file_path, skiprows=10)
        df_EVLAND = pd.read_csv(file_EVLAND, skiprows=header_line)
        
        # Add identifier column
        df_EVLAND['POC_Code'] = poc
        
        dfs.append(df_EVLAND)
    else:
        print(f"File not found: {file_path}")

# Combine all into a single DataFrame
combined_Hydro_data_EVLAND = pd.concat(dfs, ignore_index=True)

# %%
combined_Hydro_data_EVLAND

# %%
# Create a new date column
combined_Hydro_data_EVLAND['DATE'] = pd.to_datetime(
    combined_Hydro_data_EVLAND['YEAR'].astype(str) + combined_Hydro_data_EVLAND['DOY'].astype(str),
    format='%Y%j'
)

# %%
# Optional: Set DATE as index or reorder columns
# combined_Hydro_data.set_index('DATE', inplace=True)

# Preview the updated DataFrame
print(combined_Hydro_data_EVLAND[['DATE', 'YEAR', 'DOY', 'EVLAND', 'POC_Code']].head())

# %%
combined_Hydro_data_EVLAND

# %%
# # 2. Filter data between 2015-01-01 and 2024-12-31
# filtered_Hydro_data_EVLAND = combined_Hydro_data_EVLAND[
#     (combined_Hydro_data_EVLAND['DATE'] >= '2015-01-01') &
#     (combined_Hydro_data_EVLAND['DATE'] <= '2024-12-31')
# ]

# %%
# filtered_Hydro_data_EVLAND

# %%
hydro_EVLAND_df = combined_Hydro_data_EVLAND[['DATE', 'POC_Code', 'EVLAND']]

# %%
hydro_EVLAND_df

# %%
# daily_avg_EVLAND = filtered_Hydro_data_EVLAND.groupby('DATE', as_index=False)['EVLAND'].mean()

# %%
# daily_total_precip = filtered_Hydro_data_EVLAND.groupby('DATE', as_index=False)['EVLAND'].sum()

# %%
# daily_avg_EVLAND = daily_avg_EVLAND.rename(columns={'EVLAND': 'Avg_EVLAND'})

# %%
# daily_avg_EVLAND

# %%
hydro_EVLAND_df['EVLAND'] = hydro_EVLAND_df['EVLAND'].round(4)

# %%
hydro_EVLAND_df.head()

# %%
hydro_EVLAND_df.to_csv(r'C:\Users\nwn86\ResearchProject_singlensp\Staging\Climate\hydro/Hydro_Factor_Daily_EVLAND.csv', index=False)
