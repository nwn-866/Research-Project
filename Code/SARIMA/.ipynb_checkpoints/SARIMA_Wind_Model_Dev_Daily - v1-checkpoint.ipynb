# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# 1: Load all datasets 
wind_energy = pd.read_csv('wind_data.csv')
daily_all_nsp_ps = pd.read_csv('Wind_Factor_ALL_NSP_Daily_PS.csv')
daily_all_nsp_t2m = pd.read_csv('Wind_Factor_ALL_NSP_Daily_T2M.csv')
daily_all_nsp_wd50m = pd.read_csv('Wind_Factor_ALL_NSP_Daily_WD50M.csv')
daily_all_nsp_ws50m = pd.read_csv('Wind_Factor_ALL_NSP_Daily_WS50M.csv')

# %%
wind_energy.head()
# Out:
#   Fuel_Code POC_Code        DATE     Total_TP Island   Latitude  Longitude
# 0      Wind  BPE0331  2015-03-01  472971.4800     NI -40.280614  175.64051
# 1      Wind  BPE0331  2015-03-02  119485.1800     NI -40.280614  175.64051
# 2      Wind  BPE0331  2015-03-03  173416.5861     NI -40.280614  175.64051
# 3      Wind  BPE0331  2015-03-04  127370.3811     NI -40.280614  175.64051
# 4      Wind  BPE0331  2015-03-05   59379.3772     NI -40.280614  175.64051

# %%
daily_all_nsp_ps.head()
# Out:
#          DATE POC_Code     PS Island Fuel_Code   Latitude  Longitude
# 0  2015-01-01  BPE0331  99.16     NI      Wind -40.280614  175.64051
# 1  2015-01-02  BPE0331  99.64     NI      Wind -40.280614  175.64051
# 2  2015-01-03  BPE0331  99.90     NI      Wind -40.280614  175.64051
# 3  2015-01-04  BPE0331  99.88     NI      Wind -40.280614  175.64051
# 4  2015-01-05  BPE0331  99.59     NI      Wind -40.280614  175.64051

# %%
daily_all_nsp_wd50m.head()
# Out:
#          DATE POC_Code  WD50M  WD50M_rad         u         v Island Fuel_Code  \
# 0  2015-01-01  BPE0331  222.2   3.878122 -0.740805 -0.671721     NI      Wind
# 1  2015-01-02  BPE0331  317.8   5.546656  0.740805 -0.671721     NI      Wind
# 2  2015-01-03  BPE0331  128.0   2.234021 -0.615661  0.788011     NI      Wind
# 3  2015-01-04  BPE0331  315.1   5.499532  0.708340 -0.705872     NI      Wind
# 4  2015-01-05  BPE0331  312.0   5.445427  0.669131 -0.743145     NI      Wind
#
#     Latitude  Longitude
# 0 -40.280614  175.64051
# 1 -40.280614  175.64051
# 2 -40.280614  175.64051
# 3 -40.280614  175.64051
# 4 -40.280614  175.64051

# %%
daily_all_nsp_t2m.head()
# Out:
#          DATE POC_Code    T2M Island Fuel_Code   Latitude  Longitude
# 0  2015-01-01  BPE0331  16.13     NI      Wind -40.280614  175.64051
# 1  2015-01-02  BPE0331  15.73     NI      Wind -40.280614  175.64051
# 2  2015-01-03  BPE0331  16.70     NI      Wind -40.280614  175.64051
# 3  2015-01-04  BPE0331  17.84     NI      Wind -40.280614  175.64051
# 4  2015-01-05  BPE0331  17.75     NI      Wind -40.280614  175.64051

# %%
daily_all_nsp_ws50m.head()
# Out:
#          DATE POC_Code  WS50M Island Fuel_Code   Latitude  Longitude
# 0  2015-01-01  BPE0331   6.72     NI      Wind -40.280614  175.64051
# 1  2015-01-02  BPE0331   6.08     NI      Wind -40.280614  175.64051
# 2  2015-01-03  BPE0331   4.22     NI      Wind -40.280614  175.64051
# 3  2015-01-04  BPE0331   4.95     NI      Wind -40.280614  175.64051
# 4  2015-01-05  BPE0331   7.65     NI      Wind -40.280614  175.64051

# %%
# # 2. Function to convert DATE column and add a YearMonth column
# def prepare_df(df):
#     df['DATE'] = pd.to_datetime(df['DATE'])
#     df['YearMonth'] = df['DATE'].dt.strftime('%Y-%m')
#     return df

# %%
# # Prepare all DataFrames
# wind_energy = prepare_df(wind_energy)
# daily_all_nsp_ps = prepare_df(daily_all_nsp_ps)
# daily_all_nsp_t2m = prepare_df(daily_all_nsp_t2m)
# daily_all_nsp_wd50m = prepare_df(daily_all_nsp_wd50m)
# daily_all_nsp_ws50m = prepare_df(daily_all_nsp_ws50m)

# %%
# # 3. Function to extract unique (POC_Code, YearMonth) combinations as a set of tuples
# def get_poc_yearmonth(df):
#     return set(df[['POC_Code', 'YearMonth']].apply(lambda row: (row['POC_Code'], row['YearMonth']), axis=1))

# # Extract unique combinations from each DataFrame
# wind_energy_combos = get_poc_yearmonth(wind_energy)
# ps_combos = get_poc_yearmonth(daily_all_nsp_ps)
# t2m_combos = get_poc_yearmonth(daily_all_nsp_t2m)
# wd50m_combos = get_poc_yearmonth(daily_all_nsp_wd50m)
# ws50m_combos = get_poc_yearmonth(daily_all_nsp_ws50m)

# # 4. Find the common combinations across all five DataFrames
# common_combos = wind_energy_combos & ps_combos & t2m_combos & wd50m_combos & ws50m_combos

# print("Number of common (POC_Code, YearMonth) combinations:", len(common_combos))
# print("Sample common combinations:", list(common_combos)[:10])  # print a sample

# # 5. Check for extra combinations in each DataFrame that are not in the common set
# print("Extra in wind_energy:", wind_energy_combos - common_combos)
# print("Extra in Daily NSP PS:", ps_combos - common_combos)
# print("Extra in Daily NSP T2M:", t2m_combos - common_combos)
# print("Extra in Daily NSP WD50M:", wd50m_combos - common_combos)
# print("Extra in Daily NSP WS50M:", ws50m_combos - common_combos)

# %%
# Merge wind_energy and daily_all_nsp_ps
merge1 = pd.merge(wind_energy, daily_all_nsp_ps, on=['POC_Code', 'DATE'], how='inner', suffixes=('_wind', '_ps'))
print("Merge 1 (wind_energy with daily_all_nsp_ps):", merge1.shape)
# Out:
# Merge 1 (wind_energy with daily_all_nsp_ps): (35020, 12)

# %%
merge1.head()
# Out:
#   Fuel_Code_wind POC_Code        DATE     Total_TP Island_wind  Latitude_wind  \
# 0           Wind  BPE0331  2015-03-01  472971.4800          NI     -40.280614
# 1           Wind  BPE0331  2015-03-02  119485.1800          NI     -40.280614
# 2           Wind  BPE0331  2015-03-03  173416.5861          NI     -40.280614
# 3           Wind  BPE0331  2015-03-04  127370.3811          NI     -40.280614
# 4           Wind  BPE0331  2015-03-05   59379.3772          NI     -40.280614
#
#    Longitude_wind     PS Island_ps Fuel_Code_ps  Latitude_ps  Longitude_ps
# 0       175.64051  99.50        NI         Wind   -40.280614     175.64051
# 1       175.64051  99.39        NI         Wind   -40.280614     175.64051
# 2       175.64051  99.24        NI         Wind   -40.280614     175.64051
# 3       175.64051  98.90        NI         Wind   -40.280614     175.64051
# 4       175.64051  98.46        NI         Wind   -40.280614     175.64051

# %%
# Merge merge1 with daily_all_nsp_t2m
merge2 = pd.merge(merge1, daily_all_nsp_t2m, on=['POC_Code', 'DATE'], how='inner', suffixes=('', '_t2m'))
print("Merge 2 (previous merge with daily_all_nsp_t2m):", merge2.shape)
# Out:
# Merge 2 (previous merge with daily_all_nsp_t2m): (35020, 17)

# %%
# Merge merge2 with daily_all_nsp_wd50m
merge3 = pd.merge(merge2, daily_all_nsp_wd50m, on=['POC_Code', 'DATE'], how='inner', suffixes=('', '_wd50m'))
print("Merge 3 (previous merge with daily_all_nsp_wd50m):", merge3.shape)
# Out:
# Merge 3 (previous merge with daily_all_nsp_wd50m): (35020, 25)

# %%
# Merge merge3 with daily_all_nsp_ws50m
final_merge = pd.merge(merge3, daily_all_nsp_ws50m, on=['POC_Code', 'DATE'], how='inner', suffixes=('', '_ws50m'))
print("Final Merge (previous merge with daily_all_nsp_ws50m):", final_merge.shape)
# Out:
# Final Merge (previous merge with daily_all_nsp_ws50m): (35020, 30)

# %%
# Write the final merged DataFrame to a CSV file
final_merge.to_csv('final_merged.csv', index=False)

print("Final merge saved to final_merged.csv")
# Out:
# Final merge saved to final_merged.csv

# %%
# Check for missing values in each column
missing_values = final_merge.isnull().sum()
print(missing_values)

# Optionally, check if there are any missing values at all
if final_merge.isnull().values.any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values found in the DataFrame.")
# Out:
# Fuel_Code_wind     0
# POC_Code           0
# DATE               0
# Total_TP           0
# Island_wind        0
# Latitude_wind      0
# Longitude_wind     0
# PS                 0
# Island_ps          0
# Fuel_Code_ps       0
# Latitude_ps        0
# Longitude_ps       0
# T2M                0
# Island             0
# Fuel_Code          0
# Latitude           0
# Longitude          0
# WD50M              0
# WD50M_rad          0
# u                  0
# v                  0
# Island_wd50m       0
# Fuel_Code_wd50m    0
# Latitude_wd50m     0
# Longitude_wd50m    0
# WS50M              0
# Island_ws50m       0
# Fuel_Code_ws50m    0
# Latitude_ws50m     0
# Longitude_ws50m    0
# dtype: int64
# No missing values found in the DataFrame.

# %%
# List all column names as an Index object
print(final_merge.columns)

# Alternatively, list the column names as a Python list
print(final_merge.columns.tolist())
# Out:
# Index(['Fuel_Code_wind', 'POC_Code', 'DATE', 'Total_TP', 'Island_wind',
#        'Latitude_wind', 'Longitude_wind', 'PS', 'Island_ps', 'Fuel_Code_ps',
#        'Latitude_ps', 'Longitude_ps', 'T2M', 'Island', 'Fuel_Code', 'Latitude',
#        'Longitude', 'WD50M', 'WD50M_rad', 'u', 'v', 'Island_wd50m',
#        'Fuel_Code_wd50m', 'Latitude_wd50m', 'Longitude_wd50m', 'WS50M',
#        'Island_ws50m', 'Fuel_Code_ws50m', 'Latitude_ws50m', 'Longitude_ws50m'],
#       dtype='object')
# ['Fuel_Code_wind', 'POC_Code', 'DATE', 'Total_TP', 'Island_wind', 'Latitude_wind', 'Longitude_wind', 'PS', 'Island_ps', 'Fuel_Code_ps', 'Latitude_ps', 'Longitude_ps', 'T2M', 'Island', 'Fuel_Code', 'Latitude', 'Longitude', 'WD50M', 'WD50M_rad', 'u', 'v', 'Island_wd50m', 'Fuel_Code_wd50m', 'Latitude_wd50m', 'Longitude_wd50m', 'WS50M', 'Island_ws50m', 'Fuel_Code_ws50m', 'Latitude_ws50m', 'Longitude_ws50m']

# %%
selected_columns = ['Fuel_Code_wind','POC_Code', 'DATE','Island_wind','Total_TP', 'PS','T2M','WD50M','WD50M_rad','u','v','WS50M']  # Replace with your desired column names

# %%
df_wind_final_all = final_merge[selected_columns].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 df_wind_final_all = final_merge[selected_columns].copy()
# ----> 2 print(df_selected.head())
#
# NameError: name 'df_selected' is not defined

# %%
print(df_wind_final_all.head())
# Out:
#   Fuel_Code_wind POC_Code        DATE Island_wind     Total_TP     PS    T2M  \
# 0           Wind  BPE0331  2015-03-01          NI  472971.4800  99.50  18.88
# 1           Wind  BPE0331  2015-03-02          NI  119485.1800  99.39  18.43
# 2           Wind  BPE0331  2015-03-03          NI  173416.5861  99.24  18.92
# 3           Wind  BPE0331  2015-03-04          NI  127370.3811  98.90  18.34
# 4           Wind  BPE0331  2015-03-05          NI   59379.3772  98.46  19.62
#
#    WD50M  WD50M_rad         u         v  WS50M
# 0  302.2   5.274385  0.532876 -0.846193   5.89
# 1  304.9   5.321509  0.572146 -0.820152   6.52
# 2  302.8   5.284857  0.541708 -0.840567   5.08
# 3  315.5   5.506514  0.713250 -0.700909   4.19
# 4  328.2   5.728171  0.849893 -0.526956   3.64

# %%
# Alternatively, using len():
record_count = len(df_wind_final_all)
print("Record count:", record_count)
# Out:
# Record count: 35020

# %%
# Filter the DataFrame for records with POC_Code 'BPE0331'
df_BPE0331 = df_wind_final_all[df_wind_final_all['POC_Code'] == 'BPE0331'].copy()

# Get the record count
record_count = df_BPE0331.shape[0]
print("Record count for BPE0331:", record_count)
# Out:
# Record count for BPE0331: 3625

# %%
# # 2: Convert DATE columns to datetime (fixing format issues) 
# wind_data['Trading_date'] = pd.to_datetime(wind_data['Trading_date'])
# avg_ps['DATE'] = pd.to_datetime(avg_ps['DATE'])
# avg_t2m['DATE'] = pd.to_datetime(avg_t2m['DATE'], dayfirst=True) 
# avg_wd50m['DATE'] = pd.to_datetime(avg_wd50m['DATE'])
# avg_ws50m['DATE'] = pd.to_datetime(avg_ws50m['DATE'])

# # Rename Trading_date to DATE for merging
# wind_data = wind_data.rename(columns={'Trading_date': 'DATE'})

# wind_data

# %%
# # 3: Merge all datasets on DATE 
# merged_df = wind_data[['DATE', 'Total_TP']    .merge(avg_ps, on='DATE') \
#     .merge(avg_t2m, on='DATE') \
#     .merge(avg_wd50m, on='DATE') \
#     .merge(avg_ws50m, on='DATE')

# %%
# # 3: Merge all datasets on DATE 
# merged_df = wind_data[['DATE', 'Total_TP']] \
#     .merge(avg_ps, on='DATE') \
#     .merge(avg_t2m, on='DATE') \
#     .merge(avg_wd50m, on='DATE') \
#     .merge(avg_ws50m, on='DATE')

# #  4: Set DATE as index 
# merged_df.set_index('DATE', inplace=True)

# # 5: Resample to weekly frequency (mean per week) 
# # Note: resampling handles leap years automatically
# weekly_df = merged_df.resample('W').mean()

# #  Check result 
# print("Weekly data shape:", weekly_df.shape)
# print(weekly_df.head())

# %%
df_BPE0331.head()
# Out:
#   Fuel_Code_wind POC_Code        DATE Island_wind     Total_TP     PS    T2M  \
# 0           Wind  BPE0331  2015-03-01          NI  472971.4800  99.50  18.88
# 1           Wind  BPE0331  2015-03-02          NI  119485.1800  99.39  18.43
# 2           Wind  BPE0331  2015-03-03          NI  173416.5861  99.24  18.92
# 3           Wind  BPE0331  2015-03-04          NI  127370.3811  98.90  18.34
# 4           Wind  BPE0331  2015-03-05          NI   59379.3772  98.46  19.62
#
#    WD50M  WD50M_rad         u         v  WS50M
# 0  302.2   5.274385  0.532876 -0.846193   5.89
# 1  304.9   5.321509  0.572146 -0.820152   6.52
# 2  302.8   5.284857  0.541708 -0.840567   5.08
# 3  315.5   5.506514  0.713250 -0.700909   4.19
# 4  328.2   5.728171  0.849893 -0.526956   3.64

# %%
# Ensure the DATE column is in datetime format
df_BPE0331['DATE'] = pd.to_datetime(df_BPE0331['DATE'])

# Set the DATE column as the index
df_BPE0331.set_index('DATE', inplace=True)

# %%
df_BPE0331
# Out:
#            Fuel_Code_wind POC_Code Island_wind     Total_TP     PS    T2M  \
# DATE
# 2015-03-01           Wind  BPE0331          NI  472971.4800  99.50  18.88
# 2015-03-02           Wind  BPE0331          NI  119485.1800  99.39  18.43
# 2015-03-03           Wind  BPE0331          NI  173416.5861  99.24  18.92
# 2015-03-04           Wind  BPE0331          NI  127370.3811  98.90  18.34
# 2015-03-05           Wind  BPE0331          NI   59379.3772  98.46  19.62
# ...                   ...      ...         ...          ...    ...    ...
# 2025-01-27           Wind  BPE0331          NI  252506.0000  98.62  15.03
# 2025-01-28           Wind  BPE0331          NI   30843.0000  99.76  15.05
# 2025-01-29           Wind  BPE0331          NI  648108.0000  99.17  16.35
# 2025-01-30           Wind  BPE0331          NI  186353.0000  99.31  17.07
# 2025-01-31           Wind  BPE0331          NI   85075.0000  99.59  18.75
#
#             WD50M  WD50M_rad         u         v  WS50M
# DATE
# 2015-03-01  302.2   5.274385  0.532876 -0.846193   5.89
# 2015-03-02  304.9   5.321509  0.572146 -0.820152   6.52
# 2015-03-03  302.8   5.284857  0.541708 -0.840567   5.08
# 2015-03-04  315.5   5.506514  0.713250 -0.700909   4.19
# 2015-03-05  328.2   5.728171  0.849893 -0.526956   3.64
# ...           ...        ...       ...       ...    ...
# 2025-01-27  216.6   3.780383 -0.802817 -0.596225   7.03
# 2025-01-28  325.6   5.682792  0.825113 -0.564967   3.19
# 2025-01-29  304.6   5.316273  0.567844 -0.823136  11.35
# 2025-01-30  305.9   5.338962  0.586372 -0.810042   5.57
# 2025-01-31  296.4   5.173156  0.444635 -0.895712   5.01
#
# [3625 rows x 11 columns]

# %%
# #   7  Plot Total_TP over time (Weekly) 
# plt.figure(figsize=(12, 5))
# plt.plot(df_BPE0331['Total_TP'], label='Daily Wind Energy - BPE0331', marker='o', linestyle='-')
# plt.title('Weekly Wind Renewable Energy Generation (2015–2024)')
# plt.xlabel('Date')
# plt.ylabel('Total_TP - Daily')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.dates as mdates

plt.figure(figsize=(12, 5))
plt.plot(df_BPE0331.index, df_BPE0331['Total_TP'], label='Daily Wind Energy - BPE0331', marker='o', linestyle='-')
plt.title('Weekly Wind Renewable Energy Generation (2015–2024)')
plt.xlabel('Date')
plt.ylabel('Total_TP - Daily')
plt.legend()

# Set x-axis major ticks to every Monday (or adjust as needed)
plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MO, interval=1))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# Auto-format the x-axis labels for readability
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#   8 Correlation matrix using weekly data 
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
corr = df_BPE0331.corr()  # Use weekly_df instead of merged_df
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix (Weekly Data)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 6
#       3 import matplotlib.pyplot as plt
#       5 plt.figure(figsize=(8, 6))
# ----> 6 corr = df_BPE0331.corr()  # Use weekly_df instead of merged_df
#       7 sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
#       8 plt.title('Correlation Matrix (Weekly Data)')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Wind'

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Select only numeric columns
numeric_df = df_BPE0331.select_dtypes(include=[np.number])
corr = numeric_df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix (Weekly Data)')
plt.tight_layout()
plt.show()

# %%
# Select only the needed columns
# Here, we choose Total_TP as the target, and include PS, T2M, WS50M, and the u, v components
df_model = df_BPE0331[['Total_TP', 'PS', 'T2M', 'WS50M', 'u', 'v']].copy()

# Optionally, if you want to create scaled u and v components to include wind speed:
df_model['u_scaled'] = df_model['WS50M'] * df_model['u']
df_model['v_scaled'] = df_model['WS50M'] * df_model['v']

# %%
df_model.head()
# Out:
#                Total_TP     PS    T2M  WS50M         u         v  u_scaled  \
# DATE
# 2015-03-01  472971.4800  99.50  18.88   5.89  0.532876 -0.846193  3.138641
# 2015-03-02  119485.1800  99.39  18.43   6.52  0.572146 -0.820152  3.730391
# 2015-03-03  173416.5861  99.24  18.92   5.08  0.541708 -0.840567  2.751878
# 2015-03-04  127370.3811  98.90  18.34   4.19  0.713250 -0.700909  2.988519
# 2015-03-05   59379.3772  98.46  19.62   3.64  0.849893 -0.526956  3.093609
#
#             v_scaled
# DATE
# 2015-03-01 -4.984078
# 2015-03-02 -5.347390
# 2015-03-03 -4.270078
# 2015-03-04 -2.936810
# 2015-03-05 -1.918119

# %%
df_model_selected = df_model[['Total_TP', 'PS', 'T2M', 'u_scaled', 'v_scaled']].copy()
print(df_model_selected.head())
# Out:
#                Total_TP     PS    T2M  u_scaled  v_scaled
# DATE
# 2015-03-01  472971.4800  99.50  18.88  3.138641 -4.984078
# 2015-03-02  119485.1800  99.39  18.43  3.730391 -5.347390
# 2015-03-03  173416.5861  99.24  18.92  2.751878 -4.270078
# 2015-03-04  127370.3811  98.90  18.34  2.988519 -2.936810
# 2015-03-05   59379.3772  98.46  19.62  3.093609 -1.918119

# %%
plt.figure(figsize=(8, 6))

# Select only numeric columns
#numeric_df = df_BPE0331.select_dtypes(include=[np.number])
corr = df_model_selected.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix (Daily Data)')
plt.tight_layout()
plt.show()

# %%
# Step 1: Ensure DATE is datetime and set as index
df_model_selected['DATE'] = pd.to_datetime(df_model_selected['DATE'])
df_model_selected.set_index('DATE', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Step 1: Ensure DATE is datetime and set as index
# ----> 2 df_model_selected['DATE'] = pd.to_datetime(df_model_selected['DATE'])
#       3 df_model_selected.set_index('DATE', inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'DATE'

# %%
df_model_selected
# Out:
#                Total_TP     PS    T2M  u_scaled  v_scaled
# DATE
# 2015-03-01  472971.4800  99.50  18.88  3.138641 -4.984078
# 2015-03-02  119485.1800  99.39  18.43  3.730391 -5.347390
# 2015-03-03  173416.5861  99.24  18.92  2.751878 -4.270078
# 2015-03-04  127370.3811  98.90  18.34  2.988519 -2.936810
# 2015-03-05   59379.3772  98.46  19.62  3.093609 -1.918119
# ...                 ...    ...    ...       ...       ...
# 2025-01-27  252506.0000  98.62  15.03 -5.643807 -4.191461
# 2025-01-28   30843.0000  99.76  15.05  2.632112 -1.802245
# 2025-01-29  648108.0000  99.17  16.35  6.445027 -9.342598
# 2025-01-30  186353.0000  99.31  17.07  3.266094 -4.511932
# 2025-01-31   85075.0000  99.59  18.75  2.227622 -4.487516
#
# [3625 rows x 5 columns]

# %%
# Plot the target variable (Total_TP) over time
plt.figure(figsize=(12, 5))
plt.plot(df_model_selected.index, df_model_selected['Total_TP'], marker='o', linestyle='-', label='Total_TP')
plt.title('Total Wind Energy Generation Over Time')
plt.xlabel('Date')
plt.ylabel('Total_TP')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Define a function to perform the ADF test for stationarity
def adf_test(series, title=''):
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(), autolag='AIC')
    labels = ['ADF Statistic', 'p-value', '# Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f'{label} : {value}')
    if result[1] <= 0.05:
        print("=> The series is likely stationary (reject H0).")
    else:
        print("=> The series is likely non-stationary (fail to reject H0).")

# %%
# Run the ADF test on Total_TP
adf_test(df_model_selected['Total_TP'], title='Total_TP')
# Out:
# Augmented Dickey-Fuller Test: Total_TP
# ADF Statistic : -21.377341725436125
# p-value : 0.0
# # Lags Used : 4
# Number of Observations Used : 3620
# => The series is likely stationary (reject H0).

# %%
# Let's verify the overall date range:
print("Data range:", df_model_selected.index.min(), "to", df_model_selected.index.max())
# Out:
# Data range: 2015-03-01 00:00:00 to 2025-01-31 00:00:00

# %%
# Define train and test sets based on the date range
train_end = '2024-01-31'
train = df_model_selected.loc[:train_end]
test = df_model_selected.loc['2024-02-01':]

print("Train set:", train.index.min(), "to", train.index.max())
print("Test set:", test.index.min(), "to", test.index.max())
# Out:
# Train set: 2015-03-01 00:00:00 to 2024-01-31 00:00:00
# Test set: 2024-02-01 00:00:00 to 2025-01-31 00:00:00

# %%
# Define target and exogenous variables for both sets.
# Target: Total_TP
# Exogenous: PS, u_scaled, v_scaled
target_train = train['Total_TP']
exog_train = train[['PS', 'u_scaled', 'v_scaled']]

target_test = test['Total_TP']
exog_test = test[['PS', 'u_scaled', 'v_scaled']]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Define and fit the SARIMAX model
model = SARIMAX(target_train, exog=exog_train, order=(1, 0, 1), seasonal_order=(1, 0, 1, 7))
results = model.fit(disp=False)

print(results.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                          Total_TP   No. Observations:                 3259
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 7)   Log Likelihood              -43991.534
# Date:                           Sun, 06 Apr 2025   AIC                          87999.068
# Time:                                   16:19:58   BIC                          88047.782
# Sample:                               03-01-2015   HQIC                         88016.517
#                                     - 01-31-2024
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PS          2552.5673     47.776     53.428      0.000    2458.929    2646.206
# u_scaled    2571.0492    799.843      3.214      0.001    1003.386    4138.712
# v_scaled   -1.904e+04    733.703    -25.947      0.000   -2.05e+04   -1.76e+04
# ar.L1          0.2005      0.042      4.831      0.000       0.119       0.282
# ma.L1          0.2243      0.041      5.431      0.000       0.143       0.305
# ar.S.L7        0.3604      0.950      0.379      0.705      -1.502       2.223
# ma.S.L7       -0.3754      0.944     -0.397      0.691      -2.226       1.476
# sigma2      3.105e+10      0.000   1.54e+14      0.000    3.11e+10    3.11e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               101.53
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.07   Skew:                             0.43
# Prob(H) (two-sided):                  0.24   Kurtosis:                         2.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.29e+29. Standard errors may be unstable.

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
forecast_obj = results.get_forecast(steps=len(test), exog=exog_test)
forecast_values = forecast_obj.predicted_mean
conf_int = forecast_obj.conf_int()

plt.figure(figsize=(12, 6))
plt.plot(train.index, target_train, label='Train', color='blue')
plt.plot(test.index, target_test, label='Test', color='green')
plt.plot(test.index, forecast_values, label='Forecast', color='red')
plt.fill_between(test.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='pink', alpha=0.3)
plt.title('SARIMAX Forecast vs Test Data')
plt.xlabel('Date')
plt.ylabel('Total_TP')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assume 'forecast_values' is the predicted Total_TP for the test set,
# and 'target_test' is the actual Total_TP for the test set.

# Ensure forecast_values and target_test are aligned in order.
actual = target_test.values
predicted = forecast_values.values

# Compute RMSE
rmse = np.sqrt(mean_squared_error(actual, predicted))
# Compute MAE
mae = mean_absolute_error(actual, predicted)
# Compute MAPE (in percentage)
mape = np.mean(np.abs((actual - predicted) / actual)) * 100

print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# RMSE: 179688.80
# MAE: 154659.88
# MAPE: 641.52%

# %%
import pmdarima as pm

# auto_arima can help to identify appropriate orders, including seasonal components.
# We'll include exogenous variables here as well.
auto_model = pm.auto_arima(target_train, exogenous=exog_train,
                           seasonal=True, m=7,  # m=7 for weekly seasonality
                           stepwise=True, trace=True, 
                           error_action='ignore', suppress_warnings=True)

print("auto_arima selected order:", auto_model.order)
print("auto_arima selected seasonal_order:", auto_model.seasonal_order)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=88748.970, Time=3.59 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=89791.177, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=89607.007, Time=0.37 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=89236.420, Time=0.59 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=89789.178, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=88747.974, Time=2.79 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=88747.074, Time=2.12 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=88748.029, Time=2.79 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=88747.950, Time=1.01 sec
#  ARIMA(2,1,1)(0,0,0)[7] intercept   : AIC=88767.132, Time=1.25 sec
#  ARIMA(3,1,2)(0,0,0)[7] intercept   : AIC=88747.061, Time=3.85 sec
#  ARIMA(3,1,2)(1,0,0)[7] intercept   : AIC=88747.697, Time=5.09 sec
#  ARIMA(3,1,2)(0,0,1)[7] intercept   : AIC=88747.715, Time=5.05 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=88750.136, Time=4.89 sec
#  ARIMA(3,1,1)(0,0,0)[7] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(4,1,2)(0,0,0)[7] intercept   : AIC=inf, Time=3.48 sec
#  ARIMA(3,1,3)(0,0,0)[7] intercept   : AIC=inf, Time=3.90 sec
#  ARIMA(2,1,3)(0,0,0)[7] intercept   : AIC=inf, Time=2.03 sec
#  ARIMA(4,1,1)(0,0,0)[7] intercept   : AIC=88751.472, Time=2.04 sec
#  ARIMA(4,1,3)(0,0,0)[7] intercept   : AIC=inf, Time=4.86 sec
#  ARIMA(3,1,2)(0,0,0)[7]             : AIC=88740.435, Time=3.33 sec
#  ARIMA(3,1,2)(1,0,0)[7]             : AIC=inf, Time=5.37 sec
#  ARIMA(3,1,2)(0,0,1)[7]             : AIC=inf, Time=5.73 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=inf, Time=6.26 sec
#  ARIMA(2,1,2)(0,0,0)[7]             : AIC=inf, Time=1.77 sec
#  ARIMA(3,1,1)(0,0,0)[7]             : AIC=inf, Time=1.39 sec
#  ARIMA(4,1,2)(0,0,0)[7]             : AIC=inf, Time=3.92 sec
#  ARIMA(3,1,3)(0,0,0)[7]             : AIC=inf, Time=3.15 sec
#  ARIMA(2,1,1)(0,0,0)[7]             : AIC=inf, Time=1.06 sec
#  ARIMA(2,1,3)(0,0,0)[7]             : AIC=inf, Time=1.67 sec
#  ARIMA(4,1,1)(0,0,0)[7]             : AIC=inf, Time=1.86 sec
#  ARIMA(4,1,3)(0,0,0)[7]             : AIC=inf, Time=4.50 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[7]
# Total fit time: 91.335 seconds
# auto_arima selected order: (3, 1, 2)
# auto_arima selected seasonal_order: (0, 0, 0, 7)

# %%
# --- Fit the Best ARIMA Model (3,1,2)(0,0,0)[7] ---
model = SARIMAX(target_train, order=(3, 1, 2), seasonal_order=(0, 0, 0, 7))
results = model.fit(disp=False)
print(results.summary())

# --- Forecasting ---
# Forecast for the length of the test set
n_steps = len(test)
forecast_obj = results.get_forecast(steps=n_steps)
forecast_values = forecast_obj.predicted_mean
conf_int = forecast_obj.conf_int()

# --- Compute Performance Metrics ---
actual = target_test.values
predicted = forecast_values.values

rmse = np.sqrt(mean_squared_error(actual, predicted))
mae = mean_absolute_error(actual, predicted)
mape = np.mean(np.abs((actual - predicted) / actual)) * 100

print("Forecast Performance Metrics:")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Total_TP   No. Observations:                 3259
# Model:               SARIMAX(3, 1, 2)   Log Likelihood              -44364.217
# Date:                Sun, 06 Apr 2025   AIC                          88740.435
# Time:                        16:28:39   BIC                          88776.968
# Sample:                    03-01-2015   HQIC                         88753.520
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7371      0.294      2.506      0.012       0.161       1.314
# ar.L2         -0.2231      0.135     -1.655      0.098      -0.487       0.041
# ar.L3          0.0779      0.025      3.084      0.002       0.028       0.127
# ma.L1         -1.2583      0.294     -4.275      0.000      -1.835      -0.681
# ma.L2          0.2680      0.290      0.925      0.355      -0.300       0.836
# sigma2      4.307e+10   4.58e-12   9.41e+21      0.000    4.31e+10    4.31e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               122.09
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                             0.34
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.68e+38. Standard errors may be unstable.
# Forecast Performance Metrics:
# RMSE: 224494.85
# MAE: 194716.91
# MAPE: 711.71%
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Create a log-transformed version of Total_TP
df_model_selected['log_Total_TP'] = np.log(df_model_selected['Total_TP'])
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Split the data into training and testing sets
train_end = '2024-01-31'
train = df_model_selected.loc[:train_end]
test = df_model_selected.loc['2024-02-01':]

# Define target variables (in log scale)
target_train = train['log_Total_TP']
target_test = test['log_Total_TP']

# --- Fit SARIMAX on Log-Transformed Series ---
# Use the selected order ARIMA(3,1,2)(0,0,0)[7]
# Disable enforcement of stationarity and invertibility to improve numerical stability
model_log = SARIMAX(target_train, order=(3, 1, 2), seasonal_order=(0, 0, 0, 7),
                    enforce_stationarity=False, enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\nwn86\anaconda3\Lib\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           log_Total_TP   No. Observations:                 3259
# Model:               SARIMAX(3, 1, 2)   Log Likelihood                     nan
# Date:                Sun, 06 Apr 2025   AIC                                nan
# Time:                        16:32:29   BIC                                nan
# Sample:                    03-01-2015   HQIC                               nan
#                          - 01-31-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1               0        nan        nan        nan         nan         nan
# ar.L2               0        nan        nan        nan         nan         nan
# ar.L3               0        nan        nan        nan         nan         nan
# ma.L1               0        nan        nan        nan         nan         nan
# ma.L2               0        nan        nan        nan         nan         nan
# sigma2            nan        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                    nan   Jarque-Bera (JB):                  nan
# Prob(Q):                               nan   Prob(JB):                          nan
# Heteroskedasticity (H):                nan   Skew:                              nan
# Prob(H) (two-sided):                   nan   Kurtosis:                          nan
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix is singular or near-singular, with condition number    nan. Standard errors may be unstable.
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3158: UserWarning: Early subset of data for variable 0 has too few non-missing observations to calculate test statistic.
#   test_statistic, p_value = breakvar_heteroskedasticity_test(
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3158: UserWarning: Later subset of data for variable 0 has too few non-missing observations to calculate test statistic.
#   test_statistic, p_value = breakvar_heteroskedasticity_test(

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Print lengths of forecast and test target
n_steps = len(test)
print("Test set length:", n_steps)

forecast_obj_log = results_log.get_forecast(steps=n_steps)
forecast_log = forecast_obj_log.predicted_mean
conf_int_log = forecast_obj_log.conf_int()

print("Forecast log (first 5 values):")
print(forecast_log.head())

# Check if forecast_log is empty or full of NaNs
if forecast_log.empty or np.isnan(forecast_log).all():
    print("Warning: Forecast returned no valid values.")
else:
    # Back-transform the forecasts and the actual test values
    forecast_original = np.exp(forecast_log)
    target_test_original = np.exp(target_test)
    
    print("Forecast original (first 5 values):")
    print(forecast_original.head())
    print("Target test original (first 5 values):")
    print(target_test_original.head())

    # Create a mask to filter out any NaNs (if present)
    forecast_array = np.array(forecast_original)
    target_array = np.array(target_test_original)
    mask = ~np.isnan(forecast_array) & ~np.isnan(target_array)
    
    # If after masking there are no samples, warn the user.
    if mask.sum() == 0:
        print("Warning: After removing NaNs, no samples remain to compute metrics.")
    else:
        forecast_clean = forecast_array[mask]
        target_clean = target_array[mask]
    
        # Compute performance metrics
        rmse = np.sqrt(mean_squared_error(target_clean, forecast_clean))
        mae = mean_absolute_error(target_clean, forecast_clean)
        mape = np.mean(np.abs((target_clean - forecast_clean) / target_clean)) * 100
    
        print("Forecast Performance Metrics on Original Scale:")
        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")
        print(f"MAPE: {mape:.2f}%")
# Out:
# Test set length: 366
# Forecast log (first 5 values):
# 2024-02-01   NaN
# 2024-02-02   NaN
# 2024-02-03   NaN
# 2024-02-04   NaN
# 2024-02-05   NaN
# Freq: D, Name: predicted_mean, dtype: float64
# Warning: Forecast returned no valid values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Ensure df_model_selected has DATE as datetime index
if 'DATE' in df_model_selected.columns:
    df_model_selected['DATE'] = pd.to_datetime(df_model_selected['DATE'])
    df_model_selected.set_index('DATE', inplace=True)
else:
    df_model_selected.index = pd.to_datetime(df_model_selected.index)

# Create a log-transformed target variable
df_model_selected['log_Total_TP'] = np.log(df_model_selected['Total_TP'])

# Check for infinite values in log_Total_TP
inf_count = np.isinf(df_model_selected['log_Total_TP']).sum()
print("Infinite values in log_Total_TP before cleaning:", inf_count)

# Remove rows with non-finite log_Total_TP values
df_model_clean = df_model_selected[np.isfinite(df_model_selected['log_Total_TP'])].copy()
print("Data range after cleaning:", df_model_clean.index.min(), "to", df_model_clean.index.max())

# Split the data into train and test sets (using the cleaned DataFrame)
train_end = '2024-01-31'
train = df_model_clean.loc[:train_end]
test = df_model_clean.loc['2024-02-01':]

print("Train set:", train.index.min(), "to", train.index.max())
print("Test set:", test.index.min(), "to", test.index.max())

# Define target variables (in log scale)
target_train = train['log_Total_TP']
target_test = test['log_Total_TP']

# --- Fit SARIMAX on Log-Transformed Series ---
# Using ARIMA(3,1,2)(0,0,0)[7] with stationarity/invertibility enforcement disabled
model_log = SARIMAX(target_train, order=(3, 1, 2), seasonal_order=(0, 0, 0, 7),
                    enforce_stationarity=False, enforce_invertibility=False, missing='drop')
results_log = model_log.fit(method='lbfgs', disp=False)
print(results_log.summary())

# Check fitted values on training set
print("Fitted values (first 5):")
print(results_log.fittedvalues.head())

# --- Forecasting ---
n_steps = len(test)
forecast_obj_log = results_log.get_forecast(steps=n_steps)
forecast_log = forecast_obj_log.predicted_mean
conf_int_log = forecast_obj_log.conf_int()

print("Forecast log (first 5):")
print(forecast_log.head())

# If forecast_log contains valid numbers, back-transform to the original scale
if forecast_log.isnull().all():
    print("Warning: Forecast still returns NaN values.")
else:
    forecast_original = np.exp(forecast_log)
    target_test_original = np.exp(target_test)
    
    # Compute performance metrics
    rmse = np.sqrt(mean_squared_error(target_test_original, forecast_original))
    mae = mean_absolute_error(target_test_original, forecast_original)
    mape = np.mean(np.abs((target_test_original - forecast_original) / target_test_original)) * 100

    print("Forecast Performance Metrics on Original Scale:")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"MAPE: {mape:.2f}%")

    # --- Plotting ---
    plt.figure(figsize=(12,6))
    plt.plot(train.index, np.exp(train['log_Total_TP']), label='Train', color='blue')
    plt.plot(test.index, target_test_original, label='Test', color='green')
    plt.plot(test.index, forecast_original, label='Forecast', color='red')
    lower_bound = np.exp(conf_int_log.iloc[:, 0])
    upper_bound = np.exp(conf_int_log.iloc[:, 1])
    plt.fill_between(test.index, lower_bound, upper_bound, color='pink', alpha=0.3)
    plt.title("SARIMAX Forecast vs Test Data (Log Transformation)")
    plt.xlabel("Date")
    plt.ylabel("Total_TP")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Infinite values in log_Total_TP before cleaning: 2
# Data range after cleaning: 2015-03-01 00:00:00 to 2025-01-31 00:00:00
# Train set: 2015-03-01 00:00:00 to 2024-01-31 00:00:00
# Test set: 2024-02-01 00:00:00 to 2025-01-31 00:00:00
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           log_Total_TP   No. Observations:                 3257
# Model:               SARIMAX(3, 1, 2)   Log Likelihood               -5101.122
# Date:                Sun, 06 Apr 2025   AIC                          10214.244
# Time:                        16:36:18   BIC                          10250.768
# Sample:                             0   HQIC                         10227.327
#                                - 3257
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8725      0.210      4.155      0.000       0.461       1.284
# ar.L2         -0.2722      0.094     -2.910      0.004      -0.455      -0.089
# ar.L3          0.0834      0.019      4.441      0.000       0.047       0.120
# ma.L1         -1.4243      0.210     -6.768      0.000      -1.837      -1.012
# ma.L2          0.4250      0.210      2.023      0.043       0.013       0.837
# sigma2         1.3447      0.021     64.909      0.000       1.304       1.385
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4229.51
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.19   Skew:                            -1.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Fitted values (first 5):
# DATE
# 2015-03-01     0.000000
# 2015-03-02    18.767387
# 2015-03-03     9.320918
# 2015-03-04    13.099399
# 2015-03-05    11.270945
# dtype: float64
# Forecast log (first 5):
# 3257    11.926555
# 3258    12.113527
# 3259    12.132171
# 3260    12.117752
# 3261    12.115691
# Name: predicted_mean, dtype: float64
# Forecast Performance Metrics on Original Scale:
# RMSE: 250606.81
# MAE: 196858.13
# MAPE: nan%
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# C:\Users\nwn86\AppData\Local\Temp\ipykernel_588\1701081361.py:67: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape = np.mean(np.abs((target_test_original - forecast_original) / target_test_original)) * 100

# %%
import numpy as np

# Check for zeros in the actual test target values
zero_count = (target_test_original == 0).sum()
print("Number of zeros in the actual test target:", zero_count)

# Option 1: Add a small epsilon to avoid division by zero
epsilon = 1e-10
mape_adjusted = np.mean(np.abs((target_test_original - forecast_original) / (target_test_original + epsilon))) * 100
print(f"Adjusted MAPE: {mape_adjusted:.2f}%")

# Option 2: Compute MAPE only for non-zero actual values
non_zero_mask = target_test_original != 0
if non_zero_mask.sum() > 0:
    mape_non_zero = np.mean(np.abs((target_test_original[non_zero_mask] - forecast_original[non_zero_mask]) / target_test_original[non_zero_mask])) * 100
    print(f"MAPE (non-zero actuals): {mape_non_zero:.2f}%")
else:
    print("No non-zero actual values available to compute MAPE.")
# Out:
# Number of zeros in the actual test target: 0
# Adjusted MAPE: nan%
# C:\Users\nwn86\AppData\Local\Temp\ipykernel_588\1217050692.py:9: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape_adjusted = np.mean(np.abs((target_test_original - forecast_original) / (target_test_original + epsilon))) * 100
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[121], line 15
#      13 non_zero_mask = target_test_original != 0
#      14 if non_zero_mask.sum() > 0:
# ---> 15     mape_non_zero = np.mean(np.abs((target_test_original[non_zero_mask] - forecast_original[non_zero_mask]) / target_test_original[non_zero_mask])) * 100
#      16     print(f"MAPE (non-zero actuals): {mape_non_zero:.2f}%")
#      17 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1149, in Series.__getitem__(self, key)
#    1146     return self._getitem_slice(key)
#    1148 if com.is_bool_indexer(key):
# -> 1149     key = check_bool_indexer(self.index, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2662, in check_bool_indexer(index, key)
#    2660 indexer = result.index.get_indexer_for(index)
#    2661 if -1 in indexer:
# -> 2662     raise IndexingError(
#    2663         "Unalignable boolean Series provided as "
#    2664         "indexer (index of the boolean Series and of "
#    2665         "the indexed object do not match)."
#    2666     )
#    2668 result = result.take(indexer)
#    2670 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
#   9 Plot each climate factor (weekly) 
factors = ['Avg_PS', 'Avg_T2M', 'Avg_WD50M', 'Avg_WS50M']

for factor in factors:
    plt.figure(figsize=(12, 4))
    plt.plot(weekly_df[factor], label=factor, marker='o', linestyle='-')
    plt.title(f'{factor} Over Time (Weekly Mean)')
    plt.xlabel('Date')
    plt.ylabel(factor)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# 10: Augmented Dickey-Fuller (ADF) Test on weekly data 
print("\nAugmented Dickey-Fuller Test on 'Total_TP' (Weekly):")
adf_result = adfuller(weekly_df['Total_TP'].dropna())

print(f'ADF Statistic: {adf_result[0]}')
print(f'p-value: {adf_result[1]}')
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'   {key}: {value}')

# %% [markdown]
# ADF Statistic (-1.1871) is higher than the critical value (-2.8672 at 5%), Since fail to reject the null hypothesis, meaning the series likely has a trend or other non-stationary behavior.
#
# And the p-value (0.6791) is more greater than 0.05. A high p-value (> 0.05) suggests that the null hypothesis cannot be rejected, confirming that the time series is non-stationary.
#
# So the next step is "Differencing the Time Series"

# %%
weekly_diff = weekly_df['Total_TP'].diff().dropna()

# %%
from statsmodels.tsa.stattools import adfuller

print("\nADF Test on Differenced Weekly 'Total_TP':")
adf_result = adfuller(weekly_diff)

print(f"ADF Statistic: {adf_result[0]}")
print(f"p-value: {adf_result[1]}")
print("Critical Values:")
for key, value in adf_result[4].items():
    print(f"   {key}: {value}")

# %% [markdown]
# The ADF Statistic (-12.84) is much lower than the critical value (-2.8672)
# Now we can proceed with time series modeling since the data is stationary

# %%
# Make sure DATE is datetime and set as index (already handled during resampling)
# weekly_df should already have date time index after resampling

#  Split weekly data by date 
train = weekly_df[:'2023-12-31']
test = weekly_df['2024-01-01':]

#  Define exogenous variables 
exog_vars = ['Avg_PS', 'Avg_T2M', 'Avg_WD50M', 'Avg_WS50M']
exog_train = train[exog_vars]
exog_test = test[exog_vars]

#  Define target variable 
y_train = train['Total_TP']
y_test = test['Total_TP']

#  Print shapes 
print("Train shape:", train.shape)
print("Test shape:", test.shape)

# %%
from pmdarima import auto_arima


auto_model = auto_arima(y_train,
                        exogenous=exog_train,
                        seasonal=True,
                        m=7,  # weekly seasonality (cycle every 7 weeks)
                        trace=True,
                        stepwise=True)

print(auto_model.summary())

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMAX model with best parameters
model = SARIMAX(y_train,
                exog=exog_train,
                order=(2, 1, 3),
                seasonal_order=(2, 0, 1, 7),
                enforce_stationarity=False,
                enforce_invertibility=False)

results = model.fit(disp=False)
print(results.summary())

# %%
forecast = results.predict(start=test.index[0],
                           end=test.index[-1],
                           exog=exog_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(y_test.index, y_test, label='Actual', linewidth=2)
plt.plot(forecast.index, forecast, label='Forecast', linestyle='--')
plt.title('Weekly Forecast vs Actual Wind Energy (2024)')
plt.xlabel('Date')
plt.ylabel('Total_TP (Wind Energy)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, forecast)
rmse = np.sqrt(mean_squared_error(y_test, forecast))

print(f"MAE: {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")

# %% [markdown]
# remove not much needed climate factors and re-model with suitable climate factors along with correlation matrix

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

#Prepare exogenous variables
exog_vars = ['Avg_WS50M', 'Avg_WD50M']

# Add weekly index
weekly_df.index = pd.to_datetime(weekly_df.index)

# Split train/test 
train = weekly_df[:'2023-12-31']
test = weekly_df['2024-01-01':]

y_train = train['Total_TP']
y_test = test['Total_TP']

exog_train_raw = train[exog_vars]
exog_test_raw = test[exog_vars]

# Normalize exogenous variables
scaler = StandardScaler()

exog_train = pd.DataFrame(scaler.fit_transform(exog_train_raw),
                          columns=exog_vars, index=exog_train_raw.index)

exog_test = pd.DataFrame(scaler.transform(exog_test_raw),
                         columns=exog_vars, index=exog_test_raw.index)

# %%
#  auto_arima to find best order
auto_model = auto_arima(y_train,
                        exogenous=exog_train,
                        seasonal=True,
                        m=7,  
                        trace=True,
                        stepwise=True,
                        suppress_warnings=True)

# %%
# Fit SARIMAX model using best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order

model = SARIMAX(y_train,
                exog=exog_train,
                order=best_order,
                seasonal_order=best_seasonal_order,
                enforce_stationarity=False,
                enforce_invertibility=False)

results = model.fit(disp=False)
print(results.summary())

# Forecast for test period (2024)
forecast = results.predict(start=y_test.index[0],
                           end=y_test.index[-1],
                           exog=exog_test)

# Evaluate performance
mae = mean_absolute_error(y_test, forecast)
rmse = np.sqrt(mean_squared_error(y_test, forecast))

print(f"MAE: {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")


# Plot predict vs actual 
plt.figure(figsize=(14, 6))
plt.plot(y_test.index, y_test, label='Actual', linewidth=2)
plt.plot(forecast.index, forecast, label='Forecast', linestyle='--')
plt.title('Forecast vs Actual Wind Energy (2024)\nUsing Avg_WS50M & Avg_WD50M')
plt.xlabel('Date')
plt.ylabel('Total_TP (Wind Energy)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Here added Feature Engineering part

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# --- Step 1: Feature Engineering ---
weekly_df['WS50M_lag1'] = weekly_df['Avg_WS50M'].shift(1)
weekly_df['WD50M_lag1'] = weekly_df['Avg_WD50M'].shift(1)
weekly_df['WS50M_rolling3'] = weekly_df['Avg_WS50M'].rolling(3).mean()
weekly_df.dropna(inplace=True)

# --- Step 2: Prepare exogenous variables ---
exog_vars = ['Avg_WS50M', 'Avg_WD50M', 'WS50M_lag1', 'WD50M_lag1', 'WS50M_rolling3']

# --- Step 3: Set index to datetime ---
weekly_df.index = pd.to_datetime(weekly_df.index)

# --- Step 4: Split into train and test ---
train = weekly_df[:'2023-12-31']
test = weekly_df['2024-01-01':]

y_train = train['Total_TP']
y_test = test['Total_TP']

exog_train_raw = train[exog_vars]
exog_test_raw = test[exog_vars]

# --- Step 5: Normalize exogenous variables ---
scaler = StandardScaler()
exog_train = pd.DataFrame(scaler.fit_transform(exog_train_raw),
                          columns=exog_vars, index=exog_train_raw.index)
exog_test = pd.DataFrame(scaler.transform(exog_test_raw),
                         columns=exog_vars, index=exog_test_raw.index)

# %%
# Fit the SARIMAX model with best parameters
model = SARIMAX(y_train,
                exog=exog_train,
                order=(2, 1, 3),
                seasonal_order=(2, 0, 1, 7),
                enforce_stationarity=False,
                enforce_invertibility=False)

results = model.fit(disp=False)
print(results.summary())

# %%
# --- Step 8: Forecast ---
forecast = results.predict(start=y_test.index[0],
                           end=y_test.index[-1],
                           exog=exog_test)

# --- Step 9: Evaluate ---
mae = mean_absolute_error(y_test, forecast)
rmse = np.sqrt(mean_squared_error(y_test, forecast))

print(f"\n✅ MAE: {mae:,.2f}")
print(f"✅ RMSE: {rmse:,.2f}")

# --- Step 10: Plot Actual vs Forecast ---
plt.figure(figsize=(14, 6))
plt.plot(y_test.index, y_test, label='Actual', linewidth=2)
plt.plot(forecast.index, forecast, label='Forecast', linestyle='--', color='orange')
plt.title('Forecast vs Actual Wind Energy (2024)\nUsing Avg_WS50M, Avg_WD50M, Lags & Rolling Mean')
plt.xlabel('Date')
plt.ylabel('Total_TP (Wind Energy)')
plt.legend()
plt.tight_layout()
plt.show()
