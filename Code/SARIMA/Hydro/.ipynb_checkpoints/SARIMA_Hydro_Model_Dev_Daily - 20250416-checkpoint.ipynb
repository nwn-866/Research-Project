# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pmdarima as pm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Input data processing for Exploratory Data Analysis (EDA)

# %%
# 1: Load all datasets for hydro
hydro_energy = pd.read_csv('hydro_data.csv')
daily_all_nsp_evland = pd.read_csv('Hydro_Factor_Daily_EVLAND.csv')
daily_all_nsp_gwetprof = pd.read_csv('Hydro_Factor_Daily_GWETPROF.csv')
daily_all_nsp_prectotcorr = pd.read_csv('Hydro_Factor_Daily_PRECTOTCORR.csv')
daily_all_nsp_rh2m = pd.read_csv('Hydro_Factor_Daily_RH2M.csv')
daily_all_nsp_t2m = pd.read_csv('Hydro_Factor_Daily_T2M.csv')

# %%
hydro_energy.tail()
# Out:
#        Fuel_Code POC_Code        DATE   Total_TP Island   Latitude   Longitude
# 132197     Hydro  WTK0111  2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111  2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111  2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111  2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111  2025-01-31  1610301.0     SI -44.692099  170.429029

# %%
daily_all_nsp_evland.head()
# Out:
#          DATE POC_Code  EVLAND
# 0  2015-01-01  ARA2201    4.03
# 1  2015-01-02  ARA2201    1.94
# 2  2015-01-03  ARA2201    2.24
# 3  2015-01-04  ARA2201    1.54
# 4  2015-01-05  ARA2201    1.95

# %%
# daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')

# %%
print("------------hydro_energy----------------------")
print(hydro_energy.head())
print("----------------------------------------------")
print(hydro_energy.dtypes)
print("----------------------------------------------")
print("------------daily_all_nsp_evland--------------")
print(daily_all_nsp_evland.head())
print("----------------------------------------------")
print(daily_all_nsp_evland.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_gwetprof-----------")
print(daily_all_nsp_gwetprof.head())
print("----------------------------------------------")
print(daily_all_nsp_gwetprof.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_prectotcorr--------")
print(daily_all_nsp_prectotcorr.head())
print("----------------------------------------------")
print(daily_all_nsp_prectotcorr.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_rh2m---------------")
print(daily_all_nsp_rh2m.head())
print("----------------------------------------------")
print(daily_all_nsp_rh2m.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_t2m----------------")
print(daily_all_nsp_t2m.head())
print("----------------------------------------------")
print(daily_all_nsp_t2m.dtypes)
print("----------------------------------------------")
# Out:
# ------------hydro_energy----------------------
#   Fuel_Code POC_Code        DATE  Total_TP Island   Latitude   Longitude
# 0     Hydro  ARA2201  2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201  2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201  2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201  2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201  2015-03-05  891070.0     NI -38.615891  176.143036
# ----------------------------------------------
# Fuel_Code     object
# POC_Code      object
# DATE          object
# Total_TP     float64
# Island        object
# Latitude     float64
# Longitude    float64
# dtype: object
# ----------------------------------------------
# ------------daily_all_nsp_evland--------------
#          DATE POC_Code  EVLAND
# 0  2015-01-01  ARA2201    4.03
# 1  2015-01-02  ARA2201    1.94
# 2  2015-01-03  ARA2201    2.24
# 3  2015-01-04  ARA2201    1.54
# 4  2015-01-05  ARA2201    1.95
# ----------------------------------------------
# DATE         object
# POC_Code     object
# EVLAND      float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_gwetprof-----------
#          DATE POC_Code  GWETPROF
# 0  2015-01-01  ARA2201      0.26
# 1  2015-01-02  ARA2201      0.25
# 2  2015-01-03  ARA2201      0.25
# 3  2015-01-04  ARA2201      0.24
# 4  2015-01-05  ARA2201      0.24
# ----------------------------------------------
# DATE         object
# POC_Code     object
# GWETPROF    float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_prectotcorr--------
#          DATE POC_Code  PRECTOTCORR
# 0  2015-01-01  ARA2201         2.26
# 1  2015-01-02  ARA2201         0.00
# 2  2015-01-03  ARA2201         0.00
# 3  2015-01-04  ARA2201         0.00
# 4  2015-01-05  ARA2201         0.00
# ----------------------------------------------
# DATE            object
# POC_Code        object
# PRECTOTCORR    float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_rh2m---------------
#          DATE POC_Code   RH2M
# 0  2015-01-01  ARA2201  62.17
# 1  2015-01-02  ARA2201  64.52
# 2  2015-01-03  ARA2201  60.84
# 3  2015-01-04  ARA2201  68.73
# 4  2015-01-05  ARA2201  63.03
# ----------------------------------------------
# DATE         object
# POC_Code     object
# RH2M        float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_t2m----------------
#          DATE POC_Code    T2M
# 0  2015-01-01  ARA2201  18.22
# 1  2015-01-02  ARA2201  17.36
# 2  2015-01-03  ARA2201  19.23
# 3  2015-01-04  ARA2201  19.02
# 4  2015-01-05  ARA2201  19.26
# ----------------------------------------------
# DATE         object
# POC_Code     object
# T2M         float64
# dtype: object
# ----------------------------------------------

# %%
# Date coversion
#daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')

hydro_energy['DATE'] = pd.to_datetime(hydro_energy['DATE'], format='%Y-%m-%d')
daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')
daily_all_nsp_gwetprof['DATE'] = pd.to_datetime(daily_all_nsp_gwetprof['DATE'], format='%Y-%m-%d')
daily_all_nsp_prectotcorr['DATE'] = pd.to_datetime(daily_all_nsp_prectotcorr['DATE'],  format='%Y-%m-%d')
daily_all_nsp_rh2m['DATE'] = pd.to_datetime(daily_all_nsp_rh2m['DATE'],  format='%Y-%m-%d')
daily_all_nsp_t2m['DATE'] = pd.to_datetime(daily_all_nsp_t2m['DATE'], format='%Y-%m-%d')

# %%
print("------------hydro_energy----------------------")
print(hydro_energy.head())
print("----------------------------------------------")
print(hydro_energy.dtypes)
print("----------------------------------------------")
print("------------daily_all_nsp_evland--------------")
print(daily_all_nsp_evland.head())
print("----------------------------------------------")
print(daily_all_nsp_evland.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_gwetprof-----------")
print(daily_all_nsp_gwetprof.head())
print("----------------------------------------------")
print(daily_all_nsp_gwetprof.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_prectotcorr--------")
print(daily_all_nsp_prectotcorr.head())
print("----------------------------------------------")
print(daily_all_nsp_prectotcorr.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_rh2m---------------")
print(daily_all_nsp_rh2m.head())
print("----------------------------------------------")
print(daily_all_nsp_rh2m.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_t2m----------------")
print(daily_all_nsp_t2m.head())
print("----------------------------------------------")
print(daily_all_nsp_t2m.dtypes)
print("----------------------------------------------")
# Out:
# ------------hydro_energy----------------------
#   Fuel_Code POC_Code       DATE  Total_TP Island   Latitude   Longitude
# 0     Hydro  ARA2201 2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201 2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201 2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201 2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201 2015-03-05  891070.0     NI -38.615891  176.143036
# ----------------------------------------------
# Fuel_Code            object
# POC_Code             object
# DATE         datetime64[ns]
# Total_TP            float64
# Island               object
# Latitude            float64
# Longitude           float64
# dtype: object
# ----------------------------------------------
# ------------daily_all_nsp_evland--------------
#         DATE POC_Code  EVLAND
# 0 2015-01-01  ARA2201    4.03
# 1 2015-01-02  ARA2201    1.94
# 2 2015-01-03  ARA2201    2.24
# 3 2015-01-04  ARA2201    1.54
# 4 2015-01-05  ARA2201    1.95
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# EVLAND             float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_gwetprof-----------
#         DATE POC_Code  GWETPROF
# 0 2015-01-01  ARA2201      0.26
# 1 2015-01-02  ARA2201      0.25
# 2 2015-01-03  ARA2201      0.25
# 3 2015-01-04  ARA2201      0.24
# 4 2015-01-05  ARA2201      0.24
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# GWETPROF           float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_prectotcorr--------
#         DATE POC_Code  PRECTOTCORR
# 0 2015-01-01  ARA2201         2.26
# 1 2015-01-02  ARA2201         0.00
# 2 2015-01-03  ARA2201         0.00
# 3 2015-01-04  ARA2201         0.00
# 4 2015-01-05  ARA2201         0.00
# ----------------------------------------------
# DATE           datetime64[ns]
# POC_Code               object
# PRECTOTCORR           float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_rh2m---------------
#         DATE POC_Code   RH2M
# 0 2015-01-01  ARA2201  62.17
# 1 2015-01-02  ARA2201  64.52
# 2 2015-01-03  ARA2201  60.84
# 3 2015-01-04  ARA2201  68.73
# 4 2015-01-05  ARA2201  63.03
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# RH2M               float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_t2m----------------
#         DATE POC_Code    T2M
# 0 2015-01-01  ARA2201  18.22
# 1 2015-01-02  ARA2201  17.36
# 2 2015-01-03  ARA2201  19.23
# 3 2015-01-04  ARA2201  19.02
# 4 2015-01-05  ARA2201  19.26
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# T2M                float64
# dtype: object
# ----------------------------------------------

# %%
# # format date column
# wind_energy['DATE'] = pd.to_datetime(wind_energy['DATE'])
# daily_all_nsp_ps['DATE'] = pd.to_datetime(daily_all_nsp_ps['DATE'])
# # daily_all_nsp_wd50m['DATE'] = pd.to_datetime(daily_all_nsp_wd50m['DATE'])
# daily_all_nsp_t2m['DATE'] = pd.to_datetime(daily_all_nsp_t2m['DATE'])
# daily_all_nsp_ws50m['DATE'] = pd.to_datetime(daily_all_nsp_ws50m['DATE'])

# %%
# Get list of POC codes to load
unique_pocs_hydro = hydro_energy['POC_Code'].unique()
# unique_pocs_hydro = hydro_energy['POC_Code'].unique()

# %%
print(unique_pocs_hydro)
print(len(unique_pocs_hydro))
print(len(hydro_energy))
print("Min DATE:", hydro_energy['DATE'].min())
print("Max DATE:", hydro_energy['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 132202
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00

# %%
hydro_energy.tail()
# Out:
#        Fuel_Code POC_Code       DATE   Total_TP Island   Latitude   Longitude
# 132197     Hydro  WTK0111 2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111 2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111 2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111 2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111 2025-01-31  1610301.0     SI -44.692099  170.429029

# %%
# Get list of POC codes to load
unique_pocs_evland = daily_all_nsp_evland['POC_Code'].unique()

# %%
print(unique_pocs_evland)
print(len(unique_pocs_evland))
print(len(daily_all_nsp_evland))
print("Min DATE:", daily_all_nsp_evland['DATE'].min())
print("Max DATE:", daily_all_nsp_evland['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to load
unique_pocs_gwetprof = daily_all_nsp_gwetprof['POC_Code'].unique()
print(unique_pocs_gwetprof)
print(len(unique_pocs_gwetprof))
print(len(daily_all_nsp_gwetprof))
print("Min DATE:", daily_all_nsp_gwetprof['DATE'].min())
print("Max DATE:", daily_all_nsp_gwetprof['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to load
unique_pocs_prectotcorr = daily_all_nsp_prectotcorr['POC_Code'].unique()
print(unique_pocs_prectotcorr)
print(len(unique_pocs_prectotcorr))
print(len(daily_all_nsp_prectotcorr))
print("Min DATE:", daily_all_nsp_prectotcorr['DATE'].min())
print("Max DATE:", daily_all_nsp_prectotcorr['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to load
unique_pocs_rh2m = daily_all_nsp_rh2m['POC_Code'].unique()
print(unique_pocs_rh2m)
print(len(unique_pocs_rh2m))
print(len(daily_all_nsp_rh2m))
print("Min DATE:", daily_all_nsp_rh2m['DATE'].min())
print("Max DATE:", daily_all_nsp_rh2m['DATE'].max())

# print(daily_all_nsp_rh2m.dtypes)
# print("----------------------------------------------")
# print("-------------daily_all_nsp_t2m----------------")
# print(daily_all_nsp_t2m.head())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to load
unique_pocs_t2m = daily_all_nsp_t2m['POC_Code'].unique()
print(unique_pocs_t2m)
print(len(unique_pocs_t2m))
print(len(daily_all_nsp_t2m))
print("Min DATE:", daily_all_nsp_t2m['DATE'].min())
print("Max DATE:", daily_all_nsp_t2m['DATE'].max())

# print(daily_all_nsp_rh2m.dtypes)
# print("----------------------------------------------")
# print("-------------daily_all_nsp_t2m----------------")
# print(daily_all_nsp_t2m.head())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# 2. Filter data between 2015-01-01 and 2024-12-31
filtered_nsp_t2m = daily_all_nsp_t2m[(daily_all_nsp_t2m['DATE'] >= '2015-03-01') & (daily_all_nsp_t2m['DATE'] < '2025-02-01')]
filtered_nsp_evland = daily_all_nsp_evland[(daily_all_nsp_evland['DATE'] >= '2015-03-01') & (daily_all_nsp_evland['DATE'] < '2025-02-01')]
filtered_nsp_gwetprof = daily_all_nsp_gwetprof[(daily_all_nsp_gwetprof['DATE'] >= '2015-03-01') & (daily_all_nsp_gwetprof['DATE'] < '2025-02-01')]
filtered_nsp_prectotcorr = daily_all_nsp_prectotcorr[(daily_all_nsp_prectotcorr['DATE'] >= '2015-03-01') & (daily_all_nsp_prectotcorr['DATE'] < '2025-02-01')]
filtered_nsp_rh2m = daily_all_nsp_rh2m[(daily_all_nsp_rh2m['DATE'] >= '2015-03-01') & (daily_all_nsp_rh2m['DATE'] < '2025-02-01')]


# daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')
# daily_all_nsp_gwetprof['DATE'] = pd.to_datetime(daily_all_nsp_gwetprof['DATE'], format='%Y-%m-%d')
# daily_all_nsp_prectotcorr['DATE'] = pd.to_datetime(daily_all_nsp_prectotcorr['DATE'],  format='%Y-%m-%d')
# daily_all_nsp_rh2m['DATE'] = pd.to_datetime(daily_all_nsp_rh2m['DATE'],  format='%Y-%m-%d')
# daily_all_nsp_t2m['DATE'] = pd.to_datetime(daily_all_nsp_t2m['DATE'], format='%Y-%m-%d')

# %%
print(len(filtered_nsp_t2m))
print("Min DATE:", filtered_nsp_t2m['DATE'].min())
print("Max DATE:", filtered_nsp_t2m['DATE'].max())
print(len(filtered_nsp_prectotcorr))
print("Min DATE:", filtered_nsp_prectotcorr['DATE'].min())
print("Max DATE:", filtered_nsp_prectotcorr['DATE'].max())
# Out:
# 137750
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00
# 137750
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00

# %%
filtered_nsp_t2m
# Out:
#              DATE POC_Code    T2M
# 59     2015-03-01  ARA2201  19.11
# 60     2015-03-02  ARA2201  19.03
# 61     2015-03-03  ARA2201  18.00
# 62     2015-03-04  ARA2201  16.43
# 63     2015-03-05  ARA2201  18.74
# ...           ...      ...    ...
# 141023 2025-01-27  WTK0111  10.90
# 141024 2025-01-28  WTK0111  14.74
# 141025 2025-01-29  WTK0111  17.65
# 141026 2025-01-30  WTK0111  14.05
# 141027 2025-01-31  WTK0111  15.41
#
# [137750 rows x 3 columns]

# %%
record_counts_new = filtered_nsp_t2m.groupby('POC_Code').size()
print(record_counts_new)
# Out:
# POC_Code
# ARA2201    3625
# ARG1101    3625
# ARI1101    3625
# ARI1102    3625
# ASB0661    3625
# ATI2201    3625
# AVI2201    3625
# BEN2202    3625
# BWK1101    3625
# COL0661    3625
# CYD0331    3625
# CYD2201    3625
# HWA1101    3625
# HWB0331    3625
# KPO1101    3625
# MAN2201    3625
# MAT1101    3625
# MHO0331    3625
# MTI2201    3625
# NSY0331    3625
# OHA2201    3625
# OHB2201    3625
# OHC2201    3625
# OHK2201    3625
# ROT1101    3625
# ROX1101    3625
# ROX2201    3625
# RPO2201    3625
# STK0661    3625
# TGA0331    3625
# TKA0111    3625
# TKB2201    3625
# TKU2201    3625
# TUI1101    3625
# WKM2201    3625
# WPA2201    3625
# WPG0331    3625
# WTK0111    3625
# dtype: int64

# %%
record_counts_hydro = hydro_energy.groupby('POC_Code').size()
print(record_counts_hydro)
# Out:
# POC_Code
# ARA2201    3625
# ARG1101    3625
# ARI1101    3625
# ARI1102    3625
# ASB0661    3614
# ATI2201    3625
# AVI2201    3625
# BEN2202    3625
# BWK1101    3625
# COL0661    3625
# CYD0331    1858
# CYD2201    3625
# HWA1101    3625
# HWB0331    1858
# KPO1101    3625
# MAN2201    3625
# MAT1101    3612
# MHO0331    3625
# MTI2201    3625
# NSY0331    3625
# OHA2201    3625
# OHB2201    3625
# OHC2201    3625
# OHK2201    3625
# ROT1101    3625
# ROX1101    3625
# ROX2201    3625
# RPO2201    3625
# STK0661    1858
# TGA0331    3412
# TKA0111    3625
# TKB2201    3625
# TKU2201    3625
# TUI1101    3625
# WKM2201    3625
# WPA2201    3625
# WPG0331    3615
# WTK0111    3625
# dtype: int64

# %%
# # # 3. Function to extract unique (POC_Code, YearMonth) combinations as a set of tuples
# def get_poc_yearmonth(df):
#     return set(df[['POC_Code', 'DATE']].apply(lambda row: (row['POC_Code'], row['DATE']), axis=1))

# # # Extract unique combinations from each DataFrame
# hydro_energy_combos = get_poc_yearmonth(hydro_energy)
# evland_combos = get_poc_yearmonth(daily_all_nsp_evland)
# # t2m_combos = get_poc_yearmonth(daily_all_nsp_t2m)
# # wd50m_combos = get_poc_yearmonth(daily_all_nsp_wd50m)
# # ws50m_combos = get_poc_yearmonth(daily_all_nsp_ws50m)

# # # 4. Find the common combinations across all five DataFrames
# common_combos = hydro_energy_combos & evland_combos #& t2m_combos & wd50m_combos & ws50m_combos

# print("Number of common (POC_Code, YearMonth) combinations:", len(common_combos))
# print("Sample common combinations:", list(common_combos)[:10])  # print a sample

# # # 5. Check for extra combinations in each DataFrame that are not in the common set
# print("Extra in hydro_energy:", hydro_energy_combos - common_combos)
# print("Extra in daily_all_nsp_evland:", evland_combos - common_combos)
# # print("Extra in Daily NSP T2M:", t2m_combos - common_combos)
# # print("Extra in Daily NSP WD50M:", wd50m_combos - common_combos)
# # print("Extra in Daily NSP WS50M:", ws50m_combos - common_combos)

# %%
# hydro_energy['DATE'] = pd.to_datetime(hydro_energy['DATE'], format='%Y-%m-%d')
# filtered_nsp_t2m = daily_all_nsp_t2m[(daily_all_nsp_t2m['DATE'] >= '2015-03-01') & (daily_all_nsp_t2m['DATE'] < '2025-02-01')]
# filtered_nsp_evland = daily_all_nsp_evland[(daily_all_nsp_evland['DATE'] >= '2015-03-01') & (daily_all_nsp_evland['DATE'] < '2025-02-01')]
# filtered_nsp_gwetprof = daily_all_nsp_gwetprof[(daily_all_nsp_gwetprof['DATE'] >= '2015-03-01') & (daily_all_nsp_gwetprof['DATE'] < '2025-02-01')]
# filtered_nsp_prectotcorr = daily_all_nsp_prectotcorr[(daily_all_nsp_prectotcorr['DATE'] >= '2015-03-01') & (daily_all_nsp_prectotcorr['DATE'] < '2025-02-01')]
# filtered_nsp_rh2m = daily_all_nsp_rh2m[(daily_all_nsp_rh2m['DATE'] >= '2015-03-01') & (daily_all_nsp_rh2m['DATE'] < '2025-02-01')]

# %%
# Merge rh2m with prectotcorr
merge1 = pd.merge(filtered_nsp_rh2m, filtered_nsp_prectotcorr, on=['POC_Code', 'DATE'], how='inner')
print("Merge 1 (rh2m with prectotcorr):", merge1.shape)
# Out:
# Merge 1 (rh2m with prectotcorr): (137750, 4)

# %%
merge1.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR
# 0 2015-03-01  ARA2201  57.62         0.00
# 1 2015-03-02  ARA2201  68.36         0.00
# 2 2015-03-03  ARA2201  68.50         0.14
# 3 2015-03-04  ARA2201  79.20         1.09
# 4 2015-03-05  ARA2201  69.77         0.01

# %%
# Merge merge1 with gwetprof
merge2 = pd.merge(merge1, filtered_nsp_gwetprof, on=['POC_Code', 'DATE'], how='inner')
print("Merge 2 (Merge 1 (rh2m with prectotcorr) with gwetprof):", merge2.shape)
# Out:
# Merge 2 (Merge 1 (rh2m with prectotcorr) with gwetprof): (137750, 5)

# %%
merge2.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF
# 0 2015-03-01  ARA2201  57.62         0.00      0.19
# 1 2015-03-02  ARA2201  68.36         0.00      0.19
# 2 2015-03-03  ARA2201  68.50         0.14      0.19
# 3 2015-03-04  ARA2201  79.20         1.09      0.19
# 4 2015-03-05  ARA2201  69.77         0.01      0.19

# %%
# Merge merge2 with evland
merge3 = pd.merge(merge2, filtered_nsp_evland, on=['POC_Code', 'DATE'], how='inner')
print("Merge 2 (Merge 1 (rh2m with prectotcorr) with gwetprof) with evland :", merge3.shape)
# Out:
# Merge 2 (Merge 1 (rh2m with prectotcorr) with gwetprof) with evland : (137750, 6)

# %%
merge3.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND
# 0 2015-03-01  ARA2201  57.62         0.00      0.19    1.01
# 1 2015-03-02  ARA2201  68.36         0.00      0.19    0.84
# 2 2015-03-03  ARA2201  68.50         0.14      0.19    0.45
# 3 2015-03-04  ARA2201  79.20         1.09      0.19    0.95
# 4 2015-03-05  ARA2201  69.77         0.01      0.19    0.70

# %%
# Merge merge3 with t2m
merge4 = pd.merge(merge3, filtered_nsp_t2m, on=['POC_Code', 'DATE'], how='inner',)
print("merge4 (previous merge with t2m):", merge4.shape)
# Out:
# merge4 (previous merge with t2m): (137750, 7)

# %%
merge4.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0 2015-03-01  ARA2201  57.62         0.00      0.19    1.01  19.11
# 1 2015-03-02  ARA2201  68.36         0.00      0.19    0.84  19.03
# 2 2015-03-03  ARA2201  68.50         0.14      0.19    0.45  18.00
# 3 2015-03-04  ARA2201  79.20         1.09      0.19    0.95  16.43
# 4 2015-03-05  ARA2201  69.77         0.01      0.19    0.70  18.74

# %%
merge4.tail()
# Out:
#              DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 137745 2025-01-27  WTK0111  64.93         1.73      0.44    2.48  10.90
# 137746 2025-01-28  WTK0111  56.24         0.08      0.43    3.01  14.74
# 137747 2025-01-29  WTK0111  57.06         0.84      0.43    3.68  17.65
# 137748 2025-01-30  WTK0111  73.86         0.48      0.43    2.13  14.05
# 137749 2025-01-31  WTK0111  72.17         0.19      0.42    2.05  15.41

# %%
# Merge merge3 with hydro
final_merge = pd.merge(hydro_energy, merge4, on=['POC_Code', 'DATE'], how='left',)
print("final merge (previous merge with t2m):", final_merge.shape)
# Out:
# final merge (previous merge with t2m): (132202, 12)

# %%
print("hydro_energy:", hydro_energy.shape)
# Out:
# hydro_energy: (132202, 7)

# %%
final_merge.head()
# Out:
#   Fuel_Code POC_Code       DATE  Total_TP Island   Latitude   Longitude  \
# 0     Hydro  ARA2201 2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201 2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201 2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201 2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201 2015-03-05  891070.0     NI -38.615891  176.143036
#
#     RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0  57.62         0.00      0.19    1.01  19.11
# 1  68.36         0.00      0.19    0.84  19.03
# 2  68.50         0.14      0.19    0.45  18.00
# 3  79.20         1.09      0.19    0.95  16.43
# 4  69.77         0.01      0.19    0.70  18.74

# %%
final_merge.tail()
# Out:
#        Fuel_Code POC_Code       DATE   Total_TP Island   Latitude   Longitude  \
# 132197     Hydro  WTK0111 2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111 2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111 2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111 2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111 2025-01-31  1610301.0     SI -44.692099  170.429029
#
#          RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 132197  64.93         1.73      0.44    2.48  10.90
# 132198  56.24         0.08      0.43    3.01  14.74
# 132199  57.06         0.84      0.43    3.68  17.65
# 132200  73.86         0.48      0.43    2.13  14.05
# 132201  72.17         0.19      0.42    2.05  15.41

# %%
all_poc_data = final_merge.copy()

# %%
# Write the final merged DataFrame to a CSV file
all_poc_data.to_csv('Hydro_final_merged_all_POC_20150301_20250131.csv', index=False)

print("Final merge saved to final_merged.csv")
# Out:
# Final merge saved to final_merged.csv

# %%
# all_poc_data = pd.read_csv('Hydro_final_merged_all_POC_20150301_20250131.csv')

# %%
all_poc_data
# Out:
#        Fuel_Code POC_Code       DATE   Total_TP Island   Latitude   Longitude  \
# 0          Hydro  ARA2201 2015-03-01   484010.0     NI -38.615891  176.143036
# 1          Hydro  ARA2201 2015-03-02   598280.0     NI -38.615891  176.143036
# 2          Hydro  ARA2201 2015-03-03   626290.0     NI -38.615891  176.143036
# 3          Hydro  ARA2201 2015-03-04   826700.0     NI -38.615891  176.143036
# 4          Hydro  ARA2201 2015-03-05   891070.0     NI -38.615891  176.143036
# ...          ...      ...        ...        ...    ...        ...         ...
# 132197     Hydro  WTK0111 2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111 2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111 2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111 2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111 2025-01-31  1610301.0     SI -44.692099  170.429029
#
#          RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0       57.62         0.00      0.19    1.01  19.11
# 1       68.36         0.00      0.19    0.84  19.03
# 2       68.50         0.14      0.19    0.45  18.00
# 3       79.20         1.09      0.19    0.95  16.43
# 4       69.77         0.01      0.19    0.70  18.74
# ...       ...          ...       ...     ...    ...
# 132197  64.93         1.73      0.44    2.48  10.90
# 132198  56.24         0.08      0.43    3.01  14.74
# 132199  57.06         0.84      0.43    3.68  17.65
# 132200  73.86         0.48      0.43    2.13  14.05
# 132201  72.17         0.19      0.42    2.05  15.41
#
# [132202 rows x 12 columns]

# %%
# Check for missing values in each column
missing_values = all_poc_data.isnull().sum()
print(missing_values)

# Optionally, check if there are any missing values at all
if all_poc_data.isnull().values.any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values found in the DataFrame.")
# Out:
# Fuel_Code      0
# POC_Code       0
# DATE           0
# Total_TP       0
# Island         0
# Latitude       0
# Longitude      0
# RH2M           0
# PRECTOTCORR    0
# GWETPROF       0
# EVLAND         0
# T2M            0
# dtype: int64
# No missing values found in the DataFrame.

# %%
# List all column names as an Index object
print(all_poc_data.columns)

# Alternatively, list the column names as a Python list
print(all_poc_data.columns.tolist())
# Out:
# Index(['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude',
#        'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M'],
#       dtype='object')
# ['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude', 'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M']

# %%
# selected_columns_POC = ['Fuel_Code','POC_Code', 'DATE','Total_TP', 'PS','T2M','WD50M','WD50M_rad','u','v','WS50M']  # Replace with your desired column names

# %%
selected_columns_Island_POC = ['DATE','Island','Total_TP', 'RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']  # Replace with your desired column names

# %%
# df_wind_daily_final_all_POC = final_merge[selected_columns_POC].copy()

# %%
df_hydro_daily_final_all_Island_POC = all_poc_data[selected_columns_Island_POC].copy()

# %%
df_hydro_daily_final_all_Island_POC
# Out:
#              DATE Island   Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND  \
# 0      2015-03-01     NI   484010.0  57.62         0.00      0.19    1.01
# 1      2015-03-02     NI   598280.0  68.36         0.00      0.19    0.84
# 2      2015-03-03     NI   626290.0  68.50         0.14      0.19    0.45
# 3      2015-03-04     NI   826700.0  79.20         1.09      0.19    0.95
# 4      2015-03-05     NI   891070.0  69.77         0.01      0.19    0.70
# ...           ...    ...        ...    ...          ...       ...     ...
# 132197 2025-01-27     SI  1427007.0  64.93         1.73      0.44    2.48
# 132198 2025-01-28     SI  1990551.0  56.24         0.08      0.43    3.01
# 132199 2025-01-29     SI  1720931.0  57.06         0.84      0.43    3.68
# 132200 2025-01-30     SI  1407865.0  73.86         0.48      0.43    2.13
# 132201 2025-01-31     SI  1610301.0  72.17         0.19      0.42    2.05
#
#           T2M
# 0       19.11
# 1       19.03
# 2       18.00
# 3       16.43
# 4       18.74
# ...       ...
# 132197  10.90
# 132198  14.74
# 132199  17.65
# 132200  14.05
# 132201  15.41
#
# [132202 rows x 8 columns]

# %%
df_hydro_daily_final_all_Island_POC.set_index('DATE', inplace=True)

# %%
df_hydro_daily_final_all_Island_POC.head()
# Out:
#            Island  Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# DATE
# 2015-03-01     NI  484010.0  57.62         0.00      0.19    1.01  19.11
# 2015-03-02     NI  598280.0  68.36         0.00      0.19    0.84  19.03
# 2015-03-03     NI  626290.0  68.50         0.14      0.19    0.45  18.00
# 2015-03-04     NI  826700.0  79.20         1.09      0.19    0.95  16.43
# 2015-03-05     NI  891070.0  69.77         0.01      0.19    0.70  18.74

# %%
print(df_hydro_daily_final_all_Island_POC.dtypes)
# Out:
# Island          object
# Total_TP       float64
# RH2M           float64
# PRECTOTCORR    float64
# GWETPROF       float64
# EVLAND         float64
# T2M            float64
# dtype: object

# %%
record_counts = df_hydro_daily_final_all_Island_POC.groupby('Island').size()
print(record_counts)
# Out:
# Island
# NI    61399
# SI    70803
# dtype: int64

# %%
# Group by Island and Date, and compute mean of numeric columns
df_island_daily = df_hydro_daily_final_all_Island_POC.groupby(['Island', 'DATE']).mean().reset_index()

# Optional: sort by Island and Date
df_island_daily = df_island_daily.sort_values(by=['Island', 'DATE'])

# %%
df_island_daily
# Out:
#      Island       DATE      Total_TP       RH2M  PRECTOTCORR  GWETPROF  \
# 0        NI 2015-03-01  4.603414e+05  66.255294     0.012353  0.334706
# 1        NI 2015-03-02  7.043941e+05  69.953529     0.010588  0.332353
# 2        NI 2015-03-03  6.593423e+05  73.095882     0.149412  0.331176
# 3        NI 2015-03-04  6.908145e+05  79.583529     1.104706  0.330000
# 4        NI 2015-03-05  7.082638e+05  72.791765     0.080000  0.329412
# ...     ...        ...           ...        ...          ...       ...
# 7245     SI 2025-01-27  2.027018e+06  69.201905     1.970952  0.496190
# 7246     SI 2025-01-28  2.274781e+06  63.686190     0.928571  0.490952
# 7247     SI 2025-01-29  1.919709e+06  64.899524     2.401905  0.488571
# 7248     SI 2025-01-30  2.282907e+06  72.480000     0.432857  0.486667
# 7249     SI 2025-01-31  2.239832e+06  69.778095     0.139048  0.480476
#
#         EVLAND        T2M
# 0     1.637647  19.008235
# 1     1.560000  19.220588
# 2     0.888824  18.333529
# 3     0.987647  17.398235
# 4     1.417647  19.171765
# ...        ...        ...
# 7245  2.802381  10.336667
# 7246  3.248095  13.301905
# 7247  3.843333  15.252857
# 7248  2.569524  13.720000
# 7249  2.670952  14.915714
#
# [7250 rows x 8 columns]

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_island_daily[df_island_daily['Total_TP'] == 0.0]
print("Number of daily records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of daily records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Island, Total_TP, RH2M, PRECTOTCORR, GWETPROF, EVLAND, T2M]
# Index: []

# %%
df_island_daily.set_index('DATE', inplace=True)

# %%
df_island_daily
# Out:
#            Island      Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01     NI  4.603414e+05  66.255294     0.012353  0.334706  1.637647
# 2015-03-02     NI  7.043941e+05  69.953529     0.010588  0.332353  1.560000
# 2015-03-03     NI  6.593423e+05  73.095882     0.149412  0.331176  0.888824
# 2015-03-04     NI  6.908145e+05  79.583529     1.104706  0.330000  0.987647
# 2015-03-05     NI  7.082638e+05  72.791765     0.080000  0.329412  1.417647
# ...           ...           ...        ...          ...       ...       ...
# 2025-01-27     SI  2.027018e+06  69.201905     1.970952  0.496190  2.802381
# 2025-01-28     SI  2.274781e+06  63.686190     0.928571  0.490952  3.248095
# 2025-01-29     SI  1.919709e+06  64.899524     2.401905  0.488571  3.843333
# 2025-01-30     SI  2.282907e+06  72.480000     0.432857  0.486667  2.569524
# 2025-01-31     SI  2.239832e+06  69.778095     0.139048  0.480476  2.670952
#
#                   T2M
# DATE
# 2015-03-01  19.008235
# 2015-03-02  19.220588
# 2015-03-03  18.333529
# 2015-03-04  17.398235
# 2015-03-05  19.171765
# ...               ...
# 2025-01-27  10.336667
# 2025-01-28  13.301905
# 2025-01-29  15.252857
# 2025-01-30  13.720000
# 2025-01-31  14.915714
#
# [7250 rows x 7 columns]

# %%
df_island_daily_beforezerointerpolate = df_island_daily.copy()

# %%
df_island_daily_beforezerointerpolate
# Out:
#            Island      Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01     NI  4.603414e+05  66.255294     0.012353  0.334706  1.637647
# 2015-03-02     NI  7.043941e+05  69.953529     0.010588  0.332353  1.560000
# 2015-03-03     NI  6.593423e+05  73.095882     0.149412  0.331176  0.888824
# 2015-03-04     NI  6.908145e+05  79.583529     1.104706  0.330000  0.987647
# 2015-03-05     NI  7.082638e+05  72.791765     0.080000  0.329412  1.417647
# ...           ...           ...        ...          ...       ...       ...
# 2025-01-27     SI  2.027018e+06  69.201905     1.970952  0.496190  2.802381
# 2025-01-28     SI  2.274781e+06  63.686190     0.928571  0.490952  3.248095
# 2025-01-29     SI  1.919709e+06  64.899524     2.401905  0.488571  3.843333
# 2025-01-30     SI  2.282907e+06  72.480000     0.432857  0.486667  2.569524
# 2025-01-31     SI  2.239832e+06  69.778095     0.139048  0.480476  2.670952
#
#                   T2M
# DATE
# 2015-03-01  19.008235
# 2015-03-02  19.220588
# 2015-03-03  18.333529
# 2015-03-04  17.398235
# 2015-03-05  19.171765
# ...               ...
# 2025-01-27  10.336667
# 2025-01-28  13.301905
# 2025-01-29  15.252857
# 2025-01-30  13.720000
# 2025-01-31  14.915714
#
# [7250 rows x 7 columns]

# %%
# Write the final merged DataFrame to a CSV file
df_island_daily_beforezerointerpolate.reset_index().to_csv('final_df_hydro_island_grouped_daily_20150301_20250131.csv', index=False)

print("final_df_hydro_island_daily.csv")
# Out:
# final_df_hydro_island_daily.csv

# %%
# df_island_daily.to_csv('df_island_daily_hydro_beforezerointerpolate.csv', index=False)

# %%
###################### following lines exe. does not require since no nan records

# %%
# # Ensure DATE column is in datetime format
# #df_island_daily['DATE'] = pd.to_datetime(df_island_daily['DATE'])

# # Set DATE as the index
# #df_island_daily.set_index('DATE', inplace=True)
# df_island_daily.index = pd.to_datetime(df_island_daily.index)

# # Now apply time-based interpolation
# cols_to_interpolate = ['Total_TP', 'PS', 'T2M', 'WD50M', 'WS50M']
# df_island_daily[cols_to_interpolate] = df_island_daily[cols_to_interpolate].interpolate(method='time')

# %%
# Check for missing values before handling
nan_count = df_island_daily['Total_TP'].isna().sum()
print("Number of NaN values before cleaning:", nan_count)
# Out:
# Number of NaN values before cleaning: 0

# %%
# # Check for missing values before handling
# nan_count = df_island_daily['Total_TP'].isna().sum()
# print("Number of NaN values before cleaning:", nan_count)

# # Apply time-based interpolation
# df_island_daily['Total_TP'] = df_island_daily['Total_TP'].interpolate(method='time')

# Verify that there are no more missing values
nan_count_after = df_island_daily['Total_TP'].isna().sum()
print("Number of NaN values after interpolation:", nan_count_after)

# Optionally, inspect the imputed records
imputed_records = df_island_daily[df_island_daily['Total_TP'].isna()]
print("Imputed Records (should be empty):")
print(imputed_records)

# %%
# # Apply time interpolation to the target variable and exogenous variables
# cols_to_interpolate = ['PS','T2M','WD50M','WD50M_rad','u','v','WS50M']
# df_WWD1102_weekly[cols_to_interpolate] = df_WWD1102_weekly[cols_to_interpolate].interpolate(method='time')

# # Verify that missing values have been filled
# print("Missing values after time interpolation:")
# print(df_WWD1102_weekly[cols_to_interpolate].isna().sum())

# %%
# # Verify that there are no more missing values
# nan_count_after = df_WWD1102_weekly['Total_TP'].isna().sum()
# print("Number of NaN values after interpolation:", nan_count_after)

# %%
#df_wind_daily_final_all['DATE'] = pd.to_datetime(df_wind_daily_final_all['DATE'])

# %%
# df_island_daily.reset_index().to_csv('df_island_daily_beforezerointerpolate_reuse.csv', index=False)

# %%
# df_island_daily

# %%
# 2. Remove rows with zero energy generation (Total_TP)
# df_hydro_daily_final_all_POC_clean = df_island_daily[df_island_daily['Total_TP'] > 0].copy()

# %%
# record_counts_new = all_poc_data.groupby('POC_Code').size()
# # print(record_counts_new)

# %%
# # Write the final merged DataFrame to a CSV file
# df_island_daily.reset_index().to_csv('final_df_wind_island_daily_20250425.csv', index=False)

# print("final_df_wind_island_daily.csv")

# %%
print(df_island_daily.dtypes)
# Out:
# Island          object
# Total_TP       float64
# RH2M           float64
# PRECTOTCORR    float64
# GWETPROF       float64
# EVLAND         float64
# T2M            float64
# dtype: object

# %%
print(df_island_daily.head())
# Out:
#            Island       Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01     NI  460341.437647  66.255294     0.012353  0.334706  1.637647
# 2015-03-02     NI  704394.079412  69.953529     0.010588  0.332353  1.560000
# 2015-03-03     NI  659342.273529  73.095882     0.149412  0.331176  0.888824
# 2015-03-04     NI  690814.549412  79.583529     1.104706  0.330000  0.987647
# 2015-03-05     NI  708263.788824  72.791765     0.080000  0.329412  1.417647
#
#                   T2M
# DATE
# 2015-03-01  19.008235
# 2015-03-02  19.220588
# 2015-03-03  18.333529
# 2015-03-04  17.398235
# 2015-03-05  19.171765

# %%
df_island_daily.head(25)
# Out:
#            Island       Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01     NI  460341.437647  66.255294     0.012353  0.334706  1.637647
# 2015-03-02     NI  704394.079412  69.953529     0.010588  0.332353  1.560000
# 2015-03-03     NI  659342.273529  73.095882     0.149412  0.331176  0.888824
# 2015-03-04     NI  690814.549412  79.583529     1.104706  0.330000  0.987647
# 2015-03-05     NI  708263.788824  72.791765     0.080000  0.329412  1.417647
# 2015-03-06     NI  677922.467647  84.524706     3.706471  0.330000  1.907059
# 2015-03-07     NI  529038.763529  83.213529     5.834118  0.331765  2.549412
# 2015-03-08     NI  566006.267059  71.919412     1.116471  0.333529  2.179412
# 2015-03-09     NI  678002.814706  73.339412     0.056471  0.332941  1.057647
# 2015-03-10     NI  661406.613529  67.215882     0.009412  0.332941  1.370000
# 2015-03-11     NI  669391.833529  77.351176     3.162353  0.330588  1.294118
# 2015-03-12     NI  664572.445294  88.537059    10.464706  0.338824  2.374706
# 2015-03-13     NI  592310.091765  76.673529     0.875294  0.347059  2.212353
# 2015-03-14     NI  484675.756471  72.967647     1.361176  0.343529  1.825882
# 2015-03-15     NI  440527.780000  79.866471     5.987059  0.343529  1.821176
# 2015-03-16     NI  674301.705882  82.042941    19.405882  0.370000  3.798235
# 2015-03-17     NI  628202.947059  76.786471     1.715294  0.372353  2.444118
# 2015-03-18     NI  638286.353529  65.487059     0.166471  0.370000  1.692941
# 2015-03-19     NI  602267.195294  60.675294     0.145294  0.369412  1.660000
# 2015-03-20     NI  697814.162353  62.564706     0.050588  0.368824  1.452941
# 2015-03-21     NI  473933.465294  71.776471     1.057647  0.364118  1.571176
# 2015-03-22     NI  473581.021176  73.913529     0.933529  0.364118  1.437059
# 2015-03-23     NI  620410.734118  77.269412     1.416471  0.361765  1.664118
# 2015-03-24     NI  627533.187647  76.807059     0.841765  0.361765  1.633529
# 2015-03-25     NI  640786.960000  78.001765     0.172941  0.359412  1.354706
#
#                   T2M  PRECTOTCORR_lag7  PRECTOTCORR_lag5  PRECTOTCORR_lag10  \
# DATE
# 2015-03-01  19.008235               NaN               NaN                NaN
# 2015-03-02  19.220588               NaN               NaN                NaN
# 2015-03-03  18.333529               NaN               NaN                NaN
# 2015-03-04  17.398235               NaN               NaN                NaN
# 2015-03-05  19.171765               NaN               NaN                NaN
# 2015-03-06  18.074706               NaN          0.012353                NaN
# 2015-03-07  16.718824               NaN          0.010588                NaN
# 2015-03-08  16.289412          0.012353          0.149412                NaN
# 2015-03-09  16.198235          0.010588          1.104706                NaN
# 2015-03-10  18.081765          0.149412          0.080000                NaN
# 2015-03-11  17.618824          1.104706          3.706471           0.012353
# 2015-03-12  16.345294          0.080000          5.834118           0.010588
# 2015-03-13  17.216471          3.706471          1.116471           0.149412
# 2015-03-14  18.642353          5.834118          0.056471           1.104706
# 2015-03-15  17.181176          1.116471          0.009412           0.080000
# 2015-03-16  15.990000          0.056471          3.162353           3.706471
# 2015-03-17  13.852353          0.009412         10.464706           5.834118
# 2015-03-18  12.571176          3.162353          0.875294           1.116471
# 2015-03-19  12.737059         10.464706          1.361176           0.056471
# 2015-03-20  12.254118          0.875294          5.987059           0.009412
# 2015-03-21  13.995882          1.361176         19.405882           3.162353
# 2015-03-22  15.037059          5.987059          1.715294          10.464706
# 2015-03-23  15.098824         19.405882          0.166471           0.875294
# 2015-03-24  15.008824          1.715294          0.145294           1.361176
# 2015-03-25  15.997059          0.166471          0.050588           5.987059
#
#             PRECTOTCORR_lag14
# DATE
# 2015-03-01                NaN
# 2015-03-02                NaN
# 2015-03-03                NaN
# 2015-03-04                NaN
# 2015-03-05                NaN
# 2015-03-06                NaN
# 2015-03-07                NaN
# 2015-03-08                NaN
# 2015-03-09                NaN
# 2015-03-10                NaN
# 2015-03-11                NaN
# 2015-03-12                NaN
# 2015-03-13                NaN
# 2015-03-14                NaN
# 2015-03-15           0.012353
# 2015-03-16           0.010588
# 2015-03-17           0.149412
# 2015-03-18           1.104706
# 2015-03-19           0.080000
# 2015-03-20           3.706471
# 2015-03-21           5.834118
# 2015-03-22           1.116471
# 2015-03-23           0.056471
# 2015-03-24           0.009412
# 2015-03-25           3.162353

# %%
# # # df_island_daily['PRECTOTCORR_lag7'] = df['PRECTOTCORR'].shift(7)  # 1-week lag
# # df_island_daily['PRECTOTCORR_lag5'] = df_island_daily['PRECTOTCORR'].shift(5)  # 5 days lag
# df_island_daily['PRECTOTCORR_lag10'] = df_island_daily['PRECTOTCORR'].shift(10)  # 10 days lag
# df_island_daily['PRECTOTCORR_lag14'] = df_island_daily['PRECTOTCORR'].shift(14)  # 2-week lag
df_island_daily['PRECTOTCORR_lag21'] = df_island_daily['PRECTOTCORR'].shift(21)
df_island_daily['PRECTOTCORR_lag30'] = df_island_daily['PRECTOTCORR'].shift(30)

# %%
df_island_daily_cpy4 = df_island_daily.drop(columns=['Island'])

# %%
# Drop rows with any NaNs
df_clean = df_island_daily_cpy4.dropna()

# %%
df_clean
# Out:
#                 Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-31  6.469481e+05  73.203529     0.102353  0.365294  1.613529
# 2015-04-01  6.682572e+05  74.875882     0.037059  0.364706  1.317647
# 2015-04-02  6.822679e+05  81.404118     0.750000  0.364706  1.544118
# 2015-04-03  5.179393e+05  77.596471     0.017059  0.362353  1.225882
# 2015-04-04  5.104799e+05  80.281176     0.282941  0.360000  1.239412
# ...                  ...        ...          ...       ...       ...
# 2025-01-27  2.027018e+06  69.201905     1.970952  0.496190  2.802381
# 2025-01-28  2.274781e+06  63.686190     0.928571  0.490952  3.248095
# 2025-01-29  1.919709e+06  64.899524     2.401905  0.488571  3.843333
# 2025-01-30  2.282907e+06  72.480000     0.432857  0.486667  2.569524
# 2025-01-31  2.239832e+06  69.778095     0.139048  0.480476  2.670952
#
#                   T2M  PRECTOTCORR_lag7  PRECTOTCORR_lag5  PRECTOTCORR_lag10  \
# DATE
# 2015-03-31  15.030000          0.841765          2.224706           1.057647
# 2015-04-01  15.302941          0.172941          0.854706           0.933529
# 2015-04-02  15.510588          2.224706          5.080588           1.416471
# 2015-04-03  15.467059          0.854706          8.599412           0.841765
# 2015-04-04  15.311176          5.080588          0.850000           0.172941
# ...               ...               ...               ...                ...
# 2025-01-27  10.336667          0.007619          0.345238           0.125714
# 2025-01-28  13.301905          0.040952          6.506190           1.981429
# 2025-01-29  15.252857          0.345238          0.655714           0.249524
# 2025-01-30  13.720000          6.506190          2.120952           0.007619
# 2025-01-31  14.915714          0.655714         14.969524           0.040952
#
#             PRECTOTCORR_lag14  PRECTOTCORR_lag21  PRECTOTCORR_lag30
# DATE
# 2015-03-31           1.715294           0.009412           0.012353
# 2015-04-01           0.166471           3.162353           0.010588
# 2015-04-02           0.145294          10.464706           0.149412
# 2015-04-03           0.050588           0.875294           1.104706
# 2015-04-04           1.057647           1.361176           0.080000
# ...                       ...                ...                ...
# 2025-01-27           0.026667           0.018571           1.121429
# 2025-01-28           0.089048           7.156667           5.270476
# 2025-01-29           0.168095           3.117619           3.506667
# 2025-01-30           0.050000           0.477619           2.209048
# 2025-01-31           0.125714           0.748095           1.199500
#
# [7220 rows x 12 columns]

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
corr = df_clean.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
corr = df_clean.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
corr = df_clean.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
corr = df_island_daily_cpy2.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
df_island_daily.reset_index()
# Out:
#            DATE Island      Total_TP       RH2M  PRECTOTCORR  GWETPROF  \
# 0    2015-03-01     NI  4.603414e+05  66.255294     0.012353  0.334706
# 1    2015-03-02     NI  7.043941e+05  69.953529     0.010588  0.332353
# 2    2015-03-03     NI  6.593423e+05  73.095882     0.149412  0.331176
# 3    2015-03-04     NI  6.908145e+05  79.583529     1.104706  0.330000
# 4    2015-03-05     NI  7.082638e+05  72.791765     0.080000  0.329412
# ...         ...    ...           ...        ...          ...       ...
# 7245 2025-01-27     SI  2.027018e+06  69.201905     1.970952  0.496190
# 7246 2025-01-28     SI  2.274781e+06  63.686190     0.928571  0.490952
# 7247 2025-01-29     SI  1.919709e+06  64.899524     2.401905  0.488571
# 7248 2025-01-30     SI  2.282907e+06  72.480000     0.432857  0.486667
# 7249 2025-01-31     SI  2.239832e+06  69.778095     0.139048  0.480476
#
#         EVLAND        T2M  PRECTOTCORR_lag7  PRECTOTCORR_lag5  \
# 0     1.637647  19.008235               NaN               NaN
# 1     1.560000  19.220588               NaN               NaN
# 2     0.888824  18.333529               NaN               NaN
# 3     0.987647  17.398235               NaN               NaN
# 4     1.417647  19.171765               NaN               NaN
# ...        ...        ...               ...               ...
# 7245  2.802381  10.336667          0.007619          0.345238
# 7246  3.248095  13.301905          0.040952          6.506190
# 7247  3.843333  15.252857          0.345238          0.655714
# 7248  2.569524  13.720000          6.506190          2.120952
# 7249  2.670952  14.915714          0.655714         14.969524
#
#       PRECTOTCORR_lag10  PRECTOTCORR_lag14  PRECTOTCORR_lag21  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 7245           0.125714           0.026667           0.018571
# 7246           1.981429           0.089048           7.156667
# 7247           0.249524           0.168095           3.117619
# 7248           0.007619           0.050000           0.477619
# 7249           0.040952           0.125714           0.748095
#
#       PRECTOTCORR_lag30
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 7245           1.121429
# 7246           5.270476
# 7247           3.506667
# 7248           2.209048
# 7249           1.199500
#
# [7250 rows x 14 columns]

# %%
df_island_daily_upd = df_island_daily.reset_index()[selected_columns_Island_POC].copy()

# %%
df_island_daily_upd
# Out:
#            DATE Island      Total_TP       RH2M  PRECTOTCORR  GWETPROF  \
# 0    2015-03-01     NI  4.603414e+05  66.255294     0.012353  0.334706
# 1    2015-03-02     NI  7.043941e+05  69.953529     0.010588  0.332353
# 2    2015-03-03     NI  6.593423e+05  73.095882     0.149412  0.331176
# 3    2015-03-04     NI  6.908145e+05  79.583529     1.104706  0.330000
# 4    2015-03-05     NI  7.082638e+05  72.791765     0.080000  0.329412
# ...         ...    ...           ...        ...          ...       ...
# 7245 2025-01-27     SI  2.027018e+06  69.201905     1.970952  0.496190
# 7246 2025-01-28     SI  2.274781e+06  63.686190     0.928571  0.490952
# 7247 2025-01-29     SI  1.919709e+06  64.899524     2.401905  0.488571
# 7248 2025-01-30     SI  2.282907e+06  72.480000     0.432857  0.486667
# 7249 2025-01-31     SI  2.239832e+06  69.778095     0.139048  0.480476
#
#         EVLAND        T2M
# 0     1.637647  19.008235
# 1     1.560000  19.220588
# 2     0.888824  18.333529
# 3     0.987647  17.398235
# 4     1.417647  19.171765
# ...        ...        ...
# 7245  2.802381  10.336667
# 7246  3.248095  13.301905
# 7247  3.843333  15.252857
# 7248  2.569524  13.720000
# 7249  2.670952  14.915714
#
# [7250 rows x 8 columns]

# %%
#after adding lag for preceptation
df_NI_island_daily_upd_cln = df_island_daily_upd[df_island_daily_upd['Island'] == 'NI'].copy()

# %%
#after adding lag for preceptation
df_SI_island_daily_upd_cln = df_island_daily_upd[df_island_daily_upd['Island'] == 'SI'].copy()

# %%
df_NI_island_daily_upd_cln.set_index('DATE', inplace=True)

# %%
df_SI_island_daily_upd_cln.set_index('DATE', inplace=True)

# %%
# Custom aggregation
north_weekly_df = df_NI_island_daily_upd_cln.resample('W').agg({
    'Total_TP': 'mean',
    'RH2M': 'mean',
    'PRECTOTCORR': 'sum',      # rainfall summed
    'GWETPROF': 'mean',
    'EVLAND': 'sum',           # summed if it's daily mm evaporation
    'T2M': 'mean'
}).reset_index()

# %%
# Custom aggregation
south_weekly_df = df_SI_island_daily_upd_cln.resample('W').agg({
    'Total_TP': 'mean',
    'RH2M': 'mean',
    'PRECTOTCORR': 'sum',      # rainfall summed
    'GWETPROF': 'mean',
    'EVLAND': 'sum',           # summed if it's daily mm evaporation
    'T2M': 'mean'
}).reset_index()

# %%
north_weekly_df
# Out:
#           DATE       Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# 0   2015-03-01  460341.437647  66.255294     0.012353  0.334706   1.637647
# 1   2015-03-08  647968.884202  76.440336    12.001765  0.331176  11.490000
# 2   2015-03-15  598698.190756  76.564454    21.916471  0.338487  11.955882
# 3   2015-03-22  598340.978655  70.463782    23.474706  0.368403  14.056471
# 4   2015-03-29  595974.516134  80.650000    19.190588  0.360000  12.708235
# ..         ...            ...        ...          ...       ...        ...
# 514 2025-01-05  529244.151261  74.479328    19.481765  0.442689  24.628824
# 515 2025-01-12  713229.882353  67.837059     6.408235  0.425630  22.495882
# 516 2025-01-19  815054.201681  67.007143     2.745294  0.402353  18.664118
# 517 2025-01-26  728856.252101  75.025294    25.093529  0.388235  18.890588
# 518 2025-02-02  725455.870588  68.219059     4.830000  0.387294  13.147059
#
#            T2M
# 0    19.008235
# 1    17.886723
# 2    17.326303
# 3    13.776807
# 4    16.227563
# ..         ...
# 514  15.331933
# 515  15.599916
# 516  17.000084
# 517  18.570840
# 518  17.883647
#
# [519 rows x 7 columns]

# %%
south_weekly_df
# Out:
#           DATE      Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# 0   2015-03-01  2.336703e+06  77.983889     2.918333  0.450000   2.341111
# 1   2015-03-08  2.542296e+06  76.412937    42.630556  0.467698  14.370000
# 2   2015-03-15  2.574169e+06  77.127698     8.690000  0.480000  12.710000
# 3   2015-03-22  2.341324e+06  80.292381    14.711111  0.474921   9.167222
# 4   2015-03-29  2.278030e+06  83.572698    20.411111  0.482063   8.603333
# ..         ...           ...        ...          ...       ...        ...
# 514 2025-01-05  2.096868e+06  76.979041    17.854262  0.555728  23.826024
# 515 2025-01-12  2.312776e+06  72.961769    12.814762  0.535102  23.720000
# 516 2025-01-19  2.320066e+06  73.288844     2.690476  0.504014  20.321905
# 517 2025-01-26  2.195515e+06  74.280680    24.646190  0.480680  17.858571
# 518 2025-02-02  2.148849e+06  68.009143     5.873333  0.488571  15.134286
#
#            T2M
# 0    15.757778
# 1    12.941190
# 2    12.604048
# 3     8.037778
# 4    11.639524
# ..         ...
# 514  11.260983
# 515  12.327211
# 516  14.151905
# 517  14.696395
# 518  13.505429
#
# [519 rows x 7 columns]

# %%
north_weekly_df['PRECTOTCORR_lag1'] = north_weekly_df['PRECTOTCORR'].shift(1)  # 1-week lag

# %%
south_weekly_df['PRECTOTCORR_lag1'] = south_weekly_df['PRECTOTCORR'].shift(1)  # 1-week lag

# %%
north_weekly_df.set_index('DATE', inplace=True)

# %%
south_weekly_df.set_index('DATE', inplace=True)

# %%
north_weekly_df.head(50)
# Out:
#                 Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# DATE
# 2015-03-01  4.603414e+05  66.255294     0.012353  0.334706   1.637647
# 2015-03-08  6.479689e+05  76.440336    12.001765  0.331176  11.490000
# 2015-03-15  5.986982e+05  76.564454    21.916471  0.338487  11.955882
# 2015-03-22  5.983410e+05  70.463782    23.474706  0.368403  14.056471
# 2015-03-29  5.959745e+05  80.650000    19.190588  0.360000  12.708235
# 2015-04-05  5.960783e+05  77.631261     2.619412  0.362605  10.257647
# 2015-04-12  8.211039e+05  85.405462    42.200588  0.375378  10.917647
# 2015-04-19  9.339766e+05  80.490084    38.038235  0.413109  10.833529
# 2015-04-26  7.536625e+05  84.628908     6.699412  0.425714  10.036471
# 2015-05-03  8.854788e+05  81.430168    20.812353  0.436975  10.405882
# 2015-05-10  8.306166e+05  87.492521    21.441176  0.440168   7.543529
# 2015-05-17  1.035168e+06  87.296218    39.399412  0.466807   9.301176
# 2015-05-24  9.971383e+05  85.998571    19.171176  0.483529   7.060000
# 2015-05-31  1.030292e+06  82.314958     1.643529  0.492857   5.786471
# 2015-06-07  1.156616e+06  92.461597    31.329412  0.508487   7.307059
# 2015-06-14  1.133102e+06  86.861849     9.422353  0.514874   7.288235
# 2015-06-21  1.192622e+06  88.092017    35.259412  0.520756   6.366471
# 2015-06-28  1.332157e+06  85.433866     3.725882  0.540084   6.691765
# 2015-07-05  1.131876e+06  89.922689     9.656471  0.536134   5.125294
# 2015-07-12  1.397682e+06  88.033109    20.544706  0.550084   8.034706
# 2015-07-19  1.352838e+06  88.739412    40.085294  0.563025   7.511176
# 2015-07-26  1.236626e+06  86.980588     3.264706  0.581513   5.398235
# 2015-08-02  1.185759e+06  90.296975    16.000588  0.586807   6.990588
# 2015-08-09  1.394878e+06  91.428487    49.740588  0.606218   9.021765
# 2015-08-16  1.538397e+06  87.834958    28.398235  0.629076   8.968235
# 2015-08-23  1.450250e+06  86.491261    14.859412  0.643529   9.682941
# 2015-08-30  1.416592e+06  86.851429    12.965882  0.639496   9.942941
# 2015-09-06  1.599300e+06  90.259664    39.864706  0.659832  11.097059
# 2015-09-13  1.433110e+06  82.562185    11.077059  0.653277  13.172941
# 2015-09-20  1.318835e+06  86.511092    31.456471  0.641597  13.258824
# 2015-09-27  1.386959e+06  84.460084    30.364118  0.672857  18.634118
# 2015-10-04  1.329997e+06  82.691933     8.614706  0.656639  17.987059
# 2015-10-11  1.185673e+06  78.318487     1.171176  0.626471  22.490588
# 2015-10-18  1.110892e+06  83.003950     4.220588  0.595462  19.269412
# 2015-10-25  9.775858e+05  81.700504    10.661765  0.570840  19.778824
# 2015-11-01  9.573473e+05  77.973445     6.416471  0.552437  19.674118
# 2015-11-08  9.107894e+05  74.948739    22.101176  0.538739  25.471176
# 2015-11-15  7.312426e+05  75.899664    12.153529  0.511345  22.037647
# 2015-11-22  9.197132e+05  81.609832    33.748824  0.513529  21.683529
# 2015-11-29  9.449869e+05  75.527479     8.791176  0.496471  27.345294
# 2015-12-06  8.854480e+05  78.374370     5.262353  0.474706  17.367647
# 2015-12-13  9.022445e+05  74.268824     7.415294  0.449832  21.158235
# 2015-12-20  9.403276e+05  69.974622     7.931176  0.431092  20.227647
# 2015-12-27  7.328586e+05  71.587311     5.038235  0.408824  20.666471
# 2016-01-03  7.017875e+05  70.728235    37.666471  0.390084  20.201765
# 2016-01-10  7.914585e+05  70.692941    12.798235  0.409160  22.021765
# 2016-01-17  8.429528e+05  72.327815     2.468235  0.392017  17.117059
# 2016-01-24  9.178719e+05  70.621681    13.050000  0.378908  20.425294
# 2016-01-31  8.319262e+05  76.719496    26.998824  0.374538  21.272353
# 2016-02-07  8.113336e+05  74.044202    12.921176  0.370672  18.436471
#
#                   T2M  PRECTOTCORR_lag1
# DATE
# 2015-03-01  19.008235               NaN
# 2015-03-08  17.886723          0.012353
# 2015-03-15  17.326303         12.001765
# 2015-03-22  13.776807         21.916471
# 2015-03-29  16.227563         23.474706
# 2015-04-05  15.508235         19.190588
# 2015-04-12  16.036639          2.619412
# 2015-04-19  10.195378         42.200588
# 2015-04-26  13.377311         38.038235
# 2015-05-03  11.563025          6.699412
# 2015-05-10  12.806555         20.812353
# 2015-05-17  10.856555         21.441176
# 2015-05-24   9.617647         39.399412
# 2015-05-31   7.049580         19.171176
# 2015-06-07   9.794790          1.643529
# 2015-06-14   9.531681         31.329412
# 2015-06-21   8.509664          9.422353
# 2015-06-28   5.909832         35.259412
# 2015-07-05   9.073613          3.725882
# 2015-07-12   4.957731          9.656471
# 2015-07-19   7.036807         20.544706
# 2015-07-26   5.787647         40.085294
# 2015-08-02   7.772605          3.264706
# 2015-08-09   8.490000         16.000588
# 2015-08-16   5.342017         49.740588
# 2015-08-23   7.305966         28.398235
# 2015-08-30   8.599076         14.859412
# 2015-09-06   8.531765         12.965882
# 2015-09-13   7.043782         39.864706
# 2015-09-20   9.473277         11.077059
# 2015-09-27   8.660420         31.456471
# 2015-10-04  10.328067         30.364118
# 2015-10-11  10.589412          8.614706
# 2015-10-18  11.855210          1.171176
# 2015-10-25  12.067983          4.220588
# 2015-11-01  11.842605         10.661765
# 2015-11-08  11.781513          6.416471
# 2015-11-15  12.557731         22.101176
# 2015-11-22  12.670924         12.153529
# 2015-11-29  15.430588         33.748824
# 2015-12-06  15.186639          8.791176
# 2015-12-13  14.853193          5.262353
# 2015-12-20  13.901681          7.415294
# 2015-12-27  17.028655          7.931176
# 2016-01-03  18.059496          5.038235
# 2016-01-10  16.562353         37.666471
# 2016-01-17  18.284202         12.798235
# 2016-01-24  19.894286          2.468235
# 2016-01-31  20.770084         13.050000
# 2016-02-07  20.387731         26.998824

# %%
# Drop rows with any NaNs
df_clean_north_weekly = north_weekly_df.dropna()

# %%
# Drop rows with any NaNs
df_clean_south_weekly = south_weekly_df.dropna()

# %%
plt.figure(figsize=(8, 6))
corr = df_clean_north_weekly.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: North Island : Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
corr = df_clean_south_weekly.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix : South Island : Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %% [markdown]
# # --------------------Start from here df_island_north----------------------------

# %%
df_island_north = df_island_daily[df_island_daily['Island'] == 'NI'].copy()

# %%
#after adding lag for preceptation
df_island_north_cln = df_island_daily[df_island_daily['Island'] == 'NI'].copy()

# %%
df_island_north = df_island_north.drop(columns=['Island'])

# %%
df_island_north_cln = df_island_north_cln.drop(columns=['Island'])

# %%
df_island_north.head()
# Out:
#                  Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01  460341.437647  66.255294     0.012353  0.334706  1.637647
# 2015-03-02  704394.079412  69.953529     0.010588  0.332353  1.560000
# 2015-03-03  659342.273529  73.095882     0.149412  0.331176  0.888824
# 2015-03-04  690814.549412  79.583529     1.104706  0.330000  0.987647
# 2015-03-05  708263.788824  72.791765     0.080000  0.329412  1.417647
#
#                   T2M
# DATE
# 2015-03-01  19.008235
# 2015-03-02  19.220588
# 2015-03-03  18.333529
# 2015-03-04  17.398235
# 2015-03-05  19.171765

# %%
df_island_north_cln.head(40)
# Out:
#                  Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01  460341.437647  66.255294     0.012353  0.334706  1.637647
# 2015-03-02  704394.079412  69.953529     0.010588  0.332353  1.560000
# 2015-03-03  659342.273529  73.095882     0.149412  0.331176  0.888824
# 2015-03-04  690814.549412  79.583529     1.104706  0.330000  0.987647
# 2015-03-05  708263.788824  72.791765     0.080000  0.329412  1.417647
# 2015-03-06  677922.467647  84.524706     3.706471  0.330000  1.907059
# 2015-03-07  529038.763529  83.213529     5.834118  0.331765  2.549412
# 2015-03-08  566006.267059  71.919412     1.116471  0.333529  2.179412
# 2015-03-09  678002.814706  73.339412     0.056471  0.332941  1.057647
# 2015-03-10  661406.613529  67.215882     0.009412  0.332941  1.370000
# 2015-03-11  669391.833529  77.351176     3.162353  0.330588  1.294118
# 2015-03-12  664572.445294  88.537059    10.464706  0.338824  2.374706
# 2015-03-13  592310.091765  76.673529     0.875294  0.347059  2.212353
# 2015-03-14  484675.756471  72.967647     1.361176  0.343529  1.825882
# 2015-03-15  440527.780000  79.866471     5.987059  0.343529  1.821176
# 2015-03-16  674301.705882  82.042941    19.405882  0.370000  3.798235
# 2015-03-17  628202.947059  76.786471     1.715294  0.372353  2.444118
# 2015-03-18  638286.353529  65.487059     0.166471  0.370000  1.692941
# 2015-03-19  602267.195294  60.675294     0.145294  0.369412  1.660000
# 2015-03-20  697814.162353  62.564706     0.050588  0.368824  1.452941
# 2015-03-21  473933.465294  71.776471     1.057647  0.364118  1.571176
# 2015-03-22  473581.021176  73.913529     0.933529  0.364118  1.437059
# 2015-03-23  620410.734118  77.269412     1.416471  0.361765  1.664118
# 2015-03-24  627533.187647  76.807059     0.841765  0.361765  1.633529
# 2015-03-25  640786.960000  78.001765     0.172941  0.359412  1.354706
# 2015-03-26  620421.770000  81.650588     2.224706  0.357059  1.387059
# 2015-03-27  644520.649412  80.358235     0.854706  0.357647  1.690588
# 2015-03-28  515772.751765  86.817647     5.080588  0.356471  1.904118
# 2015-03-29  502375.560000  83.645294     8.599412  0.365882  3.074118
# 2015-03-30  607309.171765  78.021765     0.850000  0.365294  1.959412
# 2015-03-31  646948.078235  73.203529     0.102353  0.365294  1.613529
# 2015-04-01  668257.249412  74.875882     0.037059  0.364706  1.317647
# 2015-04-02  682267.851765  81.404118     0.750000  0.364706  1.544118
# 2015-04-03  517939.269412  77.596471     0.017059  0.362353  1.225882
# 2015-04-04  510479.882941  80.281176     0.282941  0.360000  1.239412
# 2015-04-05  539346.384118  78.035882     0.580000  0.355882  1.357647
# 2015-04-06  547072.395882  82.927059     0.670588  0.355294  1.328235
# 2015-04-07  702210.661765  78.746471     1.361176  0.355882  0.988824
# 2015-04-08  770536.177647  88.729412     8.592941  0.359412  1.165294
# 2015-04-09  928816.725882  94.681176    12.530588  0.372353  1.403529
#
#                   T2M  PRECTOTCORR_lag7  PRECTOTCORR_lag5  PRECTOTCORR_lag10  \
# DATE
# 2015-03-01  19.008235               NaN               NaN                NaN
# 2015-03-02  19.220588               NaN               NaN                NaN
# 2015-03-03  18.333529               NaN               NaN                NaN
# 2015-03-04  17.398235               NaN               NaN                NaN
# 2015-03-05  19.171765               NaN               NaN                NaN
# 2015-03-06  18.074706               NaN          0.012353                NaN
# 2015-03-07  16.718824               NaN          0.010588                NaN
# 2015-03-08  16.289412          0.012353          0.149412                NaN
# 2015-03-09  16.198235          0.010588          1.104706                NaN
# 2015-03-10  18.081765          0.149412          0.080000                NaN
# 2015-03-11  17.618824          1.104706          3.706471           0.012353
# 2015-03-12  16.345294          0.080000          5.834118           0.010588
# 2015-03-13  17.216471          3.706471          1.116471           0.149412
# 2015-03-14  18.642353          5.834118          0.056471           1.104706
# 2015-03-15  17.181176          1.116471          0.009412           0.080000
# 2015-03-16  15.990000          0.056471          3.162353           3.706471
# 2015-03-17  13.852353          0.009412         10.464706           5.834118
# 2015-03-18  12.571176          3.162353          0.875294           1.116471
# 2015-03-19  12.737059         10.464706          1.361176           0.056471
# 2015-03-20  12.254118          0.875294          5.987059           0.009412
# 2015-03-21  13.995882          1.361176         19.405882           3.162353
# 2015-03-22  15.037059          5.987059          1.715294          10.464706
# 2015-03-23  15.098824         19.405882          0.166471           0.875294
# 2015-03-24  15.008824          1.715294          0.145294           1.361176
# 2015-03-25  15.997059          0.166471          0.050588           5.987059
# 2015-03-26  16.578235          0.145294          1.057647          19.405882
# 2015-03-27  17.181176          0.050588          0.933529           1.715294
# 2015-03-28  17.140588          1.057647          1.416471           0.166471
# 2015-03-29  16.588235          0.933529          0.841765           0.145294
# 2015-03-30  15.514706          1.416471          0.172941           0.050588
# 2015-03-31  15.030000          0.841765          2.224706           1.057647
# 2015-04-01  15.302941          0.172941          0.854706           0.933529
# 2015-04-02  15.510588          2.224706          5.080588           1.416471
# 2015-04-03  15.467059          0.854706          8.599412           0.841765
# 2015-04-04  15.311176          5.080588          0.850000           0.172941
# 2015-04-05  16.421176          8.599412          0.102353           2.224706
# 2015-04-06  16.420588          0.850000          0.037059           0.854706
# 2015-04-07  17.070000          0.102353          0.750000           5.080588
# 2015-04-08  16.769412          0.037059          0.017059           8.599412
# 2015-04-09  17.187647          0.750000          0.282941           0.850000
#
#             PRECTOTCORR_lag14  PRECTOTCORR_lag21  PRECTOTCORR_lag30
# DATE
# 2015-03-01                NaN                NaN                NaN
# 2015-03-02                NaN                NaN                NaN
# 2015-03-03                NaN                NaN                NaN
# 2015-03-04                NaN                NaN                NaN
# 2015-03-05                NaN                NaN                NaN
# 2015-03-06                NaN                NaN                NaN
# 2015-03-07                NaN                NaN                NaN
# 2015-03-08                NaN                NaN                NaN
# 2015-03-09                NaN                NaN                NaN
# 2015-03-10                NaN                NaN                NaN
# 2015-03-11                NaN                NaN                NaN
# 2015-03-12                NaN                NaN                NaN
# 2015-03-13                NaN                NaN                NaN
# 2015-03-14                NaN                NaN                NaN
# 2015-03-15           0.012353                NaN                NaN
# 2015-03-16           0.010588                NaN                NaN
# 2015-03-17           0.149412                NaN                NaN
# 2015-03-18           1.104706                NaN                NaN
# 2015-03-19           0.080000                NaN                NaN
# 2015-03-20           3.706471                NaN                NaN
# 2015-03-21           5.834118                NaN                NaN
# 2015-03-22           1.116471           0.012353                NaN
# 2015-03-23           0.056471           0.010588                NaN
# 2015-03-24           0.009412           0.149412                NaN
# 2015-03-25           3.162353           1.104706                NaN
# 2015-03-26          10.464706           0.080000                NaN
# 2015-03-27           0.875294           3.706471                NaN
# 2015-03-28           1.361176           5.834118                NaN
# 2015-03-29           5.987059           1.116471                NaN
# 2015-03-30          19.405882           0.056471                NaN
# 2015-03-31           1.715294           0.009412           0.012353
# 2015-04-01           0.166471           3.162353           0.010588
# 2015-04-02           0.145294          10.464706           0.149412
# 2015-04-03           0.050588           0.875294           1.104706
# 2015-04-04           1.057647           1.361176           0.080000
# 2015-04-05           0.933529           5.987059           3.706471
# 2015-04-06           1.416471          19.405882           5.834118
# 2015-04-07           0.841765           1.715294           1.116471
# 2015-04-08           0.172941           0.166471           0.056471
# 2015-04-09           2.224706           0.145294           0.009412

# %%
df_island_north_cln_rmnan = df_island_north_cln.dropna()

# %%
# stationery check for north island daily data
from statsmodels.tsa.stattools import adfuller

# Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
result = adfuller(df_clean_north_weekly['Total_TP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.848403
# p-value: 0.000044
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_clean_north_weekly[df_clean_north_weekly['Total_TP'] == 0.0]
print("Number of daily records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of daily records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, RH2M, PRECTOTCORR, GWETPROF, EVLAND, T2M, PRECTOTCORR_lag1]
# Index: []

# %%
df_clean_north_weekly
# Out:
#                  Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# DATE
# 2015-03-08  647968.884202  76.440336    12.001765  0.331176  11.490000
# 2015-03-15  598698.190756  76.564454    21.916471  0.338487  11.955882
# 2015-03-22  598340.978655  70.463782    23.474706  0.368403  14.056471
# 2015-03-29  595974.516134  80.650000    19.190588  0.360000  12.708235
# 2015-04-05  596078.269664  77.631261     2.619412  0.362605  10.257647
# ...                   ...        ...          ...       ...        ...
# 2025-01-05  529244.151261  74.479328    19.481765  0.442689  24.628824
# 2025-01-12  713229.882353  67.837059     6.408235  0.425630  22.495882
# 2025-01-19  815054.201681  67.007143     2.745294  0.402353  18.664118
# 2025-01-26  728856.252101  75.025294    25.093529  0.388235  18.890588
# 2025-02-02  725455.870588  68.219059     4.830000  0.387294  13.147059
#
#                   T2M  PRECTOTCORR_lag1
# DATE
# 2015-03-08  17.886723          0.012353
# 2015-03-15  17.326303         12.001765
# 2015-03-22  13.776807         21.916471
# 2015-03-29  16.227563         23.474706
# 2015-04-05  15.508235         19.190588
# ...               ...               ...
# 2025-01-05  15.331933         23.029412
# 2025-01-12  15.599916         19.481765
# 2025-01-19  17.000084          6.408235
# 2025-01-26  18.570840          2.745294
# 2025-02-02  17.883647         25.093529
#
# [518 rows x 7 columns]

# %%
df_clean_north_weekly.columns
# Out:
# Index(['Total_TP', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M',
#        'PRECTOTCORR_lag1'],
#       dtype='object')

# %% [markdown]
# # Train the model

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_clean_north_weekly)
train_size = int(n * 0.8)
train_daily = df_clean_north_weekly.iloc[:train_size]
test_daily = df_clean_north_weekly.iloc[train_size:]

# %%
print("Daily Train set:", train_daily.index.min(), "to", train_daily.index.max())
print("Daily Test set:", test_daily.index.min(), "to", test_daily.index.max())
# Out:
# Daily Train set: 2015-03-08 00:00:00 to 2023-02-05 00:00:00
# Daily Test set: 2023-02-12 00:00:00 to 2025-02-02 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_daily['Total_TP']
target_test = test_daily['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
exog_train = train_daily[exog_cols]
exog_test = test_daily[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Total_TP   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -5308.412
# Date:                Wed, 16 Apr 2025   AIC                          10628.824
# Time:                        21:47:11   BIC                          10652.936
# Sample:                    03-08-2015   HQIC                         10638.363
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M             -1727.5544    815.381     -2.119      0.034   -3325.671    -129.437
# GWETPROF          2.337e+06   1.73e+05     13.527      0.000       2e+06    2.68e+06
# PRECTOTCORR_lag1  -258.0410    220.266     -1.171      0.241    -689.754     173.672
# ar.L1                0.7643      0.040     18.878      0.000       0.685       0.844
# ma.L1               -0.9838      0.010    -94.336      0.000      -1.004      -0.963
# sigma2            1.025e+10      4.415   2.32e+09      0.000    1.02e+10    1.02e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.53   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.22   Prob(JB):                         0.69
# Heteroskedasticity (H):               1.43   Skew:                             0.10
# Prob(H) (two-sided):                  0.04   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.61e+25. Standard errors may be unstable.

# %%
# Forecast on the test set - non log
n_steps = len(test_daily)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("\nForecast Performance Metrics (Without Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 245383.30
# MAE: 200415.92
# Adjusted MAPE: 20.84%

# %%
"""
exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
Forecast Performance Metrics (Without Log Transformation):
RMSE: 407435.15
MAE: 342181.88
Adjusted MAPE: 38.00%
__________________________________________________________________

exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
Forecast Performance Metrics (Without Log Transformation):
RMSE: 409731.03
MAE: 345097.55
Adjusted MAPE: 38.33%

__________________________________________________________________

exog_cols = ['GWETPROF','EVLAND','T2M']
Forecast Performance Metrics (Without Log Transformation):
RMSE: 408753.43
MAE: 343269.66
Adjusted MAPE: 38.12%

------------------------------------------------------------------

exog_cols = ['EVLAND','T2M']
Forecast Performance Metrics (Without Log Transformation):
RMSE: 535976.88
MAE: 487898.83
Adjusted MAPE: 56.36%

__________________________________________________________________

exog_cols = ['T2M']
Forecast Performance Metrics (Without Log Transformation):
RMSE: 538725.65
MAE: 490849.65
Adjusted MAPE: 56.67%

"""
# Out:
# "\nexog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']\nForecast Performance Metrics (Without Log Transformation):\nRMSE: 407435.15\nMAE: 342181.88\nAdjusted MAPE: 38.00%\n__________________________________________________________________\n\n\n"

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_daily.index, target_train, label='Train', color='blue')
plt.plot(test_daily.index, target_test, label='Test', color='green')
plt.plot(test_daily.index, forecast, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Daily SARIMAX Forecast-North Island (Without Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Log transformation to see any perfromance improvemane

# %%
# # Create a log-transformed target. Adding 1 to avoid log(0) if needed.
df_clean_north_weekly['Total_TP_log'] = np.log(df_clean_north_weekly['Total_TP'] + 1)
# Out:
# C:\Users\nwn86\AppData\Local\Temp\ipykernel_14632\3817015496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_north_weekly['Total_TP_log'] = np.log(df_clean_north_weekly['Total_TP'] + 1)

# %%
df_clean_north_weekly
# Out:
#                  Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# DATE
# 2015-03-08  647968.884202  76.440336    12.001765  0.331176  11.490000
# 2015-03-15  598698.190756  76.564454    21.916471  0.338487  11.955882
# 2015-03-22  598340.978655  70.463782    23.474706  0.368403  14.056471
# 2015-03-29  595974.516134  80.650000    19.190588  0.360000  12.708235
# 2015-04-05  596078.269664  77.631261     2.619412  0.362605  10.257647
# ...                   ...        ...          ...       ...        ...
# 2025-01-05  529244.151261  74.479328    19.481765  0.442689  24.628824
# 2025-01-12  713229.882353  67.837059     6.408235  0.425630  22.495882
# 2025-01-19  815054.201681  67.007143     2.745294  0.402353  18.664118
# 2025-01-26  728856.252101  75.025294    25.093529  0.388235  18.890588
# 2025-02-02  725455.870588  68.219059     4.830000  0.387294  13.147059
#
#                   T2M  PRECTOTCORR_lag1  Total_TP_log
# DATE
# 2015-03-08  17.886723          0.012353     13.381599
# 2015-03-15  17.326303         12.001765     13.302515
# 2015-03-22  13.776807         21.916471     13.301918
# 2015-03-29  16.227563         23.474706     13.297955
# 2015-04-05  15.508235         19.190588     13.298129
# ...               ...               ...           ...
# 2025-01-05  15.331933         23.029412     13.179207
# 2025-01-12  15.599916         19.481765     13.477560
# 2025-01-19  17.000084          6.408235     13.611011
# 2025-01-26  18.570840          2.745294     13.499233
# 2025-02-02  17.883647         25.093529     13.494557
#
# [518 rows x 8 columns]

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_clean_north_weekly)
train_size = int(n * 0.8)
train_daily = df_clean_north_weekly.iloc[:train_size]
test_daily = df_clean_north_weekly.iloc[train_size:]

# %%
print("Daily Train set:", train_daily.index.min(), "to", train_daily.index.max())
print("Daily Test set:", test_daily.index.min(), "to", test_daily.index.max())
# Out:
# Daily Train set: 2015-03-08 00:00:00 to 2023-02-05 00:00:00
# Daily Test set: 2023-02-12 00:00:00 to 2025-02-02 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
target_train_log = train_daily['Total_TP_log']
target_test_log = test_daily['Total_TP_log']

# target_train = train_weekly['Total_TP']
# target_test = test_weekly['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
exog_train = train_daily[exog_cols]
exog_test = test_daily[exog_cols]

# %%
# Fit SARIMAX on the original (log) target data
model_log = SARIMAX(target_train_log,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Total_TP_log   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 384.907
# Date:                Wed, 16 Apr 2025   AIC                           -757.813
# Time:                        21:51:20   BIC                           -733.701
# Sample:                    03-08-2015   HQIC                          -748.275
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M                -0.0009      0.001     -0.807      0.419      -0.003       0.001
# GWETPROF             1.7318      0.144     12.042      0.000       1.450       2.014
# PRECTOTCORR_lag1 -7.794e-05      0.000     -0.368      0.713      -0.000       0.000
# ar.L1                0.7060      0.042     17.002      0.000       0.625       0.787
# ma.L1               -0.9717      0.015    -63.024      0.000      -1.002      -0.942
# sigma2               0.0090      0.001     14.498      0.000       0.008       0.010
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.71   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.40   Prob(JB):                         0.69
# Heteroskedasticity (H):               1.43   Skew:                            -0.07
# Prob(H) (two-sided):                  0.04   Kurtosis:                         3.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Forecast on the test set
n_steps_log = len(test_daily)
forecast_log = results_log.get_forecast(steps=n_steps_log, exog=exog_test).predicted_mean

# %%
# Compute performance metrics
rmse = np.sqrt(mean_squared_error(target_test_log, forecast_log))
mae = mean_absolute_error(target_test_log, forecast_log)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test_log - forecast_log) / (target_test_log + epsilon))) * 100

print("\nForecast Performance Metrics (With Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (With Log Transformation):
# RMSE: 0.20
# MAE: 0.16
# Adjusted MAPE: 1.16%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_daily.index, target_train_log, label='Train', color='blue')
plt.plot(test_daily.index, target_test_log, label='Test', color='green')
plt.plot(test_daily.index, forecast_log, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Weekly SARIMAX Forecast-North Island (With Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
results_log.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# # North Island - Weekly analysis

# %%
# df_island_north = df_island_daily[df_island_daily['Island'] == 'NI'].copy()

# %%
# df_island_north = df_island_north.drop(columns=['Island'])

# %%
# df_island_north.head()

# %%
# Step 3: Resample to weekly
df_island_north_weekly = df_island_north.resample('W').mean()

# %%
# Find rows with zero Total_TP in South Island
zero_tp_south = df_island_north_weekly[df_island_north_weekly['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_tp_south.index.unique()

# Display the result
print("Dates with Total_TP = 0 in North Island:")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))

# %%
# stationery check for north island daily data
from statsmodels.tsa.stattools import adfuller

# Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
result = adfuller(df_island_north_weekly['Total_TP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_island_north_weekly[df_island_north_weekly['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)

# %%
df_island_north_weekly

# %% [markdown]
# # Train the model

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_island_north_weekly)
train_size = int(n * 0.8)
train_weekly = df_island_north_weekly.iloc[:train_size]
test_weekly = df_island_north_weekly.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly.index.min(), "to", train_weekly.index.max())
print("Weekly Test set:", test_weekly.index.min(), "to", test_weekly.index.max())

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_weekly['Total_TP']
target_test = test_weekly['Total_TP']

exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())

# %%
# Forecast on the test set - non log
n_steps = len(test_weekly)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("\nForecast Performance Metrics (Without Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train, label='Train', color='blue')
plt.plot(test_weekly.index, target_test, label='Test', color='green')
plt.plot(test_weekly.index, forecast, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Daily SARIMAX Forecast-North Island (Without Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Create a log-transformed target. Adding 1 to avoid log(0) if needed.
df_island_north_weekly['Total_TP_log'] = np.log(df_island_north_weekly['Total_TP'] + 1)

# %%
# Split the weekly data into 80% training and 20% testing sets
# n = len(df_island_north_weekly)
# train_size = int(n * 0.8)
# train_weekly = df_island_north.iloc[:train_size]
# test_weekly = df_island_north.iloc[train_size:]

# Split the weekly data into 80% training and 20% testing sets
n = len(df_island_north_weekly)
train_size = int(n * 0.8)
train_weekly = df_island_north_weekly.iloc[:train_size]
test_weekly = df_island_north_weekly.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly.index.min(), "to", train_weekly.index.max())
print("Weekly Test set:", test_weekly.index.min(), "to", test_weekly.index.max())

# %%
# Define the target variable (original Total_TP) and exogenous variables
target_train_log = train_weekly['Total_TP_log']
target_test_log = test_weekly['Total_TP_log']

# target_train = train_weekly['Total_TP']
# target_test = test_weekly['Total_TP']

exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (log) target data
model_log = SARIMAX(target_train_log,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())

# %%
# Forecast on the test set
n_steps_log = len(test_weekly)
forecast_log = results_log.get_forecast(steps=n_steps_log, exog=exog_test).predicted_mean

# %%
# Compute performance metrics
rmse = np.sqrt(mean_squared_error(target_test_log, forecast_log))
mae = mean_absolute_error(target_test_log, forecast_log)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test_log - forecast_log) / (target_test_log + epsilon))) * 100

print("\nForecast Performance Metrics (With Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train_log, label='Train', color='blue')
plt.plot(test_weekly.index, target_test_log, label='Test', color='green')
plt.plot(test_weekly.index, forecast_log, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Daily SARIMAX Forecast-North Island (With Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
results_log.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# # --------------------End island_north----------------------------

# %% [markdown]
# # -------------------- Start from here South Island ----------------------------

# %%
df_island_south = df_island_daily[df_island_daily['Island'] == 'SI'].copy()

# %%
df_island_south = df_island_south.drop(columns=['Island'])

# %%
df_island_south.head()

# %%
# Find rows with zero Total_TP in South Island
zero_tp_south = df_island_south[df_island_south['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_tp_south.index.unique()

# Display the result
print("Dates with Total_TP = 0 in South Island:")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))

# %% [markdown]
# If a zero actually means no generation (e.g., turbine was off), you might not want to interpolate—but if it’s a data artifact or gap, this is valid.

# %%
df_island_south

# %%
# Step 3: Resample to weekly
df_island_south_weekly = df_island_south.resample('W').mean()

# %%
df_clean_south_weekly
# Out:
#                 Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# DATE
# 2015-03-08  2.542296e+06  76.412937    42.630556  0.467698  14.370000
# 2015-03-15  2.574169e+06  77.127698     8.690000  0.480000  12.710000
# 2015-03-22  2.341324e+06  80.292381    14.711111  0.474921   9.167222
# 2015-03-29  2.278030e+06  83.572698    20.411111  0.482063   8.603333
# 2015-04-05  2.055918e+06  79.877222    10.513333  0.490952   9.887778
# ...                  ...        ...          ...       ...        ...
# 2025-01-05  2.096868e+06  76.979041    17.854262  0.555728  23.826024
# 2025-01-12  2.312776e+06  72.961769    12.814762  0.535102  23.720000
# 2025-01-19  2.320066e+06  73.288844     2.690476  0.504014  20.321905
# 2025-01-26  2.195515e+06  74.280680    24.646190  0.480680  17.858571
# 2025-02-02  2.148849e+06  68.009143     5.873333  0.488571  15.134286
#
#                   T2M  PRECTOTCORR_lag1
# DATE
# 2015-03-08  12.941190          2.918333
# 2015-03-15  12.604048         42.630556
# 2015-03-22   8.037778          8.690000
# 2015-03-29  11.639524         14.711111
# 2015-04-05  11.092937         20.411111
# ...               ...               ...
# 2025-01-05  11.260983         20.560000
# 2025-01-12  12.327211         17.854262
# 2025-01-19  14.151905         12.814762
# 2025-01-26  14.696395          2.690476
# 2025-02-02  13.505429         24.646190
#
# [518 rows x 7 columns]

# %%
# Find rows with zero Total_TP in South Island
zero_tp_south = df_clean_south_weekly[df_clean_south_weekly['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_tp_south.index.unique()

# Display the result
print("Dates with Total_TP = 0 in South Island:")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))
# Out:
# Dates with Total_TP = 0 in South Island:

# %%
# stationery check for north island daily data
from statsmodels.tsa.stattools import adfuller

# Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
result = adfuller(df_clean_south_weekly['Total_TP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.351832
# p-value: 0.000004
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_clean_south_weekly[df_clean_south_weekly['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of weekly records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, RH2M, PRECTOTCORR, GWETPROF, EVLAND, T2M, PRECTOTCORR_lag1]
# Index: []

# %%
df_clean_south_weekly
# Out:
#                 Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# DATE
# 2015-03-08  2.542296e+06  76.412937    42.630556  0.467698  14.370000
# 2015-03-15  2.574169e+06  77.127698     8.690000  0.480000  12.710000
# 2015-03-22  2.341324e+06  80.292381    14.711111  0.474921   9.167222
# 2015-03-29  2.278030e+06  83.572698    20.411111  0.482063   8.603333
# 2015-04-05  2.055918e+06  79.877222    10.513333  0.490952   9.887778
# ...                  ...        ...          ...       ...        ...
# 2025-01-05  2.096868e+06  76.979041    17.854262  0.555728  23.826024
# 2025-01-12  2.312776e+06  72.961769    12.814762  0.535102  23.720000
# 2025-01-19  2.320066e+06  73.288844     2.690476  0.504014  20.321905
# 2025-01-26  2.195515e+06  74.280680    24.646190  0.480680  17.858571
# 2025-02-02  2.148849e+06  68.009143     5.873333  0.488571  15.134286
#
#                   T2M  PRECTOTCORR_lag1
# DATE
# 2015-03-08  12.941190          2.918333
# 2015-03-15  12.604048         42.630556
# 2015-03-22   8.037778          8.690000
# 2015-03-29  11.639524         14.711111
# 2015-04-05  11.092937         20.411111
# ...               ...               ...
# 2025-01-05  11.260983         20.560000
# 2025-01-12  12.327211         17.854262
# 2025-01-19  14.151905         12.814762
# 2025-01-26  14.696395          2.690476
# 2025-02-02  13.505429         24.646190
#
# [518 rows x 7 columns]

# %% [markdown]
# # Train the model

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_clean_south_weekly)
train_size = int(n * 0.8)
train_weekly = df_clean_south_weekly.iloc[:train_size]
test_weekly = df_clean_south_weekly.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly.index.min(), "to", train_weekly.index.max())
print("Weekly Test set:", test_weekly.index.min(), "to", test_weekly.index.max())
# Out:
# Weekly Train set: 2015-03-08 00:00:00 to 2023-02-05 00:00:00
# Weekly Test set: 2023-02-12 00:00:00 to 2025-02-02 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_weekly['Total_TP']
target_test = test_weekly['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
#exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Total_TP   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -5482.205
# Date:                Wed, 16 Apr 2025   AIC                          10976.411
# Time:                        22:00:51   BIC                          11000.522
# Sample:                    03-08-2015   HQIC                         10985.949
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M               528.4677   2298.734      0.230      0.818   -3976.969    5033.904
# GWETPROF          5.391e+05   3.76e+05      1.432      0.152   -1.99e+05    1.28e+06
# PRECTOTCORR_lag1  1425.4247    473.838      3.008      0.003     496.719    2354.130
# ar.L1                0.2796      0.257      1.086      0.277      -0.225       0.784
# ma.L1               -0.3702      0.246     -1.506      0.132      -0.852       0.112
# sigma2            2.245e+10     20.938   1.07e+09      0.000    2.25e+10    2.25e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):                 4.49
# Prob(Q):                              0.56   Prob(JB):                         0.11
# Heteroskedasticity (H):               0.98   Skew:                            -0.11
# Prob(H) (two-sided):                  0.89   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.76e+24. Standard errors may be unstable.
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)

# %%
# Forecast on the test set - non log
n_steps = len(test_weekly)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("\nForecast Performance Metrics (Without Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 301861.32
# MAE: 244170.45
# Adjusted MAPE: 10.54%

# %%
print("Minimum of actual values in test set:", target_test.min())
print("Number of zeros in actual test set:", np.sum(target_test == 0))
# Out:
# Minimum of actual values in test set: 1541521.931972789
# Number of zeros in actual test set: 0

# %%
#
# exog_cols = ['WS50M']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 273334.64
# MAE: 213157.34
# Adjusted MAPE: 33.02%
##########################################
# exog_cols = ['WS50M','PS']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 277535.29
# MAE: 217705.17
# Adjusted MAPE: 33.91%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train, label='Train', color='blue')
plt.plot(test_weekly.index, target_test, label='Test', color='green')
plt.plot(test_weekly.index, forecast, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Weekly SARIMAX Forecast-South Island (Without Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Create a log-transformed target. Adding 1 to avoid log(0) if needed.
df_clean_south_weekly['Total_TP_log'] = np.log(df_clean_south_weekly['Total_TP'] + 1)
# Out:
# C:\Users\nwn86\AppData\Local\Temp\ipykernel_14632\3879444106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_south_weekly['Total_TP_log'] = np.log(df_clean_south_weekly['Total_TP'] + 1)

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_clean_south_weekly)
train_size = int(n * 0.8)
train_weekly = df_clean_south_weekly.iloc[:train_size]
test_weekly = df_clean_south_weekly.iloc[train_size:]

# %%
# Define the target variable (original Total_TP) and exogenous variables
target_train_log = train_weekly['Total_TP_log']
target_test_log = test_weekly['Total_TP_log']

# target_train = train_weekly['Total_TP']
# target_test = test_weekly['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
#exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (log) target data
model_log = SARIMAX(target_train_log,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Total_TP_log   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 574.674
# Date:                Wed, 16 Apr 2025   AIC                          -1137.347
# Time:                        22:04:06   BIC                          -1113.236
# Sample:                    03-08-2015   HQIC                         -1127.809
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M                 0.0003      0.001      0.333      0.739      -0.001       0.002
# GWETPROF             0.2344      0.138      1.704      0.088      -0.035       0.504
# PRECTOTCORR_lag1     0.0005      0.000      2.645      0.008       0.000       0.001
# ar.L1                0.5970      0.130      4.592      0.000       0.342       0.852
# ma.L1               -0.7439      0.117     -6.337      0.000      -0.974      -0.514
# sigma2               0.0036      0.000     14.353      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.41   Jarque-Bera (JB):                 3.70
# Prob(Q):                              0.23   Prob(JB):                         0.16
# Heteroskedasticity (H):               1.20   Skew:                            -0.15
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast on the test set
n_steps_log = len(test_weekly)
forecast_log = results_log.get_forecast(steps=n_steps_log, exog=exog_test).predicted_mean

# %%
# Compute performance metrics
rmse = np.sqrt(mean_squared_error(target_test_log, forecast_log))
mae = mean_absolute_error(target_test_log, forecast_log)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test_log - forecast_log) / (target_test_log + epsilon))) * 100

print("\nForecast Performance Metrics (With Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (With Log Transformation):
# RMSE: 0.13
# MAE: 0.10
# Adjusted MAPE: 0.70%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train_log, label='Train', color='blue')
plt.plot(test_weekly.index, target_test_log, label='Test', color='green')
plt.plot(test_weekly.index, forecast_log, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Weekly SARIMAX Forecast-South Island (With Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
results_log.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# # Both Islands in one frame

# %%
print(df_island_daily.head())

# %%
df_wind_nz = df_island_daily.copy()

# %%
print(df_island_daily['Island'].value_counts())

# %%
df_wind_nz

# %%
# Ensure DATE is datetime and set as index if not already
df_wind_nz.index = pd.to_datetime(df_wind_nz.index)

# Group by date and aggregate (mean or sum depending on requirement)
df_daily_agg = df_wind_nz.groupby(df_wind_nz.index).agg({
    'Total_TP': 'sum',   # Sum energy generation
    'PS': 'mean',        # Average air pressure
    'T2M': 'mean',       # Average temperature
    'WD50M': 'mean',     # Average wind direction
    'WS50M': 'mean'      # Average wind speed
})

# Optionally reset index if needed
df_daily_agg.index.name = 'DATE'
df_daily_agg.reset_index(inplace=True)

# View result
print(df_daily_agg.head())

# %%
df_daily_agg.set_index('DATE', inplace=True)

# %%
df_daily_agg

# %%
# df_island_combined = df_island_daily.groupby(df_island_daily.index).sum()

# %%
print(df_daily_agg.head())

# %%
# Find rows with zero Total_TP in South Island
zero_df_wind_nz = df_daily_agg[df_daily_agg['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_df_wind_nz.index.unique()

# Display the result
print("Dates with Total_TP = 0 in New Zealand:")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))

# %%
df_daily_wind_nz = df_daily_agg.copy()

# %%
df_daily_wind_nz

# %%
# df_island_north = df_island_north.drop(columns=['Island'])

# %%
# df_island_north.head()

# %%
# stationery check for north island daily data
from statsmodels.tsa.stattools import adfuller

# Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
result = adfuller(df_daily_wind_nz['Total_TP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_daily_wind_nz[df_daily_wind_nz['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)

# %%
df_daily_wind_nz

# %%
# # Check for missing values before handling
# nan_count = df_WWD1102_weekly['Total_TP'].isna().sum()
# print("Number of NaN values before cleaning:", nan_count)

# # Apply time-based interpolation
# df_WWD1102_weekly['Total_TP'] = df_WWD1102_weekly['Total_TP'].interpolate(method='time')

# # Verify that there are no more missing values
# nan_count_after = df_WWD1102_weekly['Total_TP'].isna().sum()
# print("Number of NaN values after interpolation:", nan_count_after)

# # Optionally, inspect the imputed records
# imputed_records = df_WWD1102_weekly[df_WWD1102_weekly['Total_TP'].isna()]
# print("Imputed Records (should be empty):")
# print(imputed_records)

# %%
# # Apply time interpolation to the target variable and exogenous variables
# cols_to_interpolate = ['PS','T2M','WD50M','WD50M_rad','u','v','WS50M']
# df_WWD1102_weekly[cols_to_interpolate] = df_WWD1102_weekly[cols_to_interpolate].interpolate(method='time')

# # Verify that missing values have been filled
# print("Missing values after time interpolation:")
# print(df_WWD1102_weekly[cols_to_interpolate].isna().sum())

# %%
# # stationery check for weekly data
# from statsmodels.tsa.stattools import adfuller

# # Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
# result = adfuller(df_WWD1102_weekly['Total_TP'])
# print('ADF Statistic: %f' % result[0])
# print('p-value: %f' % result[1])
# print('Critical Values:')
# for key, value in result[4].items():
#     print('\t%s: %.3f' % (key, value))

# %% [markdown]
# # Train the model

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_daily_wind_nz)
train_size = int(n * 0.8)
train_daily = df_island_north.iloc[:train_size]
test_daily = df_island_north.iloc[train_size:]

# %%
print("Daily Train set:", train_daily.index.min(), "to", train_daily.index.max())
print("Daily Test set:", test_daily.index.min(), "to", test_daily.index.max())

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_daily['Total_TP']
target_test = test_daily['Total_TP']

exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_daily[exog_cols]
exog_test = test_daily[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())

# %%
# Forecast on the test set - non log
n_steps = len(test_daily)
forecast_daily = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast_daily))
mae = mean_absolute_error(target_test, forecast_daily)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("\nForecast Performance Metrics (Without Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")

# %%
#
# exog_cols = ['WS50M']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 273334.64
# MAE: 213157.34
# Adjusted MAPE: 33.02%
##########################################
# exog_cols = ['WS50M','PS']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 277535.29
# MAE: 217705.17
# Adjusted MAPE: 33.91%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_daily.index, target_train, label='Train', color='blue')
plt.plot(test_daily.index, target_test, label='Test', color='green')
plt.plot(test_daily.index, forecast_daily, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Daily SARIMAX Forecast-New Zealand (Without Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Create a log-transformed target. Adding 1 to avoid log(0) if needed.
df_daily_wind_nz['Total_TP_log'] = np.log(df_daily_wind_nz['Total_TP'] + 1)

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_daily_wind_nz)
train_size = int(n * 0.8)
train_daily = df_daily_wind_nz.iloc[:train_size]
test_daily = df_daily_wind_nz.iloc[train_size:]

# %%
print("Daily Train set:", train_daily.index.min(), "to", train_daily.index.max())
print("Daily Test set:", test_daily.index.min(), "to", test_daily.index.max())

# %%
# Define the target variable (original Total_TP) and exogenous variables
target_train_log = train_daily['Total_TP_log']
target_test_log = test_daily['Total_TP_log']

# target_train = train_weekly['Total_TP']
# target_test = test_weekly['Total_TP']

exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_daily[exog_cols]
exog_test = test_daily[exog_cols]

# %%
# Fit SARIMAX on the original (log) target data
model_log = SARIMAX(target_train_log,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())

# %%
# Forecast on the test set
n_steps_log = len(test_daily)
forecast_log = results_log.get_forecast(steps=n_steps_log, exog=exog_test).predicted_mean

# %%
# Compute performance metrics
rmse = np.sqrt(mean_squared_error(target_test_log, forecast_log))
mae = mean_absolute_error(target_test_log, forecast_log)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test_log - forecast_log) / (target_test_log + epsilon))) * 100

print("\nForecast Performance Metrics (With Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_daily.index, target_train_log, label='Train', color='blue')
plt.plot(test_daily.index, target_test_log, label='Test', color='green')
plt.plot(test_daily.index, forecast_log, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Daily SARIMAX Forecast- New Zealand (With Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
results_log.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# # Weekly analysis for New Zealand

# %%
df_island_daily_upd
# Out:
#            DATE Island      Total_TP       RH2M  PRECTOTCORR  GWETPROF  \
# 0    2015-03-01     NI  4.603414e+05  66.255294     0.012353  0.334706
# 1    2015-03-02     NI  7.043941e+05  69.953529     0.010588  0.332353
# 2    2015-03-03     NI  6.593423e+05  73.095882     0.149412  0.331176
# 3    2015-03-04     NI  6.908145e+05  79.583529     1.104706  0.330000
# 4    2015-03-05     NI  7.082638e+05  72.791765     0.080000  0.329412
# ...         ...    ...           ...        ...          ...       ...
# 7245 2025-01-27     SI  2.027018e+06  69.201905     1.970952  0.496190
# 7246 2025-01-28     SI  2.274781e+06  63.686190     0.928571  0.490952
# 7247 2025-01-29     SI  1.919709e+06  64.899524     2.401905  0.488571
# 7248 2025-01-30     SI  2.282907e+06  72.480000     0.432857  0.486667
# 7249 2025-01-31     SI  2.239832e+06  69.778095     0.139048  0.480476
#
#         EVLAND        T2M
# 0     1.637647  19.008235
# 1     1.560000  19.220588
# 2     0.888824  18.333529
# 3     0.987647  17.398235
# 4     1.417647  19.171765
# ...        ...        ...
# 7245  2.802381  10.336667
# 7246  3.248095  13.301905
# 7247  3.843333  15.252857
# 7248  2.569524  13.720000
# 7249  2.670952  14.915714
#
# [7250 rows x 8 columns]

# %%
df_island_daily_upd_new = df_island_daily_upd.drop(columns=['Island'])

# %%
df_island_daily_upd_new
# Out:
#                 Total_TP       RH2M  PRECTOTCORR  GWETPROF    EVLAND  \
# DATE
# 2015-03-01  4.603414e+05  66.255294     0.012353  0.334706  1.637647
# 2015-03-02  7.043941e+05  69.953529     0.010588  0.332353  1.560000
# 2015-03-03  6.593423e+05  73.095882     0.149412  0.331176  0.888824
# 2015-03-04  6.908145e+05  79.583529     1.104706  0.330000  0.987647
# 2015-03-05  7.082638e+05  72.791765     0.080000  0.329412  1.417647
# ...                  ...        ...          ...       ...       ...
# 2025-01-27  2.027018e+06  69.201905     1.970952  0.496190  2.802381
# 2025-01-28  2.274781e+06  63.686190     0.928571  0.490952  3.248095
# 2025-01-29  1.919709e+06  64.899524     2.401905  0.488571  3.843333
# 2025-01-30  2.282907e+06  72.480000     0.432857  0.486667  2.569524
# 2025-01-31  2.239832e+06  69.778095     0.139048  0.480476  2.670952
#
#                   T2M
# DATE
# 2015-03-01  19.008235
# 2015-03-02  19.220588
# 2015-03-03  18.333529
# 2015-03-04  17.398235
# 2015-03-05  19.171765
# ...               ...
# 2025-01-27  10.336667
# 2025-01-28  13.301905
# 2025-01-29  15.252857
# 2025-01-30  13.720000
# 2025-01-31  14.915714
#
# [7250 rows x 6 columns]

# %%
df_island_daily_upd_new.set_index('DATE', inplace=True)

# %%
# Step 3: Resample to weekly
# Custom aggregation
df_island_daily_upd_new_v1 = df_island_daily_upd_new.resample('W').agg({
    'Total_TP': 'mean',
    'RH2M': 'mean',
    'PRECTOTCORR': 'sum',      # rainfall summed
    'GWETPROF': 'mean',
    'EVLAND': 'sum',           # summed if it's daily mm evaporation
    'T2M': 'mean'
}).reset_index()

# %%
df_island_daily_upd_new_v1['PRECTOTCORR_lag1'] = df_island_daily_upd_new_v1['PRECTOTCORR'].shift(1)  # 1-week lag

# %%
df_island_daily_cln = df_island_daily_upd_new_v1.dropna()

# %%
df_island_daily_upd_new_v1
# Out:
#           DATE      Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# 0   2015-03-01  1.398522e+06  72.119592     2.930686  0.392353   3.978758
# 1   2015-03-08  1.595132e+06  76.426636    54.632320  0.399437  25.860000
# 2   2015-03-15  1.586434e+06  76.846076    30.606471  0.409244  24.665882
# 3   2015-03-22  1.469832e+06  75.378081    38.185817  0.421662  23.223693
# 4   2015-03-29  1.437002e+06  82.111349    39.601699  0.421032  21.311569
# ..         ...           ...        ...          ...       ...        ...
# 514 2025-01-05  1.313056e+06  75.729184    37.336027  0.499208  48.454847
# 515 2025-01-12  1.513003e+06  70.399414    19.222997  0.480366  46.215882
# 516 2025-01-19  1.567560e+06  70.147993     5.435770  0.453183  38.986022
# 517 2025-01-26  1.462186e+06  74.652987    49.739720  0.434458  36.749160
# 518 2025-02-02  1.437153e+06  68.114101    10.703333  0.437933  28.281345
#
#            T2M  PRECTOTCORR_lag1
# 0    17.383007               NaN
# 1    15.413957          2.930686
# 2    14.965175         54.632320
# 3    10.907292         30.606471
# 4    13.933543         38.185817
# ..         ...               ...
# 514  13.296458         43.589412
# 515  13.963563         37.336027
# 516  15.575994         19.222997
# 517  16.633617          5.435770
# 518  15.694538         49.739720
#
# [519 rows x 8 columns]

# %%
df_island_daily_cln
# Out:
#           DATE      Total_TP       RH2M  PRECTOTCORR  GWETPROF     EVLAND  \
# 1   2015-03-08  1.595132e+06  76.426636    54.632320  0.399437  25.860000
# 2   2015-03-15  1.586434e+06  76.846076    30.606471  0.409244  24.665882
# 3   2015-03-22  1.469832e+06  75.378081    38.185817  0.421662  23.223693
# 4   2015-03-29  1.437002e+06  82.111349    39.601699  0.421032  21.311569
# 5   2015-04-05  1.325998e+06  78.754241    13.132745  0.426779  20.145425
# ..         ...           ...        ...          ...       ...        ...
# 514 2025-01-05  1.313056e+06  75.729184    37.336027  0.499208  48.454847
# 515 2025-01-12  1.513003e+06  70.399414    19.222997  0.480366  46.215882
# 516 2025-01-19  1.567560e+06  70.147993     5.435770  0.453183  38.986022
# 517 2025-01-26  1.462186e+06  74.652987    49.739720  0.434458  36.749160
# 518 2025-02-02  1.437153e+06  68.114101    10.703333  0.437933  28.281345
#
#            T2M  PRECTOTCORR_lag1
# 1    15.413957          2.930686
# 2    14.965175         54.632320
# 3    10.907292         30.606471
# 4    13.933543         38.185817
# 5    13.300586         39.601699
# ..         ...               ...
# 514  13.296458         43.589412
# 515  13.963563         37.336027
# 516  15.575994         19.222997
# 517  16.633617          5.435770
# 518  15.694538         49.739720
#
# [518 rows x 8 columns]

# %%
df_island_daily_cln.set_index('DATE', inplace=True)

# %%
plt.figure(figsize=(8, 6))
corr = df_island_daily_cln.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix : New Zealand : Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
# Find rows with zero Total_TP in South Island
zero_tp_nz = df_island_daily_cln[df_island_daily_cln['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_tp_nz.index.unique()

# Display the result
print("Dates with Total_TP = 0 in New Zealand :")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))
# Out:
# Dates with Total_TP = 0 in New Zealand :

# %%
# stationery check for north island daily data
from statsmodels.tsa.stattools import adfuller

# Assume df_model_for_forecasting has a datetime index and a 'Total_TP' column.
result = adfuller(df_island_daily_cln['Total_TP'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.024320
# p-value: 0.000020
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_island_daily_cln[df_island_daily_cln['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of weekly records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, RH2M, PRECTOTCORR, GWETPROF, EVLAND, T2M, PRECTOTCORR_lag1]
# Index: []

# %% [markdown]
# # Train the model

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_island_daily_cln)
train_size = int(n * 0.8)
train_weekly = df_island_daily_cln.iloc[:train_size]
test_weekly = df_island_daily_cln.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly.index.min(), "to", train_weekly.index.max())
print("Weekly Test set:", test_weekly.index.min(), "to", test_weekly.index.max())
# Out:
# Weekly Train set: 2015-03-08 00:00:00 to 2023-02-05 00:00:00
# Weekly Test set: 2023-02-12 00:00:00 to 2025-02-02 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_weekly['Total_TP']
target_test = test_weekly['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
#exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
# exog_train = train_weekly[exog_cols]
# exog_test = test_weekly[exog_cols]

# exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Total_TP   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -5291.758
# Date:                Wed, 16 Apr 2025   AIC                          10595.516
# Time:                        22:25:16   BIC                          10619.628
# Sample:                    03-08-2015   HQIC                         10605.054
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M             -2954.5738   1526.810     -1.935      0.053   -5947.067      37.919
# GWETPROF          1.053e+06   2.48e+05      4.242      0.000    5.66e+05    1.54e+06
# PRECTOTCORR_lag1   175.6380    155.128      1.132      0.258    -128.407     479.683
# ar.L1                0.4078      0.092      4.417      0.000       0.227       0.589
# ma.L1               -0.5505      0.081     -6.763      0.000      -0.710      -0.391
# sigma2            8.882e+09     17.532   5.07e+08      0.000    8.88e+09    8.88e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.75   Jarque-Bera (JB):                 5.87
# Prob(Q):                              0.39   Prob(JB):                         0.05
# Heteroskedasticity (H):               1.15   Skew:                            -0.23
# Prob(H) (two-sided):                  0.42   Kurtosis:                         3.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.11e+24. Standard errors may be unstable.
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)

# %%
# Forecast on the test set - non log
n_steps = len(test_weekly)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("\nForecast Performance Metrics (Without Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 247144.22
# MAE: 201097.11
# Adjusted MAPE: 12.97%

# %%
print("Minimum of actual values in test set:", target_test.min())
print("Number of zeros in actual test set:", np.sum(target_test == 0))
# Out:
# Minimum of actual values in test set: 1269121.843137255
# Number of zeros in actual test set: 0

# %%
#
# exog_cols = ['WS50M']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 273334.64
# MAE: 213157.34
# Adjusted MAPE: 33.02%
##########################################
# exog_cols = ['WS50M','PS']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 277535.29
# MAE: 217705.17
# Adjusted MAPE: 33.91%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train, label='Train', color='blue')
plt.plot(test_weekly.index, target_test, label='Test', color='green')
plt.plot(test_weekly.index, forecast, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Weekly SARIMAX Forecast-New Zealand (Without Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Create a log-transformed target. Adding 1 to avoid log(0) if needed.
df_island_daily_cln['Total_TP_log'] = np.log(df_island_daily_cln['Total_TP'] + 1)
# Out:
# C:\Users\nwn86\AppData\Local\Temp\ipykernel_14632\3141527306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_island_daily_cln['Total_TP_log'] = np.log(df_island_daily_cln['Total_TP'] + 1)

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(df_island_daily_cln)
train_size = int(n * 0.8)
train_weekly_log = df_island_daily_cln.iloc[:train_size]
test_weekly_log = df_island_daily_cln.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly_log.index.min(), "to", train_weekly_log.index.max())
print("Weekly Test set:", test_weekly_log.index.min(), "to", test_weekly_log.index.max())
# Out:
# Weekly Train set: 2015-03-08 00:00:00 to 2023-02-05 00:00:00
# Weekly Test set: 2023-02-12 00:00:00 to 2025-02-02 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
target_train_log = train_weekly_log['Total_TP_log']
target_test_log = test_weekly_log['Total_TP_log']

# target_train = train_weekly['Total_TP']
# target_test = test_weekly['Total_TP']

# %%
exog_cols = ['RH2M','GWETPROF','PRECTOTCORR_lag1']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
#exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
# exog_train = train_weekly[exog_cols]
# exog_test = test_weekly[exog_cols]

# exog_cols = ['WS50M','PS']
#exog_cols = ['WS50M']
exog_train = train_weekly[exog_cols]
exog_test = test_weekly[exog_cols]

# %%
# Fit SARIMAX on the original (log) target data
model_log = SARIMAX(target_train_log,
                exog=exog_train,
                order=(1, 1, 1),
                seasonal_order=(0, 0, 0, 0),
                enforce_stationarity=False,
                enforce_invertibility=False)
results_log = model_log.fit(disp=False)
print(results_log.summary())
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\nwn86\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:           Total_TP_log   No. Observations:                  414
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 622.679
# Date:                Wed, 16 Apr 2025   AIC                          -1233.357
# Time:                        22:27:29   BIC                          -1209.246
# Sample:                    03-08-2015   HQIC                         -1223.819
#                          - 02-05-2023
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RH2M                -0.0015      0.001     -1.838      0.066      -0.003       0.000
# GWETPROF             0.5967      0.141      4.224      0.000       0.320       0.874
# PRECTOTCORR_lag1  9.644e-05   8.87e-05      1.087      0.277   -7.74e-05       0.000
# ar.L1                0.7630      0.128      5.977      0.000       0.513       1.013
# ma.L1               -0.8557      0.119     -7.195      0.000      -1.089      -0.623
# sigma2               0.0028      0.000     15.378      0.000       0.002       0.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                10.80
# Prob(Q):                              0.67   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.49   Skew:                            -0.22
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast on the test set
n_steps_log = len(test_weekly_log)
forecast_log = results_log.get_forecast(steps=n_steps_log, exog=exog_test).predicted_mean

# %%
# Compute performance metrics
rmse = np.sqrt(mean_squared_error(target_test_log, forecast_log))
mae = mean_absolute_error(target_test_log, forecast_log)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test_log - forecast_log) / (target_test_log + epsilon))) * 100

print("\nForecast Performance Metrics (With Log Transformation):")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"Adjusted MAPE: {mape:.2f}%")
# Out:
# Forecast Performance Metrics (With Log Transformation):
# RMSE: 0.15
# MAE: 0.12
# Adjusted MAPE: 0.84%

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(14, 7))
plt.plot(train_weekly.index, target_train_log, label='Train', color='blue')
plt.plot(test_weekly.index, target_test_log, label='Test', color='green')
plt.plot(test_weekly.index, forecast_log, label='Forecast', color='red', linestyle='--')
plt.xlabel("Date")
plt.ylabel("Total_TP")
plt.title("Weekly SARIMAX Forecast- New Zealand (With Log Transformation)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %%
results_log.plot_diagnostics(figsize=(15, 10))
plt.show()
