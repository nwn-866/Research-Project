# %% [markdown]
# # Forecasting Weekly Hydro Energy Generation in New Zealand
# Model - SARIMA
#
# This notebook addresses:
# * RQ1: How well does a SARIMA model forecast weekly hydro energy generation?
# * RQ2: Does incorporating weekly-aggregated climate variables into SARIMAX improve forecasting accuracy?
#
# The analysis uses weekly sumed and weekly averaged NASA climate data, aligned with operational hydro generation data.

# %%
# Import libraries for sarima model and visuals
import pandas as pd
import numpy as np
import seaborn as sns
import pmdarima as pm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error , root_mean_squared_error , mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.losses import Huber
import random

# %% [markdown]
# # Hydro - EDA

# %%
# Step 1 : Loading previously processed hydro energy generation and climate factors
hydro_energy = pd.read_csv('hydro_data.csv')
daily_all_nsp_evland = pd.read_csv('Hydro_Factor_Daily_EVLAND.csv')
daily_all_nsp_gwetprof = pd.read_csv('Hydro_Factor_Daily_GWETPROF.csv')
daily_all_nsp_prectotcorr = pd.read_csv('Hydro_Factor_Daily_PRECTOTCORR.csv')
daily_all_nsp_rh2m = pd.read_csv('Hydro_Factor_Daily_RH2M.csv')
daily_all_nsp_t2m = pd.read_csv('Hydro_Factor_Daily_T2M.csv')

# %%
hydro_energy.tail()
# Out:
#        Fuel_Code POC_Code        DATE   Total_TP Island   Latitude   Longitude
# 132197     Hydro  WTK0111  2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111  2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111  2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111  2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111  2025-01-31  1610301.0     SI -44.692099  170.429029

# %%
daily_all_nsp_evland.head()
# Out:
#          DATE POC_Code  EVLAND
# 0  2015-01-01  ARA2201    4.03
# 1  2015-01-02  ARA2201    1.94
# 2  2015-01-03  ARA2201    2.24
# 3  2015-01-04  ARA2201    1.54
# 4  2015-01-05  ARA2201    1.95

# %%
print("------------hydro_energy----------------------")
print(hydro_energy.head())
print("----------------------------------------------")
print(hydro_energy.dtypes)
print("----------------------------------------------")
print("------------daily_all_nsp_evland--------------")
print(daily_all_nsp_evland.head())
print("----------------------------------------------")
print(daily_all_nsp_evland.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_gwetprof-----------")
print(daily_all_nsp_gwetprof.head())
print("----------------------------------------------")
print(daily_all_nsp_gwetprof.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_prectotcorr--------")
print(daily_all_nsp_prectotcorr.head())
print("----------------------------------------------")
print(daily_all_nsp_prectotcorr.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_rh2m---------------")
print(daily_all_nsp_rh2m.head())
print("----------------------------------------------")
print(daily_all_nsp_rh2m.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_t2m----------------")
print(daily_all_nsp_t2m.head())
print("----------------------------------------------")
print(daily_all_nsp_t2m.dtypes)
print("----------------------------------------------")
# Out:
# ------------hydro_energy----------------------
#   Fuel_Code POC_Code        DATE  Total_TP Island   Latitude   Longitude
# 0     Hydro  ARA2201  2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201  2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201  2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201  2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201  2015-03-05  891070.0     NI -38.615891  176.143036
# ----------------------------------------------
# Fuel_Code     object
# POC_Code      object
# DATE          object
# Total_TP     float64
# Island        object
# Latitude     float64
# Longitude    float64
# dtype: object
# ----------------------------------------------
# ------------daily_all_nsp_evland--------------
#          DATE POC_Code  EVLAND
# 0  2015-01-01  ARA2201    4.03
# 1  2015-01-02  ARA2201    1.94
# 2  2015-01-03  ARA2201    2.24
# 3  2015-01-04  ARA2201    1.54
# 4  2015-01-05  ARA2201    1.95
# ----------------------------------------------
# DATE         object
# POC_Code     object
# EVLAND      float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_gwetprof-----------
#          DATE POC_Code  GWETPROF
# 0  2015-01-01  ARA2201      0.26
# 1  2015-01-02  ARA2201      0.25
# 2  2015-01-03  ARA2201      0.25
# 3  2015-01-04  ARA2201      0.24
# 4  2015-01-05  ARA2201      0.24
# ----------------------------------------------
# DATE         object
# POC_Code     object
# GWETPROF    float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_prectotcorr--------
#          DATE POC_Code  PRECTOTCORR
# 0  2015-01-01  ARA2201         2.26
# 1  2015-01-02  ARA2201         0.00
# 2  2015-01-03  ARA2201         0.00
# 3  2015-01-04  ARA2201         0.00
# 4  2015-01-05  ARA2201         0.00
# ----------------------------------------------
# DATE            object
# POC_Code        object
# PRECTOTCORR    float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_rh2m---------------
#          DATE POC_Code   RH2M
# 0  2015-01-01  ARA2201  62.17
# 1  2015-01-02  ARA2201  64.52
# 2  2015-01-03  ARA2201  60.84
# 3  2015-01-04  ARA2201  68.73
# 4  2015-01-05  ARA2201  63.03
# ----------------------------------------------
# DATE         object
# POC_Code     object
# RH2M        float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_t2m----------------
#          DATE POC_Code    T2M
# 0  2015-01-01  ARA2201  18.22
# 1  2015-01-02  ARA2201  17.36
# 2  2015-01-03  ARA2201  19.23
# 3  2015-01-04  ARA2201  19.02
# 4  2015-01-05  ARA2201  19.26
# ----------------------------------------------
# DATE         object
# POC_Code     object
# T2M         float64
# dtype: object
# ----------------------------------------------

# %%
# As per above output dated field need to convert to date format.

# %%
# Date coversion
#daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')

hydro_energy['DATE'] = pd.to_datetime(hydro_energy['DATE'], format='%Y-%m-%d')
daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')
daily_all_nsp_gwetprof['DATE'] = pd.to_datetime(daily_all_nsp_gwetprof['DATE'], format='%Y-%m-%d')
daily_all_nsp_prectotcorr['DATE'] = pd.to_datetime(daily_all_nsp_prectotcorr['DATE'],  format='%Y-%m-%d')
daily_all_nsp_rh2m['DATE'] = pd.to_datetime(daily_all_nsp_rh2m['DATE'],  format='%Y-%m-%d')
daily_all_nsp_t2m['DATE'] = pd.to_datetime(daily_all_nsp_t2m['DATE'], format='%Y-%m-%d')

# %%
# verify the conversion

# %%
print("------------hydro_energy----------------------")
print(hydro_energy.head())
print("----------------------------------------------")
print(hydro_energy.dtypes)
print("----------------------------------------------")
print("------------daily_all_nsp_evland--------------")
print(daily_all_nsp_evland.head())
print("----------------------------------------------")
print(daily_all_nsp_evland.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_gwetprof-----------")
print(daily_all_nsp_gwetprof.head())
print("----------------------------------------------")
print(daily_all_nsp_gwetprof.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_prectotcorr--------")
print(daily_all_nsp_prectotcorr.head())
print("----------------------------------------------")
print(daily_all_nsp_prectotcorr.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_rh2m---------------")
print(daily_all_nsp_rh2m.head())
print("----------------------------------------------")
print(daily_all_nsp_rh2m.dtypes)
print("----------------------------------------------")
print("-------------daily_all_nsp_t2m----------------")
print(daily_all_nsp_t2m.head())
print("----------------------------------------------")
print(daily_all_nsp_t2m.dtypes)
print("----------------------------------------------")
# Out:
# ------------hydro_energy----------------------
#   Fuel_Code POC_Code       DATE  Total_TP Island   Latitude   Longitude
# 0     Hydro  ARA2201 2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201 2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201 2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201 2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201 2015-03-05  891070.0     NI -38.615891  176.143036
# ----------------------------------------------
# Fuel_Code            object
# POC_Code             object
# DATE         datetime64[ns]
# Total_TP            float64
# Island               object
# Latitude            float64
# Longitude           float64
# dtype: object
# ----------------------------------------------
# ------------daily_all_nsp_evland--------------
#         DATE POC_Code  EVLAND
# 0 2015-01-01  ARA2201    4.03
# 1 2015-01-02  ARA2201    1.94
# 2 2015-01-03  ARA2201    2.24
# 3 2015-01-04  ARA2201    1.54
# 4 2015-01-05  ARA2201    1.95
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# EVLAND             float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_gwetprof-----------
#         DATE POC_Code  GWETPROF
# 0 2015-01-01  ARA2201      0.26
# 1 2015-01-02  ARA2201      0.25
# 2 2015-01-03  ARA2201      0.25
# 3 2015-01-04  ARA2201      0.24
# 4 2015-01-05  ARA2201      0.24
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# GWETPROF           float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_prectotcorr--------
#         DATE POC_Code  PRECTOTCORR
# 0 2015-01-01  ARA2201         2.26
# 1 2015-01-02  ARA2201         0.00
# 2 2015-01-03  ARA2201         0.00
# 3 2015-01-04  ARA2201         0.00
# 4 2015-01-05  ARA2201         0.00
# ----------------------------------------------
# DATE           datetime64[ns]
# POC_Code               object
# PRECTOTCORR           float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_rh2m---------------
#         DATE POC_Code   RH2M
# 0 2015-01-01  ARA2201  62.17
# 1 2015-01-02  ARA2201  64.52
# 2 2015-01-03  ARA2201  60.84
# 3 2015-01-04  ARA2201  68.73
# 4 2015-01-05  ARA2201  63.03
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# RH2M               float64
# dtype: object
# ----------------------------------------------
# -------------daily_all_nsp_t2m----------------
#         DATE POC_Code    T2M
# 0 2015-01-01  ARA2201  18.22
# 1 2015-01-02  ARA2201  17.36
# 2 2015-01-03  ARA2201  19.23
# 3 2015-01-04  ARA2201  19.02
# 4 2015-01-05  ARA2201  19.26
# ----------------------------------------------
# DATE        datetime64[ns]
# POC_Code            object
# T2M                float64
# dtype: object
# ----------------------------------------------

# %%
# Get list of POC codes to load
unique_pocs_hydro = hydro_energy['POC_Code'].unique()
# unique_pocs_hydro = hydro_energy['POC_Code'].unique()

# %%
print(unique_pocs_hydro)
print(len(unique_pocs_hydro))
print(len(hydro_energy))
print("Min DATE:", hydro_energy['DATE'].min())
print("Max DATE:", hydro_energy['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 132202
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00

# %%
# hydro_energy.tail()

# %%
# Get list of POC codes to evland and it's records counts. 
unique_pocs_evland = daily_all_nsp_evland['POC_Code'].unique()
print(unique_pocs_evland)
print(len(unique_pocs_evland))
print(len(daily_all_nsp_evland))
print("Min DATE:", daily_all_nsp_evland['DATE'].min())
print("Max DATE:", daily_all_nsp_evland['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to gwetprof
unique_pocs_gwetprof = daily_all_nsp_gwetprof['POC_Code'].unique()
print(unique_pocs_gwetprof)
print(len(unique_pocs_gwetprof))
print(len(daily_all_nsp_gwetprof))
print("Min DATE:", daily_all_nsp_gwetprof['DATE'].min())
print("Max DATE:", daily_all_nsp_gwetprof['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to prectotcorr
unique_pocs_prectotcorr = daily_all_nsp_prectotcorr['POC_Code'].unique()
print(unique_pocs_prectotcorr)
print(len(unique_pocs_prectotcorr))
print(len(daily_all_nsp_prectotcorr))
print("Min DATE:", daily_all_nsp_prectotcorr['DATE'].min())
print("Max DATE:", daily_all_nsp_prectotcorr['DATE'].max())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to rh2m
unique_pocs_rh2m = daily_all_nsp_rh2m['POC_Code'].unique()
print(unique_pocs_rh2m)
print(len(unique_pocs_rh2m))
print(len(daily_all_nsp_rh2m))
print("Min DATE:", daily_all_nsp_rh2m['DATE'].min())
print("Max DATE:", daily_all_nsp_rh2m['DATE'].max())

# print(daily_all_nsp_rh2m.dtypes)
# print("----------------------------------------------")
# print("-------------daily_all_nsp_t2m----------------")
# print(daily_all_nsp_t2m.head())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Get list of POC codes to t2m
unique_pocs_t2m = daily_all_nsp_t2m['POC_Code'].unique()
print(unique_pocs_t2m)
print(len(unique_pocs_t2m))
print(len(daily_all_nsp_t2m))
print("Min DATE:", daily_all_nsp_t2m['DATE'].min())
print("Max DATE:", daily_all_nsp_t2m['DATE'].max())

# print(daily_all_nsp_rh2m.dtypes)
# print("----------------------------------------------")
# print("-------------daily_all_nsp_t2m----------------")
# print(daily_all_nsp_t2m.head())
# Out:
# ['ARA2201' 'ARG1101' 'ARI1101' 'ARI1102' 'ASB0661' 'ATI2201' 'AVI2201'
#  'BEN2202' 'BWK1101' 'COL0661' 'CYD0331' 'CYD2201' 'HWA1101' 'HWB0331'
#  'KPO1101' 'MAN2201' 'MAT1101' 'MHO0331' 'MTI2201' 'NSY0331' 'OHA2201'
#  'OHB2201' 'OHC2201' 'OHK2201' 'ROT1101' 'ROX1101' 'ROX2201' 'RPO2201'
#  'STK0661' 'TGA0331' 'TKA0111' 'TKB2201' 'TKU2201' 'TUI1101' 'WKM2201'
#  'WPA2201' 'WPG0331' 'WTK0111']
# 38
# 141056
# Min DATE: 2015-01-01 00:00:00
# Max DATE: 2025-02-28 00:00:00

# %%
# Filter data between 2015-03-01 and 2025-01-31
filtered_daily_all_nsp_t2m = daily_all_nsp_t2m[(daily_all_nsp_t2m['DATE'] >= '2015-03-01') & (daily_all_nsp_t2m['DATE'] < '2025-02-01')]
filtered_daily_all_nsp_evland = daily_all_nsp_evland[(daily_all_nsp_evland['DATE'] >= '2015-03-01') & (daily_all_nsp_evland['DATE'] < '2025-02-01')]
filtered_daily_all_nsp_gwetprof = daily_all_nsp_gwetprof[(daily_all_nsp_gwetprof['DATE'] >= '2015-03-01') & (daily_all_nsp_gwetprof['DATE'] < '2025-02-01')]
filtered_daily_all_nsp_prectotcorr = daily_all_nsp_prectotcorr[(daily_all_nsp_prectotcorr['DATE'] >= '2015-03-01') & (daily_all_nsp_prectotcorr['DATE'] < '2025-02-01')]
filtered_daily_all_nsp_rh2m = daily_all_nsp_rh2m[(daily_all_nsp_rh2m['DATE'] >= '2015-03-01') & (daily_all_nsp_rh2m['DATE'] < '2025-02-01')]


# daily_all_nsp_evland['DATE'] = pd.to_datetime(daily_all_nsp_evland['DATE'], format='%Y-%m-%d')
# daily_all_nsp_gwetprof['DATE'] = pd.to_datetime(daily_all_nsp_gwetprof['DATE'], format='%Y-%m-%d')
# daily_all_nsp_prectotcorr['DATE'] = pd.to_datetime(daily_all_nsp_prectotcorr['DATE'],  format='%Y-%m-%d')
# daily_all_nsp_rh2m['DATE'] = pd.to_datetime(daily_all_nsp_rh2m['DATE'],  format='%Y-%m-%d')
# daily_all_nsp_t2m['DATE'] = pd.to_datetime(daily_all_nsp_t2m['DATE'], format='%Y-%m-%d')

# %%
print(len(filtered_daily_all_nsp_t2m))
print("Min DATE:", filtered_daily_all_nsp_t2m['DATE'].min())
print("Max DATE:", filtered_daily_all_nsp_t2m['DATE'].max())
print(len(filtered_daily_all_nsp_prectotcorr))
print("Min DATE:", filtered_daily_all_nsp_prectotcorr['DATE'].min())
print("Max DATE:", filtered_daily_all_nsp_prectotcorr['DATE'].max())
# Out:
# 137750
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00
# 137750
# Min DATE: 2015-03-01 00:00:00
# Max DATE: 2025-01-31 00:00:00

# %%
filtered_daily_all_nsp_prectotcorr.head()
# Out:
#          DATE POC_Code  PRECTOTCORR
# 59 2015-03-01  ARA2201         0.00
# 60 2015-03-02  ARA2201         0.00
# 61 2015-03-03  ARA2201         0.14
# 62 2015-03-04  ARA2201         1.09
# 63 2015-03-05  ARA2201         0.01

# %%
record_counts_precep = filtered_daily_all_nsp_prectotcorr.groupby('POC_Code').size()
print(record_counts_precep)
# Out:
# POC_Code
# ARA2201    3625
# ARG1101    3625
# ARI1101    3625
# ARI1102    3625
# ASB0661    3625
# ATI2201    3625
# AVI2201    3625
# BEN2202    3625
# BWK1101    3625
# COL0661    3625
# CYD0331    3625
# CYD2201    3625
# HWA1101    3625
# HWB0331    3625
# KPO1101    3625
# MAN2201    3625
# MAT1101    3625
# MHO0331    3625
# MTI2201    3625
# NSY0331    3625
# OHA2201    3625
# OHB2201    3625
# OHC2201    3625
# OHK2201    3625
# ROT1101    3625
# ROX1101    3625
# ROX2201    3625
# RPO2201    3625
# STK0661    3625
# TGA0331    3625
# TKA0111    3625
# TKB2201    3625
# TKU2201    3625
# TUI1101    3625
# WKM2201    3625
# WPA2201    3625
# WPG0331    3625
# WTK0111    3625
# dtype: int64

# %%
record_counts_hydro = hydro_energy.groupby('POC_Code').size()
print(record_counts_hydro)
# Out:
# POC_Code
# ARA2201    3625
# ARG1101    3625
# ARI1101    3625
# ARI1102    3625
# ASB0661    3614
# ATI2201    3625
# AVI2201    3625
# BEN2202    3625
# BWK1101    3625
# COL0661    3625
# CYD0331    1858
# CYD2201    3625
# HWA1101    3625
# HWB0331    1858
# KPO1101    3625
# MAN2201    3625
# MAT1101    3612
# MHO0331    3625
# MTI2201    3625
# NSY0331    3625
# OHA2201    3625
# OHB2201    3625
# OHC2201    3625
# OHK2201    3625
# ROT1101    3625
# ROX1101    3625
# ROX2201    3625
# RPO2201    3625
# STK0661    1858
# TGA0331    3412
# TKA0111    3625
# TKB2201    3625
# TKU2201    3625
# TUI1101    3625
# WKM2201    3625
# WPA2201    3625
# WPG0331    3615
# WTK0111    3625
# dtype: int64

# %% [raw]
# # Following lines for merge data sets

# %%
# Merge rh2m with prectotcorr
merge1 = pd.merge(filtered_daily_all_nsp_rh2m, filtered_daily_all_nsp_prectotcorr, on=['POC_Code', 'DATE'], how='inner')
print("Merge 1 : rh2m with prectotcorr ", merge1.shape)
# Out:
# Merge 1 : rh2m with prectotcorr  (137750, 4)

# %%
merge1.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR
# 0 2015-03-01  ARA2201  57.62         0.00
# 1 2015-03-02  ARA2201  68.36         0.00
# 2 2015-03-03  ARA2201  68.50         0.14
# 3 2015-03-04  ARA2201  79.20         1.09
# 4 2015-03-05  ARA2201  69.77         0.01

# %%
# Merge merge1 with gwetprof
merge2 = pd.merge(merge1, filtered_daily_all_nsp_gwetprof, on=['POC_Code', 'DATE'], how='inner')
print("Merge 2 : Merge 1 with gwetprof):", merge2.shape)
# Out:
# Merge 2 : Merge 1 with gwetprof): (137750, 5)

# %%
merge2.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF
# 0 2015-03-01  ARA2201  57.62         0.00      0.19
# 1 2015-03-02  ARA2201  68.36         0.00      0.19
# 2 2015-03-03  ARA2201  68.50         0.14      0.19
# 3 2015-03-04  ARA2201  79.20         1.09      0.19
# 4 2015-03-05  ARA2201  69.77         0.01      0.19

# %%
# Merge merge2 with evland
merge3 = pd.merge(merge2, filtered_daily_all_nsp_evland, on=['POC_Code', 'DATE'], how='inner')
print("Merge 3 : Merge 2 with evland ", merge3.shape)
# Out:
# Merge 3 : Merge 2 with evland  (137750, 6)

# %%
merge3.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND
# 0 2015-03-01  ARA2201  57.62         0.00      0.19    1.01
# 1 2015-03-02  ARA2201  68.36         0.00      0.19    0.84
# 2 2015-03-03  ARA2201  68.50         0.14      0.19    0.45
# 3 2015-03-04  ARA2201  79.20         1.09      0.19    0.95
# 4 2015-03-05  ARA2201  69.77         0.01      0.19    0.70

# %%
# Merge merge3 with t2m
merge4 = pd.merge(merge3, filtered_daily_all_nsp_t2m, on=['POC_Code', 'DATE'], how='inner',)
print("Merge4 : Merge 3 with t2m :", merge4.shape)
# Out:
# Merge4 : Merge 3 with t2m : (137750, 7)

# %%
merge4.head()
# Out:
#         DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0 2015-03-01  ARA2201  57.62         0.00      0.19    1.01  19.11
# 1 2015-03-02  ARA2201  68.36         0.00      0.19    0.84  19.03
# 2 2015-03-03  ARA2201  68.50         0.14      0.19    0.45  18.00
# 3 2015-03-04  ARA2201  79.20         1.09      0.19    0.95  16.43
# 4 2015-03-05  ARA2201  69.77         0.01      0.19    0.70  18.74

# %%
merge4.tail()
# Out:
#              DATE POC_Code   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 137745 2025-01-27  WTK0111  64.93         1.73      0.44    2.48  10.90
# 137746 2025-01-28  WTK0111  56.24         0.08      0.43    3.01  14.74
# 137747 2025-01-29  WTK0111  57.06         0.84      0.43    3.68  17.65
# 137748 2025-01-30  WTK0111  73.86         0.48      0.43    2.13  14.05
# 137749 2025-01-31  WTK0111  72.17         0.19      0.42    2.05  15.41

# %%
# Merge merge4 with hydro
final_merge = pd.merge(hydro_energy, merge4, on=['POC_Code', 'DATE'], how='left',)
print("final merge : Merge 4 with Hydro Energy ", final_merge.shape)
# Out:
# final merge : Merge 4 with Hydro Energy  (132202, 12)

# %%
print("hydro_energy:", hydro_energy.shape)
# Out:
# hydro_energy: (132202, 7)

# %% [raw]
# # Above lines confirm hydro energy records counts tally with the final merge

# %%
final_merge.head()
# Out:
#   Fuel_Code POC_Code       DATE  Total_TP Island   Latitude   Longitude  \
# 0     Hydro  ARA2201 2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201 2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201 2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201 2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201 2015-03-05  891070.0     NI -38.615891  176.143036
#
#     RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0  57.62         0.00      0.19    1.01  19.11
# 1  68.36         0.00      0.19    0.84  19.03
# 2  68.50         0.14      0.19    0.45  18.00
# 3  79.20         1.09      0.19    0.95  16.43
# 4  69.77         0.01      0.19    0.70  18.74

# %%
final_merge.tail()
# Out:
#        Fuel_Code POC_Code       DATE   Total_TP Island   Latitude   Longitude  \
# 132197     Hydro  WTK0111 2025-01-27  1427007.0     SI -44.692099  170.429029
# 132198     Hydro  WTK0111 2025-01-28  1990551.0     SI -44.692099  170.429029
# 132199     Hydro  WTK0111 2025-01-29  1720931.0     SI -44.692099  170.429029
# 132200     Hydro  WTK0111 2025-01-30  1407865.0     SI -44.692099  170.429029
# 132201     Hydro  WTK0111 2025-01-31  1610301.0     SI -44.692099  170.429029
#
#          RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 132197  64.93         1.73      0.44    2.48  10.90
# 132198  56.24         0.08      0.43    3.01  14.74
# 132199  57.06         0.84      0.43    3.68  17.65
# 132200  73.86         0.48      0.43    2.13  14.05
# 132201  72.17         0.19      0.42    2.05  15.41

# %%
all_poc_data = final_merge.copy()

# %%
# Write the final merged DataFrame to a CSV file
all_poc_data.to_csv('EDA_Hydro_all_POC_20250602_0700.csv', index=False)

print("Final merge saved to final_merged.csv")
# Out:
# Final merge saved to final_merged.csv

# %%
# Check for missing values in each column
missing_values = all_poc_data.isnull().sum()
print(missing_values)
# Out:
# Fuel_Code      0
# POC_Code       0
# DATE           0
# Total_TP       0
# Island         0
# Latitude       0
# Longitude      0
# RH2M           0
# PRECTOTCORR    0
# GWETPROF       0
# EVLAND         0
# T2M            0
# dtype: int64

# %%
# check if there are any missing values at all
if all_poc_data.isnull().values.any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values found in the DataFrame.")
# Out:
# No missing values found in the DataFrame.

# %%
# List all column names 
print(all_poc_data.columns)

# list the column names as a list
print(all_poc_data.columns.tolist())
# Out:
# Index(['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude',
#        'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M'],
#       dtype='object')
# ['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude', 'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M']

# %%
# selected_columns_POC = ['Fuel_Code','POC_Code', 'DATE','Total_TP', 'PS','T2M','WD50M','WD50M_rad','u','v','WS50M']  # Replace with desired column names

# %%
selected_columns_for_hydro = ['DATE','Island','Total_TP', 'RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']  # Replace with your desired column names

# %%
# df_wind_daily_final_all_POC = final_merge[selected_columns_POC].copy()

# %%
df_hydro_daily_all = all_poc_data[selected_columns_for_hydro].copy()

# %%
df_hydro_daily_all.head()
# Out:
#         DATE Island  Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0 2015-03-01     NI  484010.0  57.62         0.00      0.19    1.01  19.11
# 1 2015-03-02     NI  598280.0  68.36         0.00      0.19    0.84  19.03
# 2 2015-03-03     NI  626290.0  68.50         0.14      0.19    0.45  18.00
# 3 2015-03-04     NI  826700.0  79.20         1.09      0.19    0.95  16.43
# 4 2015-03-05     NI  891070.0  69.77         0.01      0.19    0.70  18.74

# %%
df_hydro_daily_all.set_index('DATE', inplace=True)

# %%
df_hydro_daily_all.head()
# Out:
#            Island  Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# DATE
# 2015-03-01     NI  484010.0  57.62         0.00      0.19    1.01  19.11
# 2015-03-02     NI  598280.0  68.36         0.00      0.19    0.84  19.03
# 2015-03-03     NI  626290.0  68.50         0.14      0.19    0.45  18.00
# 2015-03-04     NI  826700.0  79.20         1.09      0.19    0.95  16.43
# 2015-03-05     NI  891070.0  69.77         0.01      0.19    0.70  18.74

# %%
print(df_hydro_daily_all.dtypes)
# Out:
# Island          object
# Total_TP       float64
# RH2M           float64
# PRECTOTCORR    float64
# GWETPROF       float64
# EVLAND         float64
# T2M            float64
# dtype: object

# %%
record_counts = df_hydro_daily_all.groupby('Island').size()
print(record_counts)
# Out:
# Island
# NI    61399
# SI    70803
# dtype: int64

# %%
# count the rows on a given date
count = df_hydro_daily_all.loc['2015-03-02'].shape[0]
print(f"Number of records on 2015‑03‑02: {count}")
# Out:
# Number of records on 2015‑03‑02: 35

# %% [raw]
# # To roll up your site‑level daily data into island‑level daily aggregates

# %%
# 1. Define your custom agg: sum for some columns, mean for the rest
agg_dict = {
    'Total_TP':    'sum',
    'PRECTOTCORR': 'sum',
    'EVLAND':      'sum',
    'RH2M':        'mean',
    'GWETPROF':    'mean',
    'T2M':         'mean'
   }

# %%
# Perform weekly aggregation grouped by Island
df_hydro_weekly = df_hydro_daily_all.groupby([pd.Grouper(freq='W'), 'Island']).agg(agg_dict)

# %%
df_hydro_weekly.head()
# Out:
#                        Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF  \
# DATE       Island
# 2015-03-01 NI      7.825804e+06         0.21   27.84  66.255294  0.334706
#            SI      4.206066e+07        52.53   42.14  77.983889  0.450000
# 2015-03-08 NI      7.710830e+07       204.03  195.33  76.440336  0.331176
#            SI      3.203293e+08       767.35  258.66  76.412937  0.467698
# 2015-03-15 NI      7.124508e+07       372.58  203.25  76.564454  0.338487
#
#                          T2M
# DATE       Island
# 2015-03-01 NI      19.008235
#            SI      15.757778
# 2015-03-08 NI      17.886723
#            SI      12.941190
# 2015-03-15 NI      17.326303

# %%
#North Island specific data
df_hydro_weekly_north = df_hydro_weekly.xs('NI', level='Island')

# %%
df_hydro_weekly_north.head()
# Out:
#                Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M
# DATE
# 2015-03-01   7825804.44         0.21   27.84  66.255294  0.334706  19.008235
# 2015-03-08  77108297.22       204.03  195.33  76.440336  0.331176  17.886723
# 2015-03-15  71245084.70       372.58  203.25  76.564454  0.338487  17.326303
# 2015-03-22  71202576.46       399.07  238.96  70.463782  0.368403  13.776807
# 2015-03-29  70920967.42       326.24  216.04  80.650000  0.360000  16.227563

# %%
#South Island specific data
df_hydro_weekly_south = df_hydro_weekly.xs('SI', level='Island')

# %%
df_hydro_weekly_south.head()
# Out:
#                 Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M
# DATE
# 2015-03-01  4.206066e+07        52.53   42.14  77.983889  0.450000  15.757778
# 2015-03-08  3.203293e+08       767.35  258.66  76.412937  0.467698  12.941190
# 2015-03-15  3.243453e+08       156.42  228.78  77.127698  0.480000  12.604048
# 2015-03-22  2.950068e+08       264.80  165.01  80.292381  0.474921   8.037778
# 2015-03-29  2.870318e+08       367.40  154.86  83.572698  0.482063  11.639524

# %%
# Check for rows Total_TP equals 0.0
zero_records = df_hydro_weekly_south[df_hydro_weekly_south['Total_TP'] == 0]
print("Number of daily records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of daily records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, PRECTOTCORR, EVLAND, RH2M, GWETPROF, T2M]
# Index: []

# %%
# Check for rows Total_TP equals 0.0
zero_records = df_hydro_weekly_north[df_hydro_weekly_north['Total_TP'] == 0]
print("Number of daily records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of daily records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, PRECTOTCORR, EVLAND, RH2M, GWETPROF, T2M]
# Index: []

# %%
# Check for missing values before handling
nan_count = df_hydro_weekly_south['Total_TP'].isna().sum()
print("Number of NaN values before cleaning:", nan_count)
# Out:
# Number of NaN values before cleaning: 0

# %%
# Check for missing values before handling

# %%
# # # Check for missing values before handling
# # nan_count = df_island_daily['Total_TP'].isna().sum()
# # print("Number of NaN values before cleaning:", nan_count)

# # # Apply time-based interpolation
# # df_island_daily['Total_TP'] = df_island_daily['Total_TP'].interpolate(method='time')

# # Verify that there are no more missing values
# nan_count_after = df_island_daily['Total_TP'].isna().sum()
# print("Number of NaN values after interpolation:", nan_count_after)

# # Optionally, inspect the imputed records
# imputed_records = df_island_daily[df_island_daily['Total_TP'].isna()]
# print("Imputed Records (should be empty):")
# print(imputed_records)

# %%
# # Apply time interpolation to the target variable and exogenous variables
# cols_to_interpolate = ['PS','T2M','WD50M','WD50M_rad','u','v','WS50M']
# df_WWD1102_weekly[cols_to_interpolate] = df_WWD1102_weekly[cols_to_interpolate].interpolate(method='time')

# # Verify that missing values have been filled
# print("Missing values after time interpolation:")
# print(df_WWD1102_weekly[cols_to_interpolate].isna().sum())

# %%
# # Verify that there are no more missing values
# nan_count_after = df_WWD1102_weekly['Total_TP'].isna().sum()
# print("Number of NaN values after interpolation:", nan_count_after)

# %%
print(df_hydro_weekly_north.head())
print(df_hydro_weekly_north.tail())
# Out:
#                Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M
# DATE
# 2015-03-01   7825804.44         0.21   27.84  66.255294  0.334706  19.008235
# 2015-03-08  77108297.22       204.03  195.33  76.440336  0.331176  17.886723
# 2015-03-15  71245084.70       372.58  203.25  76.564454  0.338487  17.326303
# 2015-03-22  71202576.46       399.07  238.96  70.463782  0.368403  13.776807
# 2015-03-29  70920967.42       326.24  216.04  80.650000  0.360000  16.227563
#               Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M
# DATE
# 2025-01-05  62980054.0       331.19  418.69  74.479328  0.442689  15.331933
# 2025-01-12  84874356.0       108.94  382.43  67.837059  0.425630  15.599916
# 2025-01-19  96991450.0        46.67  317.29  67.007143  0.402353  17.000084
# 2025-01-26  86733894.0       426.59  321.14  75.025294  0.388235  18.570840
# 2025-02-02  61663749.0        82.11  223.50  68.219059  0.387294  17.883647

# %%
df_hydro_weekly_north_before = df_hydro_weekly_north.copy()

# %%
print(df_hydro_weekly_north_before.shape)
# Out:
# (519, 6)

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_hydro_weekly_north = df_hydro_weekly_north.drop(index=pd.to_datetime('2015-03-01'))

# %%
df_hydro_weekly_north = df_hydro_weekly_north.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_hydro_weekly_north.shape)
# Out:
# (517, 6)

# %%
df_hydro_weekly_south_before = df_hydro_weekly_south.copy()

# %%
print(df_hydro_weekly_south_before.shape)
# Out:
# (519, 6)

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_hydro_weekly_south = df_hydro_weekly_south.drop(index=pd.to_datetime('2015-03-01'))

# %%
df_hydro_weekly_south = df_hydro_weekly_south.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_hydro_weekly_south.shape)
# Out:
# (517, 6)

# %% [markdown]
# # Correlation Analysis Between Climate Features and Hydro Generation

# %%
# Compute correlation matrix - North Island
correlation_matrix_north = df_hydro_weekly_north.corr()

# Plot heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(correlation_matrix_north, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation for hydro North Island (Weekly Aggregated)')
plt.show()

# %%
# Compute correlation matrix - South Island
correlation_matrix_south = df_hydro_weekly_south.corr()

# Plot heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(correlation_matrix_south, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation for hydro South Island (Weekly Aggregated)')
plt.show()

# %% [markdown]
# <!-- # All Island Weekly
# # df_hydro_weekly['PRECIP_7d'] = df_hydro_weekly['PRECTOTCORR'].rolling(7, min_periods=1).sum() #Rolling sums - total rain over the last 7 days
# # df_hydro_weekly['PRECIP_14d'] = df_hydro_weekly['PRECTOTCORR'].rolling(14, min_periods=1).sum() #Rolling sums - total rain over the last 7 days
# # df_hydro_weekly['PRECIP_lag1'] = df_hydro_weekly['PRECTOTCORR'].shift(1) # Lagged values yesterday’s rain
# # df_hydro_weekly['PRECIP_lag7'] = df_hydro_weekly['PRECTOTCORR'].shift(7) # Lagged values last week’s rain
# df_hydro_weekly['PRECIP_lag1w'] = df_hydro_weekly['PRECTOTCORR'].shift(1)
# df_hydro_weekly['PRECIP_lag2w'] = df_hydro_weekly['PRECTOTCORR'].shift(2)
# df_hydro_weekly['API_weekly'] = df_hydro_weekly['PRECTOTCORR'].ewm(alpha=0.3, adjust=False).mean() -->

# %%
# Add 1 to 2-week lagged climate features
df_hydro_weekly_north['TP_lag1w'] = df_hydro_weekly_north['Total_TP'].shift(1)
df_hydro_weekly_north['T2M_lag1w'] = df_hydro_weekly_north['T2M'].shift(1)
df_hydro_weekly_north['GWETPROF_lag1w'] = df_hydro_weekly_north['GWETPROF'].shift(1)
df_hydro_weekly_north['RH2M_lag1w'] = df_hydro_weekly_north['RH2M'].shift(1)
df_hydro_weekly_north['PRECIP_lag1w'] = df_hydro_weekly_north['PRECTOTCORR'].shift(1)
df_hydro_weekly_north['EVLAND_lag1w'] = df_hydro_weekly_north['EVLAND'].shift(1)
df_hydro_weekly_north['PRECIP_lag2w'] = df_hydro_weekly_north['PRECTOTCORR'].shift(2)
df_hydro_weekly_north['PRECIP_EWMA'] = df_hydro_weekly_north['PRECTOTCORR'].ewm(alpha=0.3, adjust=False).mean()
# EWMA for EVLAND with a “slow” decay (alpha = 0.1)
df_hydro_weekly_north['EVLAND_EWMA'] = df_hydro_weekly_north['EVLAND'].ewm(alpha=0.3, adjust=False).mean()
df_hydro_weekly_north['APIxGWETPROF'] = df_hydro_weekly_north['PRECIP_EWMA'] * df_hydro_weekly_north['GWETPROF']

# %%
df_hydro_weekly_north.head()
# Out:
#                Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M  \
# DATE
# 2015-03-08  77108297.22       204.03  195.33  76.440336  0.331176  17.886723
# 2015-03-15  71245084.70       372.58  203.25  76.564454  0.338487  17.326303
# 2015-03-22  71202576.46       399.07  238.96  70.463782  0.368403  13.776807
# 2015-03-29  70920967.42       326.24  216.04  80.650000  0.360000  16.227563
# 2015-04-05  70933314.09        44.53  174.38  77.631261  0.362605  15.508235
#
#                TP_lag1w  T2M_lag1w  GWETPROF_lag1w  RH2M_lag1w  PRECIP_lag1w  \
# DATE
# 2015-03-08          NaN        NaN             NaN         NaN           NaN
# 2015-03-15  77108297.22  17.886723        0.331176   76.440336        204.03
# 2015-03-22  71245084.70  17.326303        0.338487   76.564454        372.58
# 2015-03-29  71202576.46  13.776807        0.368403   70.463782        399.07
# 2015-04-05  70920967.42  16.227563        0.360000   80.650000        326.24
#
#             EVLAND_lag1w  PRECIP_lag2w  PRECIP_EWMA  EVLAND_EWMA  APIxGWETPROF
# DATE
# 2015-03-08           NaN           NaN   204.030000   195.330000     67.569935
# 2015-03-15        195.33           NaN   254.595000   197.706000     86.177198
# 2015-03-22        203.25        204.03   297.937500   210.082200    109.761176
# 2015-03-29        238.96        372.58   306.428250   211.869540    110.314170
# 2015-04-05        216.04        399.07   227.858775   200.622678     82.622741

# %%
# Drop original non-lagged features and drop NA from lagging
weekly_lagged_north = df_hydro_weekly_north[['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','APIxGWETPROF','PRECIP_lag2w','PRECIP_EWMA','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','GWETPROF','GWETPROF_lag1w','T2M','T2M_lag1w']].dropna()
weekly_lagged_north.head()
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    109.761176        204.03   297.937500  238.96        203.25
# 2015-03-29    110.314170        372.58   306.428250  216.04        238.96
# 2015-04-05     82.622741        399.07   227.858775  174.38        216.04
# 2015-04-12    140.663256        326.24   374.724142  185.60        174.38
# 2015-04-19    188.502533         44.53   456.301900  184.17        185.60
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   210.082200  70.463782   76.564454  0.368403        0.338487
# 2015-03-29   211.869540  80.650000   70.463782  0.360000        0.368403
# 2015-04-05   200.622678  77.631261   80.650000  0.362605        0.360000
# 2015-04-12   196.115875  85.405462   77.631261  0.375378        0.362605
# 2015-04-19   192.532112  80.490084   85.405462  0.413109        0.375378
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639

# %%
order = ['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','PRECIP_lag2w','PRECIP_EWMA','GWETPROF','GWETPROF_lag1w','APIxGWETPROF','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','T2M','T2M_lag1w']
weekly_lagged_north = weekly_lagged_north[order]

# %%
# Compute correlation matrix - North Island
correlation_matrix_with_lag_north = weekly_lagged_north.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix_with_lag_north, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation for Hydro North Island (Weekly Aggregated)')
plt.show()

# %%
import matplotlib.pyplot as plt

for feat in ['APIxGWETPROF', 'PRECIP_EWMA']:
    plt.figure(figsize=(5, 4))
    plt.scatter(df_hydro_weekly_north[feat], df_hydro_weekly_north['Total_TP'], alpha=0.6)
    plt.xlabel(feat)
    plt.ylabel('Total_TP')
    plt.title(f'North Island: {feat} vs. Generation')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [raw]
# # Best possibile Predictors > .3 and unique
# [
#   "TP_lag1w",       # last week’s generation
#   "APIxGWETPROF",   # precipitation‐EWMA × ground‐wetness
#   "PRECIP_EWMA",    # EWMA of precipitation
#   "GWETPROF",       # ground‐wetness index
#   "RH2M_lag1w",     # 1‐week lag humidity
#   "EVLAND_lag1w",   # 1‐week lag evapotranspiration
#   "T2M_lag1w"       # 1‐week lag temperature
# ]

# %%
factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']

for f in factors:
    plt.figure(figsize=(10, 3))
    plt.plot(df_hydro_weekly_north[f], label=f)
    plt.title(f'{f} Weekly Trend')
    plt.xlabel('Date')
    plt.ylabel(f)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# South Island

# %%
# Add 1 to 2-week lagged climate features
df_hydro_weekly_south['TP_lag1w'] = df_hydro_weekly_south['Total_TP'].shift(1)
df_hydro_weekly_south['T2M_lag1w'] = df_hydro_weekly_south['T2M'].shift(1)
df_hydro_weekly_south['GWETPROF_lag1w'] = df_hydro_weekly_south['GWETPROF'].shift(1)
df_hydro_weekly_south['RH2M_lag1w'] = df_hydro_weekly_south['RH2M'].shift(1)
df_hydro_weekly_south['PRECIP_lag1w'] = df_hydro_weekly_south['PRECTOTCORR'].shift(1)
df_hydro_weekly_south['EVLAND_lag1w'] = df_hydro_weekly_south['EVLAND'].shift(1)
df_hydro_weekly_south['PRECIP_lag2w'] = df_hydro_weekly_south['PRECTOTCORR'].shift(2)
df_hydro_weekly_south['PRECIP_EWMA'] = df_hydro_weekly_south['PRECTOTCORR'].ewm(alpha=0.3, adjust=False).mean()
# EWMA for EVLAND with a “slow” decay (alpha = 0.1)
df_hydro_weekly_south['EVLAND_EWMA'] = df_hydro_weekly_south['EVLAND'].ewm(alpha=0.3, adjust=False).mean()
df_hydro_weekly_south['APIxGWETPROF'] = df_hydro_weekly_south['PRECIP_EWMA'] * df_hydro_weekly_south['GWETPROF']

# %%
df_hydro_weekly_south.head()
# Out:
#                 Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M  \
# DATE
# 2015-03-08  3.203293e+08       767.35  258.66  76.412937  0.467698  12.941190
# 2015-03-15  3.243453e+08       156.42  228.78  77.127698  0.480000  12.604048
# 2015-03-22  2.950068e+08       264.80  165.01  80.292381  0.474921   8.037778
# 2015-03-29  2.870318e+08       367.40  154.86  83.572698  0.482063  11.639524
# 2015-04-05  2.590456e+08       189.24  177.98  79.877222  0.490952  11.092937
#
#                 TP_lag1w  T2M_lag1w  GWETPROF_lag1w  RH2M_lag1w  PRECIP_lag1w  \
# DATE
# 2015-03-08           NaN        NaN             NaN         NaN           NaN
# 2015-03-15  3.203293e+08  12.941190        0.467698   76.412937        767.35
# 2015-03-22  3.243453e+08  12.604048        0.480000   77.127698        156.42
# 2015-03-29  2.950068e+08   8.037778        0.474921   80.292381        264.80
# 2015-04-05  2.870318e+08  11.639524        0.482063   83.572698        367.40
#
#             EVLAND_lag1w  PRECIP_lag2w  PRECIP_EWMA  EVLAND_EWMA  APIxGWETPROF
# DATE
# 2015-03-08           NaN           NaN   767.350000   258.660000    358.888377
# 2015-03-15        258.66           NaN   584.071000   249.696000    280.354080
# 2015-03-22        228.78        767.35   488.289700   224.290200    231.898854
# 2015-03-29        165.01        156.42   452.022790   203.461140    217.903685
# 2015-04-05        154.86        264.80   373.187953   195.816798    183.217514

# %%
# Drop original non-lagged features and drop NA from lagging
weekly_lagged_south = df_hydro_weekly_south[['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','APIxGWETPROF','PRECIP_lag2w','PRECIP_EWMA','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','GWETPROF','GWETPROF_lag1w','T2M','T2M_lag1w']].dropna()
weekly_lagged_south.head()
# Out:
#                 Total_TP      TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  2.950068e+08  3.243453e+08       264.80        156.42
# 2015-03-29  2.870318e+08  2.950068e+08       367.40        264.80
# 2015-04-05  2.590456e+08  2.870318e+08       189.24        367.40
# 2015-04-12  2.441813e+08  2.590456e+08       470.76        189.24
# 2015-04-19  2.735290e+08  2.441813e+08       333.51        470.76
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    231.898854        767.35   488.289700  165.01        228.78
# 2015-03-29    217.903685        156.42   452.022790  154.86        165.01
# 2015-04-05    183.217514        264.80   373.187953  177.98        154.86
# 2015-04-12    202.251903        367.40   402.459567  166.54        177.98
# 2015-04-19    198.916737        189.24   381.774697  129.33        166.54
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   224.290200  80.292381   77.127698  0.474921        0.480000
# 2015-03-29   203.461140  83.572698   80.292381  0.482063        0.474921
# 2015-04-05   195.816798  79.877222   83.572698  0.490952        0.482063
# 2015-04-12   187.033759  83.569683   79.877222  0.502540        0.490952
# 2015-04-19   169.722631  85.104524   83.569683  0.521032        0.502540
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22   8.037778  12.604048
# 2015-03-29  11.639524   8.037778
# 2015-04-05  11.092937  11.639524
# 2015-04-12   9.989206  11.092937
# 2015-04-19   4.725635   9.989206

# %%
order = ['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','PRECIP_lag2w','PRECIP_EWMA','GWETPROF','GWETPROF_lag1w','APIxGWETPROF','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','T2M','T2M_lag1w']
weekly_lagged_south = weekly_lagged_south[order]

# %%
# Compute correlation matrix - South Island
correlation_matrix_with_lag_south = weekly_lagged_south.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix_with_lag_south, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation for Hydro South Island (Weekly Aggregated)')
plt.show()

# %%
factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']

for f in factors:
    plt.figure(figsize=(10, 3))
    plt.plot(df_hydro_weekly_south[f], label=f)
    plt.title(f'{f} Weekly Trend')
    plt.xlabel('Date')
    plt.ylabel(f)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [raw]
# # # ---------Weekly------------------
# # df_hydro_weekly
# # df_hydro_weekly_south
# # df_hydro_weekly_north
#
#
# print(df_hydro_weekly_tmp.columns.tolist())
# print(df_hydro_daily_tmp.columns.tolist())

# %% [raw]
# factors = ['Total_TP', 'PRECTOTCORR', 'EVLAND', 'RH2M', 'GWETPROF', 'T2M', 'PRECIP_lag1w', 'PRECIP_lag2w', 'API_weekly']
#
# for f in factors:
#     plt.figure(figsize=(10, 3))
#     plt.plot(df_hydro_weekly_tmp[f], label=f)
#     plt.title(f'{f} Weekly Trend')
#     plt.xlabel('Date')
#     plt.ylabel(f)
#     plt.legend()
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# # SARIMA model for hydro

# %% [markdown]
# ## Pre Checks - stationery

# %% [raw]
# ############# Data Frames to Use ############
# # # ---------Weekly------------------
# # df_hydro_weekly_south / weekly_lagged_south
# # df_hydro_weekly_north / weekly_lagged_north
#
#
# print(df_hydro_weekly_tmp.columns.tolist())
# print(df_hydro_daily_tmp.columns.tolist())

# %%
# Frequency setting 'W' (weekly)
df_hydro_weekly_north.head()
df_hydro_weekly_north.index.freq
# Out:
# <Week: weekday=6>

# %%
weekly_lagged_north.head()
weekly_lagged_north.index.freq
# Out:
# <Week: weekday=6>

# %%
weekly_lagged_north.head()
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
#
#             PRECIP_lag2w  PRECIP_EWMA  GWETPROF  GWETPROF_lag1w  APIxGWETPROF  \
# DATE
# 2015-03-22        204.03   297.937500  0.368403        0.338487    109.761176
# 2015-03-29        372.58   306.428250  0.360000        0.368403    110.314170
# 2015-04-05        399.07   227.858775  0.362605        0.360000     82.622741
# 2015-04-12        326.24   374.724142  0.375378        0.362605    140.663256
# 2015-04-19         44.53   456.301900  0.413109        0.375378    188.502533
#
#             EVLAND  EVLAND_lag1w  EVLAND_EWMA       RH2M  RH2M_lag1w  \
# DATE
# 2015-03-22  238.96        203.25   210.082200  70.463782   76.564454
# 2015-03-29  216.04        238.96   211.869540  80.650000   70.463782
# 2015-04-05  174.38        216.04   200.622678  77.631261   80.650000
# 2015-04-12  185.60        174.38   196.115875  85.405462   77.631261
# 2015-04-19  184.17        185.60   192.532112  80.490084   85.405462
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639

# %%
plt.figure(figsize=(12,4))
plt.plot(weekly_lagged_north['Total_TP'], marker='o', linestyle='-')
plt.title("North Island: Weekly Hydro Generation (Total_TP)")
plt.ylabel("KWh (weekly total)")
plt.xlabel("Date")
plt.grid(True)
plt.show()

# %%
# stationery check for north Island weekly data
from statsmodels.tsa.stattools import adfuller

result = adfuller(weekly_lagged_north['Total_TP'])
print('stationery check for North Island - Weekly' )
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# stationery check for North Island - Weekly
# ADF Statistic: -4.839144
# p-value: 0.000046
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
# stationery check for South Island Weekly data
from statsmodels.tsa.stattools import adfuller


result = adfuller(weekly_lagged_south['Total_TP'])
print('stationery check for South Island - Weekly ' )
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# stationery check for South Island - Weekly
# ADF Statistic: -6.723656
# p-value: 0.000000
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %% [raw]
# # Plot ACF & PACF North Island
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# north = weekly_lagged_north['Total_TP']
# #north = df_hydro_weekly_north['Total_TP']
#
# plt.figure(figsize=(10,4))
# plot_acf(north,  lags=60)
# plt.title("North Island: ACF of Weekly Total_TP")
# plt.show()
#
# plt.figure(figsize=(10,4))
# plot_pacf(north, lags=60, method='ywm')
# plt.title("North Island: PACF of Weekly Total_TP")
# plt.show()

# %% [raw]
# # Plot ACF & PACF South Island
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# south = weekly_lagged_south['Total_TP']
#
#
# plt.figure(figsize=(10,4))
# plot_acf(south,  lags=60)
# plt.title("South Island: ACF of Weekly Total_TP")
# plt.show()
#
# plt.figure(figsize=(10,4))
# plot_pacf(south, lags=60, method='ywm')
# plt.title("South Island: PACF of Weekly Total_TP")
# plt.show()

# %%
north = weekly_lagged_north['Total_TP']
south = weekly_lagged_south['Total_TP']

# %% [markdown]
# # Model Development

# %% [markdown]
# ## Start North Island - Weekly

# %%
# Repeat the same steps for North Island:
series_n = north
n_n = len(series_n)
split_n = int(n_n * 0.8)

train_n = series_n.iloc[:split_n]
test_n  = series_n.iloc[split_n:]

model_n = SARIMAX(
    train_n,
    order=(0, 0, 2),
    seasonal_order=(1, 0, 0, 52),
    enforce_stationarity=False,
    enforce_invertibility=False
)
res_n = model_n.fit(disp=False)
print(res_n.summary())

fc_n = res_n.get_forecast(steps=len(test_n))
pred_n = pd.Series(fc_n.predicted_mean.values, index=test_n.index)

mae_n  = mean_absolute_error(test_n, pred_n)
rmse_n = np.sqrt(mean_squared_error(test_n, pred_n))
mape_n = np.mean(np.abs((test_n - pred_n) / test_n)) * 100

# rmse = np.sqrt(mean_squared_error(target_test, forecast))
# mae = mean_absolute_error(target_test, forecast)
# epsilon = 1e-10  # small constant to avoid division by zero in MAPE
# mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("North Island SARIMA(1, 0, 1)x(0, 0, 1, 52) → MAE:", f"{mae_n:.2f}",
      "RMSE:", f"{rmse_n:.2f}", "MAPE:", f"{mape_n:.2f}%")
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                            Total_TP   No. Observations:                  412
# Model:             SARIMAX(0, 0, 2)x(1, 0, [], 52)   Log Likelihood               -7070.609
# Date:                             Thu, 05 Jun 2025   AIC                          14149.218
# Time:                                     00:57:13   BIC                          14164.763
# Sample:                                 03-22-2015   HQIC                         14155.399
#                                       - 02-05-2023
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.8216      1.843      0.446      0.656      -2.790       4.434
# ma.L2          0.4413      1.946      0.227      0.821      -3.372       4.255
# ar.S.L52       0.9628      0.795      1.210      0.226      -0.596       2.522
# sigma2      1.781e+16   1.27e-17    1.4e+33      0.000    1.78e+16    1.78e+16
# ===================================================================================
# Ljung-Box (L1) (Q):                  11.94   Jarque-Bera (JB):                 8.10
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               1.02   Skew:                             0.31
# Prob(H) (two-sided):                  0.94   Kurtosis:                         3.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.12e+50. Standard errors may be unstable.
# North Island SARIMA(1, 0, 1)x(0, 0, 1, 52) → MAE: 35428932.46 RMSE: 42261054.28 MAPE: 31.10%

# %% [raw]
# 1. North Island SARIMA(1, 0, 0)x(0, 0, 1, 52) → MAE: 42161903.18 RMSE: 46826358.62 MAPE: 38.63%
# 2. North Island SARIMA(1, 0, 1)x(0, 0, 1, 52) → MAE: 49650634.05 RMSE: 53755194.10 MAPE: 45.59%

# %% [raw]
# North Island SARIMA(0, 0, 2)x(1, 0, 0, 52) → MAE: 35428932.46 RMSE: 42261054.28 MAPE: 31.10%

# %%
### ANN for comparison ###

#   Set seeds for reproducibility  
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_hydro_north_wk = weekly_lagged_north[['Total_TP','TP_lag1w']]

n_hydro_ann     = len(df_ann_hydro_north_wk)
split_ann = int(n_hydro_ann * 0.8)

train_n_ann = df_ann_hydro_north_wk.iloc[:split_ann]
test_n_ann  = df_ann_hydro_north_wk.iloc[split_ann:]

X_train_n_ann = train_n_ann[['TP_lag1w']].values
y_train_n_ann = train_n_ann['Total_TP'].values.reshape(-1,1)
X_test_n_ann  = test_n_ann[['TP_lag1w']].values
y_test_n_ann  = test_n_ann['Total_TP'].values.reshape(-1,1)


# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s_n_ann = scaler_X.fit_transform(X_train_n_ann)
X_test_s_n_ann  = scaler_X.transform(X_test_n_ann)

scaler_y = MinMaxScaler()
y_train_s_n_ann = scaler_y.fit_transform(y_train_n_ann)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# 4) Build the ANN
model_ann = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann.compile(optimizer='adam', loss='mse')

# 5) Train the ANN (the shuffle order is now deterministic)
history = model_ann.fit(
    X_train_s_n_ann, y_train_s_n_ann,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# 6) Predict & rescale
y_pred_s_n_ann = model_ann.predict(X_test_s_n_ann)
y_pred_n_ann   = scaler_y.inverse_transform(y_pred_s_n_ann).flatten()


# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test_n_ann.flatten(), y_pred_n_ann)
rmse_ann = np.sqrt(mean_squared_error(y_test_n_ann.flatten(), y_pred_n_ann))
mape_ann = np.mean(np.abs((y_test_n_ann.flatten() - y_pred_n_ann) / y_test_n_ann.flatten())) * 100

#print(f"Univariate ANN - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")

print("North Island ANN → MAE:", f"{mae_ann:.2f}",
      "RMSE:", f"{rmse_ann:.2f}", "MAPE:", f"{mape_ann:.2f}%")
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# North Island ANN → MAE: 11263851.50 RMSE: 14145051.16 MAPE: 9.71%

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(10,4))
plt.plot(train_n.index, train_n, label="Train",   color="gray")
plt.plot(test_n.index,  test_n,  label="Actual",  color="black")
plt.plot(pred_n.index,  pred_n,  label="Forecast",color="cornflowerblue")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("North Island: SARIMA Hydro Forecast vs. Actual (RQ1)" , fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(12,5))
plt.plot(train_n.index, train_n, label="Train",   color="gray")
plt.plot(test_n.index,  test_n,  label="Actual",  color="black")
plt.plot(pred_n.index,  pred_n,  label="Forecast-SARIMA",color="cornflowerblue")
plt.plot(test_n_ann.index, y_pred_n_ann, label="Forecast-ANN",      color="darkorange")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("North Island: Hydro Forecast vs. Actual (Weekly) (RQ1)" , fontsize=10)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# %% [raw]
# import pandas as pd
# import numpy as np
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
# # -----------------------------------------------------------------------------
# # ASSUMPTIONS / PRE‐DEFINED VARIABLES
# # -----------------------------------------------------------------------------
# # • series_n : pandas.Series of weekly North Island “Total_TP” (kWh), indexed by date.
# # -----------------------------------------------------------------------------
#
# # 1) Create train/test split (80/20)
# n_n      = len(series_n)
# split_n  = int(n_n * 0.8)
#
# train_n = series_n.iloc[:split_n].copy()
# test_n  = series_n.iloc[split_n:].copy()
#
# # 2) Define the four candidate (order, seasonal_order) pairs
# candidates = [
#     ((1, 0, 1), (0, 0, 0, 52)),
#     ((0, 0, 1), (0, 0, 1, 52)),
#     ((1, 0, 1), (1, 0, 0, 52)),
#     ((0, 0, 2), (1, 0, 0, 52)),
#     ((1, 0, 0), (0, 0, 1, 52)),
#     ((1, 0, 1), (0, 0, 1, 52))
# ]
#
# # 3) Loop through candidates, fit, forecast, and compute metrics
# results_list = []
#
# for idx, ((p, d, q), (P, D, Q, s)) in enumerate(candidates, start=1):
#     # 3a) Fit SARIMAX on the TRAIN segment
#     model = SARIMAX(
#         train_n,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res = model.fit(disp=False)
#
#     # 3b) Forecast on TEST segment
#     n_steps = len(test_n)
#     fc      = res.get_forecast(steps=n_steps)
#
#     # 3c) Align the forecasted mean with test_n.index
#     pred       = pd.Series(fc.predicted_mean.values, index=test_n.index)
#     conf_int   = fc.conf_int().copy()
#     conf_int.index = test_n.index
#
#     # 3d) Compute MAE, RMSE, MAPE
#     y_true = test_n.values
#     y_pred = pred.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     # 3e) Collect results
#     results_list.append({
#         "candidate_index":   idx,
#         "order":             (p, d, q),
#         "seasonal_order":    (P, D, Q, s),
#         "AIC":               res.aic,
#         "BIC":               res.bic,
#         "MAE":               mae,
#         "RMSE":              rmse,
#         "MAPE":              mape
#     })
#
# # 4) Convert to DataFrame and display
# df_results = pd.DataFrame(results_list)
# print(df_results.to_string(index=False))

# %% [raw]
# candidate_index     order seasonal_order          AIC          BIC          MAE         RMSE      MAPE
#                1 (1, 0, 1)  (0, 0, 0, 52) 14640.546295 14652.594767 4.351857e+07 4.800440e+07 40.284255
#                2 (0, 0, 1)  (0, 0, 1, 52) 14109.295172 14120.936771 8.522146e+07 9.317783e+07 71.317012
#                3 (1, 0, 1)  (1, 0, 0, 52) 12815.392705 12830.925995 4.919004e+07 5.323636e+07 45.138168
#                4 (0, 0, 2)  (1, 0, 0, 52) 14149.218466 14164.762882 3.542893e+07 4.226105e+07 31.096100
#                5 (1, 0, 0)  (0, 0, 1, 52) 12818.889015 12830.538982 4.216190e+07 4.682636e+07 38.632713
#                6 (1, 0, 1)  (0, 0, 1, 52) 12781.458510 12796.980642 4.965063e+07 5.375519e+07 45.592485

# %% [raw]
# # df_hydro_weekly_south / weekly_lagged_south
# # df_hydro_weekly_north / weekly_lagged_north

# %%
weekly_lagged_north
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
# ...                  ...          ...          ...           ...
# 2024-12-29  7.731263e+07  83933260.00       391.50        468.64
# 2025-01-05  6.298005e+07  77312627.00       331.19        391.50
# 2025-01-12  8.487436e+07  62980054.00       108.94        331.19
# 2025-01-19  9.699145e+07  84874356.00        46.67        108.94
# 2025-01-26  8.673389e+07  96991450.00       426.59         46.67
#
#             PRECIP_lag2w  PRECIP_EWMA  GWETPROF  GWETPROF_lag1w  APIxGWETPROF  \
# DATE
# 2015-03-22        204.03   297.937500  0.368403        0.338487    109.761176
# 2015-03-29        372.58   306.428250  0.360000        0.368403    110.314170
# 2015-04-05        399.07   227.858775  0.362605        0.360000     82.622741
# 2015-04-12        326.24   374.724142  0.375378        0.362605    140.663256
# 2015-04-19         44.53   456.301900  0.413109        0.375378    188.502533
# ...                  ...          ...       ...             ...           ...
# 2024-12-29        400.52   331.569510  0.453025        0.458739    150.209347
# 2025-01-05        468.64   331.455657  0.442689        0.453025    146.731798
# 2025-01-12        391.50   264.700960  0.425630        0.442689    112.664736
# 2025-01-19        331.19   199.291672  0.402353        0.425630     80.185590
# 2025-01-26        108.94   267.481170  0.388235        0.402353    103.845631
#
#             EVLAND  EVLAND_lag1w  EVLAND_EWMA       RH2M  RH2M_lag1w  \
# DATE
# 2015-03-22  238.96        203.25   210.082200  70.463782   76.564454
# 2015-03-29  216.04        238.96   211.869540  80.650000   70.463782
# 2015-04-05  174.38        216.04   200.622678  77.631261   80.650000
# 2015-04-12  185.60        174.38   196.115875  85.405462   77.631261
# 2015-04-19  184.17        185.60   192.532112  80.490084   85.405462
# ...            ...           ...          ...        ...         ...
# 2024-12-29  452.03        498.24   438.334654  74.004958   78.571765
# 2025-01-05  418.69        452.03   432.441258  74.479328   74.004958
# 2025-01-12  382.43        418.69   417.437880  67.837059   74.479328
# 2025-01-19  317.29        382.43   387.393516  67.007143   67.837059
# 2025-01-26  321.14        317.29   367.517461  75.025294   67.007143
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639
# ...               ...        ...
# 2024-12-29  17.281008  16.798655
# 2025-01-05  15.331933  17.281008
# 2025-01-12  15.599916  15.331933
# 2025-01-19  17.000084  15.599916
# 2025-01-26  18.570840  17.000084
#
# [515 rows x 16 columns]

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(weekly_lagged_north)
train_size = int(n * 0.8)
train_wk = weekly_lagged_north.iloc[:train_size]
test_wk = weekly_lagged_north.iloc[train_size:]

# %%
print("Daily Train set:", train_wk.index.min(), "to", train_wk.index.max())
print("Daily Test set:", test_wk.index.min(), "to", test_wk.index.max())
# Out:
# Daily Train set: 2015-03-22 00:00:00 to 2023-02-05 00:00:00
# Daily Test set: 2023-02-12 00:00:00 to 2025-01-26 00:00:00

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_wk['Total_TP']
target_test = test_wk['Total_TP']

# %% [raw]
# #['Total_TP', 'PRECTOTCORR', 'EVLAND', 'RH2M', 'GWETPROF', 'T2M', 'PRECIP_7d', 'PRECIP_14d', 'PRECIP_lag1', 'PRECIP_lag7']

# %% [raw]
# 'TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w'

# %%
#exog_cols = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w' ]
#exog_cols = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w' ]
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M']
#exog_cols = ['RH2M', 'GWETPROF', 'EVLAND', 'T2M','PRECTOTCORR_lag1']
#exog_cols = ['T2M','PRECTOTCORR_lag7','GWETPROF']
#exog_cols = ['EVLAND','T2M']
#exog_cols = ['GWETPROF','EVLAND','T2M']
#exog_cols = ['PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['RH2M','PRECTOTCORR','GWETPROF','EVLAND','T2M']
#exog_cols = ['WS50M']
#exog_cols = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w' ]
#exog_cols = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w' ]

exog_cols = ['TP_lag1w', 'RH2M_lag1w', 'PRECIP_EWMA']

# %%
exog_train = train_wk[exog_cols]
exog_test = test_wk[exog_cols]

# %%
# Fit SARIMAX on the original (non-log) target data
model = SARIMAX(target_train,
                exog=exog_train,
                # order=(1, 1, 1),
                # seasonal_order=(0, 0, 0, 0),
                order=(0, 0, 2),
                seasonal_order=(1, 0, 0, 52),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                            Total_TP   No. Observations:                  412
# Model:             SARIMAX(0, 0, 2)x(1, 0, [], 52)   Log Likelihood               -6379.006
# Date:                             Thu, 05 Jun 2025   AIC                          12772.013
# Time:                                     00:59:17   BIC                          12799.215
# Sample:                                 03-22-2015   HQIC                         12782.829
#                                       - 02-05-2023
# Covariance Type:                               opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TP_lag1w        0.8256      0.025     32.678      0.000       0.776       0.875
# RH2M_lag1w    1.19e+05   4.14e+04      2.873      0.004    3.78e+04       2e+05
# PRECIP_EWMA  3.456e+04   4362.327      7.923      0.000     2.6e+04    4.31e+04
# ma.L1          -0.0968      0.062     -1.565      0.118      -0.218       0.024
# ma.L2           0.0319      0.059      0.541      0.588      -0.084       0.147
# ar.S.L52        0.1769      0.052      3.400      0.001       0.075       0.279
# sigma2       1.464e+14    2.9e-06   5.06e+19      0.000    1.46e+14    1.46e+14
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.13
# Prob(Q):                              0.99   Prob(JB):                         0.57
# Heteroskedasticity (H):               1.29   Skew:                             0.10
# Prob(H) (two-sided):                  0.17   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.34e+36. Standard errors may be unstable.

# %%
# Forecast on the test set - non log
n_steps = len(test_wk)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# fc_n = res_n.get_forecast(steps=len(test_n))
# pred_n = pd.Series(fc_n.predicted_mean.values, index=test_n.index)

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

# print("\nForecast Performance Metrics (Without Log Transformation):")
# print(f"RMSE: {rmse:.2f}")
# print(f"MAE: {mae:.2f}")
# print(f"Adjusted MAPE: {mape:.2f}%")
print("North Island SARIMA with exog (0, 0, 2)x(1, 0, 0, 52) → MAE:", f"{mae:.2f}",
      "RMSE:", f"{rmse:.2f}", "MAPE:", f"{mape:.2f}%")
# Out:
# North Island SARIMA with exog (0, 0, 2)x(1, 0, 0, 52) → MAE: 11210000.28 RMSE: 13990826.65 MAPE: 9.79%

# %% [raw]
# """
# ### After reforming the data set
# exog_cols = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w' ]
#                 order=(1, 0, 0),
#                 seasonal_order=(0, 0, 1, 52),
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 14054850.88
# MAE: 11282213.54
# Adjusted MAPE: 9.87%
#
# exog_cols = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w' ]
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 29476558.18
# MAE: 23558509.09
# Adjusted MAPE: 20.79%
# """

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(12,5))
plt.plot(train_wk.index, target_train, label="Train",   color="gray")
plt.plot(test_wk.index,  target_test,  label="Actual",  color="black")
plt.plot(forecast.index,  forecast,  label="Forecast",color="cornflowerblue")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("North Island: SARIMA Hydro Forecast vs. Actual (RQ2)" , fontsize=10)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# # Plot Actual vs. Forecast North Island Hydro
# plt.figure(figsize=(12, 5))
# plt.plot(train_wk.index, target_train, label='Train', color='blue')
# plt.plot(test_wk.index, target_test, label='Test', color='green')
# plt.plot(test_wk.index, forecast, label='Forecast', color='red', linestyle='--')
# plt.xlabel("Date")
# plt.ylabel("Total_TP")
# plt.title("Hydro weekly forecast using SARIMA - North Island (Without Log Transformation)")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
### ANN for comparison ###

factors_n_ann = ['TP_lag1w', 'PRECIP_EWMA']

# 2) Split via slicing
n = len(weekly_lagged_north)
split_idx = int(n * 0.8)

train_df_n_ann = weekly_lagged_north.iloc[:split_idx]
test_df_n_ann  = weekly_lagged_north.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw_n_ann = train_df_n_ann[factors_n_ann].values
X_test_raw_n_ann  = test_df_n_ann[factors_n_ann].values
y_train_raw_n_ann = train_df_n_ann['Total_TP'].values.reshape(-1, 1)
y_test_raw_n_ann  = test_df_n_ann['Total_TP'].values.reshape(-1, 1)

# 4) Scale
x_scaler = StandardScaler().fit(X_train_raw_n_ann)
y_scaler = StandardScaler().fit(y_train_raw_n_ann)

X_train_n_ann = x_scaler.transform(X_train_raw_n_ann)
X_test_n_ann  = x_scaler.transform(X_test_raw_n_ann)
y_train_n_ann = y_scaler.transform(y_train_raw_n_ann)
y_test_n_ann  = y_scaler.transform(y_test_raw_n_ann)

# 5) Sanity‐check shapes
print(X_train_n_ann.shape, y_train_n_ann.shape)
print(X_test_n_ann.shape,  y_test_n_ann.shape)

# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

# #model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model = Sequential([
    Dense(64, input_shape=(X_train_n_ann.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(16),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])


model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# ── 5) Train (use 10% of train_df as internal validation, keep test_df fully unseen) ──
history = model.fit(
    X_train_n_ann, y_train_n_ann,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# 1) Predict & inverse‑scale
y_pred_s_n_ann = model.predict(X_test_n_ann)
y_pred_n_ann = y_scaler.inverse_transform(y_pred_s_n_ann).ravel()
y_true_n_ann = y_scaler.inverse_transform(y_test_n_ann).ravel()


# 2) Metrics
mae  = mean_absolute_error(y_true_n_ann, y_pred_n_ann)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true_n_ann, y_pred_n_ann)
mape = mean_absolute_percentage_error(y_true_n_ann, y_pred_n_ann) * 100
# print("\nRQ2‐ANN Performance - Hydro (North Island):")
# print(f"MAE : {mae:,.2f}")
# print(f"RMSE: {rmse:,.2f}")
# print(f"MAPE: {mape:.2f}%")
print("RQ2-North Island ANN (with regressors) → MAE:", f"{mae:.2f}",
      "RMSE:", f"{rmse:.2f}", "MAPE:", f"{mape:.2f}%")

# # 3) Plot
# plt.figure(figsize=(12,5))
# plt.plot(dates_test, y_true, label="Actual")
# plt.plot(dates_test, y_pred, linestyle="--", color="red", label="Predicted")
# plt.title("Sliding‑Window MLP: Actual vs. Predicted")
# plt.xlabel("Date")
# plt.ylabel("Total_TP")
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# (412, 2) (412, 1)
# (103, 2) (103, 1)
# Epoch 1/200
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.4642 - mape: 224.5731 - val_loss: 0.4047 - val_mape: 103.2327 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3178 - mape: 181.5711 - val_loss: 0.3599 - val_mape: 92.4565 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2066 - mape: 132.2389 - val_loss: 0.3344 - val_mape: 87.4016 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1707 - mape: 162.5216 - val_loss: 0.3118 - val_mape: 82.5455 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1569 - mape: 147.9105 - val_loss: 0.2955 - val_mape: 79.3979 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1583 - mape: 158.5605 - val_loss: 0.2792 - val_mape: 75.5502 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1373 - mape: 148.4594 - val_loss: 0.2631 - val_mape: 71.5411 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1256 - mape: 132.7885 - val_loss: 0.2481 - val_mape: 67.2051 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1281 - mape: 130.1723 - val_loss: 0.2345 - val_mape: 64.1138 - learning_rate: 5.0000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1356 - mape: 102.5471 - val_loss: 0.2135 - val_mape: 59.3918 - learning_rate: 5.0000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1194 - mape: 146.0591 - val_loss: 0.1919 - val_mape: 55.0765 - learning_rate: 5.0000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1170 - mape: 115.8922 - val_loss: 0.1779 - val_mape: 52.8994 - learning_rate: 5.0000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1160 - mape: 111.8237 - val_loss: 0.1637 - val_mape: 50.7102 - learning_rate: 5.0000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1082 - mape: 107.7862 - val_loss: 0.1545 - val_mape: 49.2808 - learning_rate: 5.0000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0988 - mape: 117.9486 - val_loss: 0.1479 - val_mape: 48.2653 - learning_rate: 5.0000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1043 - mape: 118.0740 - val_loss: 0.1346 - val_mape: 46.4521 - learning_rate: 5.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0998 - mape: 100.0528 - val_loss: 0.1281 - val_mape: 45.9280 - learning_rate: 5.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1068 - mape: 108.9366 - val_loss: 0.1182 - val_mape: 45.2594 - learning_rate: 5.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1002 - mape: 100.9462 - val_loss: 0.1107 - val_mape: 45.5540 - learning_rate: 5.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0974 - mape: 121.0162 - val_loss: 0.1074 - val_mape: 45.5011 - learning_rate: 5.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0997 - mape: 97.7896 - val_loss: 0.1056 - val_mape: 45.3984 - learning_rate: 5.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0963 - mape: 92.9898 - val_loss: 0.1010 - val_mape: 45.4860 - learning_rate: 5.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0924 - mape: 137.1607 - val_loss: 0.0965 - val_mape: 45.8146 - learning_rate: 5.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0986 - mape: 102.3599 - val_loss: 0.0918 - val_mape: 46.3974 - learning_rate: 5.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0964 - mape: 107.8668 - val_loss: 0.0883 - val_mape: 47.0382 - learning_rate: 5.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0930 - mape: 122.3639 - val_loss: 0.0876 - val_mape: 47.6229 - learning_rate: 5.0000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0874 - mape: 98.5336 - val_loss: 0.0855 - val_mape: 48.9458 - learning_rate: 5.0000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0851 - mape: 121.1115 - val_loss: 0.0848 - val_mape: 49.8509 - learning_rate: 5.0000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0882 - mape: 104.1962 - val_loss: 0.0833 - val_mape: 51.0799 - learning_rate: 5.0000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0933 - mape: 123.9391 - val_loss: 0.0844 - val_mape: 53.0953 - learning_rate: 5.0000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0936 - mape: 112.0011 - val_loss: 0.0859 - val_mape: 55.0117 - learning_rate: 5.0000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0898 - mape: 99.4505 - val_loss: 0.0867 - val_mape: 56.7547 - learning_rate: 5.0000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0882 - mape: 94.4071 - val_loss: 0.0869 - val_mape: 57.4546 - learning_rate: 5.0000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0851 - mape: 119.8178 - val_loss: 0.0875 - val_mape: 58.2027 - learning_rate: 5.0000e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0899 - mape: 102.1485 - val_loss: 0.0875 - val_mape: 58.4150 - learning_rate: 2.5000e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0925 - mape: 144.2743 - val_loss: 0.0870 - val_mape: 58.2562 - learning_rate: 2.5000e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0906 - mape: 95.6182 - val_loss: 0.0877 - val_mape: 59.5585 - learning_rate: 2.5000e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0935 - mape: 123.0421 - val_loss: 0.0893 - val_mape: 60.8140 - learning_rate: 2.5000e-04
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0882 - mape: 131.9528 - val_loss: 0.0914 - val_mape: 62.2270 - learning_rate: 2.5000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# RQ2-North Island ANN (with regressors) → MAE: 10989147.79 RMSE: 13851371.85 MAPE: 9.67%

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(12,5))
plt.plot(train_wk.index, target_train, label="Train",   color="gray")
plt.plot(test_wk.index,  target_test,  label="Actual",  color="black")
plt.plot(forecast.index,  forecast,  label="Forecast-SARIMA",color="cornflowerblue")
plt.plot(test_df_n_ann.index,y_pred_n_ann,label="Forecast-ANN",color="darkorange")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("North Island: Hydro Forecast vs. Actual (Weekly) (RQ2)" , fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()
# plt.title("North Island: Hydro Forecast vs. Actual (Weekly) (RQ1)" , fontsize=10)

# %%
weekly_lagged_north
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
# ...                  ...          ...          ...           ...
# 2024-12-29  7.731263e+07  83933260.00       391.50        468.64
# 2025-01-05  6.298005e+07  77312627.00       331.19        391.50
# 2025-01-12  8.487436e+07  62980054.00       108.94        331.19
# 2025-01-19  9.699145e+07  84874356.00        46.67        108.94
# 2025-01-26  8.673389e+07  96991450.00       426.59         46.67
#
#             PRECIP_lag2w  PRECIP_EWMA  GWETPROF  GWETPROF_lag1w  APIxGWETPROF  \
# DATE
# 2015-03-22        204.03   297.937500  0.368403        0.338487    109.761176
# 2015-03-29        372.58   306.428250  0.360000        0.368403    110.314170
# 2015-04-05        399.07   227.858775  0.362605        0.360000     82.622741
# 2015-04-12        326.24   374.724142  0.375378        0.362605    140.663256
# 2015-04-19         44.53   456.301900  0.413109        0.375378    188.502533
# ...                  ...          ...       ...             ...           ...
# 2024-12-29        400.52   331.569510  0.453025        0.458739    150.209347
# 2025-01-05        468.64   331.455657  0.442689        0.453025    146.731798
# 2025-01-12        391.50   264.700960  0.425630        0.442689    112.664736
# 2025-01-19        331.19   199.291672  0.402353        0.425630     80.185590
# 2025-01-26        108.94   267.481170  0.388235        0.402353    103.845631
#
#             EVLAND  EVLAND_lag1w  EVLAND_EWMA       RH2M  RH2M_lag1w  \
# DATE
# 2015-03-22  238.96        203.25   210.082200  70.463782   76.564454
# 2015-03-29  216.04        238.96   211.869540  80.650000   70.463782
# 2015-04-05  174.38        216.04   200.622678  77.631261   80.650000
# 2015-04-12  185.60        174.38   196.115875  85.405462   77.631261
# 2015-04-19  184.17        185.60   192.532112  80.490084   85.405462
# ...            ...           ...          ...        ...         ...
# 2024-12-29  452.03        498.24   438.334654  74.004958   78.571765
# 2025-01-05  418.69        452.03   432.441258  74.479328   74.004958
# 2025-01-12  382.43        418.69   417.437880  67.837059   74.479328
# 2025-01-19  317.29        382.43   387.393516  67.007143   67.837059
# 2025-01-26  321.14        317.29   367.517461  75.025294   67.007143
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639
# ...               ...        ...
# 2024-12-29  17.281008  16.798655
# 2025-01-05  15.331933  17.281008
# 2025-01-12  15.599916  15.331933
# 2025-01-19  17.000084  15.599916
# 2025-01-26  18.570840  17.000084
#
# [515 rows x 16 columns]

# %% [raw]
# import pandas as pd
# import numpy as np
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
# # -----------------------------------------------------------------------------
# # ASSUMPTIONS / PREDEFINED:
# #
# # • weekly_lagged_north : pandas.DataFrame indexed by DATE (weekly), with columns:
# #       – 'Total_TP'        (this is the target series)
# #       – 'APIxGWETPROF'
# #       – 'PRECIP_EWMA'
# #       – 'GWETPROF'
# #       – 'RH2M_lag1w'
# #       – 'EVLAND_lag1w'
# #       – 'T2M_lag1w'
# #       – … (and any other columns you might have)
# #
# # • We already know from your ADF/pacf/… work that the best (p,d,q,P,D,Q,s) for North‐island wind is:
# p, d, q   = 0, 0, 2        # nonseasonal MA(2)
# P, D, Q, s = 1, 0, 0, 52   # single seasonal AR(1) at lag 52
# # -----------------------------------------------------------------------------
#
# # 1) Train/test split (80/20) on the *entire* DataFrame
# n_n     = len(weekly_lagged_north)
# split_n = int(n_n * 0.8)
#
# # The target series is 'Total_TP'
# train_y = weekly_lagged_north['Total_TP'].iloc[:split_n].copy()
# test_y  = weekly_lagged_north['Total_TP'].iloc[split_n:].copy()
#
# # The SAME split indices will apply to exogenous columns as well.
# train_df = weekly_lagged_north.iloc[:split_n].copy()
# test_df  = weekly_lagged_north.iloc[split_n:].copy()
#
# # 2) List of all single‐column exogenous candidates
# exog_cols = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w']
#
# results_exog = []
#
# for col in exog_cols:
#     # 2a) Pull that single column out for train/test
#     exog_train = train_df[[col]].copy()
#     exog_test  = test_df[[col]].copy()
#
#     # 2b) It’s possible the first row or two in exog_train are NaN
#     #     (e.g. because RH2M_lag1w or EVLAND_lag1w have to be shifted).
#     #     So we drop any leading NaNs so that indices align:
#     first_valid = exog_train[col].first_valid_index()
#     if first_valid is not None:
#         train_y_trim    = train_y.loc[first_valid:].copy()
#         exog_train_trim = exog_train.loc[first_valid:].copy()
#     else:
#         # If no NaNs, just keep everything
#         train_y_trim    = train_y.copy()
#         exog_train_trim = exog_train.copy()
#
#     # For the test period, we assume lagged exogs are already aligned.
#     # If your test exog also has NaNs you can drop those same dates, but
#     # typically only the train side has missing rows from lags.
#     test_y_trim    = test_y.copy()
#     exog_test_trim = exog_test.copy()
#
#     # 2c) Fit SARIMAX(train_y_trim, exog=exog_train_trim)
#     model_exog = SARIMAX(
#         train_y_trim,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         exog=exog_train_trim,
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res_exog = model_exog.fit(disp=False)
#
#     # 2d) Forecast on the test set, passing exog_test_trim
#     n_steps = len(test_y_trim)
#     fc      = res_exog.get_forecast(steps=n_steps, exog=exog_test_trim)
#
#     # Align the predicted mean to the exact same index as test_y_trim
#     pred = pd.Series(fc.predicted_mean.values, index=test_y_trim.index)
#
#     # 2e) Compute MAE, RMSE, MAPE
#     y_true = test_y_trim.values
#     y_pred = pred.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     results_exog.append({
#         "exog_col": col,
#         "AIC":      res_exog.aic,
#         "BIC":      res_exog.bic,
#         "MAE":      mae,
#         "RMSE":     rmse,
#         "MAPE":     mape
#     })
#
# # 3) Turn the list of dicts into a DataFrame and sort by MAPE
# df_exog_res = pd.DataFrame(results_exog)
# df_exog_res = df_exog_res.sort_values("MAPE").reset_index(drop=True)
#
# print(df_exog_res.to_string(index=False))

# %%
# p, d, q   = 0, 0, 2        # nonseasonal MA(2)
# P, D, Q, s = 1, 0, 0, 52   # single seasonal AR(1) at lag 52
# exog_col          AIC          BIC          MAE         RMSE      MAPE
#     TP_lag1w 12851.424154 12870.854674 1.163244e+07 1.455464e+07  9.982751
#   RH2M_lag1w 13145.112796 13164.543316 2.020679e+07 2.492807e+07 18.725949
#     GWETPROF 12843.557885 12862.988405 2.386567e+07 2.973413e+07 21.166716
#  PRECIP_EWMA 13538.314421 13557.744941 3.032475e+07 3.827029e+07 24.876096
# APIxGWETPROF 13577.795477 13597.225997 3.881998e+07 4.804771e+07 32.121012

# %% [raw]
# import pandas as pd
# import numpy as np
# from itertools import combinations
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
# # -----------------------------------------------------------------------------
# # ASSUMPTIONS / PREDEFINED:
# # -----------------------------------------------------------------------------
# # • weekly_lagged_north : pandas.DataFrame indexed by DATE (weekly), with columns:
# #       – 'Total_TP'        (target series)
# #       – 'TP_lag1w'
# #       – 'RH2M_lag1w'
# #       – 'GWETPROF'
# #       – 'PRECIP_EWMA'
# #       – 'APIxGWETPROF'
# #
# # • We have already chosen from earlier diagnostics:
# #     p, d, q   = 0, 0, 2        # nonseasonal (an MA(2))
# #     P, D, Q, s = 1, 0, 0, 52   # seasonal AR(1) at lag 52
# # -----------------------------------------------------------------------------
#
# p, d, q   = 0, 0, 2
# P, D, Q, s = 1, 0, 0, 52
#
# # 1) Split 80/20
# n_n     = len(weekly_lagged_north)
# split_n = int(n_n * 0.8)
#
# train_y = weekly_lagged_north['Total_TP'].iloc[:split_n].copy()
# test_y  = weekly_lagged_north['Total_TP'].iloc[split_n:].copy()
#
# # We'll slice the SAME indices for all exog columns.
# train_df = weekly_lagged_north.iloc[:split_n].copy()
# test_df  = weekly_lagged_north.iloc[split_n:].copy()
#
# # 2) List of exogenous column names (from your DataFrame)
# exog_cols = [
#     'TP_lag1w',
#     'RH2M_lag1w',
#     'GWETPROF',
#     'PRECIP_EWMA',
#     'APIxGWETPROF'
# ]
#
# # -----------------------------------------------------------------------------
# # A) SINGLE exog results (you already have these, but we re‐compute for completeness)
# # -----------------------------------------------------------------------------
# single_results = []
#
# for col in exog_cols:
#     exog_train = train_df[[col]].copy()
#     exog_test  = test_df[[col]].copy()
#
#     # Drop the very first NA rows if this lag column has NaNs at the top
#     first_valid = exog_train[col].first_valid_index()
#     if first_valid is not None:
#         train_y_trim    = train_y.loc[first_valid:].copy()
#         exog_train_trim = exog_train.loc[first_valid:].copy()
#     else:
#         train_y_trim    = train_y.copy()
#         exog_train_trim = exog_train.copy()
#
#     test_y_trim    = test_y.copy()
#     exog_test_trim = exog_test.copy()
#
#     model_exog = SARIMAX(
#         train_y_trim,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         exog=exog_train_trim,
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res_exog = model_exog.fit(disp=False)
#
#     fc   = res_exog.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
#     pred = pd.Series(fc.predicted_mean.values, index=test_y_trim.index)
#
#     y_true = test_y_trim.values
#     y_pred = pred.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     single_results.append({
#         "exog_cols": (col,),
#         "AIC":       res_exog.aic,
#         "BIC":       res_exog.bic,
#         "MAE":       mae,
#         "RMSE":      rmse,
#         "MAPE":      mape
#     })
#
# df_single = pd.DataFrame(single_results).sort_values("MAPE").reset_index(drop=True)
#
# print("\n=== Single‐Exogenous Results ===")
# print(df_single.to_string(index=False))
#
#
# # -----------------------------------------------------------------------------
# # B) PAIRWISE combinations (two exogs at a time)
# # -----------------------------------------------------------------------------
# pair_results = []
#
# for combo in combinations(exog_cols, 2):
#     exog_train = train_df[list(combo)].copy()
#     exog_test  = test_df[list(combo)].copy()
#
#     # Drop leading NaNs (in case any lag columns produce NaN at the top)
#     # We drop all rows up to the first index where *both* columns are non‐NaN.
#     valid_idx   = exog_train.dropna().index.min()
#     if valid_idx is not None:
#         train_y_trim    = train_y.loc[valid_idx:].copy()
#         exog_train_trim = exog_train.loc[valid_idx:].copy()
#     else:
#         train_y_trim    = train_y.copy()
#         exog_train_trim = exog_train.copy()
#
#     test_y_trim    = test_y.copy()
#     exog_test_trim = exog_test.copy()
#
#     model_combo = SARIMAX(
#         train_y_trim,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         exog=exog_train_trim,
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res_combo = model_combo.fit(disp=False)
#
#     fc_combo = res_combo.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
#     pred_combo = pd.Series(fc_combo.predicted_mean.values, index=test_y_trim.index)
#
#     y_true = test_y_trim.values
#     y_pred = pred_combo.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     pair_results.append({
#         "exog_cols": combo,
#         "AIC":       res_combo.aic,
#         "BIC":       res_combo.bic,
#         "MAE":       mae,
#         "RMSE":      rmse,
#         "MAPE":      mape
#     })
#
# df_pair = pd.DataFrame(pair_results).sort_values("MAPE").reset_index(drop=True)
#
# print("\n=== Pairwise Exogenous Results ===")
# print(df_pair.to_string(index=False))
#
#
# # -----------------------------------------------------------------------------
# # C) OPTIONAL: TRIPLE combinations (three exogs at a time)
# # -----------------------------------------------------------------------------
# triple_results = []
#
# for combo in combinations(exog_cols, 3):
#     exog_train = train_df[list(combo)].copy()
#     exog_test  = test_df[list(combo)].copy()
#
#     # Drop leading NaNs if any
#     valid_idx = exog_train.dropna().index.min()
#     if valid_idx is not None:
#         train_y_trim    = train_y.loc[valid_idx:].copy()
#         exog_train_trim = exog_train.loc[valid_idx:].copy()
#     else:
#         train_y_trim    = train_y.copy()
#         exog_train_trim = exog_train.copy()
#
#     test_y_trim    = test_y.copy()
#     exog_test_trim = exog_test.copy()
#
#     model_triple = SARIMAX(
#         train_y_trim,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         exog=exog_train_trim,
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res_triple = model_triple.fit(disp=False)
#
#     fc_triple = res_triple.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
#     pred_triple = pd.Series(fc_triple.predicted_mean.values, index=test_y_trim.index)
#
#     y_true = test_y_trim.values
#     y_pred = pred_triple.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     triple_results.append({
#         "exog_cols": combo,
#         "AIC":       res_triple.aic,
#         "BIC":       res_triple.bic,
#         "MAE":       mae,
#         "RMSE":      rmse,
#         "MAPE":      mape
#     })
#
# df_triple = pd.DataFrame(triple_results).sort_values("MAPE").reset_index(drop=True)
#
# print("\n=== Triple‐Exogenous Results ===")
# print(df_triple.to_string(index=False))

# %%
import pandas as pd
import numpy as np
from itertools import combinations
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error

# -----------------------------------------------------------------------------
# ASSUMPTIONS / PREDEFINED:
#
# • weekly_lagged_north : pandas.DataFrame indexed by DATE (weekly), with columns:
#       – 'Total_TP'        (target series)
#       – 'TP_lag1w'
#       – 'RH2M_lag1w'
#       – 'GWETPROF'
#       – 'PRECIP_EWMA'
#       – 'APIxGWETPROF'
#
# • SARIMA orders chosen from prior diagnostics:
#     p, d, q   = 0, 0, 2        # nonseasonal (i.e. MA(2))
#     P, D, Q, s = 1, 0, 0, 52   # seasonal AR(1) at lag 52
# -----------------------------------------------------------------------------

p, d, q   = 0, 0, 2
P, D, Q, s = 1, 0, 0, 52

# 1) Split data 80/20
n_n     = len(weekly_lagged_north)
split_n = int(n_n * 0.8)

train_y = weekly_lagged_north['Total_TP'].iloc[:split_n].copy()
test_y  = weekly_lagged_north['Total_TP'].iloc[split_n:].copy()

train_df = weekly_lagged_north.iloc[:split_n].copy()
test_df  = weekly_lagged_north.iloc[split_n:].copy()

# 2) List of exogenous candidates
exog_cols = [
    'TP_lag1w',
    'RH2M_lag1w',
    'GWETPROF',
    'PRECIP_EWMA',
    'APIxGWETPROF'
]

# -----------------------------------------------------------------------------
# A) SINGLE exog results
# -----------------------------------------------------------------------------
single_results = []

for col in exog_cols:
    exog_train = train_df[[col]].copy()
    exog_test  = test_df[[col]].copy()

    # Drop leading NaNs on the train side
    first_valid = exog_train[col].first_valid_index()
    if first_valid is not None:
        train_y_trim    = train_y.loc[first_valid:].copy()
        exog_train_trim = exog_train.loc[first_valid:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_exog = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_exog = model_exog.fit(disp=False)

    fc   = res_exog.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred = pd.Series(fc.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    single_results.append({
        "exog_cols":  (col,),
        "num_exogs":  1,
        "AIC":        res_exog.aic,
        "BIC":        res_exog.bic,
        "MAE":        mae,
        "RMSE":       rmse,
        "MAPE":       mape
    })

df_single = pd.DataFrame(single_results)

# -----------------------------------------------------------------------------
# B) PAIRWISE combinations (two exogs at a time)
# -----------------------------------------------------------------------------
pair_results = []

for combo in combinations(exog_cols, 2):
    exog_train = train_df[list(combo)].copy()
    exog_test  = test_df[list(combo)].copy()

    # Drop leading NaNs on the train side
    valid_idx = exog_train.dropna().index.min()
    if valid_idx is not None:
        train_y_trim    = train_y.loc[valid_idx:].copy()
        exog_train_trim = exog_train.loc[valid_idx:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_combo = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_combo = model_combo.fit(disp=False)

    fc_combo = res_combo.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred_combo = pd.Series(fc_combo.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred_combo.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    pair_results.append({
        "exog_cols":  combo,
        "num_exogs":  2,
        "AIC":        res_combo.aic,
        "BIC":        res_combo.bic,
        "MAE":        mae,
        "RMSE":       rmse,
        "MAPE":       mape
    })

df_pair = pd.DataFrame(pair_results)

# -----------------------------------------------------------------------------
# C) TRIPLE combinations (three exogs at a time)
# -----------------------------------------------------------------------------
triple_results = []

for combo in combinations(exog_cols, 3):
    exog_train = train_df[list(combo)].copy()
    exog_test  = test_df[list(combo)].copy()

    # Drop leading NaNs on the train side
    valid_idx = exog_train.dropna().index.min()
    if valid_idx is not None:
        train_y_trim    = train_y.loc[valid_idx:].copy()
        exog_train_trim = exog_train.loc[valid_idx:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_triple = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_triple = model_triple.fit(disp=False)

    fc_triple = res_triple.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred_triple = pd.Series(fc_triple.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred_triple.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    triple_results.append({
        "exog_cols":  combo,
        "num_exogs":  3,
        "AIC":        res_triple.aic,
        "BIC":        res_triple.bic,
        "MAE":        mae,
        "RMSE":       rmse,
        "MAPE":       mape
    })

df_triple = pd.DataFrame(triple_results)

# -----------------------------------------------------------------------------
# D) OPTIONAL: QUAD (4‐way) combinations
# -----------------------------------------------------------------------------
quad_results = []

for combo in combinations(exog_cols, 4):
    exog_train = train_df[list(combo)].copy()
    exog_test  = test_df[list(combo)].copy()

    valid_idx = exog_train.dropna().index.min()
    if valid_idx is not None:
        train_y_trim    = train_y.loc[valid_idx:].copy()
        exog_train_trim = exog_train.loc[valid_idx:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_quad = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_quad = model_quad.fit(disp=False)

    fc_quad = res_quad.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred_quad = pd.Series(fc_quad.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred_quad.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    quad_results.append({
        "exog_cols":  combo,
        "num_exogs":  4,
        "AIC":        res_quad.aic,
        "BIC":        res_quad.bic,
        "MAE":        mae,
        "RMSE":       rmse,
        "MAPE":       mape
    })

df_quad = pd.DataFrame(quad_results)

# -----------------------------------------------------------------------------
# E) OPTIONAL: ALL FIVE exogs together
# -----------------------------------------------------------------------------
all5_results = []

exog_train_all5 = train_df[exog_cols].copy()
exog_test_all5  = test_df[exog_cols].copy()

valid_idx = exog_train_all5.dropna().index.min()
if valid_idx is not None:
    train_y_trim    = train_y.loc[valid_idx:].copy()
    exog_train_trim = exog_train_all5.loc[valid_idx:].copy()
else:
    train_y_trim    = train_y.copy()
    exog_train_trim = exog_train_all5.copy()

test_y_trim     = test_y.copy()
exog_test_trim  = exog_test_all5.copy()

model_all5 = SARIMAX(
    train_y_trim,
    order=(p, d, q),
    seasonal_order=(P, D, Q, s),
    exog=exog_train_trim,
    enforce_stationarity=False,
    enforce_invertibility=False
)
res_all5 = model_all5.fit(disp=False)

fc_all5     = res_all5.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
pred_all5   = pd.Series(fc_all5.predicted_mean.values, index=test_y_trim.index)

y_true = test_y_trim.values
y_pred = pred_all5.values

mae   = mean_absolute_error(y_true, y_pred)
rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

all5_results.append({
    "exog_cols":  tuple(exog_cols),
    "num_exogs":  5,
    "AIC":        res_all5.aic,
    "BIC":        res_all5.bic,
    "MAE":        mae,
    "RMSE":       rmse,
    "MAPE":       mape
})

df_all5 = pd.DataFrame(all5_results)

# -----------------------------------------------------------------------------
# F) CONCATENATE ALL SUBSETS INTO A SINGLE DataFrame
# -----------------------------------------------------------------------------
df_all = pd.concat(
    [df_single, df_pair, df_triple, df_quad, df_all5],
    ignore_index=True, 
    sort=False
)

# Sort by MAPE so the best combination (of any size) appears at the top
df_all = df_all.sort_values("MAPE").reset_index(drop=True)

print("\n=== All Exogenous‐Combination Results in One DataFrame ===")
print(df_all.to_string(index=False))
# Out:
# === All Exogenous‐Combination Results in One DataFrame ===
#                                                   exog_cols  num_exogs          AIC          BIC          MAE         RMSE      MAPE
#                         (TP_lag1w, RH2M_lag1w, PRECIP_EWMA)          3 12772.012752 12799.215480 1.121000e+07 1.399083e+07  9.788866
#                                      (TP_lag1w, RH2M_lag1w)          2 12829.534352 12852.850976 1.118792e+07 1.403948e+07  9.821726
#                                     (TP_lag1w, PRECIP_EWMA)          2 12780.738626 12804.055250 1.141360e+07 1.435403e+07  9.836208
#                       (TP_lag1w, PRECIP_EWMA, APIxGWETPROF)          3 12782.720396 12809.923124 1.141626e+07 1.435756e+07  9.837196
# (TP_lag1w, RH2M_lag1w, GWETPROF, PRECIP_EWMA, APIxGWETPROF)          5 12759.306101 12794.281038 1.128757e+07 1.403736e+07  9.850634
#                        (TP_lag1w, RH2M_lag1w, APIxGWETPROF)          3 12757.150250 12784.352978 1.130387e+07 1.406209e+07  9.880807
#                                    (TP_lag1w, APIxGWETPROF)          2 12795.612404 12818.929028 1.157757e+07 1.456950e+07  9.893795
#              (TP_lag1w, RH2M_lag1w, GWETPROF, APIxGWETPROF)          4 12758.974334 12790.063166 1.132684e+07 1.408282e+07  9.907162
#           (TP_lag1w, RH2M_lag1w, PRECIP_EWMA, APIxGWETPROF)          4 12757.331295 12788.420128 1.135620e+07 1.410741e+07  9.932785
#                                                 (TP_lag1w,)          1 12851.424154 12870.854674 1.163244e+07 1.455464e+07  9.982751
#               (TP_lag1w, RH2M_lag1w, GWETPROF, PRECIP_EWMA)          4 12767.111789 12798.200621 1.143329e+07 1.421391e+07 10.059069
#             (TP_lag1w, GWETPROF, PRECIP_EWMA, APIxGWETPROF)          4 12768.804327 12799.893160 1.156524e+07 1.438034e+07 10.148990
#                           (TP_lag1w, GWETPROF, PRECIP_EWMA)          3 12766.698688 12793.901417 1.157199e+07 1.438786e+07 10.151385
#                          (TP_lag1w, GWETPROF, APIxGWETPROF)          3 12772.254765 12799.457493 1.183910e+07 1.468833e+07 10.334927
#                            (TP_lag1w, RH2M_lag1w, GWETPROF)          3 12797.898157 12825.100885 1.187049e+07 1.493951e+07 10.531153
#                                        (TP_lag1w, GWETPROF)          2 12795.918101 12819.234725 1.204316e+07 1.514142e+07 10.641299
#                                   (RH2M_lag1w, PRECIP_EWMA)          2 13074.815439 13098.132063 1.841135e+07 2.264596e+07 16.727163
#                                  (RH2M_lag1w, APIxGWETPROF)          2 13000.814296 13024.130920 1.918684e+07 2.321393e+07 17.013667
#                     (RH2M_lag1w, PRECIP_EWMA, APIxGWETPROF)          3 12950.688949 12977.891677 2.007052e+07 2.473020e+07 17.796112
#                                               (RH2M_lag1w,)          1 13145.112796 13164.543316 2.020679e+07 2.492807e+07 18.725949
#           (RH2M_lag1w, GWETPROF, PRECIP_EWMA, APIxGWETPROF)          4 12847.285781 12878.374613 2.276295e+07 2.821208e+07 20.244958
#                        (RH2M_lag1w, GWETPROF, APIxGWETPROF)          3 12845.066549 12872.269277 2.294637e+07 2.843931e+07 20.421958
#                         (RH2M_lag1w, GWETPROF, PRECIP_EWMA)          3 12845.832021 12873.034749 2.315437e+07 2.871670e+07 20.613842
#                       (GWETPROF, PRECIP_EWMA, APIxGWETPROF)          3 12846.916028 12874.118756 2.345232e+07 2.909839e+07 20.838945
#                                     (GWETPROF, PRECIP_EWMA)          2 12844.625715 12867.942339 2.351883e+07 2.917418e+07 20.869401
#                                      (RH2M_lag1w, GWETPROF)          2 12845.467188 12868.783812 2.354575e+07 2.928735e+07 20.953464
#                                    (GWETPROF, APIxGWETPROF)          2 12844.427973 12867.744597 2.373468e+07 2.948821e+07 21.027298
#                                                 (GWETPROF,)          1 12843.557885 12862.988405 2.386567e+07 2.973413e+07 21.166716
#                                              (PRECIP_EWMA,)          1 13538.314421 13557.744941 3.032475e+07 3.827029e+07 24.876096
#                                 (PRECIP_EWMA, APIxGWETPROF)          2 13539.567360 13562.883984 3.054154e+07 3.852483e+07 25.057520
#                                             (APIxGWETPROF,)          1 13577.795477 13597.225997 3.881998e+07 4.804771e+07 32.121012

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# ## South Island - Weekly

# %%
weekly_lagged_south
# Out:
#                 Total_TP      TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  2.950068e+08  3.243453e+08       264.80        156.42
# 2015-03-29  2.870318e+08  2.950068e+08       367.40        264.80
# 2015-04-05  2.590456e+08  2.870318e+08       189.24        367.40
# 2015-04-12  2.441813e+08  2.590456e+08       470.76        189.24
# 2015-04-19  2.735290e+08  2.441813e+08       333.51        470.76
# ...                  ...           ...          ...           ...
# 2024-12-29  3.134675e+08  3.769670e+08       431.76        567.99
# 2025-01-05  3.059220e+08  3.134675e+08       373.74        431.76
# 2025-01-12  3.399780e+08  3.059220e+08       269.11        373.74
# 2025-01-19  3.410497e+08  3.399780e+08        56.50        269.11
# 2025-01-26  3.227407e+08  3.410497e+08       517.57         56.50
#
#             PRECIP_lag2w  PRECIP_EWMA  GWETPROF  GWETPROF_lag1w  APIxGWETPROF  \
# DATE
# 2015-03-22        767.35   488.289700  0.474921        0.480000    231.898854
# 2015-03-29        156.42   452.022790  0.482063        0.474921    217.903685
# 2015-04-05        264.80   373.187953  0.490952        0.482063    183.217514
# 2015-04-12        367.40   402.459567  0.502540        0.490952    202.251903
# 2015-04-19        189.24   381.774697  0.521032        0.502540    198.916737
# ...                  ...          ...       ...             ...           ...
# 2024-12-29        334.96   436.783276  0.568231        0.577619    248.193925
# 2025-01-05        567.99   417.870293  0.555685        0.568231    232.204225
# 2025-01-12        431.76   373.242205  0.535102        0.555685    199.722666
# 2025-01-19        373.74   278.219544  0.504014        0.535102    140.226435
# 2025-01-26        269.11   350.024681  0.480680        0.504014    168.249959
#
#             EVLAND  EVLAND_lag1w  EVLAND_EWMA       RH2M  RH2M_lag1w  \
# DATE
# 2015-03-22  165.01        228.78   224.290200  80.292381   77.127698
# 2015-03-29  154.86        165.01   203.461140  83.572698   80.292381
# 2015-04-05  177.98        154.86   195.816798  79.877222   83.572698
# 2015-04-12  166.54        177.98   187.033759  83.569683   79.877222
# 2015-04-19  129.33        166.54   169.722631  85.104524   83.569683
# ...            ...           ...          ...        ...         ...
# 2024-12-29  524.58        509.09   543.042882  78.089796   78.759660
# 2025-01-05  497.24        524.58   529.302017  76.967260   78.089796
# 2025-01-12  498.12        497.24   519.947412  72.961769   76.967260
# 2025-01-19  426.76        498.12   491.991188  73.288844   72.961769
# 2025-01-26  375.03        426.76   456.902832  74.280680   73.288844
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22   8.037778  12.604048
# 2015-03-29  11.639524   8.037778
# 2015-04-05  11.092937  11.639524
# 2015-04-12   9.989206  11.092937
# 2015-04-19   4.725635   9.989206
# ...               ...        ...
# 2024-12-29  14.621837  11.802789
# 2025-01-05  11.257329  14.621837
# 2025-01-12  12.327211  11.257329
# 2025-01-19  14.151905  12.327211
# 2025-01-26  14.696395  14.151905
#
# [515 rows x 16 columns]

# %%
south.head()
# Out:
# DATE
# 2015-03-22    2.950068e+08
# 2015-03-29    2.870318e+08
# 2015-04-05    2.590456e+08
# 2015-04-12    2.441813e+08
# 2015-04-19    2.735290e+08
# Freq: W-SUN, Name: Total_TP, dtype: float64

# %%
south
# Out:
# DATE
# 2015-03-22    2.950068e+08
# 2015-03-29    2.870318e+08
# 2015-04-05    2.590456e+08
# 2015-04-12    2.441813e+08
# 2015-04-19    2.735290e+08
#                   ...
# 2024-12-29    3.134675e+08
# 2025-01-05    3.059220e+08
# 2025-01-12    3.399780e+08
# 2025-01-19    3.410497e+08
# 2025-01-26    3.227407e+08
# Freq: W-SUN, Name: Total_TP, Length: 515, dtype: float64

# %%
# Repeat the same steps for South Island:
series_s = south
n_n = len(series_s)
split_n = int(n_n * 0.8)

train_n = series_s.iloc[:split_n]
test_n  = series_s.iloc[split_n:]

model_n = SARIMAX(
    train_n,
    order=(0, 0, 2),
    seasonal_order=(1, 0, 0, 52),
    enforce_stationarity=False,
    enforce_invertibility=False
)
res_n = model_n.fit(disp=False)
print(res_n.summary())

fc_n = res_n.get_forecast(steps=len(test_n))
pred_n = pd.Series(fc_n.predicted_mean.values, index=test_n.index)

mae_n  = mean_absolute_error(test_n, pred_n)
rmse_n = np.sqrt(mean_squared_error(test_n, pred_n))
mape_n = np.mean(np.abs((test_n - pred_n) / test_n)) * 100

# rmse = np.sqrt(mean_squared_error(target_test, forecast))
# mae = mean_absolute_error(target_test, forecast)
# epsilon = 1e-10  # small constant to avoid division by zero in MAPE
# mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

print("South Island SARIMA Hydro (0, 0, 2)x(1, 0, 0, 52) → MAE:", f"{mae_n:.2f}",
      "RMSE:", f"{rmse_n:.2f}", "MAPE:", f"{mape_n:.2f}%")
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                            Total_TP   No. Observations:                  412
# Model:             SARIMAX(0, 0, 2)x(1, 0, [], 52)   Log Likelihood               -7405.906
# Date:                             Thu, 05 Jun 2025   AIC                          14819.811
# Time:                                     01:31:36   BIC                          14835.356
# Sample:                                 03-22-2015   HQIC                         14825.992
#                                       - 02-05-2023
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.8017      3.810      0.210      0.833      -6.666       8.270
# ma.L2          0.4476      4.955      0.090      0.928      -9.264      10.159
# ar.S.L52       0.9772      1.256      0.778      0.437      -1.485       3.440
# sigma2      1.166e+17        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.54   Jarque-Bera (JB):                12.60
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.41e+51. Standard errors may be unstable.
# South Island SARIMA Hydro (0, 0, 2)x(1, 0, 0, 52) → MAE: 41404929.34 RMSE: 53213526.44 MAPE: 12.69%

# %% [raw]
# 1. South Island SARIMA(1, 0, 0)x(0, 0, 1, 52) → MAE: 75226135.36 RMSE: 84557781.81 MAPE: 21.44%
# 2. South Island SARIMA(1, 0, 1)x(0, 0, 1, 52) → MAE: 68755956.11 RMSE: 77859468.87 MAPE: 19.54%

# %%
pred_n
# Out:
# DATE
# 2023-02-12    3.120306e+08
# 2023-02-19    3.091040e+08
# 2023-02-26    3.304843e+08
# 2023-03-05    3.202119e+08
# 2023-03-12    3.121345e+08
#                   ...
# 2024-12-29    2.971700e+08
# 2025-01-05    3.202603e+08
# 2025-01-12    3.191837e+08
# 2025-01-19    3.195681e+08
# 2025-01-26    2.885162e+08
# Freq: W-SUN, Length: 103, dtype: float64

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(10,4))
plt.plot(train_n.index, train_n, label="Train",   color="gray")
plt.plot(test_n.index,  test_n,  label="Actual",  color="black")
plt.plot(pred_n.index,  pred_n,  label="Forecast",color="cornflowerblue")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("South Island: SARIMA Hydro Forecast vs. Actual (RQ1)", fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# %%
df_ann_hydro_south_wk
# Out:
#                 Total_TP      TP_lag1w
# DATE
# 2015-03-22  2.950068e+08  3.243453e+08
# 2015-03-29  2.870318e+08  2.950068e+08
# 2015-04-05  2.590456e+08  2.870318e+08
# 2015-04-12  2.441813e+08  2.590456e+08
# 2015-04-19  2.735290e+08  2.441813e+08
# ...                  ...           ...
# 2024-12-29  3.134675e+08  3.769670e+08
# 2025-01-05  3.059220e+08  3.134675e+08
# 2025-01-12  3.399780e+08  3.059220e+08
# 2025-01-19  3.410497e+08  3.399780e+08
# 2025-01-26  3.227407e+08  3.410497e+08
#
# [515 rows x 2 columns]

# %%
# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_hydro_south_wk = weekly_lagged_south[['Total_TP','TP_lag1w']]

s_hydro_ann     = len(df_ann_hydro_south_wk)
split_ann = int(s_hydro_ann * 0.8)

train_s_ann = df_ann_hydro_south_wk.iloc[:split_ann]
test_s_ann  = df_ann_hydro_south_wk.iloc[split_ann:]

X_train_s_ann = train_s_ann[['TP_lag1w']].values
y_train_s_ann = train_s_ann['Total_TP'].values.reshape(-1,1)
X_test_s_ann  = test_s_ann[['TP_lag1w']].values
y_test_s_ann  = test_s_ann['Total_TP'].values.reshape(-1,1)

# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s_s_ann = scaler_X.fit_transform(X_train_s_ann)
X_test_s_s_ann  = scaler_X.transform(X_test_s_ann)

scaler_y = MinMaxScaler()
y_train_s_s_ann = scaler_y.fit_transform(y_train_s_ann)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# 4) Build the ANN
model_ann_s = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann_s.compile(optimizer='adam', loss='mse')

# 5) Train the ANN (the shuffle order is now deterministic)
history_s = model_ann_s.fit(
    X_train_s_s_ann, y_train_s_s_ann,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# 6) Predict & rescale
y_pred_s_s_ann = model_ann_s.predict(X_test_s_s_ann)
y_pred_s_ann   = scaler_y.inverse_transform(y_pred_s_s_ann).flatten()

# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test_s_ann.flatten(), y_pred_s_ann)
rmse_ann = np.sqrt(mean_squared_error(y_test_s_ann.flatten(), y_pred_s_ann))
mape_ann = np.mean(np.abs((y_test_s_ann.flatten() - y_pred_s_ann) / y_test_s_ann.flatten())) * 100

# print(f"Univariate ANN - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")
print("South Island ANN Hydro (without regressors) → MAE:", f"{mae_ann:.2f}",
      "RMSE:", f"{rmse_ann:.2f}", "MAPE:", f"{mape_ann:.2f}%")
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# South Island ANN Hydro (without regressors) → MAE: 17450042.51 RMSE: 23000848.11 MAPE: 5.37%

# %%
plt.figure(figsize=(10,4))
plt.plot(train_s_ann.index,y_train_s_ann.flatten(),label="Train (2015 -> split)",color="lightgray")
plt.plot(test_s_ann.index, y_test_s_ann, label="Actual",color="black")
plt.plot(test_s_ann.index, y_pred_s_ann, label="Forecast",color="darkorange")
plt.title("RQ1‐ANN: South Island Weekly Hydro (Actual vs. Forecast)" , fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)", fontsize=9)
plt.legend(loc="upper right", fontsize=7)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(12,5))
plt.plot(train_n.index, train_n, label="Train",   color="gray")
plt.plot(test_n.index,  test_n,  label="Actual",  color="black")
plt.plot(pred_n.index,  pred_n,  label="Forecast-SARIMA",color="cornflowerblue")
plt.plot(test_s_ann.index, y_pred_s_ann, label="Forecast-ANN",color="darkorange")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("South Island: Hydro Forecast vs. Actual (Weekly) (RQ1)", fontsize=10)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# plt.title("North Island: Hydro Forecast vs. Actual (Weekly) (RQ1)" , fontsize=10)

# %%
plt.figure(figsize=(12,4))
plt.plot(weekly_lagged_south['Total_TP'], marker='o', linestyle='-')
plt.title("South Island: Weekly Hydro Generation (Total_TP)")
plt.ylabel("KWh (weekly total)")
plt.xlabel("Date")
plt.grid(True)
plt.show()

# %% [raw]
# import pandas as pd
# import numpy as np
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
# # -----------------------------------------------------------------------------
# # ASSUMPTIONS / PRE‐DEFINED VARIABLES
# # -----------------------------------------------------------------------------
# # • series_n : pandas.Series of weekly North Island “Total_TP” (kWh), indexed by date.
# # -----------------------------------------------------------------------------
#
# # 1) Create train/test split (80/20)
# s_s      = len(series_s)
# split_n  = int(s_s * 0.8)
#
# train_s = series_s.iloc[:split_n].copy()
# test_s  = series_s.iloc[split_n:].copy()
#
# # 2) Define the four candidate (order, seasonal_order) pairs
# candidates = [
#     ((1, 0, 1), (0, 0, 0, 52)),
#     ((0, 0, 1), (0, 0, 1, 52)),
#     ((1, 0, 1), (1, 0, 0, 52)),
#     ((0, 0, 2), (1, 0, 0, 52)),
#     ((1, 0, 0), (0, 0, 1, 52)),
#     ((1, 0, 1), (0, 0, 1, 52))
# ]
#
# # 3) Loop through candidates, fit, forecast, and compute metrics
# results_list = []
#
# for idx, ((p, d, q), (P, D, Q, s)) in enumerate(candidates, start=1):
#     # 3a) Fit SARIMAX on the TRAIN segment
#     model = SARIMAX(
#         train_s,
#         order=(p, d, q),
#         seasonal_order=(P, D, Q, s),
#         enforce_stationarity=False,
#         enforce_invertibility=False
#     )
#     res = model.fit(disp=False)
#
#     # 3b) Forecast on TEST segment
#     n_steps = len(test_s)
#     fc      = res.get_forecast(steps=n_steps)
#
#     # 3c) Align the forecasted mean with test_n.index
#     pred       = pd.Series(fc.predicted_mean.values, index=test_s.index)
#     conf_int   = fc.conf_int().copy()
#     conf_int.index = test_s.index
#
#     # 3d) Compute MAE, RMSE, MAPE
#     y_true = test_s.values
#     y_pred = pred.values
#
#     mae   = mean_absolute_error(y_true, y_pred)
#     rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
#     mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100
#
#     # 3e) Collect results
#     results_list.append({
#         "candidate_index":   idx,
#         "order":             (p, d, q),
#         "seasonal_order":    (P, D, Q, s),
#         "AIC":               res.aic,
#         "BIC":               res.bic,
#         "MAE":               mae,
#         "RMSE":              rmse,
#         "MAPE":              mape
#     })
#
# # 4) Convert to DataFrame and display
# df_results = pd.DataFrame(results_list)
# print(df_results.to_string(index=False))

# %% [raw]
# candidate_index     order seasonal_order          AIC          BIC          MAE         RMSE      MAPE
#                1 (1, 0, 1)  (0, 0, 0, 52) 14973.847540 14985.896012 6.026392e+07 6.948857e+07 17.035058
#                2 (0, 0, 1)  (0, 0, 1, 52) 14766.201561 14777.843160 2.679297e+08 2.774335e+08 80.052560
#                3 (1, 0, 1)  (1, 0, 0, 52) 13102.539808 13118.073098 6.822416e+07 7.728208e+07 19.392804
#                4 (0, 0, 2)  (1, 0, 0, 52) 14819.811387 14835.355804 4.140493e+07 5.321353e+07 12.689068
#                5 (1, 0, 0)  (0, 0, 1, 52) 13107.291473 13118.941440 7.522614e+07 8.455778e+07 21.435574
#                6 (1, 0, 1)  (0, 0, 1, 52) 13067.348585 13082.870716 6.875596e+07 7.785947e+07 19.538741

# %% [raw]
# # df_hydro_weekly_south / weekly_lagged_south
# # df_hydro_weekly_north / weekly_lagged_north

# %%
# Find rows with zero Total_TP in South Island
zero_tp_south = weekly_lagged_south[weekly_lagged_south['Total_TP'] == 0]

# Get the unique dates
zero_dates = zero_tp_south.index.unique()

# Display the result
print("Dates with Total_TP = 0 in South Island:")
for date in zero_dates:
    print(date.strftime('%Y-%m-%d'))
# Out:
# Dates with Total_TP = 0 in South Island:

# %%
weekly_lagged_south.head(5)
# Out:
#                 Total_TP      TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  2.950068e+08  3.243453e+08       264.80        156.42
# 2015-03-29  2.870318e+08  2.950068e+08       367.40        264.80
# 2015-04-05  2.590456e+08  2.870318e+08       189.24        367.40
# 2015-04-12  2.441813e+08  2.590456e+08       470.76        189.24
# 2015-04-19  2.735290e+08  2.441813e+08       333.51        470.76
#
#             PRECIP_lag2w  PRECIP_EWMA  GWETPROF  GWETPROF_lag1w  APIxGWETPROF  \
# DATE
# 2015-03-22        767.35   488.289700  0.474921        0.480000    231.898854
# 2015-03-29        156.42   452.022790  0.482063        0.474921    217.903685
# 2015-04-05        264.80   373.187953  0.490952        0.482063    183.217514
# 2015-04-12        367.40   402.459567  0.502540        0.490952    202.251903
# 2015-04-19        189.24   381.774697  0.521032        0.502540    198.916737
#
#             EVLAND  EVLAND_lag1w  EVLAND_EWMA       RH2M  RH2M_lag1w  \
# DATE
# 2015-03-22  165.01        228.78   224.290200  80.292381   77.127698
# 2015-03-29  154.86        165.01   203.461140  83.572698   80.292381
# 2015-04-05  177.98        154.86   195.816798  79.877222   83.572698
# 2015-04-12  166.54        177.98   187.033759  83.569683   79.877222
# 2015-04-19  129.33        166.54   169.722631  85.104524   83.569683
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22   8.037778  12.604048
# 2015-03-29  11.639524   8.037778
# 2015-04-05  11.092937  11.639524
# 2015-04-12   9.989206  11.092937
# 2015-04-19   4.725635   9.989206

# %%
# Split the weekly data into 80% training and 20% testing sets
n = len(weekly_lagged_south)
train_size = int(n * 0.8)
train_weekly = weekly_lagged_south.iloc[:train_size]
test_weekly = weekly_lagged_south.iloc[train_size:]

# %%
print("Weekly Train set:", train_weekly.index.min(), "to", train_weekly.index.max() , " Records count : ",len(train_weekly) )
print("Weekly Test set:", test_weekly.index.min(), "to", test_weekly.index.max(), " Records count : ",len(test_weekly) )
# Out:
# Weekly Train set: 2015-03-22 00:00:00 to 2023-02-05 00:00:00  Records count :  412
# Weekly Test set: 2023-02-12 00:00:00 to 2025-01-26 00:00:00  Records count :  103

# %%
# Define the target variable (original Total_TP) and exogenous variables
# target_train_log = train_weekly['Total_TP_log']
# target_test_log = test_weekly['Total_TP_log']

target_train = train_weekly['Total_TP']
target_test = test_weekly['Total_TP']

# %%
#['Total_TP', 'PRECTOTCORR', 'EVLAND', 'RH2M', 'GWETPROF', 'T2M', 'PRECIP_lag1w', 'PRECIP_lag2w', 'API_weekly']
#befoe exog_cols_wk = ['RH2M', 'GWETPROF', 'PRECIP_lag1w', 'PRECIP_lag2w', 'API_weekly']
#exog_cols_wk = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
#exog_cols_wk = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
#exog_cols = ['WS50M']
#'TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w'

exog_cols_wk = ['TP_lag1w', 'APIxGWETPROF', 'PRECIP_EWMA']

# %%
exog_train = train_weekly[exog_cols_wk]
exog_test = test_weekly[exog_cols_wk]

# %%
# Fit SARIMAX on the original (non-log) target data
#1. South Island SARIMA(1, 0, 0)x(0, 0, 1, 52) → MAE: 75226135.36 RMSE: 84557781.81 MAPE: 21.44%
#2. South Island SARIMA(1, 0, 1)x(0, 0, 1, 52) → MAE: 68755956.11 RMSE: 77859468.87 MAPE: 19.54%
model = SARIMAX(target_train,
                exog=exog_train,
                order=(0, 0, 2),
                seasonal_order=(1, 0, 0, 52),
                enforce_stationarity=False,
                enforce_invertibility=False)
results = model.fit(disp=False)
print(results.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                            Total_TP   No. Observations:                  412
# Model:             SARIMAX(0, 0, 2)x(1, 0, [], 52)   Log Likelihood               -6548.960
# Date:                             Thu, 05 Jun 2025   AIC                          13111.920
# Time:                                     01:51:03   BIC                          13139.123
# Sample:                                 03-22-2015   HQIC                         13122.736
#                                       - 02-05-2023
# Covariance Type:                               opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TP_lag1w         0.9502      0.009    107.737      0.000       0.933       0.967
# APIxGWETPROF  -468.4696    2.1e+04     -0.022      0.982   -4.16e+04    4.07e+04
# PRECIP_EWMA   4.307e+04   1.75e+04      2.463      0.014    8800.483    7.73e+04
# ma.L1           -0.1953      0.053     -3.714      0.000      -0.298      -0.092
# ma.L2           -0.1356      0.054     -2.497      0.013      -0.242      -0.029
# ar.S.L52         0.1766      0.050      3.516      0.000       0.078       0.275
# sigma2         3.79e+14   1.67e-06   2.27e+20      0.000    3.79e+14    3.79e+14
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.12
# Prob(Q):                              1.00   Prob(JB):                         0.35
# Heteroskedasticity (H):               1.44   Skew:                            -0.16
# Prob(H) (two-sided):                  0.04   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.58e+36. Standard errors may be unstable.

# %%
# Forecast on the test set - non log
n_steps = len(test_weekly)
forecast = results.get_forecast(steps=n_steps, exog=exog_test).predicted_mean

# %%
# Compute performance metrics - non log
rmse = np.sqrt(mean_squared_error(target_test, forecast))
mae = mean_absolute_error(target_test, forecast)
epsilon = 1e-10  # small constant to avoid division by zero in MAPE
mape = np.mean(np.abs((target_test - forecast) / (target_test + epsilon))) * 100

# print("\nForecast Performance Metrics (Without Log Transformation):")
# print(f"RMSE: {rmse:.2f}")
# print(f"MAE: {mae:.2f}")
# print(f"Adjusted MAPE: {mape:.2f}%")
print("South Island SARIMA Hydro (0, 0, 2)x(1, 0, 0, 52) → MAE:", f"{mae:.2f}",
      "RMSE:", f"{rmse:.2f}", "MAPE:", f"{mape:.2f}%")
# Out:
# South Island SARIMA Hydro (0, 0, 2)x(1, 0, 0, 52) → MAE: 16453845.96 RMSE: 22079011.63 MAPE: 4.97%

# %% [raw]
# # order=(1, 0, 1),
# #                 seasonal_order=(0, 0, 1, 52),
# # exog_cols_wk = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
# # Forecast Performance Metrics (Without Log Transformation):
# # RMSE: 21693929.83
# # MAE: 16100802.84
# # Adjusted MAPE: 4.90%
# #---------------------------------------------------------------------------------
# # order=(1, 0, 1),
# #                 seasonal_order=(0, 0, 1, 52),
# # exog_cols_wk = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
# # Forecast Performance Metrics (Without Log Transformation):
# # RMSE: 37179038.21
# # MAE: 28638472.09
# # Adjusted MAPE: 8.95%
# ##############################
#                 order=(1, 0, 0),
#                 seasonal_order=(0, 0, 1, 52),
# # exog_cols_wk = ['APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 37135187.63
# MAE: 28642294.31
# Adjusted MAPE: 8.95%
# ###################################################################################
#                 order=(1, 0, 0),
#                 seasonal_order=(0, 0, 1, 52),
# # exog_cols_wk = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']
# Forecast Performance Metrics (Without Log Transformation):
# RMSE: 21690736.24
# MAE: 16094837.98
# Adjusted MAPE: 4.90%

# %%
# # Plot Actual vs. Forecast
# plt.figure(figsize=(14, 7))
# plt.plot(train_weekly.index, target_train, label='Train', color='blue')
# plt.plot(test_weekly.index, target_test, label='Test', color='green')
# plt.plot(test_weekly.index, forecast, label='Forecast', color='red', linestyle='--')
# plt.xlabel("Date")
# plt.ylabel("Total_TP")
# plt.title("Weekly SARIMAX Forecast-North Island (Without Log Transformation)")
# plt.legend()
# plt.tight_layout()
# plt.show()

# Repeat a similar plot for North Island:
plt.figure(figsize=(10,4))
plt.plot(train_weekly.index, target_train, label="Train",   color="gray")
plt.plot(test_weekly.index,  target_test,  label="Actual)",  color="black")
plt.plot(forecast.index,  forecast,  label="Forecast",color="cornflowerblue")
# plt.fill_between(
#     fc_n.conf_int().index,
#     fc_n.conf_int().iloc[:,0],
#     fc_n.conf_int().iloc[:,1],
#     color="lightblue", alpha=0.2
# )
plt.legend()
plt.title("South Island: SARIMA Hydro Forecast vs. Actual (RQ2)", fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# plt.legend()
# plt.title("South Island: SARIMA Hydro Forecast vs. Actual (RQ1)", fontsize=9)
# plt.xlabel("Date")
# plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
# plt.grid(True)
# plt.tight_layout()
# plt.legend(loc="upper right", fontsize=7)
# plt.show()

# %%
#factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']

factors_s_ann2 = ['TP_lag1w', 'APIxGWETPROF']

# 2) Split via slicing
n = len(weekly_lagged_south)
split_idx = int(n * 0.8)

train_df_s_ann2 = weekly_lagged_south.iloc[:split_idx]
test_df_s_ann2 = weekly_lagged_south.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw_s_ann2 = train_df_s_ann2[factors_s_ann2].values  # (n_samples, n_features)
X_test_raw_s_ann2 = test_df_s_ann2[factors_s_ann2].values
y_train_raw_s_ann2 = train_df_s_ann2['Total_TP'].values.reshape(-1, 1)
y_test_raw_s_ann2 = test_df_s_ann2['Total_TP'].values.reshape(-1, 1) # (n_samples, 1)

# 4) Scale
x_scaler_s_ann2  = StandardScaler().fit(X_train_raw_s_ann2)
y_scaler_s_ann2  = StandardScaler().fit(y_train_raw_s_ann2)

X_train_s_ann2  = x_scaler.transform(X_train_raw_s_ann2)
X_test_s_ann2   = x_scaler.transform(X_test_raw_s_ann2)
y_train_s_ann2  = y_scaler.transform(y_train_raw_s_ann2)
y_test_s_ann2   = y_scaler.transform(y_test_raw_s_ann2)

# 5) Sanity‐check shapes
print(X_train_s_ann2.shape, y_train_s_ann2.shape)
print(X_test_s_ann2.shape,  y_test_s_ann2.shape)

# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

#   ANN Model  
model = Sequential([
    Dense(64, input_shape=(X_train_s_ann2.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(16),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])

#model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")


model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

history = model.fit(
    X_train_s_ann2, y_train_s_ann2,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# 1) Predict & inverse‑scale
y_pred_s_s_ann2 = model.predict(X_test_s_ann2)
y_pred_s_ann2 = y_scaler.inverse_transform(y_pred_s_s_ann2).ravel()
y_true_s_ann2 = y_scaler.inverse_transform(y_test_s_ann2).ravel()

# 2) Metrics
mae  = mean_absolute_error(y_true_s_ann2, y_pred_s_ann2)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true_s_ann2, y_pred_s_ann2)
mape = mean_absolute_percentage_error(y_true_s_ann2, y_pred_s_ann2) * 100
# print("\nRQ2‐ANN Performance - Hydro (South Island):")
# print(f"MAE : {mae:,.2f}")
# print(f"RMSE: {rmse:,.2f}")
# print(f"MAPE: {mape:.2f}%")

print("South Island ANN Hydro  → MAE:", f"{mae:.2f}",
      "RMSE:", f"{rmse:.2f}", "MAPE:", f"{mape:.2f}%")
# Out:
# (412, 2) (412, 1)
# (103, 2) (103, 1)
# Epoch 1/200
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.8839 - mape: 103.6399 - val_loss: 3.2740 - val_mape: 109.2628 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8644 - mape: 102.7340 - val_loss: 3.2412 - val_mape: 108.1880 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8208 - mape: 101.0167 - val_loss: 3.2005 - val_mape: 106.8492 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7903 - mape: 100.0054 - val_loss: 3.1768 - val_mape: 106.0732 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7477 - mape: 98.5069 - val_loss: 3.1566 - val_mape: 105.4064 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7137 - mape: 97.4534 - val_loss: 3.1528 - val_mape: 105.2525 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6847 - mape: 96.4878 - val_loss: 3.1283 - val_mape: 104.4240 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6426 - mape: 94.9522 - val_loss: 3.0769 - val_mape: 102.7165 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6082 - mape: 94.0824 - val_loss: 3.0354 - val_mape: 101.2814 - learning_rate: 5.0000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5670 - mape: 92.6628 - val_loss: 2.9866 - val_mape: 99.5986 - learning_rate: 5.0000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5316 - mape: 91.5506 - val_loss: 2.9421 - val_mape: 98.0491 - learning_rate: 5.0000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4910 - mape: 90.2238 - val_loss: 2.8977 - val_mape: 96.5268 - learning_rate: 5.0000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4642 - mape: 89.5092 - val_loss: 2.8471 - val_mape: 94.8302 - learning_rate: 5.0000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4193 - mape: 87.8729 - val_loss: 2.8026 - val_mape: 93.3274 - learning_rate: 5.0000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3879 - mape: 86.7562 - val_loss: 2.7733 - val_mape: 92.3066 - learning_rate: 5.0000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3584 - mape: 85.3904 - val_loss: 2.7270 - val_mape: 90.7529 - learning_rate: 5.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3132 - mape: 84.0748 - val_loss: 2.6839 - val_mape: 89.3447 - learning_rate: 5.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2786 - mape: 82.6067 - val_loss: 2.6080 - val_mape: 86.8755 - learning_rate: 5.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2359 - mape: 81.7411 - val_loss: 2.5091 - val_mape: 83.6810 - learning_rate: 5.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1865 - mape: 79.4866 - val_loss: 2.4444 - val_mape: 81.5981 - learning_rate: 5.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1529 - mape: 78.6534 - val_loss: 2.4244 - val_mape: 80.9612 - learning_rate: 5.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1111 - mape: 76.9886 - val_loss: 2.3914 - val_mape: 79.9690 - learning_rate: 5.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0711 - mape: 75.7160 - val_loss: 2.3576 - val_mape: 78.9875 - learning_rate: 5.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0334 - mape: 74.6220 - val_loss: 2.3122 - val_mape: 77.5649 - learning_rate: 5.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9924 - mape: 73.1202 - val_loss: 2.2733 - val_mape: 76.2775 - learning_rate: 5.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9517 - mape: 71.4571 - val_loss: 2.2413 - val_mape: 75.1849 - learning_rate: 5.0000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9059 - mape: 70.0559 - val_loss: 2.2275 - val_mape: 74.7525 - learning_rate: 5.0000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8682 - mape: 68.8353 - val_loss: 2.1732 - val_mape: 73.0193 - learning_rate: 5.0000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8143 - mape: 66.7720 - val_loss: 2.1012 - val_mape: 70.7074 - learning_rate: 5.0000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7726 - mape: 65.6022 - val_loss: 2.0810 - val_mape: 70.0885 - learning_rate: 5.0000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7288 - mape: 63.7734 - val_loss: 2.0293 - val_mape: 68.4501 - learning_rate: 5.0000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6885 - mape: 62.2021 - val_loss: 1.9990 - val_mape: 67.4943 - learning_rate: 5.0000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6419 - mape: 60.8828 - val_loss: 1.9669 - val_mape: 66.4939 - learning_rate: 5.0000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5908 - mape: 59.0362 - val_loss: 1.9371 - val_mape: 65.5506 - learning_rate: 5.0000e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5523 - mape: 57.5111 - val_loss: 1.8924 - val_mape: 64.1382 - learning_rate: 5.0000e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5090 - mape: 55.6860 - val_loss: 1.8650 - val_mape: 63.2609 - learning_rate: 5.0000e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4568 - mape: 54.0009 - val_loss: 1.8289 - val_mape: 62.1014 - learning_rate: 5.0000e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4181 - mape: 52.9047 - val_loss: 1.7755 - val_mape: 60.2546 - learning_rate: 5.0000e-04
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3629 - mape: 50.7968 - val_loss: 1.7590 - val_mape: 59.7111 - learning_rate: 5.0000e-04
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3259 - mape: 49.3062 - val_loss: 1.6904 - val_mape: 57.5376 - learning_rate: 5.0000e-04
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2707 - mape: 47.6234 - val_loss: 1.6212 - val_mape: 55.2767 - learning_rate: 5.0000e-04
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2108 - mape: 45.1786 - val_loss: 1.5918 - val_mape: 54.2858 - learning_rate: 5.0000e-04
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1759 - mape: 43.9386 - val_loss: 1.4989 - val_mape: 51.2961 - learning_rate: 5.0000e-04
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1322 - mape: 42.7106 - val_loss: 1.3799 - val_mape: 47.5200 - learning_rate: 5.0000e-04
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0832 - mape: 41.2233 - val_loss: 1.3369 - val_mape: 46.1929 - learning_rate: 5.0000e-04
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0266 - mape: 39.3466 - val_loss: 1.2800 - val_mape: 44.3113 - learning_rate: 5.0000e-04
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9809 - mape: 37.6697 - val_loss: 1.2240 - val_mape: 42.6016 - learning_rate: 5.0000e-04
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9289 - mape: 35.6347 - val_loss: 1.1599 - val_mape: 40.5363 - learning_rate: 5.0000e-04
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8919 - mape: 34.6452 - val_loss: 1.1090 - val_mape: 38.7834 - learning_rate: 5.0000e-04
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8353 - mape: 32.6276 - val_loss: 1.0553 - val_mape: 37.0109 - learning_rate: 5.0000e-04
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7844 - mape: 30.5608 - val_loss: 0.9781 - val_mape: 34.5390 - learning_rate: 5.0000e-04
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7538 - mape: 29.3439 - val_loss: 0.8883 - val_mape: 31.6945 - learning_rate: 5.0000e-04
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6974 - mape: 27.6408 - val_loss: 0.7839 - val_mape: 28.3940 - learning_rate: 5.0000e-04
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6519 - mape: 26.1828 - val_loss: 0.7896 - val_mape: 28.5444 - learning_rate: 5.0000e-04
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6114 - mape: 24.6219 - val_loss: 0.7143 - val_mape: 26.0902 - learning_rate: 5.0000e-04
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5616 - mape: 23.2848 - val_loss: 0.6205 - val_mape: 23.1954 - learning_rate: 5.0000e-04
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5214 - mape: 21.6494 - val_loss: 0.5802 - val_mape: 21.8055 - learning_rate: 5.0000e-04
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4820 - mape: 20.6164 - val_loss: 0.5146 - val_mape: 19.5501 - learning_rate: 5.0000e-04
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4447 - mape: 18.9737 - val_loss: 0.4693 - val_mape: 18.1440 - learning_rate: 5.0000e-04
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4117 - mape: 18.2887 - val_loss: 0.4695 - val_mape: 18.0530 - learning_rate: 5.0000e-04
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3768 - mape: 17.3836 - val_loss: 0.4635 - val_mape: 17.7617 - learning_rate: 5.0000e-04
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3477 - mape: 16.0859 - val_loss: 0.4288 - val_mape: 16.7946 - learning_rate: 5.0000e-04
# Epoch 63/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3114 - mape: 14.5763 - val_loss: 0.3987 - val_mape: 15.9547 - learning_rate: 5.0000e-04
# Epoch 64/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3168 - mape: 14.7769 - val_loss: 0.4125 - val_mape: 16.1164 - learning_rate: 5.0000e-04
# Epoch 65/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2719 - mape: 13.4673 - val_loss: 0.4159 - val_mape: 16.1776 - learning_rate: 5.0000e-04
# Epoch 66/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2792 - mape: 13.6216 - val_loss: 0.4049 - val_mape: 15.9293 - learning_rate: 5.0000e-04
# Epoch 67/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2301 - mape: 11.7666 - val_loss: 0.3922 - val_mape: 15.4868 - learning_rate: 5.0000e-04
# Epoch 68/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2190 - mape: 11.3485 - val_loss: 0.3839 - val_mape: 15.2139 - learning_rate: 5.0000e-04
# Epoch 69/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2275 - mape: 11.8739 - val_loss: 0.3522 - val_mape: 14.3122 - learning_rate: 5.0000e-04
# Epoch 70/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2206 - mape: 11.5866 - val_loss: 0.3324 - val_mape: 13.7605 - learning_rate: 5.0000e-04
# Epoch 71/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2060 - mape: 11.0280 - val_loss: 0.3219 - val_mape: 13.4256 - learning_rate: 5.0000e-04
# Epoch 72/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1871 - mape: 10.2678 - val_loss: 0.3138 - val_mape: 13.1387 - learning_rate: 5.0000e-04
# Epoch 73/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1871 - mape: 10.3073 - val_loss: 0.3150 - val_mape: 13.0961 - learning_rate: 5.0000e-04
# Epoch 74/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2002 - mape: 11.1786 - val_loss: 0.3045 - val_mape: 12.7614 - learning_rate: 5.0000e-04
# Epoch 75/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1676 - mape: 9.6893 - val_loss: 0.2950 - val_mape: 12.7639 - learning_rate: 5.0000e-04
# Epoch 76/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1888 - mape: 10.6289 - val_loss: 0.2927 - val_mape: 13.0196 - learning_rate: 5.0000e-04
# Epoch 77/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1623 - mape: 9.7567 - val_loss: 0.2891 - val_mape: 12.9224 - learning_rate: 5.0000e-04
# Epoch 78/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1680 - mape: 9.6794 - val_loss: 0.2845 - val_mape: 12.6124 - learning_rate: 5.0000e-04
# Epoch 79/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1671 - mape: 9.8391 - val_loss: 0.2863 - val_mape: 12.7295 - learning_rate: 5.0000e-04
# Epoch 80/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1761 - mape: 10.2297 - val_loss: 0.2920 - val_mape: 12.9865 - learning_rate: 5.0000e-04
# Epoch 81/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1795 - mape: 10.2199 - val_loss: 0.2911 - val_mape: 12.8898 - learning_rate: 5.0000e-04
# Epoch 82/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1763 - mape: 10.2566 - val_loss: 0.2877 - val_mape: 12.7472 - learning_rate: 5.0000e-04
# Epoch 83/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1764 - mape: 10.1293 - val_loss: 0.2861 - val_mape: 12.7250 - learning_rate: 5.0000e-04
# Epoch 84/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1654 - mape: 9.8597 - val_loss: 0.2838 - val_mape: 12.6632 - learning_rate: 2.5000e-04
# Epoch 85/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1641 - mape: 9.7734 - val_loss: 0.2797 - val_mape: 12.5536 - learning_rate: 2.5000e-04
# Epoch 86/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1707 - mape: 9.8909 - val_loss: 0.2764 - val_mape: 12.4514 - learning_rate: 2.5000e-04
# Epoch 87/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1747 - mape: 10.2914 - val_loss: 0.2733 - val_mape: 12.3299 - learning_rate: 2.5000e-04
# Epoch 88/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1902 - mape: 10.7915 - val_loss: 0.2699 - val_mape: 12.2140 - learning_rate: 2.5000e-04
# Epoch 89/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1648 - mape: 9.5962 - val_loss: 0.2682 - val_mape: 12.1393 - learning_rate: 2.5000e-04
# Epoch 90/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1431 - mape: 8.8143 - val_loss: 0.2664 - val_mape: 12.0993 - learning_rate: 2.5000e-04
# Epoch 91/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1665 - mape: 9.9049 - val_loss: 0.2648 - val_mape: 12.0717 - learning_rate: 2.5000e-04
# Epoch 92/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1445 - mape: 8.9770 - val_loss: 0.2632 - val_mape: 12.0474 - learning_rate: 2.5000e-04
# Epoch 93/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1629 - mape: 9.6283 - val_loss: 0.2628 - val_mape: 12.0565 - learning_rate: 2.5000e-04
# Epoch 94/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1604 - mape: 9.5308 - val_loss: 0.2629 - val_mape: 12.1081 - learning_rate: 2.5000e-04
# Epoch 95/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1606 - mape: 9.6762 - val_loss: 0.2622 - val_mape: 12.0831 - learning_rate: 2.5000e-04
# Epoch 96/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1611 - mape: 9.5669 - val_loss: 0.2626 - val_mape: 12.0807 - learning_rate: 2.5000e-04
# Epoch 97/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1622 - mape: 9.7681 - val_loss: 0.2609 - val_mape: 12.0047 - learning_rate: 2.5000e-04
# Epoch 98/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1684 - mape: 9.8873 - val_loss: 0.2605 - val_mape: 12.0099 - learning_rate: 2.5000e-04
# Epoch 99/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1570 - mape: 9.4844 - val_loss: 0.2595 - val_mape: 12.0012 - learning_rate: 2.5000e-04
# Epoch 100/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1564 - mape: 9.3969 - val_loss: 0.2588 - val_mape: 12.0181 - learning_rate: 2.5000e-04
# Epoch 101/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1652 - mape: 9.9335 - val_loss: 0.2584 - val_mape: 12.0005 - learning_rate: 2.5000e-04
# Epoch 102/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1541 - mape: 9.3742 - val_loss: 0.2574 - val_mape: 11.9611 - learning_rate: 2.5000e-04
# Epoch 103/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1610 - mape: 9.5281 - val_loss: 0.2574 - val_mape: 11.9559 - learning_rate: 2.5000e-04
# Epoch 104/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1622 - mape: 9.7252 - val_loss: 0.2573 - val_mape: 11.9423 - learning_rate: 2.5000e-04
# Epoch 105/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1674 - mape: 9.8682 - val_loss: 0.2561 - val_mape: 11.8911 - learning_rate: 2.5000e-04
# Epoch 106/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1601 - mape: 9.5150 - val_loss: 0.2552 - val_mape: 11.8577 - learning_rate: 2.5000e-04
# Epoch 107/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1708 - mape: 10.2300 - val_loss: 0.2552 - val_mape: 11.8558 - learning_rate: 2.5000e-04
# Epoch 108/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1654 - mape: 9.9024 - val_loss: 0.2548 - val_mape: 11.8799 - learning_rate: 2.5000e-04
# Epoch 109/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1560 - mape: 9.5148 - val_loss: 0.2550 - val_mape: 11.9283 - learning_rate: 2.5000e-04
# Epoch 110/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1658 - mape: 10.0382 - val_loss: 0.2550 - val_mape: 11.9302 - learning_rate: 2.5000e-04
# Epoch 111/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1532 - mape: 9.2597 - val_loss: 0.2551 - val_mape: 11.9345 - learning_rate: 2.5000e-04
# Epoch 112/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1496 - mape: 9.1951 - val_loss: 0.2552 - val_mape: 11.9423 - learning_rate: 2.5000e-04
# Epoch 113/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1691 - mape: 10.1128 - val_loss: 0.2551 - val_mape: 11.9349 - learning_rate: 2.5000e-04
# Epoch 114/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1570 - mape: 9.4578 - val_loss: 0.2542 - val_mape: 11.9116 - learning_rate: 1.2500e-04
# Epoch 115/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1531 - mape: 9.2868 - val_loss: 0.2535 - val_mape: 11.8969 - learning_rate: 1.2500e-04
# Epoch 116/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1594 - mape: 9.5814 - val_loss: 0.2528 - val_mape: 11.8602 - learning_rate: 1.2500e-04
# Epoch 117/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1588 - mape: 9.5581 - val_loss: 0.2520 - val_mape: 11.8416 - learning_rate: 1.2500e-04
# Epoch 118/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1597 - mape: 9.7234 - val_loss: 0.2517 - val_mape: 11.8338 - learning_rate: 1.2500e-04
# Epoch 119/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1536 - mape: 9.2703 - val_loss: 0.2512 - val_mape: 11.8146 - learning_rate: 1.2500e-04
# Epoch 120/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1642 - mape: 9.7067 - val_loss: 0.2506 - val_mape: 11.7856 - learning_rate: 1.2500e-04
# Epoch 121/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1531 - mape: 9.2183 - val_loss: 0.2500 - val_mape: 11.7782 - learning_rate: 1.2500e-04
# Epoch 122/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1519 - mape: 9.1450 - val_loss: 0.2495 - val_mape: 11.7640 - learning_rate: 1.2500e-04
# Epoch 123/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1717 - mape: 10.1179 - val_loss: 0.2494 - val_mape: 11.7756 - learning_rate: 1.2500e-04
# Epoch 124/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1526 - mape: 9.3573 - val_loss: 0.2491 - val_mape: 11.7786 - learning_rate: 1.2500e-04
# Epoch 125/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1501 - mape: 9.1117 - val_loss: 0.2493 - val_mape: 11.7659 - learning_rate: 1.2500e-04
# Epoch 126/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1571 - mape: 9.5635 - val_loss: 0.2492 - val_mape: 11.7531 - learning_rate: 1.2500e-04
# Epoch 127/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1341 - mape: 8.3521 - val_loss: 0.2497 - val_mape: 11.7625 - learning_rate: 1.2500e-04
# Epoch 128/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1623 - mape: 9.6625 - val_loss: 0.2493 - val_mape: 11.7500 - learning_rate: 1.2500e-04
# Epoch 129/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1457 - mape: 8.9698 - val_loss: 0.2493 - val_mape: 11.7451 - learning_rate: 1.2500e-04
# Epoch 130/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1711 - mape: 10.0628 - val_loss: 0.2496 - val_mape: 11.7517 - learning_rate: 6.2500e-05
# Epoch 131/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1678 - mape: 9.8475 - val_loss: 0.2493 - val_mape: 11.7363 - learning_rate: 6.2500e-05
# Epoch 132/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1579 - mape: 9.7797 - val_loss: 0.2489 - val_mape: 11.7219 - learning_rate: 6.2500e-05
# Epoch 133/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1526 - mape: 9.2707 - val_loss: 0.2487 - val_mape: 11.7116 - learning_rate: 6.2500e-05
# Epoch 134/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1652 - mape: 9.8986 - val_loss: 0.2485 - val_mape: 11.7090 - learning_rate: 6.2500e-05
# Epoch 135/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1587 - mape: 9.7710 - val_loss: 0.2488 - val_mape: 11.7206 - learning_rate: 6.2500e-05
# Epoch 136/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1453 - mape: 9.1001 - val_loss: 0.2482 - val_mape: 11.7022 - learning_rate: 6.2500e-05
# Epoch 137/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1504 - mape: 9.4006 - val_loss: 0.2474 - val_mape: 11.6768 - learning_rate: 6.2500e-05
# Epoch 138/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1493 - mape: 9.3028 - val_loss: 0.2474 - val_mape: 11.6736 - learning_rate: 6.2500e-05
# Epoch 139/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1463 - mape: 8.9645 - val_loss: 0.2475 - val_mape: 11.6644 - learning_rate: 6.2500e-05
# Epoch 140/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1481 - mape: 9.1237 - val_loss: 0.2474 - val_mape: 11.6631 - learning_rate: 6.2500e-05
# Epoch 141/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1627 - mape: 9.6771 - val_loss: 0.2473 - val_mape: 11.6524 - learning_rate: 6.2500e-05
# Epoch 142/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1548 - mape: 9.3268 - val_loss: 0.2476 - val_mape: 11.6619 - learning_rate: 6.2500e-05
# Epoch 143/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1499 - mape: 9.2174 - val_loss: 0.2474 - val_mape: 11.6530 - learning_rate: 3.1250e-05
# Epoch 144/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1545 - mape: 9.2981 - val_loss: 0.2472 - val_mape: 11.6458 - learning_rate: 3.1250e-05
# Epoch 145/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1594 - mape: 9.5780 - val_loss: 0.2477 - val_mape: 11.6661 - learning_rate: 3.1250e-05
# Epoch 146/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1445 - mape: 8.9278 - val_loss: 0.2474 - val_mape: 11.6531 - learning_rate: 3.1250e-05
# Epoch 147/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1591 - mape: 9.7202 - val_loss: 0.2472 - val_mape: 11.6413 - learning_rate: 3.1250e-05
# Epoch 148/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1600 - mape: 9.6032 - val_loss: 0.2471 - val_mape: 11.6389 - learning_rate: 3.1250e-05
# Epoch 149/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1604 - mape: 9.6971 - val_loss: 0.2467 - val_mape: 11.6271 - learning_rate: 3.1250e-05
# Epoch 150/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1571 - mape: 9.4160 - val_loss: 0.2466 - val_mape: 11.6161 - learning_rate: 3.1250e-05
# Epoch 151/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1681 - mape: 9.8704 - val_loss: 0.2468 - val_mape: 11.6191 - learning_rate: 3.1250e-05
# Epoch 152/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1435 - mape: 8.9806 - val_loss: 0.2464 - val_mape: 11.6077 - learning_rate: 3.1250e-05
# Epoch 153/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1545 - mape: 9.5404 - val_loss: 0.2461 - val_mape: 11.6053 - learning_rate: 3.1250e-05
# Epoch 154/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1507 - mape: 9.1501 - val_loss: 0.2466 - val_mape: 11.6235 - learning_rate: 3.1250e-05
# Epoch 155/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1633 - mape: 9.5834 - val_loss: 0.2464 - val_mape: 11.6111 - learning_rate: 3.1250e-05
# Epoch 156/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1524 - mape: 9.4781 - val_loss: 0.2461 - val_mape: 11.6033 - learning_rate: 3.1250e-05
# Epoch 157/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1523 - mape: 9.4789 - val_loss: 0.2461 - val_mape: 11.5971 - learning_rate: 3.1250e-05
# Epoch 158/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1675 - mape: 9.9579 - val_loss: 0.2458 - val_mape: 11.5839 - learning_rate: 3.1250e-05
# Epoch 159/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1457 - mape: 9.0380 - val_loss: 0.2456 - val_mape: 11.5747 - learning_rate: 3.1250e-05
# Epoch 160/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1501 - mape: 9.1635 - val_loss: 0.2456 - val_mape: 11.5740 - learning_rate: 3.1250e-05
# Epoch 161/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1571 - mape: 9.3569 - val_loss: 0.2459 - val_mape: 11.5900 - learning_rate: 3.1250e-05
# Epoch 162/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1537 - mape: 9.2897 - val_loss: 0.2454 - val_mape: 11.5666 - learning_rate: 3.1250e-05
# Epoch 163/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1590 - mape: 9.5490 - val_loss: 0.2455 - val_mape: 11.5767 - learning_rate: 3.1250e-05
# Epoch 164/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1573 - mape: 9.4393 - val_loss: 0.2455 - val_mape: 11.5694 - learning_rate: 3.1250e-05
# Epoch 165/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1526 - mape: 9.3338 - val_loss: 0.2454 - val_mape: 11.5672 - learning_rate: 3.1250e-05
# Epoch 166/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1590 - mape: 9.5255 - val_loss: 0.2457 - val_mape: 11.5824 - learning_rate: 3.1250e-05
# Epoch 167/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1629 - mape: 9.7422 - val_loss: 0.2456 - val_mape: 11.5848 - learning_rate: 3.1250e-05
# Epoch 168/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1508 - mape: 9.2712 - val_loss: 0.2452 - val_mape: 11.5758 - learning_rate: 1.5625e-05
# Epoch 169/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1457 - mape: 9.1154 - val_loss: 0.2453 - val_mape: 11.5750 - learning_rate: 1.5625e-05
# Epoch 170/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1527 - mape: 9.3281 - val_loss: 0.2457 - val_mape: 11.5878 - learning_rate: 1.5625e-05
# Epoch 171/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1531 - mape: 9.1882 - val_loss: 0.2458 - val_mape: 11.5905 - learning_rate: 1.5625e-05
# Epoch 172/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1494 - mape: 9.1735 - val_loss: 0.2458 - val_mape: 11.5850 - learning_rate: 1.5625e-05
# Epoch 173/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1618 - mape: 9.7259 - val_loss: 0.2465 - val_mape: 11.6092 - learning_rate: 1.5625e-05
# Epoch 174/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1523 - mape: 9.1873 - val_loss: 0.2464 - val_mape: 11.6062 - learning_rate: 7.8125e-06
# Epoch 175/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1441 - mape: 8.8859 - val_loss: 0.2464 - val_mape: 11.6014 - learning_rate: 7.8125e-06
# Epoch 176/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1485 - mape: 8.9723 - val_loss: 0.2463 - val_mape: 11.5938 - learning_rate: 7.8125e-06
# Epoch 177/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1455 - mape: 9.1109 - val_loss: 0.2463 - val_mape: 11.5962 - learning_rate: 7.8125e-06
# Epoch 178/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1619 - mape: 9.7362 - val_loss: 0.2461 - val_mape: 11.5849 - learning_rate: 7.8125e-06
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# South Island ANN Hydro  → MAE: 16550888.13 RMSE: 23248071.43 MAPE: 5.03%

# %%
# Repeat a similar plot for North Island:
plt.figure(figsize=(12,5))
plt.plot(train_weekly.index, target_train, label="Train",   color="gray")
plt.plot(test_weekly.index,  target_test,  label="Actual)",  color="black")
plt.plot(forecast.index,  forecast,  label="Forecast-SARIMA",color="cornflowerblue")
plt.plot(test_df_s_ann2.index,y_pred_s_ann2,label="Forecast-ANN",color="darkorange")
plt.legend()
plt.title("South Island: Hydro Forecast vs. Actual (Weekly) (RQ2)", fontsize=9)
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)" ,  fontsize=9)
plt.grid(True)
plt.tight_layout()
plt.legend(loc="upper right", fontsize=7)
plt.show()

# %%
results.plot_diagnostics(figsize=(15, 10))
plt.show()

# %% [markdown]
# If a zero actually means no generation (e.g., turbine was off), you might not want to interpolate—but if it’s a data artifact or gap, this is valid.

# %%
import pandas as pd
import numpy as np
from itertools import combinations
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error

# -----------------------------------------------------------------------------
# ASSUMPTIONS / PREDEFINED:
# -----------------------------------------------------------------------------
# • weekly_lagged_north : pandas.DataFrame indexed by DATE (weekly), with columns:
#       – 'Total_TP'        (target series)
#       – 'TP_lag1w'
#       – 'RH2M_lag1w'
#       – 'GWETPROF'
#       – 'PRECIP_EWMA'
#       – 'APIxGWETPROF'
#
# • We have already chosen from earlier diagnostics:
#     p, d, q   = 0, 0, 2        # nonseasonal (an MA(2))
#     P, D, Q, s = 1, 0, 0, 52   # seasonal AR(1) at lag 52
# -----------------------------------------------------------------------------

p, d, q   = 0, 0, 2
P, D, Q, s = 1, 0, 0, 52

# 1) Split 80/20
n_n     = len(weekly_lagged_south)
split_n = int(n_n * 0.8)

train_y = weekly_lagged_south['Total_TP'].iloc[:split_n].copy()
test_y  = weekly_lagged_south['Total_TP'].iloc[split_n:].copy()

# We'll slice the SAME indices for all exog columns.
train_df = weekly_lagged_south.iloc[:split_n].copy()
test_df  = weekly_lagged_south.iloc[split_n:].copy()

# 2) List of exogenous column names (from your DataFrame)
exog_cols = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF_lag1w']

# -----------------------------------------------------------------------------
# A) SINGLE exog results (you already have these, but we re‐compute for completeness)
# -----------------------------------------------------------------------------
single_results = []

for col in exog_cols:
    exog_train = train_df[[col]].copy()
    exog_test  = test_df[[col]].copy()

    # Drop the very first NA rows if this lag column has NaNs at the top
    first_valid = exog_train[col].first_valid_index()
    if first_valid is not None:
        train_y_trim    = train_y.loc[first_valid:].copy()
        exog_train_trim = exog_train.loc[first_valid:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_exog = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_exog = model_exog.fit(disp=False)

    fc   = res_exog.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred = pd.Series(fc.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    single_results.append({
        "exog_cols": (col,),
        "AIC":       res_exog.aic,
        "BIC":       res_exog.bic,
        "MAE":       mae,
        "RMSE":      rmse,
        "MAPE":      mape
    })

df_single = pd.DataFrame(single_results).sort_values("MAPE").reset_index(drop=True)

print("\n=== Single‐Exogenous Results ===")
print(df_single.to_string(index=False))


# -----------------------------------------------------------------------------
# B) PAIRWISE combinations (two exogs at a time)
# -----------------------------------------------------------------------------
pair_results = []

for combo in combinations(exog_cols, 2):
    exog_train = train_df[list(combo)].copy()
    exog_test  = test_df[list(combo)].copy()

    # Drop leading NaNs (in case any lag columns produce NaN at the top)
    # We drop all rows up to the first index where *both* columns are non‐NaN.
    valid_idx   = exog_train.dropna().index.min()
    if valid_idx is not None:
        train_y_trim    = train_y.loc[valid_idx:].copy()
        exog_train_trim = exog_train.loc[valid_idx:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_combo = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_combo = model_combo.fit(disp=False)

    fc_combo = res_combo.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred_combo = pd.Series(fc_combo.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred_combo.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    pair_results.append({
        "exog_cols": combo,
        "AIC":       res_combo.aic,
        "BIC":       res_combo.bic,
        "MAE":       mae,
        "RMSE":      rmse,
        "MAPE":      mape
    })

df_pair = pd.DataFrame(pair_results).sort_values("MAPE").reset_index(drop=True)

print("\n=== Pairwise Exogenous Results ===")
print(df_pair.to_string(index=False))


# -----------------------------------------------------------------------------
# C) OPTIONAL: TRIPLE combinations (three exogs at a time)
# -----------------------------------------------------------------------------
triple_results = []

for combo in combinations(exog_cols, 3):
    exog_train = train_df[list(combo)].copy()
    exog_test  = test_df[list(combo)].copy()

    # Drop leading NaNs if any
    valid_idx = exog_train.dropna().index.min()
    if valid_idx is not None:
        train_y_trim    = train_y.loc[valid_idx:].copy()
        exog_train_trim = exog_train.loc[valid_idx:].copy()
    else:
        train_y_trim    = train_y.copy()
        exog_train_trim = exog_train.copy()

    test_y_trim    = test_y.copy()
    exog_test_trim = exog_test.copy()

    model_triple = SARIMAX(
        train_y_trim,
        order=(p, d, q),
        seasonal_order=(P, D, Q, s),
        exog=exog_train_trim,
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    res_triple = model_triple.fit(disp=False)

    fc_triple = res_triple.get_forecast(steps=len(test_y_trim), exog=exog_test_trim)
    pred_triple = pd.Series(fc_triple.predicted_mean.values, index=test_y_trim.index)

    y_true = test_y_trim.values
    y_pred = pred_triple.values

    mae   = mean_absolute_error(y_true, y_pred)
    rmse  = np.sqrt(mean_squared_error(y_true, y_pred))
    mape  = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-10))) * 100

    triple_results.append({
        "exog_cols": combo,
        "AIC":       res_triple.aic,
        "BIC":       res_triple.bic,
        "MAE":       mae,
        "RMSE":      rmse,
        "MAPE":      mape
    })

df_triple = pd.DataFrame(triple_results).sort_values("MAPE").reset_index(drop=True)

print("\n=== Triple‐Exogenous Results ===")
print(df_triple.to_string(index=False))
# Out:
# === Single‐Exogenous Results ===
#         exog_cols          AIC          BIC          MAE         RMSE      MAPE
#       (TP_lag1w,) 13133.552603 13152.983123 1.753915e+07 2.363470e+07  5.293878
# (GWETPROF_lag1w,) 13586.373533 13605.804053 3.981730e+07 4.917208e+07 12.410425
#    (PRECIP_EWMA,) 14043.603817 14063.034337 8.067088e+07 9.980413e+07 24.568036
#   (APIxGWETPROF,) 14113.602496 14133.033016 1.007212e+08 1.276652e+08 30.865339
#
# === Pairwise Exogenous Results ===
#                      exog_cols          AIC          BIC          MAE         RMSE      MAPE
#        (TP_lag1w, PRECIP_EWMA) 13109.916311 13133.232935 1.645535e+07 2.207932e+07  4.972034
#       (TP_lag1w, APIxGWETPROF) 13113.633549 13136.950173 1.685992e+07 2.239669e+07  5.090567
#     (TP_lag1w, GWETPROF_lag1w) 13125.708400 13149.025025 1.728159e+07 2.303248e+07  5.217656
# (APIxGWETPROF, GWETPROF_lag1w) 13589.684378 13613.001002 3.995473e+07 4.947755e+07 12.460172
#  (PRECIP_EWMA, GWETPROF_lag1w) 13563.203827 13586.520451 4.369128e+07 5.679465e+07 13.630258
#    (APIxGWETPROF, PRECIP_EWMA) 14043.112805 14066.429429 7.950975e+07 9.730014e+07 24.141698
#
# === Triple‐Exogenous Results ===
#                                   exog_cols          AIC          BIC          MAE         RMSE     MAPE
#       (TP_lag1w, APIxGWETPROF, PRECIP_EWMA) 13111.919785 13139.122513 1.645385e+07 2.207901e+07 4.971577
#     (TP_lag1w, PRECIP_EWMA, GWETPROF_lag1w) 13111.758740 13138.961468 1.647338e+07 2.190186e+07 4.991126
#    (TP_lag1w, APIxGWETPROF, GWETPROF_lag1w) 13116.915846 13144.118574 1.689152e+07 2.238754e+07 5.102760
# (APIxGWETPROF, PRECIP_EWMA, GWETPROF_lag1w) 13321.285382 13348.488110 2.877990e+07 3.733934e+07 9.005862
