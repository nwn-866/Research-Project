# %% [markdown]
# # Forecasting Weekly Wind Energy Generation in New Zealand
# Model - ANN
#
# This notebook addresses:
# * RQ1: How well does a ANN model forecast weekly wind energy generation?
# * RQ2: Does incorporating weekly-aggregated climate variables into ANN improve forecasting accuracy?
#
# The analysis uses weekly sumed and weekly averaged NASA climate data, aligned with operational wind generation data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense, Dropout, BatchNormalization, LeakyReLU
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error , root_mean_squared_error , mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
all_poc_data = pd.read_csv('EDA_Wind_all_nsp.csv')

# %%
all_poc_data
# Out:
#       Fuel_Code POC_Code        DATE     Total_TP Island   Latitude  \
# 0          Wind  BPE0331  2015-03-01  472971.4800     NI -40.280614
# 1          Wind  BPE0331  2015-03-02  119485.1800     NI -40.280614
# 2          Wind  BPE0331  2015-03-03  173416.5861     NI -40.280614
# 3          Wind  BPE0331  2015-03-04  127370.3811     NI -40.280614
# 4          Wind  BPE0331  2015-03-05   59379.3772     NI -40.280614
# ...         ...      ...         ...          ...    ...        ...
# 35015      Wind  WWD1103  2025-01-27  443172.0000     NI -41.295618
# 35016      Wind  WWD1103  2025-01-28  338884.0000     NI -41.295618
# 35017      Wind  WWD1103  2025-01-29  983736.0000     NI -41.295618
# 35018      Wind  WWD1103  2025-01-30  114433.0000     NI -41.295618
# 35019      Wind  WWD1103  2025-01-31  544447.0000     NI -41.295618
#
#         Longitude      PS    T2M  WD50M  WD50M_rad         u         v  WS50M
# 0      175.640510   99.50  18.88  302.2   5.274385  0.532876 -0.846193   5.89
# 1      175.640510   99.39  18.43  304.9   5.321509  0.572146 -0.820152   6.52
# 2      175.640510   99.24  18.92  302.8   5.284857  0.541708 -0.840567   5.08
# 3      175.640510   98.90  18.34  315.5   5.506514  0.713250 -0.700909   4.19
# 4      175.640510   98.46  19.62  328.2   5.728171  0.849893 -0.526956   3.64
# ...           ...     ...    ...    ...        ...       ...       ...    ...
# 35015  174.660496  100.13  15.20  185.2   3.232350 -0.995884 -0.090633   6.37
# 35016  174.660496  101.12  16.11  342.9   5.984734  0.955793 -0.294040   5.59
# 35017  174.660496  100.28  17.92  320.9   5.600762  0.776046 -0.630676  10.59
# 35018  174.660496  100.73  16.00  134.7   2.350959 -0.703395  0.710799   3.85
# 35019  174.660496  100.91  17.22  338.2   5.902704  0.928486 -0.371368   5.09
#
# [35020 rows x 14 columns]

# %%
all_poc_data['DATE'] = pd.to_datetime(all_poc_data['DATE'])

# %%
all_poc_data['Fuel_Code'] = all_poc_data['Fuel_Code'].astype(str)

# %%
all_poc_data['Island'] = all_poc_data['Island'].astype(str)

# %%
print(all_poc_data.dtypes)
# Out:
# Fuel_Code            object
# POC_Code             object
# DATE         datetime64[ns]
# Total_TP            float64
# Island               object
# Latitude            float64
# Longitude           float64
# PS                  float64
# T2M                 float64
# WD50M               float64
# WD50M_rad           float64
# u                   float64
# v                   float64
# WS50M               float64
# dtype: object

# %%
# Check for missing values in each column
missing_values = all_poc_data.isnull().sum()
print(missing_values)

# Optionally, check if there are any missing values at all
if all_poc_data.isnull().values.any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values found in the DataFrame.")
# Out:
# Fuel_Code    0
# POC_Code     0
# DATE         0
# Total_TP     0
# Island       0
# Latitude     0
# Longitude    0
# PS           0
# T2M          0
# WD50M        0
# WD50M_rad    0
# u            0
# v            0
# WS50M        0
# dtype: int64
# No missing values found in the DataFrame.

# %%
# List all column names as an Index object
print(all_poc_data.columns)
# Out:
# Index(['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude',
#        'Longitude', 'PS', 'T2M', 'WD50M', 'WD50M_rad', 'u', 'v', 'WS50M'],
#       dtype='object')

# %%
selected_col_for_wind = ['DATE','Island', 'Total_TP','PS', 'T2M', 'WD50M', 'WD50M_rad', 'u', 'v', 'WS50M']  # Replace with your desired column names

# %%
df_wind_daily_all_nsp = all_poc_data[selected_col_for_wind].copy()

# %%
print(df_wind_daily_all_nsp.dtypes)
# Out:
# DATE         datetime64[ns]
# Island               object
# Total_TP            float64
# PS                  float64
# T2M                 float64
# WD50M               float64
# WD50M_rad           float64
# u                   float64
# v                   float64
# WS50M               float64
# dtype: object

# %%
df_wind_daily_all_nsp.head()
# Out:
#         DATE Island     Total_TP     PS    T2M  WD50M  WD50M_rad         u  \
# 0 2015-03-01     NI  472971.4800  99.50  18.88  302.2   5.274385  0.532876
# 1 2015-03-02     NI  119485.1800  99.39  18.43  304.9   5.321509  0.572146
# 2 2015-03-03     NI  173416.5861  99.24  18.92  302.8   5.284857  0.541708
# 3 2015-03-04     NI  127370.3811  98.90  18.34  315.5   5.506514  0.713250
# 4 2015-03-05     NI   59379.3772  98.46  19.62  328.2   5.728171  0.849893
#
#           v  WS50M
# 0 -0.846193   5.89
# 1 -0.820152   6.52
# 2 -0.840567   5.08
# 3 -0.700909   4.19
# 4 -0.526956   3.64

# %%
df_wind_daily_all_nsp.set_index('DATE', inplace=True)

# %%
df_wind_daily_all_nsp.head()
# Out:
#            Island     Total_TP     PS    T2M  WD50M  WD50M_rad         u  \
# DATE
# 2015-03-01     NI  472971.4800  99.50  18.88  302.2   5.274385  0.532876
# 2015-03-02     NI  119485.1800  99.39  18.43  304.9   5.321509  0.572146
# 2015-03-03     NI  173416.5861  99.24  18.92  302.8   5.284857  0.541708
# 2015-03-04     NI  127370.3811  98.90  18.34  315.5   5.506514  0.713250
# 2015-03-05     NI   59379.3772  98.46  19.62  328.2   5.728171  0.849893
#
#                    v  WS50M
# DATE
# 2015-03-01 -0.846193   5.89
# 2015-03-02 -0.820152   6.52
# 2015-03-03 -0.840567   5.08
# 2015-03-04 -0.700909   4.19
# 2015-03-05 -0.526956   3.64

# %%
record_counts = df_wind_daily_all_nsp.groupby('Island').size()
print(record_counts)
# Out:
# Island
# NI    30876
# SI     4144
# dtype: int64

# %%
# list the column names
print(df_wind_daily_all_nsp.columns.tolist())
# Out:
# ['Island', 'Total_TP', 'PS', 'T2M', 'WD50M', 'WD50M_rad', 'u', 'v', 'WS50M']

# %%
df_wind_daily_all_nsp
# Out:
#            Island     Total_TP      PS    T2M  WD50M  WD50M_rad         u  \
# DATE
# 2015-03-01     NI  472971.4800   99.50  18.88  302.2   5.274385  0.532876
# 2015-03-02     NI  119485.1800   99.39  18.43  304.9   5.321509  0.572146
# 2015-03-03     NI  173416.5861   99.24  18.92  302.8   5.284857  0.541708
# 2015-03-04     NI  127370.3811   98.90  18.34  315.5   5.506514  0.713250
# 2015-03-05     NI   59379.3772   98.46  19.62  328.2   5.728171  0.849893
# ...           ...          ...     ...    ...    ...        ...       ...
# 2025-01-27     NI  443172.0000  100.13  15.20  185.2   3.232350 -0.995884
# 2025-01-28     NI  338884.0000  101.12  16.11  342.9   5.984734  0.955793
# 2025-01-29     NI  983736.0000  100.28  17.92  320.9   5.600762  0.776046
# 2025-01-30     NI  114433.0000  100.73  16.00  134.7   2.350959 -0.703395
# 2025-01-31     NI  544447.0000  100.91  17.22  338.2   5.902704  0.928486
#
#                    v  WS50M
# DATE
# 2015-03-01 -0.846193   5.89
# 2015-03-02 -0.820152   6.52
# 2015-03-03 -0.840567   5.08
# 2015-03-04 -0.700909   4.19
# 2015-03-05 -0.526956   3.64
# ...              ...    ...
# 2025-01-27 -0.090633   6.37
# 2025-01-28 -0.294040   5.59
# 2025-01-29 -0.630676  10.59
# 2025-01-30  0.710799   3.85
# 2025-01-31 -0.371368   5.09
#
# [35020 rows x 9 columns]

# %%
# 1. Define custom agg: sum for some columns, mean for the rest
agg_dict = {
    'Total_TP':    'sum',
    'PS':          'mean',
    'T2M':         'mean',
    'WS50M':       'mean'
   }

# %%
# Perform weekly aggregation grouped by Island
df_wind_weekly = df_wind_daily_all_nsp.groupby([pd.Grouper(freq='W'), 'Island']).agg(agg_dict)

# %%
df_wind_weekly.head()
# Out:
#                        Total_TP          PS        T2M     WS50M
# DATE       Island
# 2015-03-01 NI      5.260841e+06  100.112857  19.091429  5.437143
#            SI      6.983304e+05  100.890000  16.700000  6.830000
# 2015-03-08 NI      2.970966e+07   99.060204  18.372449  7.480408
#            SI      2.978269e+06   99.881429  13.911429  6.545714
# 2015-03-15 NI      1.724348e+07   99.761224  17.476327  4.644694

# %%
#North Island specific data
df_wind_weekly_north = df_wind_weekly.xs('NI', level='Island')

# %%
print(df_wind_weekly_north.shape)
# Out:
# (519, 4)

# %%
#South Island specific data
df_wind_weekly_south = df_wind_weekly.xs('SI', level='Island')

# %%
print(df_wind_weekly_south.shape)
# Out:
# (519, 4)

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_wind_weekly[df_wind_weekly['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of weekly records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, PS, T2M, WS50M]
# Index: []

# %%
df_wind_weekly_north_before = df_wind_weekly_north.copy()

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_wind_weekly_north = df_wind_weekly_north.drop(index=pd.to_datetime('2015-03-01'))
df_wind_weekly_north = df_wind_weekly_north.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_wind_weekly_north.shape)
# Out:
# (517, 4)

# %%
df_wind_weekly_south_before = df_wind_weekly_south.copy()

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_wind_weekly_south = df_wind_weekly_south.drop(index=pd.to_datetime('2015-03-01'))
df_wind_weekly_south = df_wind_weekly_south.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_wind_weekly_south.shape)
# Out:
# (517, 4)

# %% [markdown]
# ## North Island Daily

# %%
# Add 1 to 2-week lagged climate features
df_wind_weekly_north['TP_lag1w'] = df_wind_weekly_north['Total_TP'].shift(1)
df_wind_weekly_north['T2M_lag1w'] = df_wind_weekly_north['T2M'].shift(1)
df_wind_weekly_north['PS_lag1w'] = df_wind_weekly_north['PS'].shift(1)
df_wind_weekly_north['WS50M_lag1w'] = df_wind_weekly_north['WS50M'].shift(1)
df_wind_weekly_north['WS50M_lag2w'] = df_wind_weekly_north['WS50M'].shift(2)
df_wind_weekly_north['WS50M_EWMA'] = df_wind_weekly_north['WS50M'].ewm(alpha=0.3, adjust=False).mean()
#df_hydro_weekly_north['APIxGWETPROF'] = df_hydro_weekly_north['PRECIP_EWMA'] * df_hydro_weekly_north['GWETPROF']

# %%
print(df_wind_weekly_north.columns.tolist())
# Out:
# ['Total_TP', 'PS', 'T2M', 'WS50M', 'TP_lag1w', 'T2M_lag1w', 'PS_lag1w', 'WS50M_lag1w', 'WS50M_lag2w', 'WS50M_EWMA']

# %%
# Retain only lagged + target, drop NA
df_wind_weekly_lagged_north = df_wind_weekly_north[['Total_TP', 'PS', 'T2M', 'WS50M', 'TP_lag1w', 'T2M_lag1w', 'PS_lag1w', 'WS50M_lag1w', 'WS50M_lag2w', 'WS50M_EWMA']].dropna()
df_wind_weekly_lagged_north.head()
# Out:
#                 Total_TP          PS        T2M     WS50M      TP_lag1w  \
# DATE
# 2015-03-22  2.317096e+07   99.580612  13.854694  7.118980  1.724348e+07
# 2015-03-29  2.053256e+07   99.906531  16.650408  5.629796  2.317096e+07
# 2015-04-05  3.000496e+07  100.376327  16.031224  6.114286  2.053256e+07
# 2015-04-12  3.550845e+07   99.678367  16.105510  8.142449  3.000496e+07
# 2015-04-19  2.991374e+07   99.568980  11.181837  7.519388  3.550845e+07
#
#             T2M_lag1w    PS_lag1w  WS50M_lag1w  WS50M_lag2w  WS50M_EWMA
# DATE
# 2015-03-22  17.476327   99.761224     4.644694     7.480408    6.776480
# 2015-03-29  13.854694   99.580612     7.118980     4.644694    6.432474
# 2015-04-05  16.650408   99.906531     5.629796     7.118980    6.337018
# 2015-04-12  16.031224  100.376327     6.114286     5.629796    6.878647
# 2015-04-19  16.105510   99.678367     8.142449     6.114286    7.070869

# %% [raw]
# ##########   Feature Engineering    ##########

# %%
#   Set seeds for reproducibility  
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
df_wind_weekly_lagged_north.head()
# Out:
#                 Total_TP          PS        T2M     WS50M      TP_lag1w  \
# DATE
# 2015-03-22  2.317096e+07   99.580612  13.854694  7.118980  1.724348e+07
# 2015-03-29  2.053256e+07   99.906531  16.650408  5.629796  2.317096e+07
# 2015-04-05  3.000496e+07  100.376327  16.031224  6.114286  2.053256e+07
# 2015-04-12  3.550845e+07   99.678367  16.105510  8.142449  3.000496e+07
# 2015-04-19  2.991374e+07   99.568980  11.181837  7.519388  3.550845e+07
#
#             T2M_lag1w    PS_lag1w  WS50M_lag1w  WS50M_lag2w  WS50M_EWMA
# DATE
# 2015-03-22  17.476327   99.761224     4.644694     7.480408    6.776480
# 2015-03-29  13.854694   99.580612     7.118980     4.644694    6.432474
# 2015-04-05  16.650408   99.906531     5.629796     7.118980    6.337018
# 2015-04-12  16.031224  100.376327     6.114286     5.629796    6.878647
# 2015-04-19  16.105510   99.678367     8.142449     6.114286    7.070869

# %%
# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_wind_north_wk = df_wind_weekly_lagged_north[['Total_TP','TP_lag1w']]

# %%
df_ann_wind_north_wk.head()
# Out:
#                 Total_TP      TP_lag1w
# DATE
# 2015-03-22  2.317096e+07  1.724348e+07
# 2015-03-29  2.053256e+07  2.317096e+07
# 2015-04-05  3.000496e+07  2.053256e+07
# 2015-04-12  3.550845e+07  3.000496e+07
# 2015-04-19  2.991374e+07  3.550845e+07

# %%
n_wind_ann     = len(df_ann_wind_north_wk)
split_ann = int(n_wind_ann * 0.8)

train_n_ann = df_ann_wind_north_wk.iloc[:split_ann]
test_n_ann  = df_ann_wind_north_wk.iloc[split_ann:]

X_train = train_n_ann[['TP_lag1w']].values
y_train = train_n_ann['Total_TP'].values.reshape(-1,1)
X_test  = test_n_ann[['TP_lag1w']].values
y_test  = test_n_ann['Total_TP'].values.reshape(-1,1)

# %%
# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s = scaler_X.fit_transform(X_train)
X_test_s  = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_s = scaler_y.fit_transform(y_train)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# %%
# 4) Build the ANN
model_ann = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) Train the ANN (the shuffle order is now deterministic)
history = model_ann.fit(
    X_train_s, y_train_s,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# %%
# 6) Predict & rescale
y_pred_s = model_ann.predict(X_test_s)
y_pred   = scaler_y.inverse_transform(y_pred_s).flatten()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test.flatten(), y_pred)
rmse_ann = np.sqrt(mean_squared_error(y_test.flatten(), y_pred))
mape_ann = np.mean(np.abs((y_test.flatten() - y_pred) / y_test.flatten())) * 100

print(f"Univariate ANN - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")
# Out:
# Univariate ANN - MAE: 19554300.14, RMSE: 23627402.89, MAPE: 30.94%

# %%
plt.figure(figsize=(15,7))
plt.plot(train_n_ann.index,y_train.flatten(),label="Train Actual (2015 -> split)",color="lightgray")
plt.plot(test_n_ann.index, y_test, label="Actual Total_TP",   color="black")
plt.plot(test_n_ann.index, y_pred, label="ANN Forecast",      color="darkorange")
plt.title("RQ1‐ANN: South Island Weekly Hydro (Actual vs. Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_wind_weekly_lagged_north.head()
# Out:
#                 Total_TP          PS        T2M     WS50M      TP_lag1w  \
# DATE
# 2015-03-22  2.317096e+07   99.580612  13.854694  7.118980  1.724348e+07
# 2015-03-29  2.053256e+07   99.906531  16.650408  5.629796  2.317096e+07
# 2015-04-05  3.000496e+07  100.376327  16.031224  6.114286  2.053256e+07
# 2015-04-12  3.550845e+07   99.678367  16.105510  8.142449  3.000496e+07
# 2015-04-19  2.991374e+07   99.568980  11.181837  7.519388  3.550845e+07
#
#             T2M_lag1w    PS_lag1w  WS50M_lag1w  WS50M_lag2w  WS50M_EWMA
# DATE
# 2015-03-22  17.476327   99.761224     4.644694     7.480408    6.776480
# 2015-03-29  13.854694   99.580612     7.118980     4.644694    6.432474
# 2015-04-05  16.650408   99.906531     5.629796     7.118980    6.337018
# 2015-04-12  16.031224  100.376327     6.114286     5.629796    6.878647
# 2015-04-19  16.105510   99.678367     8.142449     6.114286    7.070869

# %%
print(df_wind_weekly_lagged_north.columns.tolist())
# Out:
# ['Total_TP', 'PS', 'T2M', 'WS50M', 'TP_lag1w', 'T2M_lag1w', 'PS_lag1w', 'WS50M_lag1w', 'WS50M_lag2w', 'WS50M_EWMA']

# %%
#exog_cols = ['WS50M', 'TP_lag1w']

# %%
factors = ['WS50M', 'TP_lag1w']

# %%
# 2) Split via slicing
n = len(df_wind_weekly_lagged_north)
split_idx = int(n * 0.8)

train_df = df_wind_weekly_lagged_north.iloc[:split_idx]
test_df  = df_wind_weekly_lagged_north.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw = train_df[factors].values
X_test_raw  = test_df[factors].values
y_train_raw = train_df['Total_TP'].values.reshape(-1, 1)
y_test_raw  = test_df['Total_TP'].values.reshape(-1, 1)

# %%
# 4) Scale
x_scaler = StandardScaler().fit(X_train_raw)
y_scaler = StandardScaler().fit(y_train_raw)

X_train = x_scaler.transform(X_train_raw)
X_test  = x_scaler.transform(X_test_raw)
y_train = y_scaler.transform(y_train_raw)
y_test  = y_scaler.transform(y_test_raw)

# %%
# 5) Sanity‐check shapes
print(X_train.shape, y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (412, 2) (412, 1)
# (103, 2) (103, 1)

# %%
# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

# %%
# #model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(16),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# %%
# ── 5) Train (use 10% of train_df as internal validation, keep test_df fully unseen) ──
history = model.fit(
    X_train, y_train,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.3520 - mape: 234.9507 - val_loss: 0.5821 - val_mape: 99.6390 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2628 - mape: 184.6924 - val_loss: 0.5531 - val_mape: 106.6114 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2208 - mape: 248.4794 - val_loss: 0.5418 - val_mape: 108.0844 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2187 - mape: 205.4134 - val_loss: 0.5329 - val_mape: 108.2972 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1907 - mape: 150.8809 - val_loss: 0.5235 - val_mape: 108.5037 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1789 - mape: 175.8625 - val_loss: 0.5138 - val_mape: 108.7432 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1645 - mape: 142.6505 - val_loss: 0.5077 - val_mape: 110.6594 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1629 - mape: 177.8728 - val_loss: 0.5042 - val_mape: 113.0059 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1610 - mape: 182.9709 - val_loss: 0.4987 - val_mape: 114.6375 - learning_rate: 5.0000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1757 - mape: 175.2348 - val_loss: 0.4911 - val_mape: 116.1746 - learning_rate: 5.0000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1509 - mape: 150.6328 - val_loss: 0.4851 - val_mape: 118.7259 - learning_rate: 5.0000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1515 - mape: 138.2041 - val_loss: 0.4820 - val_mape: 121.0211 - learning_rate: 5.0000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1542 - mape: 184.2037 - val_loss: 0.4749 - val_mape: 122.3694 - learning_rate: 5.0000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1599 - mape: 164.0439 - val_loss: 0.4676 - val_mape: 126.0056 - learning_rate: 5.0000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1381 - mape: 149.9380 - val_loss: 0.4572 - val_mape: 127.8210 - learning_rate: 5.0000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1602 - mape: 180.4246 - val_loss: 0.4479 - val_mape: 130.5783 - learning_rate: 5.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1588 - mape: 175.8248 - val_loss: 0.4375 - val_mape: 130.9338 - learning_rate: 5.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1414 - mape: 149.0482 - val_loss: 0.4300 - val_mape: 130.4827 - learning_rate: 5.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1385 - mape: 150.2071 - val_loss: 0.4211 - val_mape: 131.2829 - learning_rate: 5.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1290 - mape: 145.3837 - val_loss: 0.4112 - val_mape: 131.1828 - learning_rate: 5.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1323 - mape: 138.8275 - val_loss: 0.4018 - val_mape: 132.5537 - learning_rate: 5.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1454 - mape: 170.9875 - val_loss: 0.3979 - val_mape: 132.5763 - learning_rate: 5.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1387 - mape: 154.3096 - val_loss: 0.3904 - val_mape: 133.0260 - learning_rate: 5.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1346 - mape: 158.0438 - val_loss: 0.3873 - val_mape: 133.5006 - learning_rate: 5.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1443 - mape: 155.2026 - val_loss: 0.3780 - val_mape: 135.4583 - learning_rate: 5.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1402 - mape: 156.6135 - val_loss: 0.3722 - val_mape: 138.5482 - learning_rate: 5.0000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1251 - mape: 149.5359 - val_loss: 0.3641 - val_mape: 140.8923 - learning_rate: 5.0000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1362 - mape: 149.6771 - val_loss: 0.3556 - val_mape: 142.0785 - learning_rate: 5.0000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1286 - mape: 159.1574 - val_loss: 0.3519 - val_mape: 143.2523 - learning_rate: 5.0000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1387 - mape: 154.7855 - val_loss: 0.3463 - val_mape: 147.7156 - learning_rate: 5.0000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1475 - mape: 182.3474 - val_loss: 0.3425 - val_mape: 150.8282 - learning_rate: 5.0000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1325 - mape: 150.8470 - val_loss: 0.3430 - val_mape: 149.5158 - learning_rate: 5.0000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1397 - mape: 174.3277 - val_loss: 0.3386 - val_mape: 149.0713 - learning_rate: 5.0000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1300 - mape: 132.2504 - val_loss: 0.3394 - val_mape: 148.8438 - learning_rate: 5.0000e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1382 - mape: 148.5809 - val_loss: 0.3411 - val_mape: 148.6821 - learning_rate: 5.0000e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1278 - mape: 141.0730 - val_loss: 0.3375 - val_mape: 149.0325 - learning_rate: 5.0000e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1293 - mape: 151.3003 - val_loss: 0.3331 - val_mape: 149.9975 - learning_rate: 5.0000e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1345 - mape: 145.7549 - val_loss: 0.3332 - val_mape: 150.7453 - learning_rate: 5.0000e-04
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1298 - mape: 127.7191 - val_loss: 0.3323 - val_mape: 150.8014 - learning_rate: 5.0000e-04
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1302 - mape: 125.4058 - val_loss: 0.3291 - val_mape: 150.5706 - learning_rate: 5.0000e-04
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1264 - mape: 134.4401 - val_loss: 0.3284 - val_mape: 152.9729 - learning_rate: 5.0000e-04
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1288 - mape: 142.9849 - val_loss: 0.3255 - val_mape: 155.4389 - learning_rate: 5.0000e-04
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1321 - mape: 142.2287 - val_loss: 0.3234 - val_mape: 155.7990 - learning_rate: 5.0000e-04
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1268 - mape: 139.2089 - val_loss: 0.3272 - val_mape: 156.4411 - learning_rate: 5.0000e-04
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1333 - mape: 160.6996 - val_loss: 0.3227 - val_mape: 158.4190 - learning_rate: 5.0000e-04
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1351 - mape: 145.2524 - val_loss: 0.3227 - val_mape: 157.2867 - learning_rate: 5.0000e-04
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1323 - mape: 157.0691 - val_loss: 0.3219 - val_mape: 158.3994 - learning_rate: 5.0000e-04
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1265 - mape: 142.9694 - val_loss: 0.3198 - val_mape: 155.2458 - learning_rate: 5.0000e-04
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1213 - mape: 120.5781 - val_loss: 0.3199 - val_mape: 152.5534 - learning_rate: 5.0000e-04
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1261 - mape: 136.7133 - val_loss: 0.3176 - val_mape: 153.8045 - learning_rate: 5.0000e-04
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1300 - mape: 169.2193 - val_loss: 0.3154 - val_mape: 156.4901 - learning_rate: 5.0000e-04
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1373 - mape: 176.5786 - val_loss: 0.3154 - val_mape: 158.6430 - learning_rate: 5.0000e-04
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1300 - mape: 155.1488 - val_loss: 0.3186 - val_mape: 159.1835 - learning_rate: 5.0000e-04
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1319 - mape: 141.3353 - val_loss: 0.3153 - val_mape: 158.9252 - learning_rate: 5.0000e-04
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1207 - mape: 139.0997 - val_loss: 0.3153 - val_mape: 157.8079 - learning_rate: 5.0000e-04
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1284 - mape: 164.7328 - val_loss: 0.3174 - val_mape: 157.0808 - learning_rate: 5.0000e-04
# Epoch 57/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1305 - mape: 151.9504 - val_loss: 0.3219 - val_mape: 157.7767 - learning_rate: 5.0000e-04
# Epoch 58/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1253 - mape: 132.2253 - val_loss: 0.3281 - val_mape: 158.5837 - learning_rate: 5.0000e-04
# Epoch 59/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1205 - mape: 144.6046 - val_loss: 0.3237 - val_mape: 159.4653 - learning_rate: 5.0000e-04
# Epoch 60/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1248 - mape: 132.7373 - val_loss: 0.3224 - val_mape: 158.6122 - learning_rate: 2.5000e-04
# Epoch 61/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1290 - mape: 142.5808 - val_loss: 0.3192 - val_mape: 158.2086 - learning_rate: 2.5000e-04
# Epoch 62/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1271 - mape: 135.1929 - val_loss: 0.3191 - val_mape: 157.8279 - learning_rate: 2.5000e-04
# Epoch 63/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1331 - mape: 156.5224 - val_loss: 0.3218 - val_mape: 156.0512 - learning_rate: 2.5000e-04
# Epoch 64/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1255 - mape: 151.9397 - val_loss: 0.3217 - val_mape: 155.1879 - learning_rate: 2.5000e-04

# %%
# 1) Predict & inverse‑scale
y_pred_s = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_s).ravel()
y_true = y_scaler.inverse_transform(y_test).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
# 2) Metrics
mae  = mean_absolute_error(y_true, y_pred)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred) * 100
print("\nRQ2‐ANN Performance - Hydro (South Island):")
print(f"MAE : {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# RQ2‐ANN Performance - Hydro (South Island):
# MAE : 18,500,602.50
# RMSE: 21,659,789.96
# MAPE: 29.20%

# %%
# factors = ['WS50M', 'TP_lag1w']
# RQ2‐ANN Performance - Hydro (South Island):
# MAE : 18,033,781.28
# RMSE: 21,014,915.23
# MAPE: 28.48%

# %%
# 11) Plot Train, Test Actuals, and RQ2‐ANN Forecast
plt.figure(figsize=(15, 7))
# 11a) Training‐period actuals (2015 to split)
plt.plot(train_df.index, y_train_raw.flatten(),label="Train Actual (2015 -> split)",  color="lightgray")
# 11b) Test‐period actuals
plt.plot(test_df.index,y_test_raw.flatten(),label="Test Actual",color="black")
# 11c) RQ2‐ANN forecast over test period
plt.plot(test_df.index,y_pred,label="Forecast",color="darkorange")
plt.title("RQ2‐ANN: South Island Weekly Wind Generation (Train & Test Actual vs Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## End Noth Island

# %% [markdown]
# # South Island

# %%
df_wind_weekly_south.head()
# Out:
#                 Total_TP          PS        T2M     WS50M
# DATE
# 2015-03-08  2.978269e+06   99.881429  13.911429  6.545714
# 2015-03-15  2.755933e+06  101.075714  13.817143  4.945714
# 2015-03-22  2.169076e+06  101.260000  11.324286  5.302857
# 2015-03-29  1.893987e+06  100.988571  13.421429  3.867143
# 2015-04-05  4.960861e+06  101.465714  13.738571  7.328571

# %%
# Add 1 to 2-week lagged climate features
df_wind_weekly_south['TP_lag1w'] = df_wind_weekly_south['Total_TP'].shift(1)
df_wind_weekly_south['T2M_lag1w'] = df_wind_weekly_south['T2M'].shift(1)
df_wind_weekly_south['PS_lag1w'] = df_wind_weekly_south['PS'].shift(1)
df_wind_weekly_south['WS50M_lag1w'] = df_wind_weekly_south['WS50M'].shift(1)
df_wind_weekly_south['WS50M_lag2w'] = df_wind_weekly_south['WS50M'].shift(2)
df_wind_weekly_south['WS50M_EWMA'] = df_wind_weekly_south['WS50M'].ewm(alpha=0.3, adjust=False).mean()
#df_hydro_weekly_north['APIxGWETPROF'] = df_hydro_weekly_north['PRECIP_EWMA'] * df_hydro_weekly_north['GWETPROF']

# %%
# Retain only lagged + target, drop NA
df_wind_weekly_lagged_south = df_wind_weekly_south[['Total_TP', 'PS', 'T2M', 'WS50M', 'TP_lag1w', 'T2M_lag1w', 'PS_lag1w', 'WS50M_lag1w', 'WS50M_lag2w', 'WS50M_EWMA']].dropna()
df_wind_weekly_lagged_south.head()
# Out:
#                 Total_TP          PS        T2M     WS50M      TP_lag1w  \
# DATE
# 2015-03-22  2.169076e+06  101.260000  11.324286  5.302857  2.755933e+06
# 2015-03-29  1.893987e+06  100.988571  13.421429  3.867143  2.169076e+06
# 2015-04-05  4.960861e+06  101.465714  13.738571  7.328571  1.893987e+06
# 2015-04-12  2.796316e+06  100.537143  11.622857  7.647143  4.960861e+06
# 2015-04-19  2.640676e+06  101.004286   9.812857  7.208571  2.796316e+06
#
#             T2M_lag1w    PS_lag1w  WS50M_lag1w  WS50M_lag2w  WS50M_EWMA
# DATE
# 2015-03-22  13.817143  101.075714     4.945714     6.545714    5.836857
# 2015-03-29  11.324286  101.260000     5.302857     4.945714    5.245943
# 2015-04-05  13.421429  100.988571     3.867143     5.302857    5.870731
# 2015-04-12  13.738571  101.465714     7.328571     3.867143    6.403655
# 2015-04-19  11.622857  100.537143     7.647143     7.328571    6.645130

# %%
# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_wind_south_wk = df_wind_weekly_lagged_south[['Total_TP','TP_lag1w']]

# %%
s_hydro_ann     = len(df_ann_wind_south_wk)
split_ann = int(s_hydro_ann * 0.8)

train_s_ann = df_ann_wind_south_wk.iloc[:split_ann]
test_s_ann  = df_ann_wind_south_wk.iloc[split_ann:]

X_train = train_s_ann[['TP_lag1w']].values
y_train = train_s_ann['Total_TP'].values.reshape(-1,1)
X_test  = test_s_ann[['TP_lag1w']].values
y_test  = test_s_ann['Total_TP'].values.reshape(-1,1)

# %%
# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s = scaler_X.fit_transform(X_train)
X_test_s  = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_s = scaler_y.fit_transform(y_train)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# %%
# 4) Build the ANN
model_ann_s = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann_s.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) Train the ANN (the shuffle order is now deterministic)
history_s = model_ann_s.fit(
    X_train_s, y_train_s,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# %%
# 6) Predict & rescale
y_pred_s = model_ann_s.predict(X_test_s)
y_pred   = scaler_y.inverse_transform(y_pred_s).flatten()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A65D6CD300> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A65D6CD300> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test.flatten(), y_pred)
rmse_ann = np.sqrt(mean_squared_error(y_test.flatten(), y_pred))
mape_ann = np.mean(np.abs((y_test.flatten() - y_pred) / y_test.flatten())) * 100

print(f"Univariate ANN : South Island - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")
# Out:
# Univariate ANN : South Island - MAE: 1776606.86, RMSE: 2316326.45, MAPE: 46.03%

# %%
plt.figure(figsize=(15,7))
plt.plot(train_s_ann.index,y_train.flatten(),label="Train Actual (2015 -> split)",color="lightgray")
plt.plot(test_s_ann.index, y_test, label="Actual Total_TP",   color="black")
plt.plot(test_s_ann.index, y_pred, label="ANN Forecast",      color="darkorange")
plt.title("RQ1‐ANN: South Island Weekly Wind (Actual vs. Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RQ2 Start

# %%
factors = ['WS50M', 'TP_lag1w','PS_lag1w']

# %%
df_wind_weekly_lagged_south.head()
# Out:
#                 Total_TP          PS        T2M     WS50M      TP_lag1w  \
# DATE
# 2015-03-22  2.169076e+06  101.260000  11.324286  5.302857  2.755933e+06
# 2015-03-29  1.893987e+06  100.988571  13.421429  3.867143  2.169076e+06
# 2015-04-05  4.960861e+06  101.465714  13.738571  7.328571  1.893987e+06
# 2015-04-12  2.796316e+06  100.537143  11.622857  7.647143  4.960861e+06
# 2015-04-19  2.640676e+06  101.004286   9.812857  7.208571  2.796316e+06
#
#             T2M_lag1w    PS_lag1w  WS50M_lag1w  WS50M_lag2w  WS50M_EWMA
# DATE
# 2015-03-22  13.817143  101.075714     4.945714     6.545714    5.836857
# 2015-03-29  11.324286  101.260000     5.302857     4.945714    5.245943
# 2015-04-05  13.421429  100.988571     3.867143     5.302857    5.870731
# 2015-04-12  13.738571  101.465714     7.328571     3.867143    6.403655
# 2015-04-19  11.622857  100.537143     7.647143     7.328571    6.645130

# %%
print(df_wind_weekly_lagged_south.columns.tolist())
# Out:
# ['Total_TP', 'PS', 'T2M', 'WS50M', 'TP_lag1w', 'T2M_lag1w', 'PS_lag1w', 'WS50M_lag1w', 'WS50M_lag2w', 'WS50M_EWMA']

# %%
# df_wind_weekly_lagged_south['PS_lag1wx_WS50M'] = df_wind_weekly_lagged_south['PS_lag1w'] * df_wind_weekly_lagged_south['WS50M']

# %%
# 2) Split via slicing
n = len(df_wind_weekly_lagged_south)
split_idx = int(n * 0.8)

train_df = df_wind_weekly_lagged_south.iloc[:split_idx]
test_df  = df_wind_weekly_lagged_south.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw = train_df[factors].values  # (n_samples, n_features)
X_test_raw  = test_df[factors].values
y_train_raw = train_df['Total_TP'].values.reshape(-1, 1)
y_test_raw  = test_df['Total_TP'].values.reshape(-1, 1) # (n_samples, 1)

# %%
# 4) Scale
x_scaler = StandardScaler().fit(X_train_raw)
y_scaler = StandardScaler().fit(y_train_raw)

X_train = x_scaler.transform(X_train_raw)
X_test  = x_scaler.transform(X_test_raw)
y_train = y_scaler.transform(y_train_raw)
y_test  = y_scaler.transform(y_test_raw)

# %%
# 5) Sanity‐check shapes
print(X_train.shape, y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (412, 3) (412, 1)
# (103, 3) (103, 1)

# %%
# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

# %%
#   ANN Model  
model = Sequential([
    Dense(128, input_shape=(X_train.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(64),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])

#model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3178 - mape: 3792.5630 - val_loss: 0.2750 - val_mape: 89.4085 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2609 - mape: 3625.3076 - val_loss: 0.2684 - val_mape: 85.7977 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2652 - mape: 2800.0317 - val_loss: 0.2725 - val_mape: 88.9759 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2545 - mape: 4454.6948 - val_loss: 0.2767 - val_mape: 92.1692 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2068 - mape: 7233.7563 - val_loss: 0.2728 - val_mape: 92.7943 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2005 - mape: 3182.4634 - val_loss: 0.2685 - val_mape: 95.8003 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2219 - mape: 3912.8755 - val_loss: 0.2622 - val_mape: 97.1570 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1901 - mape: 4061.1877 - val_loss: 0.2553 - val_mape: 98.4322 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1915 - mape: 3221.9521 - val_loss: 0.2473 - val_mape: 95.6325 - learning_rate: 5.0000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1955 - mape: 8792.7051 - val_loss: 0.2379 - val_mape: 93.4758 - learning_rate: 5.0000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1985 - mape: 1745.3577 - val_loss: 0.2326 - val_mape: 94.4743 - learning_rate: 5.0000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1953 - mape: 1108.0930 - val_loss: 0.2282 - val_mape: 93.5366 - learning_rate: 5.0000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1993 - mape: 6030.8872 - val_loss: 0.2184 - val_mape: 93.3766 - learning_rate: 5.0000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2023 - mape: 1765.3912 - val_loss: 0.2142 - val_mape: 95.0913 - learning_rate: 5.0000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1848 - mape: 3296.2773 - val_loss: 0.2115 - val_mape: 95.6939 - learning_rate: 5.0000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1899 - mape: 5547.3511 - val_loss: 0.2017 - val_mape: 95.4293 - learning_rate: 5.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1746 - mape: 3415.9153 - val_loss: 0.1985 - val_mape: 96.6739 - learning_rate: 5.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1871 - mape: 4928.6587 - val_loss: 0.2033 - val_mape: 99.8782 - learning_rate: 5.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1817 - mape: 4355.4829 - val_loss: 0.2129 - val_mape: 103.4451 - learning_rate: 5.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1768 - mape: 4427.2988 - val_loss: 0.2077 - val_mape: 104.0633 - learning_rate: 5.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1860 - mape: 3315.0718 - val_loss: 0.2011 - val_mape: 105.2119 - learning_rate: 5.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1870 - mape: 5274.9062 - val_loss: 0.1958 - val_mape: 103.8228 - learning_rate: 5.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1798 - mape: 5592.0342 - val_loss: 0.1920 - val_mape: 102.6068 - learning_rate: 5.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1743 - mape: 4965.2085 - val_loss: 0.1937 - val_mape: 107.0916 - learning_rate: 5.0000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1807 - mape: 3631.6470 - val_loss: 0.1985 - val_mape: 110.5353 - learning_rate: 5.0000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1773 - mape: 4025.4084 - val_loss: 0.2004 - val_mape: 115.3863 - learning_rate: 5.0000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1776 - mape: 3938.0054 - val_loss: 0.2058 - val_mape: 118.9747 - learning_rate: 5.0000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1805 - mape: 4945.5737 - val_loss: 0.2083 - val_mape: 118.5466 - learning_rate: 5.0000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1718 - mape: 4594.7397 - val_loss: 0.2061 - val_mape: 117.1268 - learning_rate: 2.5000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1665 - mape: 2755.3655 - val_loss: 0.2037 - val_mape: 116.1450 - learning_rate: 2.5000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1697 - mape: 5009.6318 - val_loss: 0.2008 - val_mape: 114.2556 - learning_rate: 2.5000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1680 - mape: 2182.1860 - val_loss: 0.2024 - val_mape: 116.2084 - learning_rate: 2.5000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1767 - mape: 6979.5220 - val_loss: 0.2014 - val_mape: 116.0114 - learning_rate: 2.5000e-04

# %%
# 1) Predict & inverse‑scale
y_pred_s = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_s).ravel()
y_true = y_scaler.inverse_transform(y_test).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
# 2) Metrics
mae  = mean_absolute_error(y_true, y_pred)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred) * 100
print("\nRQ2‐ANN Performance - Wind (South Island):")
print(f"MAE : {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# RQ2‐ANN Performance - Wind (South Island):
# MAE : 2,180,504.70
# RMSE: 2,649,076.27
# MAPE: 50.30%

# %%
# 64X
# RQ2‐ANN Performance - Wind (South Island):
# MAE : 1,998,118.16
# RMSE: 2,405,874.11
# MAPE: 45.24%

# %%
# 11) Plot Train, Test Actuals, and RQ2‐ANN Forecast
plt.figure(figsize=(15, 7))
# 11a) Training‐period actuals (2015 to split)
plt.plot(train_df.index, y_train_raw.flatten(),label="Train Actual (2015 -> split)",  color="lightgray")
# 11b) Test‐period actuals
plt.plot(test_df.index,y_test_raw.flatten(),label="Test Actual",color="black")
# 11c) RQ2‐ANN forecast over test period
plt.plot(test_df.index,y_pred,label="Forecast",linestyle="--",color="darkorange")
plt.title("RQ2‐ANN: South Island Weekly Wind Generation (Train & Test Actual vs Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
