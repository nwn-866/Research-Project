# %% [markdown]
# # ANN Forecasting of Weekly Hydro Energy Generation in New Zealand
#
# This notebook addresses:
# * RQ1: How accurately can ANN forecast weekly hydro energy compared to SARIMA?
# * RQ2: Does incorporating weekly-aggregated climate variables into ANN improve forecasting accuracy?
#
# Hydro generation data is merged with NASA climate variables and aggregated to weekly frequency.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error , root_mean_squared_error , mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.losses import Huber
import random

# %%
# use preprocessed file used in SARIMA model.

# %%
all_poc_data = pd.read_csv('EDA_Hydro_all_POC_20250602_0700.csv')

# %%
all_poc_data
# Out:
#        Fuel_Code POC_Code        DATE   Total_TP Island   Latitude  \
# 0          Hydro  ARA2201  2015-03-01   484010.0     NI -38.615891
# 1          Hydro  ARA2201  2015-03-02   598280.0     NI -38.615891
# 2          Hydro  ARA2201  2015-03-03   626290.0     NI -38.615891
# 3          Hydro  ARA2201  2015-03-04   826700.0     NI -38.615891
# 4          Hydro  ARA2201  2015-03-05   891070.0     NI -38.615891
# ...          ...      ...         ...        ...    ...        ...
# 132197     Hydro  WTK0111  2025-01-27  1427007.0     SI -44.692099
# 132198     Hydro  WTK0111  2025-01-28  1990551.0     SI -44.692099
# 132199     Hydro  WTK0111  2025-01-29  1720931.0     SI -44.692099
# 132200     Hydro  WTK0111  2025-01-30  1407865.0     SI -44.692099
# 132201     Hydro  WTK0111  2025-01-31  1610301.0     SI -44.692099
#
#          Longitude   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0       176.143036  57.62         0.00      0.19    1.01  19.11
# 1       176.143036  68.36         0.00      0.19    0.84  19.03
# 2       176.143036  68.50         0.14      0.19    0.45  18.00
# 3       176.143036  79.20         1.09      0.19    0.95  16.43
# 4       176.143036  69.77         0.01      0.19    0.70  18.74
# ...            ...    ...          ...       ...     ...    ...
# 132197  170.429029  64.93         1.73      0.44    2.48  10.90
# 132198  170.429029  56.24         0.08      0.43    3.01  14.74
# 132199  170.429029  57.06         0.84      0.43    3.68  17.65
# 132200  170.429029  73.86         0.48      0.43    2.13  14.05
# 132201  170.429029  72.17         0.19      0.42    2.05  15.41
#
# [132202 rows x 12 columns]

# %%
print(all_poc_data.dtypes)
# Out:
# Fuel_Code       object
# POC_Code        object
# DATE            object
# Total_TP       float64
# Island          object
# Latitude       float64
# Longitude      float64
# RH2M           float64
# PRECTOTCORR    float64
# GWETPROF       float64
# EVLAND         float64
# T2M            float64
# dtype: object

# %%
all_poc_data['DATE'] = pd.to_datetime(
    all_poc_data['DATE']#, #dayfirst = True
   # format='%d/%m/%Y'     # day/month/4 digit‐year
)

# %%
print(all_poc_data.dtypes)
# Out:
# Fuel_Code              object
# POC_Code               object
# DATE           datetime64[ns]
# Total_TP              float64
# Island                 object
# Latitude              float64
# Longitude             float64
# RH2M                  float64
# PRECTOTCORR           float64
# GWETPROF              float64
# EVLAND                float64
# T2M                   float64
# dtype: object

# %%
all_poc_data.head()
# Out:
#   Fuel_Code POC_Code       DATE  Total_TP Island   Latitude   Longitude  \
# 0     Hydro  ARA2201 2015-03-01  484010.0     NI -38.615891  176.143036
# 1     Hydro  ARA2201 2015-03-02  598280.0     NI -38.615891  176.143036
# 2     Hydro  ARA2201 2015-03-03  626290.0     NI -38.615891  176.143036
# 3     Hydro  ARA2201 2015-03-04  826700.0     NI -38.615891  176.143036
# 4     Hydro  ARA2201 2015-03-05  891070.0     NI -38.615891  176.143036
#
#     RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# 0  57.62         0.00      0.19    1.01  19.11
# 1  68.36         0.00      0.19    0.84  19.03
# 2  68.50         0.14      0.19    0.45  18.00
# 3  79.20         1.09      0.19    0.95  16.43
# 4  69.77         0.01      0.19    0.70  18.74

# %%
all_poc_data['Fuel_Code'] = all_poc_data['Fuel_Code'].astype(str)

# %%
all_poc_data['Island'] = all_poc_data['Island'].astype(str)

# %%
print(all_poc_data.dtypes)
# Out:
# Fuel_Code              object
# POC_Code               object
# DATE           datetime64[ns]
# Total_TP              float64
# Island                 object
# Latitude              float64
# Longitude             float64
# RH2M                  float64
# PRECTOTCORR           float64
# GWETPROF              float64
# EVLAND                float64
# T2M                   float64
# dtype: object

# %%
# Check for missing values in each column
missing_values = all_poc_data.isnull().sum()
print(missing_values)

# check if there are any missing values at all
if all_poc_data.isnull().values.any():
    print("There are missing values in the DataFrame.")
else:
    print("No missing values found in the DataFrame.")
# Out:
# Fuel_Code      0
# POC_Code       0
# DATE           0
# Total_TP       0
# Island         0
# Latitude       0
# Longitude      0
# RH2M           0
# PRECTOTCORR    0
# GWETPROF       0
# EVLAND         0
# T2M            0
# dtype: int64
# No missing values found in the DataFrame.

# %%
# List all column names as an Index object
print(all_poc_data.columns)

# Alternatively, list the column names as a Python list
print(all_poc_data.columns.tolist())
# Out:
# Index(['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude',
#        'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M'],
#       dtype='object')
# ['Fuel_Code', 'POC_Code', 'DATE', 'Total_TP', 'Island', 'Latitude', 'Longitude', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M']

# %%
selected_col_hydro = ['DATE','Island','Total_TP', 'RH2M', 'PRECTOTCORR', 'GWETPROF', 'EVLAND', 'T2M']  # Replace with your desired column names

# %%
df_hydro_daily_all_nsp = all_poc_data[selected_col_hydro].copy()

# %%
df_hydro_daily_all_nsp
# Out:
#              DATE Island   Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND  \
# 0      2015-03-01     NI   484010.0  57.62         0.00      0.19    1.01
# 1      2015-03-02     NI   598280.0  68.36         0.00      0.19    0.84
# 2      2015-03-03     NI   626290.0  68.50         0.14      0.19    0.45
# 3      2015-03-04     NI   826700.0  79.20         1.09      0.19    0.95
# 4      2015-03-05     NI   891070.0  69.77         0.01      0.19    0.70
# ...           ...    ...        ...    ...          ...       ...     ...
# 132197 2025-01-27     SI  1427007.0  64.93         1.73      0.44    2.48
# 132198 2025-01-28     SI  1990551.0  56.24         0.08      0.43    3.01
# 132199 2025-01-29     SI  1720931.0  57.06         0.84      0.43    3.68
# 132200 2025-01-30     SI  1407865.0  73.86         0.48      0.43    2.13
# 132201 2025-01-31     SI  1610301.0  72.17         0.19      0.42    2.05
#
#           T2M
# 0       19.11
# 1       19.03
# 2       18.00
# 3       16.43
# 4       18.74
# ...       ...
# 132197  10.90
# 132198  14.74
# 132199  17.65
# 132200  14.05
# 132201  15.41
#
# [132202 rows x 8 columns]

# %%
df_hydro_daily_all_nsp.set_index('DATE', inplace=True)

# %%
df_hydro_daily_all_nsp.head()
# Out:
#            Island  Total_TP   RH2M  PRECTOTCORR  GWETPROF  EVLAND    T2M
# DATE
# 2015-03-01     NI  484010.0  57.62         0.00      0.19    1.01  19.11
# 2015-03-02     NI  598280.0  68.36         0.00      0.19    0.84  19.03
# 2015-03-03     NI  626290.0  68.50         0.14      0.19    0.45  18.00
# 2015-03-04     NI  826700.0  79.20         1.09      0.19    0.95  16.43
# 2015-03-05     NI  891070.0  69.77         0.01      0.19    0.70  18.74

# %%
record_counts = df_hydro_daily_all_nsp.groupby('Island').size()
print(record_counts)
# Out:
# Island
# NI    61399
# SI    70803
# dtype: int64

# %%
# 1. Define custom agg: sum for some columns, mean for the rest
agg_dict = {
    'Total_TP':    'sum',
    'PRECTOTCORR': 'sum',
    'EVLAND':      'sum',
    'RH2M':        'mean',
    'GWETPROF':    'mean',
    'T2M':         'mean'
   }

# %%
# Perform weekly aggregation grouped by Island
df_hydro_weekly = df_hydro_daily_all_nsp.groupby([pd.Grouper(freq='W'), 'Island']).agg(agg_dict)

# %%
df_hydro_weekly
# Out:
#                        Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF  \
# DATE       Island
# 2015-03-01 NI      7.825804e+06         0.21   27.84  66.255294  0.334706
#            SI      4.206066e+07        52.53   42.14  77.983889  0.450000
# 2015-03-08 NI      7.710830e+07       204.03  195.33  76.440336  0.331176
#            SI      3.203293e+08       767.35  258.66  76.412937  0.467698
# 2015-03-15 NI      7.124508e+07       372.58  203.25  76.564454  0.338487
# ...                         ...          ...     ...        ...       ...
# 2025-01-19 SI      3.410497e+08        56.50  426.76  73.288844  0.504014
# 2025-01-26 NI      8.673389e+07       426.59  321.14  75.025294  0.388235
#            SI      3.227407e+08       517.57  375.03  74.280680  0.480680
# 2025-02-02 NI      6.166375e+07        82.11  223.50  68.219059  0.387294
#            SI      2.256292e+08       123.34  317.82  68.009143  0.488571
#
#                          T2M
# DATE       Island
# 2015-03-01 NI      19.008235
#            SI      15.757778
# 2015-03-08 NI      17.886723
#            SI      12.941190
# 2015-03-15 NI      17.326303
# ...                      ...
# 2025-01-19 SI      14.151905
# 2025-01-26 NI      18.570840
#            SI      14.696395
# 2025-02-02 NI      17.883647
#            SI      13.505429
#
# [1038 rows x 6 columns]

# %%
#North Island specific data
df_hydro_weekly_north = df_hydro_weekly.xs('NI', level='Island')

# %%
print(df_hydro_weekly_north.shape)
# Out:
# (519, 6)

# %%
#South Island specific data
df_hydro_weekly_south = df_hydro_weekly.xs('SI', level='Island')

# %%
print(df_hydro_weekly_south.shape)
# Out:
# (519, 6)

# %%
# Check for rows where Total_TP equals 0.0
zero_records = df_hydro_weekly_north[df_hydro_weekly_north['Total_TP'] == 0.0]
print("Number of weekly records with Total_TP equal to 0:", len(zero_records))
print(zero_records)
# Out:
# Number of weekly records with Total_TP equal to 0: 0
# Empty DataFrame
# Columns: [Total_TP, PRECTOTCORR, EVLAND, RH2M, GWETPROF, T2M]
# Index: []

# %%
df_hydro_weekly_north_before = df_hydro_weekly_north.copy()

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_hydro_weekly_north = df_hydro_weekly_north.drop(index=pd.to_datetime('2015-03-01'))
df_hydro_weekly_north = df_hydro_weekly_north.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_hydro_weekly_north.shape)
# Out:
# (517, 6)

# %%
df_hydro_weekly_south_before = df_hydro_weekly_south.copy()

# %%
# Drop the 2015‑03‑01 and 2025-02-02	 rows , looks incomplete
df_hydro_weekly_south = df_hydro_weekly_south.drop(index=pd.to_datetime('2015-03-01'))
df_hydro_weekly_south = df_hydro_weekly_south.drop(index=pd.to_datetime('2025-02-02'))

# %%
print(df_hydro_weekly_south.shape)
# Out:
# (517, 6)

# %% [markdown]
# ## Start North Island

# %% [raw]
# ##########   Feature Engineering    ##########

# %%
# Add 1 to 2-week lagged climate features
df_hydro_weekly_north['TP_lag1w'] = df_hydro_weekly_north['Total_TP'].shift(1)
df_hydro_weekly_north['T2M_lag1w'] = df_hydro_weekly_north['T2M'].shift(1)
df_hydro_weekly_north['GWETPROF_lag1w'] = df_hydro_weekly_north['GWETPROF'].shift(1)
df_hydro_weekly_north['RH2M_lag1w'] = df_hydro_weekly_north['RH2M'].shift(1)
df_hydro_weekly_north['PRECIP_lag1w'] = df_hydro_weekly_north['PRECTOTCORR'].shift(1)
df_hydro_weekly_north['EVLAND_lag1w'] = df_hydro_weekly_north['EVLAND'].shift(1)
df_hydro_weekly_north['PRECIP_lag2w'] = df_hydro_weekly_north['PRECTOTCORR'].shift(2)
df_hydro_weekly_north['PRECIP_EWMA'] = df_hydro_weekly_north['PRECTOTCORR'].ewm(alpha=0.3, adjust=False).mean()
# EWMA for EVLAND with a “slow” decay (alpha = 0.1)
df_hydro_weekly_north['EVLAND_EWMA'] = df_hydro_weekly_north['EVLAND'].ewm(alpha=0.3, adjust=False).mean()
df_hydro_weekly_north['APIxGWETPROF'] = df_hydro_weekly_north['PRECIP_EWMA'] * df_hydro_weekly_north['GWETPROF']

# %%
df_hydro_weekly_north
# Out:
#                Total_TP  PRECTOTCORR  EVLAND       RH2M  GWETPROF        T2M  \
# DATE
# 2015-03-08  77108297.22       204.03  195.33  76.440336  0.331176  17.886723
# 2015-03-15  71245084.70       372.58  203.25  76.564454  0.338487  17.326303
# 2015-03-22  71202576.46       399.07  238.96  70.463782  0.368403  13.776807
# 2015-03-29  70920967.42       326.24  216.04  80.650000  0.360000  16.227563
# 2015-04-05  70933314.09        44.53  174.38  77.631261  0.362605  15.508235
# ...                 ...          ...     ...        ...       ...        ...
# 2024-12-29  77312627.00       391.50  452.03  74.004958  0.453025  17.281008
# 2025-01-05  62980054.00       331.19  418.69  74.479328  0.442689  15.331933
# 2025-01-12  84874356.00       108.94  382.43  67.837059  0.425630  15.599916
# 2025-01-19  96991450.00        46.67  317.29  67.007143  0.402353  17.000084
# 2025-01-26  86733894.00       426.59  321.14  75.025294  0.388235  18.570840
#
#                TP_lag1w  T2M_lag1w  GWETPROF_lag1w  RH2M_lag1w  PRECIP_lag1w  \
# DATE
# 2015-03-08          NaN        NaN             NaN         NaN           NaN
# 2015-03-15  77108297.22  17.886723        0.331176   76.440336        204.03
# 2015-03-22  71245084.70  17.326303        0.338487   76.564454        372.58
# 2015-03-29  71202576.46  13.776807        0.368403   70.463782        399.07
# 2015-04-05  70920967.42  16.227563        0.360000   80.650000        326.24
# ...                 ...        ...             ...         ...           ...
# 2024-12-29  83933260.00  16.798655        0.458739   78.571765        468.64
# 2025-01-05  77312627.00  17.281008        0.453025   74.004958        391.50
# 2025-01-12  62980054.00  15.331933        0.442689   74.479328        331.19
# 2025-01-19  84874356.00  15.599916        0.425630   67.837059        108.94
# 2025-01-26  96991450.00  17.000084        0.402353   67.007143         46.67
#
#             EVLAND_lag1w  PRECIP_lag2w  PRECIP_EWMA  EVLAND_EWMA  APIxGWETPROF
# DATE
# 2015-03-08           NaN           NaN   204.030000   195.330000     67.569935
# 2015-03-15        195.33           NaN   254.595000   197.706000     86.177198
# 2015-03-22        203.25        204.03   297.937500   210.082200    109.761176
# 2015-03-29        238.96        372.58   306.428250   211.869540    110.314170
# 2015-04-05        216.04        399.07   227.858775   200.622678     82.622741
# ...                  ...           ...          ...          ...           ...
# 2024-12-29        498.24        400.52   331.569510   438.334654    150.209347
# 2025-01-05        452.03        468.64   331.455657   432.441258    146.731798
# 2025-01-12        418.69        391.50   264.700960   417.437880    112.664736
# 2025-01-19        382.43        331.19   199.291672   387.393516     80.185590
# 2025-01-26        317.29        108.94   267.481170   367.517461    103.845631
#
# [517 rows x 16 columns]

# %%
# Drop original non-lagged features and drop NA from lagging
weekly_lagged_north = df_hydro_weekly_north[['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','APIxGWETPROF','PRECIP_lag2w','PRECIP_EWMA','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','GWETPROF','GWETPROF_lag1w','T2M','T2M_lag1w']].dropna()
weekly_lagged_north.head()
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    109.761176        204.03   297.937500  238.96        203.25
# 2015-03-29    110.314170        372.58   306.428250  216.04        238.96
# 2015-04-05     82.622741        399.07   227.858775  174.38        216.04
# 2015-04-12    140.663256        326.24   374.724142  185.60        174.38
# 2015-04-19    188.502533         44.53   456.301900  184.17        185.60
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   210.082200  70.463782   76.564454  0.368403        0.338487
# 2015-03-29   211.869540  80.650000   70.463782  0.360000        0.368403
# 2015-04-05   200.622678  77.631261   80.650000  0.362605        0.360000
# 2015-04-12   196.115875  85.405462   77.631261  0.375378        0.362605
# 2015-04-19   192.532112  80.490084   85.405462  0.413109        0.375378
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639

# %% [raw]
# factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']

# %% [raw]
# climate_cols = ['PRECTOTCORR','EVLAND','RH2M','GWETPROF','T2M']

# %% [raw]
# for lag in [1,2,3,4,5,6,7]:
#     for col in climate_cols:
#         df_island_north_wk[f'{col}_lag{lag}'] = df_island_north_wk[col].shift(lag)

# %% [raw]
# windows      = [1,2,3,4,5,6,7]
# for col in climate_cols:
#     for w in windows:
#         df_island_north_wk[f'{col}_mean_{w}d'] = df_island_north_wk[col].rolling(w, min_periods=1).mean()
#         #df_island_north[f'{col}_std_{w}d']  = df_island_north[col].rolling(w, min_periods=1).std()

# %% [raw]
# # # 1) Create the seasonality flags
# df_island_north_wk['doy']     = df_island_north_wk.index.dayofyear
# df_island_north_wk['sin_doy'] = np.sin(2*np.pi * df_island_north_wk['doy']/365)
# df_island_north_wk['cos_doy'] = np.cos(2*np.pi * df_island_north_wk['doy']/365)
#
# # df['doy']     = df.index.dayofyear
# # df['sin_doy'] = np.sin(2 * np.pi * df['doy'] / 365)
# # df['cos_doy'] = np.cos(2 * np.pi * df['doy'] / 365)

# %% [raw]
# df_island_north_wk['T2M_RH2M_interaction'] = df_island_north_wk['T2M'] * df_island_north_wk['RH2M'] # adding temperature humidity interaction
# df_island_north_wk['GWETPROF_PRECEPITATION_interaction'] = df_island_north_wk['GWETPROF'] * df_island_north_wk['PRECTOTCORR'] # adding precipitation and wetprofile interaction
# # North Island daily
# df_island_north_wk['PRECIP_7d'] = df_island_north_wk['PRECTOTCORR'].rolling(7, min_periods=1).sum() #Rolling sums - total rain over the last 7 days

# %% [raw]
# #   Set seeds for reproducibility
# np.random.seed(42)
# random.seed(42)
# tf.random.set_seed(42)
#
# # #   Feature Engineering
# # df_island_north['PRECIP_lag3'] = df_island_north['PRECTOTCORR'].shift(3)
# # df_island_north['PRECIP_lag5'] = df_island_north['PRECTOTCORR'].shift(5)
# # #df_island_north['PRECIP_lag14'] = df_island_north['PRECTOTCORR'].shift(14)
# # #df_island_north['Total_TP_lag2'] = df_island_north['Total_TP'].shift(2)
# # #df_island_north['Total_TP_diff'] = df_island_north['Total_TP'].diff()
# # # df_island_north['WS50M_diff'] = df_island_north['WS50M'].diff()
# # #df_island_north['Total_TP_rolling3'] = df_island_north['Total_TP'].rolling(3).mean()
#
#
# # # weekly_df['Total_TP_lag1'] = weekly_df['Total_TP'].shift(1)
# # # weekly_df['Total_TP_lag2'] = weekly_df['Total_TP'].shift(2)
# # # weekly_df['Total_TP_rolling3'] = weekly_df['Total_TP'].rolling(3).mean()
# # # weekly_df['T2M_RH2M_interaction'] = weekly_df['Avg_T2M'] * weekly_df['AVG_RH2M']
#
# # # North Island daily
# # df_island_north['PRECIP_7d'] = df_island_north['PRECTOTCORR'].rolling(7, min_periods=1).sum() #Rolling sums - total rain over the last 7 days
# # # df_island_north['PRECIP_14d'] = df_island_north['PRECTOTCORR'].rolling(14, min_periods=1).sum() #Rolling sums - total rain over the last 14 days
# # # df_island_north['PRECIP_lag1'] = df_island_north['PRECTOTCORR'].shift(1) # Lagged values yesterday’s rain
# # # df_island_north['PRECIP_lag7'] = df_island_north['PRECTOTCORR'].shift(7) # Lagged values last week’s rain

# %% [raw]
# # # 1) Create the seasonality flags
# # df_island_north['woy']     = df_island_north.index.isocalendar().week
# # df_island_north['sin_woy'] = np.sin(2*np.pi * df_island_north['woy']/52)
# # df_island_north['cos_woy'] = np.cos(2*np.pi * df_island_north['woy']/52)

# %% [raw]
# #
# df_island_north_wk['TP_lag1'] = df_island_north_wk['Total_TP'].shift(1)
# df_island_north_wk['TP_lag7'] = df_island_north_wk['Total_TP'].shift(7)

# %% [raw]
# df_island_north_wk['rain*sin_7d'] = (df_island_north_wk['PRECTOTCORR'].rolling(7, min_periods=1).sum()* df_island_north_wk['sin_doy'])

# %% [raw]
# df_island_north_wk['rain*sin_1d'] = df_island_north_wk['PRECTOTCORR'] * df_island_north_wk['sin_doy']

# %% [raw]
# # for w in [3,5,7,14,30]:
# #     df_island_north[f'PRECTOT_{w}d_mean'] = df_island_north['PRECTOTCORR'].rolling(w).mean()

# %% [raw]
# df_island_north_wk.head(30)

# %% [raw]
# df_island_north_wk.dropna(inplace=True)

# %% [raw]
# print(df_island_north_wk.columns)

# %% [raw]
# df_island_north_wk

# %% [raw]
# # check corelationship in each feacture with lag and window
# features_set1 = [
#    'Total_TP', 'TP_lag1',
# 'TP_lag7', 'sin_doy','rain*sin_1d',
# 'rain*sin_7d', 'cos_doy'
# ]
# corr = df_island_north_wk[features_set1].corr()
# print(corr)

# %% [raw]
# # in your own notebook, run:
# core_features = [ 'Total_TP', 'TP_lag1',
# 'TP_lag7',
# 'EVLAND_lag7',
# 'GWETPROF',
# 'GWETPROF_mean_1d',
# 'PRECIP_7d',
# 'PRECTOTCORR_mean_7d',
# 'RH2M_lag7',
# 'RH2M_mean_7d',
# 'T2M',
# 'T2M_lag7'
#    # 'Total_TP', 'PRECTOTCORR',  'PRECTOTCORR_mean_1d', 'PRECTOTCORR_mean_2d', 'PRECTOTCORR_mean_3d',
#    #     'PRECTOTCORR_mean_7d','PRECIP_lag5', 'PRECIP_7d'
# ]
# corr = df_island_north_wk[core_features].corr()
# print(corr)

# %%
#   Feature Selection  
features = [# raw climate
#   #'PRECTOTCORR',#'EVLAND',
#     'RH2M'
#     ,'GWETPROF'#'T2M',
#   # pruned precip
#   ,'PRECIP_lag3'
#   #,  'PRECIP_7d'
# #'PRECTOT_30d_mean',
#   # hydro autocorrelation
#   ,'TP_lag1'
#  , 'TP_lag7'
# #'sin_woy',    # sin(2π·week_of_year/52)
# #    'cos_woy'     # cos(2π·week_of_year/52)
#     ,'rain*sin_woy'

  #   'PRECIP_7d',
  #     'TP_lag1',   # yesterday’s hydro output
  # 'TP_lag7',   # last week’s hydro output
  # 'GWETPROF',  # ground wetness (strong climate driver)
  # 'T2M',       # temperature
  # 'sin_woy',   # weekly seasonality (sine component)
  # 'RH2M'       # humidity
'Total_TP',
'TP_lag1',   # yesterday’s hydro output (strongest autocorr)
'TP_lag7',   # last week’s output (weekly inertia)
'GWETPROF',  # ground wetness profile (high climate driver)
'GWETPROF_mean_1d',
'PRECIP_7d',
'PRECTOTCORR_mean_7d',
'RH2M_lag7',
'RH2M_mean_7d'
#'T2M',       # temperature (strong correlation, retain over cos_doy)
#'sin_doy',   # seasonal cycle (keep sin, drop cos to avoid T2M–cos_doy redundancy)
#'RH2M' ,      # humidity (next‑highest corr after seasonality)
# 'PRECTOTCORR_mean_7d',
# 'rain*sin_doy7',
# 'rain*sin_doy'
]

# %%
# Correlation Matrix: Hydro Energy vs Climate Factors : Daily
import seaborn as sns

plt.figure(figsize=(8, 5))
corr = df_island_north_wk[features].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix (daily) : Hydro Energy vs Climate Factors')
plt.tight_layout()
plt.show()

# %%
# X = df_island_north[features]
# y = df_island_north['Total_TP']

# %%
#   Set seeds for reproducibility  
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
weekly_lagged_north.head()
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    109.761176        204.03   297.937500  238.96        203.25
# 2015-03-29    110.314170        372.58   306.428250  216.04        238.96
# 2015-04-05     82.622741        399.07   227.858775  174.38        216.04
# 2015-04-12    140.663256        326.24   374.724142  185.60        174.38
# 2015-04-19    188.502533         44.53   456.301900  184.17        185.60
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   210.082200  70.463782   76.564454  0.368403        0.338487
# 2015-03-29   211.869540  80.650000   70.463782  0.360000        0.368403
# 2015-04-05   200.622678  77.631261   80.650000  0.362605        0.360000
# 2015-04-12   196.115875  85.405462   77.631261  0.375378        0.362605
# 2015-04-19   192.532112  80.490084   85.405462  0.413109        0.375378
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639

# %%
# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_hydro_north_wk = weekly_lagged_north[['Total_TP','TP_lag1w']]

# %%
df_ann_hydro_north_wk.head()
# Out:
#                 Total_TP     TP_lag1w
# DATE
# 2015-03-22  7.120258e+07  71245084.70
# 2015-03-29  7.092097e+07  71202576.46
# 2015-04-05  7.093331e+07  70920967.42
# 2015-04-12  9.771136e+07  70933314.09
# 2015-04-19  1.111432e+08  97711358.20

# %%
n_hydro_ann     = len(df_ann_hydro_north_wk)
split_ann = int(n_hydro_ann * 0.8)

train_n_ann = df_ann_hydro_north_wk.iloc[:split_ann]
test_n_ann  = df_ann_hydro_north_wk.iloc[split_ann:]

X_train = train_n_ann[['TP_lag1w']].values
y_train = train_n_ann['Total_TP'].values.reshape(-1,1)
X_test  = test_n_ann[['TP_lag1w']].values
y_test  = test_n_ann['Total_TP'].values.reshape(-1,1)

# %%
# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s = scaler_X.fit_transform(X_train)
X_test_s  = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_s = scaler_y.fit_transform(y_train)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# %%
# 4) Build the ANN
model_ann = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) Train the ANN (the shuffle order is now deterministic)
history = model_ann.fit(
    X_train_s, y_train_s,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# %%
# 6) Predict & rescale
y_pred_s = model_ann.predict(X_test_s)
y_pred   = scaler_y.inverse_transform(y_pred_s).flatten()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test.flatten(), y_pred)
rmse_ann = np.sqrt(mean_squared_error(y_test.flatten(), y_pred))
mape_ann = np.mean(np.abs((y_test.flatten() - y_pred) / y_test.flatten())) * 100

print(f"Univariate ANN - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")
# Out:
# Univariate ANN - MAE: 11263851.50, RMSE: 14145051.16, MAPE: 9.71%

# %% [raw]
# RQ1 - Univariate ANN - MAE: 11263851.50, RMSE: 14145051.16, MAPE: 9.71%

# %%
plt.figure(figsize=(15,7))
plt.plot(train_n_ann.index,y_train.flatten(),label="Train Actual (2015 -> split)",color="lightgray")
plt.plot(test_n_ann.index, y_test, label="Actual Total_TP",   color="black")
plt.plot(test_n_ann.index, y_pred, label="ANN Forecast",      color="darkorange")
plt.title("RQ1‐ANN: North Island Weekly Hydro (Actual vs. Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# daily_feats = [
#     # 'TP_lag1',        # yesterday’s output
#     # 'TP_lag7',        # last week’s output
#     # 'GWETPROF',       # ground wetness
#     # 'RH2M_mean_7d',   # 7‑day mean humidity
#     # 'sin_doy',        # seasonal cycle (day‑of‑year sine)
#     # 'PRECIP_7d'       # 7‑day total rainfall

# 'TP_lag1',   # yesterday’s hydro output (strongest autocorr)
# 'TP_lag7',   # last week’s output (weekly inertia)
# #'GWETPROF',  # ground wetness profile (high climate driver)
# 'GWETPROF_mean_1d',
# 'PRECIP_7d',
# #'PRECTOTCORR_mean_7d',
# #'RH2M_lag7',
# 'RH2M_mean_7d'
#     #'T2M'
# ]

# %%
weekly_lagged_north.head()
# Out:
#                 Total_TP     TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  7.120258e+07  71245084.70       399.07        372.58
# 2015-03-29  7.092097e+07  71202576.46       326.24        399.07
# 2015-04-05  7.093331e+07  70920967.42        44.53        326.24
# 2015-04-12  9.771136e+07  70933314.09       717.41         44.53
# 2015-04-19  1.111432e+08  97711358.20       646.65        717.41
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    109.761176        204.03   297.937500  238.96        203.25
# 2015-03-29    110.314170        372.58   306.428250  216.04        238.96
# 2015-04-05     82.622741        399.07   227.858775  174.38        216.04
# 2015-04-12    140.663256        326.24   374.724142  185.60        174.38
# 2015-04-19    188.502533         44.53   456.301900  184.17        185.60
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   210.082200  70.463782   76.564454  0.368403        0.338487
# 2015-03-29   211.869540  80.650000   70.463782  0.360000        0.368403
# 2015-04-05   200.622678  77.631261   80.650000  0.362605        0.360000
# 2015-04-12   196.115875  85.405462   77.631261  0.375378        0.362605
# 2015-04-19   192.532112  80.490084   85.405462  0.413109        0.375378
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22  13.776807  17.326303
# 2015-03-29  16.227563  13.776807
# 2015-04-05  15.508235  16.227563
# 2015-04-12  16.036639  15.508235
# 2015-04-19  10.195378  16.036639

# %%
#1.factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']

# %%
factors = ['TP_lag1w','APIxGWETPROF']

# %% [raw]
# factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']

# %%
# X_raw = weekly_lagged_north[factors].values                  # (n_samples, n_features)
# y_raw = weekly_lagged_north['Total_TP'].values.reshape(-1, 1) # (n_samples, 1)

# %%
# # 3) Split *once* (no shuffling)
# X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(
#     X_raw, y_raw, train_size=0.8, shuffle=False
# )
# n_raw    = len(X_raw)
# split_raw = int(n_raw * 0.8)

# X_train_raw = X_raw[:split_raw]
# X_test_raw  = X_raw[split_raw:]
# y_train_raw = y_raw[:split_raw]
# y_test_raw  = y_raw[split_raw:]


# 2) Split via slicing
n = len(weekly_lagged_north)
split_idx = int(n * 0.8)

train_df = weekly_lagged_north.iloc[:split_idx]
test_df  = weekly_lagged_north.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw = train_df[factors].values
X_test_raw  = test_df[factors].values
y_train_raw = train_df['Total_TP'].values.reshape(-1, 1)
y_test_raw  = test_df['Total_TP'].values.reshape(-1, 1)

# %%
# 4) Scale
x_scaler = StandardScaler().fit(X_train_raw)
y_scaler = StandardScaler().fit(y_train_raw)

X_train = x_scaler.transform(X_train_raw)
X_test  = x_scaler.transform(X_test_raw)
y_train = y_scaler.transform(y_train_raw)
y_test  = y_scaler.transform(y_test_raw)

# %%
# 5) Sanity‐check shapes
print(X_train.shape, y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (412, 2) (412, 1)
# (103, 2) (103, 1)

# %%
# commented 2025/04/21 for tuninig 
#   Scaling  
'''X_scaler = MinMaxScaler()
X_scaled = X_scaler.fit_transform(X)

y_scaler = MinMaxScaler()
y_scaled = y_scaler.fit_transform(y.values.reshape(-1, 1))'''
# Out:
# 'X_scaler = MinMaxScaler()\nX_scaled = X_scaler.fit_transform(X)\n\ny_scaler = MinMaxScaler()\ny_scaled = y_scaler.fit_transform(y.values.reshape(-1, 1))'

# %%
# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

# %%
# #   ANN Model  
# model = Sequential([
#     Dense(128, input_shape=(X_train.shape[1],)),
#     LeakyReLU(),
#     BatchNormalization(),
#     Dropout(0.2),
#     # Dense(128),
#     # BatchNormalization(),
#     # LeakyReLU(),
#     # Dropout(0.2),
    
#     Dense(64),
#     LeakyReLU(),
#     BatchNormalization(),
#     Dropout(0.2),
    
#     Dense(32),
#     LeakyReLU(),
#     Dense(1)
# ])

# #model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(16),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# %%
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_test, y_test),
#     epochs=200, batch_size=32,
#     callbacks=callbacks, verbose=1
# )

# ── 5) Train (use 10% of train_df as internal validation, keep test_df fully unseen) ──
history = model.fit(
    X_train, y_train,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step - loss: 0.4610 - mape: 449.1482 - val_loss: 0.3104 - val_mape: 84.7658 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3557 - mape: 197.9728 - val_loss: 0.2840 - val_mape: 78.6897 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3295 - mape: 252.6957 - val_loss: 0.2736 - val_mape: 76.6348 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2865 - mape: 188.4497 - val_loss: 0.2751 - val_mape: 77.4303 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2592 - mape: 347.0211 - val_loss: 0.2851 - val_mape: 80.3302 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2325 - mape: 271.7125 - val_loss: 0.2853 - val_mape: 80.2134 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2073 - mape: 254.7291 - val_loss: 0.2901 - val_mape: 80.9474 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1778 - mape: 252.3963 - val_loss: 0.3000 - val_mape: 84.2086 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1692 - mape: 189.3480 - val_loss: 0.2998 - val_mape: 84.3064 - learning_rate: 2.5000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2000 - mape: 168.0630 - val_loss: 0.2962 - val_mape: 82.9440 - learning_rate: 2.5000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1810 - mape: 283.7370 - val_loss: 0.2894 - val_mape: 81.1072 - learning_rate: 2.5000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1450 - mape: 141.2576 - val_loss: 0.2769 - val_mape: 77.3694 - learning_rate: 2.5000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1664 - mape: 170.6465 - val_loss: 0.2633 - val_mape: 73.3849 - learning_rate: 2.5000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1577 - mape: 158.1677 - val_loss: 0.2516 - val_mape: 69.9481 - learning_rate: 2.5000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1520 - mape: 161.3792 - val_loss: 0.2478 - val_mape: 68.7149 - learning_rate: 2.5000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1389 - mape: 151.3531 - val_loss: 0.2349 - val_mape: 65.1761 - learning_rate: 2.5000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1409 - mape: 150.1700 - val_loss: 0.2225 - val_mape: 62.2247 - learning_rate: 2.5000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1621 - mape: 159.5432 - val_loss: 0.2072 - val_mape: 57.5606 - learning_rate: 2.5000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1438 - mape: 153.1855 - val_loss: 0.1985 - val_mape: 54.5890 - learning_rate: 2.5000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1377 - mape: 222.1875 - val_loss: 0.1957 - val_mape: 53.6665 - learning_rate: 2.5000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1251 - mape: 137.9338 - val_loss: 0.1879 - val_mape: 52.4483 - learning_rate: 2.5000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1405 - mape: 133.0758 - val_loss: 0.1835 - val_mape: 51.5751 - learning_rate: 2.5000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1215 - mape: 97.6999 - val_loss: 0.1783 - val_mape: 51.1779 - learning_rate: 2.5000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1300 - mape: 156.6873 - val_loss: 0.1666 - val_mape: 49.3043 - learning_rate: 2.5000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1264 - mape: 131.3605 - val_loss: 0.1547 - val_mape: 47.9199 - learning_rate: 2.5000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1134 - mape: 116.9487 - val_loss: 0.1536 - val_mape: 48.3774 - learning_rate: 2.5000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1350 - mape: 199.9418 - val_loss: 0.1487 - val_mape: 48.8985 - learning_rate: 2.5000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1186 - mape: 244.7478 - val_loss: 0.1382 - val_mape: 48.3004 - learning_rate: 2.5000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1388 - mape: 174.5231 - val_loss: 0.1288 - val_mape: 48.2037 - learning_rate: 2.5000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1223 - mape: 204.4778 - val_loss: 0.1183 - val_mape: 48.2108 - learning_rate: 2.5000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1158 - mape: 124.8621 - val_loss: 0.1115 - val_mape: 48.7248 - learning_rate: 2.5000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1097 - mape: 165.7496 - val_loss: 0.1037 - val_mape: 49.0156 - learning_rate: 2.5000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1138 - mape: 178.2084 - val_loss: 0.0989 - val_mape: 49.1019 - learning_rate: 2.5000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1155 - mape: 123.8636 - val_loss: 0.0924 - val_mape: 48.8322 - learning_rate: 2.5000e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1039 - mape: 169.4805 - val_loss: 0.0863 - val_mape: 49.1463 - learning_rate: 2.5000e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1128 - mape: 122.6958 - val_loss: 0.0827 - val_mape: 50.1801 - learning_rate: 2.5000e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1013 - mape: 107.3570 - val_loss: 0.0813 - val_mape: 50.4842 - learning_rate: 2.5000e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1029 - mape: 110.7937 - val_loss: 0.0802 - val_mape: 50.4179 - learning_rate: 2.5000e-04
# Epoch 39/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0995 - mape: 127.5783 - val_loss: 0.0765 - val_mape: 50.9800 - learning_rate: 2.5000e-04
# Epoch 40/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1186 - mape: 121.7859 - val_loss: 0.0715 - val_mape: 50.9311 - learning_rate: 2.5000e-04
# Epoch 41/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1124 - mape: 160.7062 - val_loss: 0.0696 - val_mape: 51.6876 - learning_rate: 2.5000e-04
# Epoch 42/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1206 - mape: 144.0761 - val_loss: 0.0696 - val_mape: 52.6727 - learning_rate: 2.5000e-04
# Epoch 43/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1055 - mape: 127.2542 - val_loss: 0.0704 - val_mape: 52.3432 - learning_rate: 2.5000e-04
# Epoch 44/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0992 - mape: 108.3809 - val_loss: 0.0707 - val_mape: 51.9289 - learning_rate: 2.5000e-04
# Epoch 45/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0992 - mape: 118.6004 - val_loss: 0.0690 - val_mape: 51.8236 - learning_rate: 2.5000e-04
# Epoch 46/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1110 - mape: 162.5903 - val_loss: 0.0682 - val_mape: 52.0983 - learning_rate: 2.5000e-04
# Epoch 47/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1086 - mape: 150.6453 - val_loss: 0.0700 - val_mape: 52.8532 - learning_rate: 2.5000e-04
# Epoch 48/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0915 - mape: 124.4766 - val_loss: 0.0705 - val_mape: 53.4460 - learning_rate: 2.5000e-04
# Epoch 49/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1081 - mape: 133.0867 - val_loss: 0.0715 - val_mape: 53.7159 - learning_rate: 2.5000e-04
# Epoch 50/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1088 - mape: 112.2762 - val_loss: 0.0726 - val_mape: 54.5160 - learning_rate: 2.5000e-04
# Epoch 51/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0959 - mape: 172.5116 - val_loss: 0.0740 - val_mape: 56.0337 - learning_rate: 2.5000e-04
# Epoch 52/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1028 - mape: 112.2745 - val_loss: 0.0743 - val_mape: 56.1217 - learning_rate: 1.2500e-04
# Epoch 53/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1096 - mape: 148.1284 - val_loss: 0.0762 - val_mape: 57.1017 - learning_rate: 1.2500e-04
# Epoch 54/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1027 - mape: 140.4340 - val_loss: 0.0768 - val_mape: 57.1853 - learning_rate: 1.2500e-04
# Epoch 55/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1022 - mape: 165.9588 - val_loss: 0.0783 - val_mape: 57.4254 - learning_rate: 1.2500e-04
# Epoch 56/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0993 - mape: 109.9001 - val_loss: 0.0820 - val_mape: 57.8270 - learning_rate: 1.2500e-04

# %%
# 1) Predict & inverse‑scale
y_pred_s = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_s).ravel()
y_true = y_scaler.inverse_transform(y_test).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step

# %%
# 2) Metrics
mae  = mean_absolute_error(y_true, y_pred)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred) * 100
print("\nRQ2‐ANN Performance - Hydro (North Island):")
print(f"MAE : {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")
print(f"MAPE: {mape:.2f}%")

# # 3) Plot
# plt.figure(figsize=(12,5))
# plt.plot(dates_test, y_true, label="Actual")
# plt.plot(dates_test, y_pred, linestyle="--", color="red", label="Predicted")
# plt.title("Sliding‑Window MLP: Actual vs. Predicted")
# plt.xlabel("Date")
# plt.ylabel("Total_TP")
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# RQ2‐ANN Performance - Hydro (North Island):
# MAE : 11,377,323.84
# RMSE: 13,999,399.38
# MAPE: 9.73%

# %%
# North Island Data 
##########################################################################################################
#factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']
# MAE : 17,740,182.62
# RMSE: 21,460,900.94
# MAPE: 16.20%

# 2. factors = ['TP_lag1w','APIxGWETPROF'
# MAE : 11,165,021.75
# RMSE: 14,196,859.85
# MAPE: 9.82%

# MAE : 10,881,930.16
# RMSE: 13,483,613.27
# MAPE: 9.48%

# RQ2‐ANN Performance - Hydro (North Island):******use
# MAE : 10,778,353.03
# RMSE: 13,611,978.03
# MAPE: 9.49%

# 3. factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA',
# MAE : 12,531,191.22
# RMSE: 16,172,144.16
# MAPE: 11.27%

# 4. factors = ['TP_lag1w','PRECIP_EWMA','GWETPROF',
# MAE : 12,720,671.24
# RMSE: 16,004,662.82
# MAPE: 11.64%

# 5. factors = ['TP_lag1w','GWETPROF','PRECIP_EWMA','RH2M_lag1w']
# MAE : 14,927,997.50
# RMSE: 18,154,043.80
# MAPE: 13.99%

# 6. APIxGWETPROF
# MAE : 19,755,775.67
# RMSE: 23,583,489.21
# MAPE: 17.91%

# %%
# APR run - 2025
# MAE : 10,982,659.64
# RMSE: 13,721,128.84
# MAPE: 9.61%

# %%
# MAE : 1,879,974.26
# RMSE: 2,356,271.49
# MAPE: 11.35%

# %%
# 11) Plot Train, Test Actuals, and RQ2‐ANN Forecast
plt.figure(figsize=(15, 7))
# 11a) Training‐period actuals (2015 to split)
plt.plot(train_df.index, y_train_raw.flatten(),label="Train Actual (2015 -> split)",  color="lightgray")
# 11b) Test‐period actuals
plt.plot(test_df.index,y_test_raw.flatten(),label="Test Actual",color="black")
# 11c) RQ2‐ANN forecast over test period
plt.plot(test_df.index,y_pred,label="Forecast",color="darkorange")
plt.title("RQ2‐ANN: North Island Weekly Hydro Generation (Train & Test Actual vs Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## End Noth Island

# %% [markdown]
# ## Start South Island

# %%
# Add 1 to 2-week lagged climate features
df_hydro_weekly_south['TP_lag1w'] = df_hydro_weekly_south['Total_TP'].shift(1)
df_hydro_weekly_south['T2M_lag1w'] = df_hydro_weekly_south['T2M'].shift(1)
df_hydro_weekly_south['GWETPROF_lag1w'] = df_hydro_weekly_south['GWETPROF'].shift(1)
df_hydro_weekly_south['RH2M_lag1w'] = df_hydro_weekly_south['RH2M'].shift(1)
df_hydro_weekly_south['PRECIP_lag1w'] = df_hydro_weekly_south['PRECTOTCORR'].shift(1)
df_hydro_weekly_south['EVLAND_lag1w'] = df_hydro_weekly_south['EVLAND'].shift(1)
df_hydro_weekly_south['PRECIP_lag2w'] = df_hydro_weekly_south['PRECTOTCORR'].shift(2)
df_hydro_weekly_south['PRECIP_EWMA'] = df_hydro_weekly_south['PRECTOTCORR'].ewm(alpha=0.3, adjust=False).mean()
# EWMA for EVLAND with a “slow” decay (alpha = 0.1)
df_hydro_weekly_south['EVLAND_EWMA'] = df_hydro_weekly_south['EVLAND'].ewm(alpha=0.3, adjust=False).mean()
df_hydro_weekly_south['APIxGWETPROF'] = df_hydro_weekly_south['PRECIP_EWMA'] * df_hydro_weekly_south['GWETPROF']

# %%
# Drop original non-lagged features and drop NA from lagging
weekly_lagged_south = df_hydro_weekly_south[['Total_TP','TP_lag1w','PRECTOTCORR','PRECIP_lag1w','APIxGWETPROF','PRECIP_lag2w','PRECIP_EWMA','EVLAND','EVLAND_lag1w','EVLAND_EWMA','RH2M','RH2M_lag1w','GWETPROF','GWETPROF_lag1w','T2M','T2M_lag1w']].dropna()
weekly_lagged_south.head()
# Out:
#                 Total_TP      TP_lag1w  PRECTOTCORR  PRECIP_lag1w  \
# DATE
# 2015-03-22  2.950068e+08  3.243453e+08       264.80        156.42
# 2015-03-29  2.870318e+08  2.950068e+08       367.40        264.80
# 2015-04-05  2.590456e+08  2.870318e+08       189.24        367.40
# 2015-04-12  2.441813e+08  2.590456e+08       470.76        189.24
# 2015-04-19  2.735290e+08  2.441813e+08       333.51        470.76
#
#             APIxGWETPROF  PRECIP_lag2w  PRECIP_EWMA  EVLAND  EVLAND_lag1w  \
# DATE
# 2015-03-22    231.898854        767.35   488.289700  165.01        228.78
# 2015-03-29    217.903685        156.42   452.022790  154.86        165.01
# 2015-04-05    183.217514        264.80   373.187953  177.98        154.86
# 2015-04-12    202.251903        367.40   402.459567  166.54        177.98
# 2015-04-19    198.916737        189.24   381.774697  129.33        166.54
#
#             EVLAND_EWMA       RH2M  RH2M_lag1w  GWETPROF  GWETPROF_lag1w  \
# DATE
# 2015-03-22   224.290200  80.292381   77.127698  0.474921        0.480000
# 2015-03-29   203.461140  83.572698   80.292381  0.482063        0.474921
# 2015-04-05   195.816798  79.877222   83.572698  0.490952        0.482063
# 2015-04-12   187.033759  83.569683   79.877222  0.502540        0.490952
# 2015-04-19   169.722631  85.104524   83.569683  0.521032        0.502540
#
#                   T2M  T2M_lag1w
# DATE
# 2015-03-22   8.037778  12.604048
# 2015-03-29  11.639524   8.037778
# 2015-04-05  11.092937  11.639524
# 2015-04-12   9.989206  11.092937
# 2015-04-19   4.725635   9.989206

# %%
#factors = ['TP_lag1w','APIxGWETPROF','PRECIP_EWMA','GWETPROF','RH2M_lag1w','EVLAND_lag1w','T2M_lag1w']

# %%
# 2) Data prep (no randomness here, aside from ’shift’ which is deterministic)
df_ann_hydro_south_wk = weekly_lagged_south[['Total_TP','TP_lag1w']]

# %%
s_hydro_ann     = len(df_ann_hydro_south_wk)
split_ann = int(s_hydro_ann * 0.8)

train_s_ann = df_ann_hydro_north_wk.iloc[:split_ann]
test_s_ann  = df_ann_hydro_north_wk.iloc[split_ann:]

X_train = train_s_ann[['TP_lag1w']].values
y_train = train_s_ann['Total_TP'].values.reshape(-1,1)
X_test  = test_s_ann[['TP_lag1w']].values
y_test  = test_s_ann['Total_TP'].values.reshape(-1,1)

# %%
# 3) Scaling
scaler_X = MinMaxScaler()
X_train_s = scaler_X.fit_transform(X_train)
X_test_s  = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_s = scaler_y.fit_transform(y_train)
# (We hold off on transforming y_test because we want raw y_test for metrics.)

# %%
# 4) Build the ANN
model_ann_s = Sequential([
    Dense(16, activation='relu', input_shape=(1,)),
    Dense(8,  activation='relu'),
    Dense(1)
])
model_ann_s.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 5) Train the ANN (the shuffle order is now deterministic)
history_s = model_ann_s.fit(
    X_train_s, y_train_s,
    epochs=100,
    batch_size=16,
    validation_split=0.05,
    verbose=0
)

# %%
# 6) Predict & rescale
y_pred_s = model_ann_s.predict(X_test_s)
y_pred   = scaler_y.inverse_transform(y_pred_s).flatten()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
# 7) Metrics on raw scale
mae_ann  = mean_absolute_error(y_test.flatten(), y_pred)
rmse_ann = np.sqrt(mean_squared_error(y_test.flatten(), y_pred))
mape_ann = np.mean(np.abs((y_test.flatten() - y_pred) / y_test.flatten())) * 100

print(f"Univariate ANN - MAE: {mae_ann:.2f}, RMSE: {rmse_ann:.2f}, MAPE: {mape_ann:.2f}%")
# Out:
# Univariate ANN - MAE: 11225546.31, RMSE: 14091050.21, MAPE: 9.67%

# %%
plt.figure(figsize=(15,7))
plt.plot(train_s_ann.index,y_train.flatten(),label="Train Actual (2015 -> split)",color="lightgray")
plt.plot(test_s_ann.index, y_test, label="Actual Total_TP",   color="black")
plt.plot(test_s_ann.index, y_pred, label="ANN Forecast",      color="darkorange")
plt.title("RQ1‐ANN: South Island Weekly Hydro (Actual vs. Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RQ2 Start

# %%
factors = ['TP_lag1w','APIxGWETPROF']

# %%
# 2) Split via slicing
n = len(weekly_lagged_south)
split_idx = int(n * 0.8)

train_df = weekly_lagged_south.iloc[:split_idx]
test_df  = weekly_lagged_south.iloc[split_idx:]

# 3) Extract raw X and y for train/test
X_train_raw = train_df[factors].values  # (n_samples, n_features)
X_test_raw  = test_df[factors].values
y_train_raw = train_df['Total_TP'].values.reshape(-1, 1)
y_test_raw  = test_df['Total_TP'].values.reshape(-1, 1) # (n_samples, 1)

# %%
# 4) Scale
x_scaler = StandardScaler().fit(X_train_raw)
y_scaler = StandardScaler().fit(y_train_raw)

X_train = x_scaler.transform(X_train_raw)
X_test  = x_scaler.transform(X_test_raw)
y_train = y_scaler.transform(y_train_raw)
y_test  = y_scaler.transform(y_test_raw)

# %%
# 5) Sanity‐check shapes
print(X_train.shape, y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (412, 2) (412, 1)
# (103, 2) (103, 1)

# %%
# optimizer with clipping & lower LR
opt = tf.keras.optimizers.Adam(learning_rate=5e-4, clipnorm=1.0)

# %%
#   ANN Model  
model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],)),  # start with 64 neurons
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(32),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.2),

    Dense(16),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),

    Dense(1)  # linear output for regression
])

#model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="mse")
# Out:
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\nwn86\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.compile(
    optimizer=opt,
    loss=Huber(delta=0.5),
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

# %%
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_test, y_test),
#     epochs=200, batch_size=32,
#     callbacks=callbacks, verbose=1
# )

history = model.fit(
    X_train, y_train,
    validation_split=0.10,  # 10% of training for validation
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - loss: 0.3838 - mape: 368.2122 - val_loss: 0.2659 - val_mape: 96.7575 - learning_rate: 5.0000e-04
# Epoch 2/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2905 - mape: 248.7693 - val_loss: 0.2450 - val_mape: 92.3974 - learning_rate: 5.0000e-04
# Epoch 3/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2527 - mape: 308.2911 - val_loss: 0.2318 - val_mape: 89.3681 - learning_rate: 5.0000e-04
# Epoch 4/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2360 - mape: 308.5325 - val_loss: 0.2257 - val_mape: 90.1666 - learning_rate: 5.0000e-04
# Epoch 5/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2142 - mape: 284.0569 - val_loss: 0.2196 - val_mape: 91.5610 - learning_rate: 5.0000e-04
# Epoch 6/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2114 - mape: 261.4033 - val_loss: 0.2161 - val_mape: 92.1150 - learning_rate: 5.0000e-04
# Epoch 7/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1939 - mape: 275.4510 - val_loss: 0.2112 - val_mape: 94.0358 - learning_rate: 5.0000e-04
# Epoch 8/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1707 - mape: 253.3432 - val_loss: 0.2066 - val_mape: 95.0453 - learning_rate: 5.0000e-04
# Epoch 9/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1612 - mape: 193.7144 - val_loss: 0.2050 - val_mape: 93.9666 - learning_rate: 5.0000e-04
# Epoch 10/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1688 - mape: 231.2364 - val_loss: 0.2006 - val_mape: 93.9277 - learning_rate: 5.0000e-04
# Epoch 11/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1438 - mape: 271.6755 - val_loss: 0.1944 - val_mape: 97.0697 - learning_rate: 5.0000e-04
# Epoch 12/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1675 - mape: 230.6523 - val_loss: 0.1904 - val_mape: 98.9767 - learning_rate: 5.0000e-04
# Epoch 13/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1613 - mape: 234.0523 - val_loss: 0.1860 - val_mape: 101.2042 - learning_rate: 5.0000e-04
# Epoch 14/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1444 - mape: 267.5976 - val_loss: 0.1829 - val_mape: 103.7389 - learning_rate: 5.0000e-04
# Epoch 15/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1497 - mape: 258.6663 - val_loss: 0.1806 - val_mape: 107.1035 - learning_rate: 5.0000e-04
# Epoch 16/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1358 - mape: 226.0652 - val_loss: 0.1778 - val_mape: 110.2940 - learning_rate: 5.0000e-04
# Epoch 17/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1548 - mape: 223.2917 - val_loss: 0.1740 - val_mape: 112.4657 - learning_rate: 5.0000e-04
# Epoch 18/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1434 - mape: 233.7057 - val_loss: 0.1725 - val_mape: 114.2381 - learning_rate: 5.0000e-04
# Epoch 19/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1389 - mape: 278.5335 - val_loss: 0.1734 - val_mape: 115.4081 - learning_rate: 5.0000e-04
# Epoch 20/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1425 - mape: 216.2054 - val_loss: 0.1737 - val_mape: 117.6893 - learning_rate: 5.0000e-04
# Epoch 21/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1397 - mape: 210.0814 - val_loss: 0.1728 - val_mape: 119.7376 - learning_rate: 5.0000e-04
# Epoch 22/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1360 - mape: 256.0201 - val_loss: 0.1738 - val_mape: 121.9262 - learning_rate: 5.0000e-04
# Epoch 23/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1425 - mape: 226.5794 - val_loss: 0.1735 - val_mape: 123.5160 - learning_rate: 5.0000e-04
# Epoch 24/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1378 - mape: 269.3243 - val_loss: 0.1734 - val_mape: 125.8733 - learning_rate: 2.5000e-04
# Epoch 25/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1476 - mape: 241.6409 - val_loss: 0.1730 - val_mape: 127.6771 - learning_rate: 2.5000e-04
# Epoch 26/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1220 - mape: 215.0703 - val_loss: 0.1730 - val_mape: 130.0170 - learning_rate: 2.5000e-04
# Epoch 27/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1316 - mape: 242.0392 - val_loss: 0.1732 - val_mape: 131.9423 - learning_rate: 2.5000e-04
# Epoch 28/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1362 - mape: 185.6261 - val_loss: 0.1720 - val_mape: 133.6482 - learning_rate: 2.5000e-04
# Epoch 29/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1381 - mape: 179.4407 - val_loss: 0.1734 - val_mape: 136.0894 - learning_rate: 2.5000e-04
# Epoch 30/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1293 - mape: 231.8984 - val_loss: 0.1755 - val_mape: 138.2488 - learning_rate: 2.5000e-04
# Epoch 31/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1384 - mape: 266.3462 - val_loss: 0.1771 - val_mape: 140.6387 - learning_rate: 2.5000e-04
# Epoch 32/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1331 - mape: 283.7676 - val_loss: 0.1773 - val_mape: 142.3308 - learning_rate: 2.5000e-04
# Epoch 33/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1330 - mape: 230.4163 - val_loss: 0.1775 - val_mape: 143.9416 - learning_rate: 2.5000e-04
# Epoch 34/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1290 - mape: 243.9599 - val_loss: 0.1786 - val_mape: 144.7172 - learning_rate: 1.2500e-04
# Epoch 35/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1382 - mape: 225.9933 - val_loss: 0.1791 - val_mape: 145.6280 - learning_rate: 1.2500e-04
# Epoch 36/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1318 - mape: 184.1652 - val_loss: 0.1810 - val_mape: 147.5321 - learning_rate: 1.2500e-04
# Epoch 37/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1292 - mape: 194.2694 - val_loss: 0.1820 - val_mape: 148.8407 - learning_rate: 1.2500e-04
# Epoch 38/200
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1259 - mape: 167.2815 - val_loss: 0.1822 - val_mape: 150.2403 - learning_rate: 1.2500e-04

# %%
# 1) Predict & inverse‑scale
y_pred_s = model.predict(X_test)
y_pred = y_scaler.inverse_transform(y_pred_s).ravel()
y_true = y_scaler.inverse_transform(y_test).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step

# %%
# 2) Metrics
mae  = mean_absolute_error(y_true, y_pred)
#rmse = mean_squared_error(y_true, y_pred, squared=False)
rmse = root_mean_squared_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred) * 100
print("\nRQ2‐ANN Performance - Hydro (South Island):")
print(f"MAE : {mae:,.2f}")
print(f"RMSE: {rmse:,.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# RQ2‐ANN Performance - Hydro (South Island):
# MAE : 18,244,258.69
# RMSE: 23,749,179.90
# MAPE: 5.71%

# %%
# 11) Plot Train, Test Actuals, and RQ2‐ANN Forecast
plt.figure(figsize=(15, 7))
# 11a) Training‐period actuals (2015 to split)
plt.plot(train_df.index, y_train_raw.flatten(),label="Train Actual (2015 -> split)",  color="lightgray")
# 11b) Test‐period actuals
plt.plot(test_df.index,y_test_raw.flatten(),label="Test Actual",color="black")
# 11c) RQ2‐ANN forecast over test period
plt.plot(test_df.index,y_pred,label="Forecast",linestyle="--",color="darkorange")
plt.title("RQ2‐ANN: South Island Weekly Hydro Generation (Train & Test Actual vs Forecast)")
plt.xlabel("Date")
plt.ylabel("Weekly Total_TP (×10⁸ kWh)")
plt.grid(True)
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()


















# # 1) Rebuild the “clean” DataFrame exactly as you did before splitting:
# df_clean = df_island_south_wk.copy()
# # … your feature engineering here …
# df_clean.dropna(inplace=True)

# # 2) Compute train_size the same way you did for X_train/X_test:
# n = len(df_clean)
# train_size = int(0.8 * n)

# # 3) Grab the dates for the test slice:
# test_dates = df_clean.index[train_size:]

# # 4) Now plot, flattening your 1‑D arrays:
# plt.figure(figsize=(14, 6))
# plt.plot(test_dates, y_true.ravel(), label="Actual Hydro Energy")
# plt.plot(test_dates, y_pred.ravel(),       label="Predicted Hydro Energy", linestyle="--", color="red")

# plt.title("Actual vs Predicted Hydro Energy Generation")
# plt.xlabel("Date")
# plt.ylabel("Total_TP (Hydro Energy)")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## End South Island
