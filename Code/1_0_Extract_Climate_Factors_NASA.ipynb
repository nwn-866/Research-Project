# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import requests
import os
import time

# %%
file_path = r"C:\Users\nwn86\ResearchProject\Input"

# %%
file_name = "nsp_info_final_v1.csv"

# %%
output_file = os.path.join(file_path, file_name)

# %%
nsp_info = pd.read_csv(output_file)

# %%
nsp_info.columns.tolist()
# Out:
# ['POC_Code',
#  'NZTM_easting',
#  'NZTM_northing',
#  'Fuel_Code',
#  'Latitude',
#  'Longitude']

# %%
NSP_Coordinates  = nsp_info[['POC_Code','Latitude', 'Longitude']].copy()

# %%
NSP_Coordinates
# Out:
#    POC_Code   Latitude   Longitude
# 0   ARA2201 -38.615891  176.143036
# 1   ARG1101 -41.670851  173.202251
# 2   ARI1101 -38.072026  175.642919
# 3   ARI1102 -38.072026  175.642919
# 4   ASB0661 -43.941637  171.802149
# 5   ATI2201 -38.392831  176.022730
# 6   AVI2201 -44.658443  170.354335
# 7   BEN2202 -44.565596  170.193571
# 8   BPE0331 -40.280614  175.640510
# 9   BWK1101 -45.940470  170.102172
# 10  COL0661 -43.363766  171.527122
# 11  CYD0331 -45.180391  169.306224
# 12  CYD2201 -45.180391  169.306224
# 13  EDG0331 -37.987259  176.828883
# 14  GOR0331 -46.115091  168.911652
# 15  HWA1101 -39.566497  174.310117
# 16  HWB0331 -45.854874  170.475700
# 17  KOE1101 -35.396162  173.810632
# 18  KPO1101 -37.924349  175.537461
# 19  LTN0331 -40.410452  175.631394
# 20  LTN2201 -40.410452  175.631394
# 21  MAN2201 -45.520868  167.277500
# 22  MAT1101 -38.113429  176.814617
# 23  MHO0331 -40.576575  175.448930
# 24  MTI2201 -38.352736  175.744267
# 25  NMA0331 -46.305391  168.359527
# 26  NSY0331 -45.033180  170.093353
# 27  OHA2201 -44.265872  170.029212
# 28  OHB2201 -44.301801  170.110551
# 29  OHC2201 -44.343561  170.179492
# 30  OHK2201 -38.407966  176.085969
# 31  ROT1101 -38.148250  176.227041
# 32  ROX1101 -45.477213  169.319136
# 33  ROX2201 -45.477213  169.319136
# 34  RPO2201 -39.153194  175.837443
# 35  STK0661 -41.314941  173.243059
# 36  TGA0331 -37.727716  176.130869
# 37  TKA0111 -44.013807  170.460853
# 38  TKB2201 -44.125161  170.211748
# 39  TKU2201 -38.981721  175.770224
# 40  TUI1101 -38.805354  177.151399
# 41  TWC2201 -40.354267  175.773710
# 42  TWH0331 -37.738327  175.154139
# 43  WDV1101 -40.315457  175.856067
# 44  WIL0331 -41.258396  174.759556
# 45  WKM2201 -38.419082  175.800363
# 46  WPA2201 -38.291661  175.683408
# 47  WPG0331 -45.855209  170.475388
# 48  WTK0111 -44.692099  170.429029
# 49  WVY1101 -39.754097  174.635503
# 50  WWD1102 -41.295618  174.660496
# 51  WWD1103 -41.295618  174.660496
# 52  HRP2201 -39.604330  176.753550

# %%
# Wind Power
# ---------------------------------------------------------------------
# 'WS50M', # Wind Speed at 50 Meters                    ---------- Use
# 'WD50M', # Wind Direction at 50 Meters				  ---------- Use
# 'T2M', # Temperature at 2 Meters					  ---------- Use
# 'PS', # Surface Pressure                              ---------- Use

# Hydro Power
# ---------------------------------------------------------------------
# 'PRECTOTCORR', # Precipitation Corrected				---------- Use
# 'EVLAND', # Evaporation Land							---------- Use
# 'T2M', # Temperature at 2 Meters						---------- Use
# 'GWETPROF', # Profile Soil Moisture TARGET				---------- Use

# %%
# --WS50M done

# %%
# Define constants
parameters = "GWETPROF"
start_date = "20150101"
end_date = "20250228"
community = "AG"
format_type = "CSV"

# %%
# Define local save folder (optional)
output_folder = "NASA_Climate_Downloads"
os.makedirs(output_folder, exist_ok=True)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nwn86\\ResearchProject\\Code'

# %%
# Loop through each unique POC_Code + coordinate pair
for index, row in NSP_Coordinates.iterrows():
    lat = row["Latitude"]
    lon = row["Longitude"]
    poc = row["POC_Code"]

    filename = f"{output_folder}/NASA_{poc}_{parameters}_{start_date}_{end_date}.csv"
    
    # Skip if file already exists
    if os.path.exists(filename):
        print(f"File already exists for {poc}, skipping...")
        continue

    # Build URL
    url = (
        f"https://power.larc.nasa.gov/api/temporal/daily/point?"
        f"parameters={parameters}&community={community}&longitude={lon}&latitude={lat}"
        f"&start={start_date}&end={end_date}&format={format_type}"
    )

    # Make the request
    print(f"Requesting data for {poc} (Lat: {lat}, Lon: {lon})")
    response = requests.get(url)

    if response.status_code == 200:
        with open(filename, "w") as f:
            f.write(response.text)
        print(f"Saved: {filename}")
    else:
        print(f"Failed for {poc}: {response.status_code}")

    # Optional: Delay between requests to avoid hitting rate limits
    time.sleep(1)
# Out:
# Requesting data for ARA2201 (Lat: -38.615890622309216, Lon: 176.14303617726966)
# Saved: NASA_Climate_Downloads/NASA_ARA2201_GWETPROF_20150101_20250228.csv
# Requesting data for ARG1101 (Lat: -41.67085104083395, Lon: 173.20225109954703)
# Saved: NASA_Climate_Downloads/NASA_ARG1101_GWETPROF_20150101_20250228.csv
# Requesting data for ARI1101 (Lat: -38.07202558323021, Lon: 175.6429192777623)
# Saved: NASA_Climate_Downloads/NASA_ARI1101_GWETPROF_20150101_20250228.csv
# Requesting data for ARI1102 (Lat: -38.07202558323021, Lon: 175.6429192777623)
# Saved: NASA_Climate_Downloads/NASA_ARI1102_GWETPROF_20150101_20250228.csv
# Requesting data for ASB0661 (Lat: -43.94163711869947, Lon: 171.80214899733002)
# Saved: NASA_Climate_Downloads/NASA_ASB0661_GWETPROF_20150101_20250228.csv
# Requesting data for ATI2201 (Lat: -38.3928313316102, Lon: 176.02273036017607)
# Saved: NASA_Climate_Downloads/NASA_ATI2201_GWETPROF_20150101_20250228.csv
# Requesting data for AVI2201 (Lat: -44.658443022399226, Lon: 170.35433493633775)
# Saved: NASA_Climate_Downloads/NASA_AVI2201_GWETPROF_20150101_20250228.csv
# Requesting data for BEN2202 (Lat: -44.56559629595882, Lon: 170.1935706066449)
# Saved: NASA_Climate_Downloads/NASA_BEN2202_GWETPROF_20150101_20250228.csv
# Requesting data for BPE0331 (Lat: -40.280614262851415, Lon: 175.6405101202204)
# Saved: NASA_Climate_Downloads/NASA_BPE0331_GWETPROF_20150101_20250228.csv
# Requesting data for BWK1101 (Lat: -45.940469563132105, Lon: 170.102172162034)
# Saved: NASA_Climate_Downloads/NASA_BWK1101_GWETPROF_20150101_20250228.csv
# Requesting data for COL0661 (Lat: -43.363765600228255, Lon: 171.52712192899153)
# Saved: NASA_Climate_Downloads/NASA_COL0661_GWETPROF_20150101_20250228.csv
# Requesting data for CYD0331 (Lat: -45.1803905106997, Lon: 169.30622444263136)
# Saved: NASA_Climate_Downloads/NASA_CYD0331_GWETPROF_20150101_20250228.csv
# Requesting data for CYD2201 (Lat: -45.1803905106997, Lon: 169.30622444263136)
# Saved: NASA_Climate_Downloads/NASA_CYD2201_GWETPROF_20150101_20250228.csv
# Requesting data for EDG0331 (Lat: -37.98725855244769, Lon: 176.8288826778607)
# Saved: NASA_Climate_Downloads/NASA_EDG0331_GWETPROF_20150101_20250228.csv
# Requesting data for GOR0331 (Lat: -46.11509135612844, Lon: 168.91165218210566)
# Saved: NASA_Climate_Downloads/NASA_GOR0331_GWETPROF_20150101_20250228.csv
# Requesting data for HWA1101 (Lat: -39.56649650464245, Lon: 174.31011668341935)
# Saved: NASA_Climate_Downloads/NASA_HWA1101_GWETPROF_20150101_20250228.csv
# Requesting data for HWB0331 (Lat: -45.85487428862088, Lon: 170.4756995786027)
# Saved: NASA_Climate_Downloads/NASA_HWB0331_GWETPROF_20150101_20250228.csv
# Requesting data for KOE1101 (Lat: -35.39616192457392, Lon: 173.81063157178892)
# Failed for KOE1101: 502
# Requesting data for KPO1101 (Lat: -37.92434939402106, Lon: 175.53746149356627)
# Saved: NASA_Climate_Downloads/NASA_KPO1101_GWETPROF_20150101_20250228.csv
# Requesting data for LTN0331 (Lat: -40.41045203836097, Lon: 175.63139355408708)
# Saved: NASA_Climate_Downloads/NASA_LTN0331_GWETPROF_20150101_20250228.csv
# Requesting data for LTN2201 (Lat: -40.41045203836097, Lon: 175.63139355408708)
# Saved: NASA_Climate_Downloads/NASA_LTN2201_GWETPROF_20150101_20250228.csv
# Requesting data for MAN2201 (Lat: -45.52086826280509, Lon: 167.27749983729146)
# Saved: NASA_Climate_Downloads/NASA_MAN2201_GWETPROF_20150101_20250228.csv
# Requesting data for MAT1101 (Lat: -38.11342928926832, Lon: 176.8146170668076)
# Saved: NASA_Climate_Downloads/NASA_MAT1101_GWETPROF_20150101_20250228.csv
# Requesting data for MHO0331 (Lat: -40.576575256590594, Lon: 175.4489301731142)
# Saved: NASA_Climate_Downloads/NASA_MHO0331_GWETPROF_20150101_20250228.csv
# Requesting data for MTI2201 (Lat: -38.35273636334996, Lon: 175.7442674612387)
# Saved: NASA_Climate_Downloads/NASA_MTI2201_GWETPROF_20150101_20250228.csv
# Requesting data for NMA0331 (Lat: -46.3053908844324, Lon: 168.35952698071387)
# Saved: NASA_Climate_Downloads/NASA_NMA0331_GWETPROF_20150101_20250228.csv
# Requesting data for NSY0331 (Lat: -45.03318014098585, Lon: 170.09335298588852)
# Saved: NASA_Climate_Downloads/NASA_NSY0331_GWETPROF_20150101_20250228.csv
# Requesting data for OHA2201 (Lat: -44.26587174035304, Lon: 170.0292116435563)
# Saved: NASA_Climate_Downloads/NASA_OHA2201_GWETPROF_20150101_20250228.csv
# Requesting data for OHB2201 (Lat: -44.3018013104678, Lon: 170.1105511030352)
# Saved: NASA_Climate_Downloads/NASA_OHB2201_GWETPROF_20150101_20250228.csv
# Requesting data for OHC2201 (Lat: -44.34356090558411, Lon: 170.17949166475873)
# Saved: NASA_Climate_Downloads/NASA_OHC2201_GWETPROF_20150101_20250228.csv
# Requesting data for OHK2201 (Lat: -38.40796630351797, Lon: 176.08596914380684)
# Saved: NASA_Climate_Downloads/NASA_OHK2201_GWETPROF_20150101_20250228.csv
# Requesting data for ROT1101 (Lat: -38.1482501499588, Lon: 176.22704092769607)
# Saved: NASA_Climate_Downloads/NASA_ROT1101_GWETPROF_20150101_20250228.csv
# Requesting data for ROX1101 (Lat: -45.47721291172585, Lon: 169.31913607442934)
# Saved: NASA_Climate_Downloads/NASA_ROX1101_GWETPROF_20150101_20250228.csv
# Requesting data for ROX2201 (Lat: -45.47721291172585, Lon: 169.31913607442934)
# Saved: NASA_Climate_Downloads/NASA_ROX2201_GWETPROF_20150101_20250228.csv
# Requesting data for RPO2201 (Lat: -39.1531940904646, Lon: 175.83744312216007)
# Saved: NASA_Climate_Downloads/NASA_RPO2201_GWETPROF_20150101_20250228.csv
# Requesting data for STK0661 (Lat: -41.31494147101567, Lon: 173.24305864003037)
# Saved: NASA_Climate_Downloads/NASA_STK0661_GWETPROF_20150101_20250228.csv
# Requesting data for TGA0331 (Lat: -37.72771588652059, Lon: 176.13086945006472)
# Saved: NASA_Climate_Downloads/NASA_TGA0331_GWETPROF_20150101_20250228.csv
# Requesting data for TKA0111 (Lat: -44.01380710962175, Lon: 170.46085338494768)
# Saved: NASA_Climate_Downloads/NASA_TKA0111_GWETPROF_20150101_20250228.csv
# Requesting data for TKB2201 (Lat: -44.12516128022085, Lon: 170.211747584784)
# Saved: NASA_Climate_Downloads/NASA_TKB2201_GWETPROF_20150101_20250228.csv
# Requesting data for TKU2201 (Lat: -38.98172132326077, Lon: 175.77022447300635)
# Saved: NASA_Climate_Downloads/NASA_TKU2201_GWETPROF_20150101_20250228.csv
# Requesting data for TUI1101 (Lat: -38.805354216670914, Lon: 177.1513989212492)
# Saved: NASA_Climate_Downloads/NASA_TUI1101_GWETPROF_20150101_20250228.csv
# Requesting data for TWC2201 (Lat: -40.354267210562405, Lon: 175.77371000444347)
# Saved: NASA_Climate_Downloads/NASA_TWC2201_GWETPROF_20150101_20250228.csv
# Requesting data for TWH0331 (Lat: -37.73832727387181, Lon: 175.1541387898066)
# Saved: NASA_Climate_Downloads/NASA_TWH0331_GWETPROF_20150101_20250228.csv
# Requesting data for WDV1101 (Lat: -40.31545683722073, Lon: 175.85606683277967)
# Saved: NASA_Climate_Downloads/NASA_WDV1101_GWETPROF_20150101_20250228.csv
# Requesting data for WIL0331 (Lat: -41.25839614790544, Lon: 174.7595561745668)
# Saved: NASA_Climate_Downloads/NASA_WIL0331_GWETPROF_20150101_20250228.csv
# Requesting data for WKM2201 (Lat: -38.41908188047464, Lon: 175.80036274527754)
# Saved: NASA_Climate_Downloads/NASA_WKM2201_GWETPROF_20150101_20250228.csv
# Requesting data for WPA2201 (Lat: -38.29166089985859, Lon: 175.68340782978112)
# Saved: NASA_Climate_Downloads/NASA_WPA2201_GWETPROF_20150101_20250228.csv
# Requesting data for WPG0331 (Lat: -45.855209435021216, Lon: 170.4753881351091)
# Saved: NASA_Climate_Downloads/NASA_WPG0331_GWETPROF_20150101_20250228.csv
# Requesting data for WTK0111 (Lat: -44.69209931296851, Lon: 170.42902880701246)
# Saved: NASA_Climate_Downloads/NASA_WTK0111_GWETPROF_20150101_20250228.csv
# Requesting data for WVY1101 (Lat: -39.75409738031374, Lon: 174.63550258187146)
# Saved: NASA_Climate_Downloads/NASA_WVY1101_GWETPROF_20150101_20250228.csv
# Requesting data for WWD1102 (Lat: -41.29561783478981, Lon: 174.66049610393674)
# Failed for WWD1102: 502
# Requesting data for WWD1103 (Lat: -41.29561783478981, Lon: 174.66049610393674)
# Saved: NASA_Climate_Downloads/NASA_WWD1103_GWETPROF_20150101_20250228.csv
# Requesting data for HRP2201 (Lat: -39.60433, Lon: 176.75355)
# Saved: NASA_Climate_Downloads/NASA_HRP2201_GWETPROF_20150101_20250228.csv

# %%
### for manual checks for failed records

# %%
#Wind Energy Generation - 1

import requests
import pandas as pd
import os

# Define parameters
#-41.29561783	174.66049610393674


latitude = -41.29561783
longitude = 174.66049610393674
parameters = "GWETPROF"  # WS50M (Wind Speed at 50 Meters):-35.39616192 The average of wind speed at 50 meters above the surface of the earth
start_date = "20150101"
end_date = "20250228"
community = "AG"
format_type = "CSV"
poc = "WWD1102"

#filepath = "D:\Research_Project\DataSet\Climate"

# Construct API URL
url = f"https://power.larc.nasa.gov/api/temporal/daily/point?parameters={parameters}&community={community}&longitude={longitude}&latitude={latitude}&start={start_date}&end={end_date}&format={format_type}"

#try: 
# Request data
response = requests.get(url)

# Save to file
#filename = os.path.join(filepath, f"NASA_Climate_{parameters}_{start_date}_{end_date}.csv")
filename = f"{output_folder}/NASA_{poc}_{parameters}_{start_date}_{end_date}.csv"
if response.status_code == 200:
    with open(filename, "w") as file:
        file.write(response.text)  # Correct indentation

    print(f"Data successfully saved to {filename}")
else:
    print("Failed to fetch data:", response.status_code)
# Out:
# Data successfully saved to NASA_Climate_Downloads/NASA_WWD1102_GWETPROF_20150101_20250228.csv
